# %%
import os
import pandas as pd
import numpy as np
import string
from operator import itemgetter
from collections import Counter, OrderedDict

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %%
wine = pd.read_csv('../raw_data/winemag-data-130k-v2.csv')
wine_list = list(wine['description'])
#wine_list_normalized = [clean_description(w) for w in wine_list]
#wine_list_preprocessed = list(set(wine_list_normalized))

# %%
full_wine_reviews_list = [str(r) for r in wine_list]
full_wine_corpus = ' '.join(wine_list)
wine_sentences_tokenized = sent_tokenize(full_wine_corpus)

# %%
stop_words = set(stopwords.words('english')) 

punctuation_table = str.maketrans({key: None for key in string.punctuation})
sno = SnowballStemmer('english')

def normalize_text(raw_text):
    try:
        word_list = word_tokenize(raw_text)
        normalized_sentence = []
        for w in word_list:
            try:
                w = str(w)
                lower_case_word = str.lower(w)
                stemmed_word = sno.stem(lower_case_word)
                no_punctuation = stemmed_word.translate(punctuation_table)
                if len(no_punctuation) > 1 and no_punctuation not in stop_words:
                    normalized_sentence.append(no_punctuation)
            except:
                continue
        return normalized_sentence
    except:
        return ''

# normalized_sentences = []
# for s in sentences_tokenized:
#     normalized_text = normalize_text(s)
#     normalized_sentences.append(normalized_text)

normalized_wine_sentences = []
for s in wine_sentences_tokenized:
    normalized_text = normalize_text(s)
    normalized_wine_sentences.append(normalized_text)

# %%
import pickle

# %%
with open("../notebooks/g_wine_preprocessing.txt", "rb") as fp:   # Unpickling
    wine_sentences = pickle.load(fp)

# %%
wine_word2vec_model = Word2Vec.load("../raw_data/food_word2vec_model.bin")

# %%
descriptor_mapping = pd.read_csv('../raw_data/descriptor_mapping.csv',delimiter=';', encoding='latin1').set_index('raw descriptor')

# %%
descriptor_mapping
# Out:
#                     level_3       level_2 level_1    type
# raw descriptor
# abras              abrasive   high_tannin  tannin  bitter
# acacia               acacia       flowery  flower     fat
# acacia_flower        acacia       flowery  flower     fat
# aciddriven      acid_driven     high_acid    acid    acid
# aggress          aggressive     high_acid    acid    acid
# ...                     ...           ...     ...     ...
# zest                   zest  citrus_fruit   fruit   sweet
# zesti                 zesty     high_acid    acid    acid
# zing                  zingy     high_acid    acid    acid
# zingi                 zingy     high_acid    acid    acid
# zippi                 zippy     high_acid    acid    acid
#
# [1015 rows x 4 columns]

# %%
wine_trigram_model = Phraser.load('wine_trigrams.pkl')

# %%
variety_mapping = {'Shiraz': 'Syrah', 'Pinot Gris': 'Pinot Grigio', 'Pinot Grigio/Gris': 'Pinot Grigio', 
                   'Garnacha, Grenache': 'Grenache', 'Garnacha': 'Grenache', 'CarmenÃ¨re': 'Carmenere',
                    'GrÃ¼ner Veltliner': 'Gruner Veltliner', 'TorrontÃ©s': 'Torrontes', 
                   'RhÃ´ne-style Red Blend': 'Rhone-style Red Blend', 'AlbariÃ±o': 'Albarino',
                  'GewÃ¼rztraminer': 'Gewurztraminer', 'RhÃ´ne-style White Blend': 'Rhone-style White Blend',
                  'SpÃƒÂ¤tburgunder, Pinot Noir': 'Pinot Noir', 'Sauvignon, Sauvignon Blanc': 'Sauvignon Blanc',
                  'Pinot Nero, Pinot Noir': 'Pinot Noir', 'Malbec-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                  'Meritage, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Garnacha, Grenache': 'Grenache',
                   'FumÃ© Blanc': 'Sauvignon Blanc', 'Cabernet Sauvignon-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Cabernet Sauvignon-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Blend, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Malbec-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Merlot-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Franc-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Malbec, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Primitivo, Zinfandel': 'Zinfandel',
                   'AragonÃªs, Tempranillo': 'Aragonez, Tempranillo'
                  }

def consolidate_varieties(variety_name):
    if variety_name in variety_mapping:
        return variety_mapping[variety_name]
    else:
        return variety_name

wine_df_clean = wine.copy()
wine_df_clean['variety'] = wine_df_clean['variety'].apply(consolidate_varieties)

# %%
order_of_geographies = ['region_1', 'province', 'country']

# replace any nan values in the geography columns with the word none
def replace_nan_for_zero(value):
    if str(value) == '0' or str(value) == 'nan':
        return 'none'
    else:
        return value

for o in order_of_geographies:
    wine_df_clean[o] = wine_df_clean[o].apply(replace_nan_for_zero)

wine_df_clean.loc[:, order_of_geographies].fillna('none', inplace=True)

# %%
wine.shape
# Out:
# (129971, 14)

# %%
variety_geo = wine_df_clean.groupby(['variety', 'country', 'province', 'region_1']).size().reset_index().rename(columns={0:'count'})
variety_geo_sliced = variety_geo.loc[variety_geo['count'] > 1]

vgeos_df = pd.DataFrame(variety_geo_sliced, columns=['variety', 'country', 'province', 'region_1', 'count']) 
vgeos_df.to_csv('varieties_all_geos.csv')

# %%
wine_df_clean.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                 none                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2    Pinot Grigio            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
variety_geo_df = pd.read_csv('../raw_data/varieties_all_geos_normalized.csv', index_col=0)
wine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['variety', 'country', 'province', 'region_1', 'region_2'],
                         right_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'])
wine_df_merged.drop(['Unnamed: 0', 'Country', 'taster_name', 'taster_twitter_handle',
                     'Region', 'Subregion', 'count'], 
                    axis=1, inplace=True)
wine_df_merged.shape

# %%
variety_geo_df.head()
# Out:
#                   Variety Country        Province                 Region  \
# 0  Aglianico, Italian Red   Italy     Italy Other          Vino Spumante
# 2  Aglianico, Italian Red   Italy  Southern Italy  Aglianico del Taburno
# 3  Aglianico, Italian Red   Italy  Southern Italy  Aglianico del Vulture
# 4  Aglianico, Italian Red   Italy  Southern Italy             Basilicata
# 5  Aglianico, Italian Red   Italy  Southern Italy            Beneventano
#
#   Subregion  count                     geo_normalized
# 0      none      5                                NaN
# 2      none     13    Campania, Southern Italy, Italy
# 3      none     68  Basilicata, Southern Italy, Italy
# 4      none      2  Basilicata, Southern Italy, Italy
# 5      none      2    Campania, Southern Italy, Italy

# %%
variety_geo_df.geo_normalized.unique()
# Out:
# array([nan, 'Campania, Southern Italy, Italy',
#        'Basilicata, Southern Italy, Italy',
#        'Puglia, Southern Italy, Italy', 'Molise, Southern Italy, Italy',
#        'Paso Robles, Central Coast, California, USA',
#        'Clear Lake, North Coast, California',
#        'Sierra Foothills, California, USA',
#        'Emilia-Romagna, Northeast Italy, Italy',
#        'Sicily, Southern Italy, Italy', 'Tuscany, Central Italy, Italy',
#        'Alsace, France', 'Lisboa, Portugal', 'Alentejo, Portugal',
#        'Setubal, Portugal', 'Tejo, Portugal',
#        'Piedmont, Northwest Italy, Italy',
#        'Mendocino, North Coast, California, USA', 'Burgenland, Austria',
#        'Niederosterreich, Austria', 'Steiermark, Austria',
#        'Vienna, Austria', 'Mendoza, Argentina', 'Salta, Argentina',
#        'Patagonia, Argentina', 'South Australia, Australia',
#        'Victoria, Australia', 'Western Australia, Australia',
#        'Thracian Valley, Bulgaria', 'British Columbia, Canada',
#        'Aconcagua Valley, Aconcagua Region, Chile',
#        'Colchagua Valley, Central Valley, Chile',
#        'Maipo Valley, Central Valley, Chile',
#        'Maule Valley, Central Valley, Chile',
#        'Bourg & Blaye, Bordeaux, France', 'Libournais, Bordeaux, France',
#        'Entre-Deux-Mers, Bordeaux', 'Graves, Bordeaux, France',
#        'Medoc, Bordeaux, France', 'Sauternais, Bordeaux, France',
#        'Anjou-Saumar, Loire Valley, France', 'Provence, France',
#        'Southwest France, France', 'Southern Greece, Greece',
#        'Villany, Hungary', 'Galilee, Israel', 'Judea, Israel',
#        'Valle de Guadalupe, Mexico', "Hawke's Bay, New Zealand",
#        'Nelson, New Zealand', 'Auckland, New Zealand',
#        'Wairarapa, New Zealand', 'Bairrada, Portugal',
#        'Littoral, Slovenia', 'Coastal Region, South Africa',
#        'Cape South Coast, South Africa',
#        'Catalunya, Northeast Spain, Spain',
#        'Castilla-La Mancha, Central Spain, Spain',
#        'Navarra, Northeast Spain, Spain', 'Aegean Region, Turkey',
#        'Monterey, Central Coast, California, USA',
#        'Santa Barbara, Central Coast, California, USA',
#        'San Francisco Bay, Central Coast, California, USA',
#        'San Benito, Central Coast, California, USA',
#        'Inland Valleys, California, USA',
#        'Napa Valley, North Coast, California, USA',
#        'Sonoma Valley, North Coast, California, USA',
#        'South Coast, California, USA', 'Colorado, USA', 'Idaho, USA',
#        'Michigan, USA', 'New Jersey, USA', 'New Mexico, USA',
#        'Finger Lakes, New York, USA', 'Long Island, New York, USA',
#        'North Carolina, USA', 'Columbia Valley, Oregon, USA',
#        'Southern Oregon, Oregon, USA', 'Virginia, USA',
#        'Columbia Valley, Washington, USA',
#        'Sardinia, Southern Italy, Italy',
#        'Cachapoal Valley, Central Valley, Chile',
#        'Rapel Valley, Central Valley, Chile', 'Macedonia, Greece',
#        'Murcia, Northeast Spain, Spain', 'Aragon, Northeast Spain, Spain',
#        'San Juan, Argentina', 'Ontario, Canada',
#        'Casablanca Valley, Aconcagua Region, Chile',
#        'Curico Valley, Central Valley, Chile',
#        'Touraine, Loire Valley, France', 'Samaria, Israel',
#        'Napa-Sonoma, North Coast, California, USA',
#        'Western Connecticut, Connecticut, USA',
#        'Hudson Valley, New York, USA', 'Pennsylvania, USA', 'Texas, USA',
#        'San Jose, Uruguay', 'Catamarca, Argentina', 'La Rioja, Argentina',
#        'New South Wales, Australia', 'Vale dos Vinhedos, Brazil',
#        'Danube Plain, Bulgaria', 'Limari Valley, Coquimbo Region, Chile',
#        'Languedoc, Languedoc-Roussillon, France',
#        'Central Greece, Greece', 'Golan Heights, Israel', 'Negev, Israel',
#        'Rahoveci Valley, Kosovo', 'Muntenia, Romania', 'Banat, Romania',
#        'Cederberg, South Africa', 'Breede River Valley',
#        'Valencia, Northeast Spain, Spain',
#        'Castilla and Leon, Northwest Spain, Spain', 'Thrace, Turkey',
#        'San Luis Obispo, Central Coast, California, USA',
#        'Humboldt County, North Coast, California, USA',
#        'Solano County, North Coast, California, USA', 'Missouri, USA',
#        'Ohio, USA', 'Canelones, Uruguay',
#        'Andalucia, Southern Spain, Spain',
#        'Elqui Valley, Coquimbo, Chile', 'Tasmania, Australia',
#        'Serra Gaucha, Brazil', 'Bio-Bio Valley, South Region, Chile',
#        'Itata Valley, South Region, Chile',
#        'San Antonio, Aconcagua Region, Chile',
#        'San Antonio Valley, Aconcagua, Chile', 'Beaujolais, France',
#        'Cote de Beaune, Burgundy, France', 'Chablis, Burgundy, France',
#        'Cote de Nuits, Burgundy, France',
#        'Cote Chalonnaise, Burgundy, France',
#        'Maconnais, Burgundy, France', 'Champagne, France',
#        'Jura, Burgundy, France', 'Corsica, France', 'Pfalz, Germany',
#        'Eger, Hungary', 'Abruzzo, Central Italy, Italy',
#        'Umbria, Central Italy, Italy', 'Lombardy, Northwest Italy, Italy',
#        'Alto Adige, Northeast Italy, Italy',
#        'Friuli-Venezia Giulia, Northeast Italy, Italy',
#        'Veneto, Northeast Italy, Italy', 'Trento, Northeast Italy, Italy',
#        "Valle d'Aosta, Northwest Italy, Italy",
#        'Canterbury and Waipara, New Zealand',
#        'Central Otago, New Zealand', 'Gisborne, New Zealand',
#        'Marlborough, New Zealand', 'Douro Valley, Portugal',
#        'Tras-os-Montes, Portugal', 'Central Romania, Romania',
#        'Massachussets, USA', 'Willamette Valley, Oregon, USA',
#        'Calabria, Southern Italy, Italy', 'Bugey, France',
#        'Auvergne, Loire Valley, France',
#        'La Rioja, Northeast Spain, Spain', 'Rheinhessen, Germany',
#        'Lazio, Central Italy, Italy',
#        'Roussillon, Languedoc-Roussillon, France',
#        'Southern Rhone, Rhone Valley, France',
#        'Vinos de Madrid, Central Spain, Spain', 'Pannonhalma, Hungary',
#        'Ica, Peru', 'Madeira, Portugal', 'Canary Islands, Spain',
#        'Ticino, Switzerland', 'Le Marche, Central Italy, Italy',
#        'Liguria, Northwest Italy, Italy', 'Baden, Germany',
#        'Nahe, Germany', 'Moselle Luxembourg, Luxembourg',
#        'Podravje, Slovenia', 'Centre, Loire Valley, France',
#        'Ahr, Germany', 'Mosel, Germany', 'Rheingau, Germany',
#        'Wurttemberg, Germany', 'Tikves, Macedonia',
#        'Ceres Plateau, South Africa', 'Graubunden, Switzerland',
#        'Puget Sound, Washington, USA', 'Campanha, Brazil',
#        'Vale Trentino, Brazil', 'Istria, Croatia', 'Dalmatia, Croatia',
#        'Commandaria, Cyprus', 'Kathikas, Cyprus',
#        'Coteaux de Languedoc, Languedoc-Roussillon, France',
#        'Aegean Islands, Greece', 'Bekaa Valley, Lebanon',
#        'Cahul, Moldova', 'Zenata, Morocco', 'Beira Interior, Portugal',
#        'Dao, Portugal', 'Vinho Verde, Portugal',
#        'Extremadura, Central Spain, Spain',
#        'Galicia, Northwest Spain, Spain',
#        'Mallorca, Southern Spain, Spain', 'La Cote, Switzerland',
#        'Cappadocia, Turkey', 'Arizona, USA', 'Franken, Germany',
#        'Mittelrhein, Germany', 'Muzla, Slovakia',
#        'Moravia, Czech Republic', 'Nashik, India',
#        'Johannesburg, South Africa', 'Choapa Valley, Coquimbo, Chile',
#        'Northern Rhone, Rhone Valley, France', 'Tokaj, Hungary',
#        'Cyprus, Cyprus', 'Savoie, France',
#        'Pais Vasco, Northwest Spain, Spain'], dtype=object)

# %%
wine_df_merged.geo_normalized.unique()
# Out:
# array(['Willamette Valley, Oregon, USA', nan,
#        'Finger Lakes, New York, USA', 'Long Island, New York, USA',
#        'Sierra Foothills, California, USA',
#        'Southern Oregon, Oregon, USA', 'South Coast, California, USA',
#        'Napa-Sonoma, North Coast, California, USA'], dtype=object)

# %%
variety_geos = wine_df_merged.groupby(['Variety', 'geo_normalized']).size()
at_least_n_types = variety_geos[variety_geos > 30].reset_index()
# at_least_n_types.head(10)
wine_df_merged_filtered = pd.merge(wine_df_merged, at_least_n_types, left_on=['Variety', 'geo_normalized'], right_on=['Variety', 'geo_normalized'])
wine_df_merged_filtered = wine_df_merged_filtered[['title', 'Variety', 'geo_normalized', 'description']]
wine_df_merged_filtered.head()
# Out:
#                                                title       Variety  \
# 0      Rainstorm 2013 Pinot Gris (Willamette Valley)  Pinot Grigio
# 1  Coelho 2015 Renovação Estate Vineyards Pinot G...  Pinot Grigio
# 2  Stanton Vineyard 2013 Pinot Gris (Willamette V...  Pinot Grigio
# 3  Oak Knoll 2014 Cloud Rest Vineyard Pinot Gris ...  Pinot Grigio
# 4          Lange 2010 Pinot Gris (Willamette Valley)  Pinot Grigio
#
#                    geo_normalized  \
# 0  Willamette Valley, Oregon, USA
# 1  Willamette Valley, Oregon, USA
# 2  Willamette Valley, Oregon, USA
# 3  Willamette Valley, Oregon, USA
# 4  Willamette Valley, Oregon, USA
#
#                                          description
# 0  Tart and snappy, the flavors of lime flesh and...
# 1  Quite tart, the fruit here touches (just barel...
# 2  Creamy and fresh, this is made from estate-gro...
# 3  This is a neutral, papery white wine, with a f...
# 4  Fruit-driven, with pear and apple, but an inte...

# %%
wine_reviews = list(wine_df_merged['description'])

core_tastes = ['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter']

descriptor_mappings = dict()
for c in core_tastes:
    descriptor_mapping_filtered=descriptor_mapping[descriptor_mapping['type']==c]
    descriptor_mappings[c] = descriptor_mapping_filtered                                                   
    

def return_descriptor_from_mapping(descriptor_mapping, word, core_tastes):
    if word in list(descriptor_mapping.index):
        descriptor_to_return = descriptor_mapping['level_3'][word]
        return descriptor_to_return
    else:
        return None

review_descriptors = []
for review in wine_reviews:
    taste_descriptors = []
    normalized_review = normalize_text(review)
    phrased_review = wine_trigram_model[normalized_review]
    #print(normalized_review)
    
    for c in core_tastes:                                                      
        descriptors_only = [return_descriptor_from_mapping(descriptor_mappings[c], word, c) for word in phrased_review]
        no_nones = [str(d).strip() for d in descriptors_only if d is not None]
        descriptorized_review = ' '.join(no_nones)
        taste_descriptors.append(descriptorized_review)
    review_descriptors.append(taste_descriptors)

# %%
review_descriptors
# Out:
# [['green', '', 'lime rind pineapple', 'tart snappy crisp', '', '', '', ''],
#  ['steel', '', 'fruit melon orange lemon_peel lime', 'tart', '', '', '', ''],
#  ['steel oak',
#   '',
#   'fruit melon pear sweet honeysuckle',
#   'fresh',
#   '',
#   '',
#   'cream',
#   ''],
#  ['white', '', 'apple fruit', 'flat fresh', '', 'licorice', '', ''],
#  ['', '', 'fruit-forward pear apple fruit', '', '', 'licorice', 'depth', ''],
#  ['',
#   'lush',
#   'stone_fruit sweet pear',
#   'fresh',
#   '',
#   'cinnamon spice',
#   'complex cream',
#   ''],
#  ['watery', 'light_bodied', 'fruit', 'tart', '', '', '', ''],
#  ['gold shine dense pollen oil vanilla',
#   'light_bodied',
#   'lemon apple pear cookie',
#   'bright clean',
#   '',
#   '',
#   '',
#   ''],
#  ['white',
#   '',
#   'ripe apple pear fruit citrus',
#   'fresh',
#   '',
#   '',
#   '',
#   'firm polished'],
#  ['minerality',
#   'refined',
#   'lemon lemon grapefruit nectarine',
#   'refreshing',
#   '',
#   '',
#   'complex',
#   ''],
#  ['grass', 'light_bodied', 'fruit', 'sour tart', '', '', '', ''],
#  ['dust', 'light_bodied', 'sweet apple sugar', '', '', '', '', ''],
#  ['oak', '', 'pear apple honey', '', '', '', '', 'round fleshy'],
#  ['pine tar', '', 'fruit apple orange', 'sharp fresh', '', '', '', ''],
#  ['green',
#   '',
#   'fruit-forward apple melon pear fruit',
#   '',
#   '',
#   '',
#   'celery',
#   'bitter'],
#  ['flower steel',
#   '',
#   'lemon fruit apricot sweet',
#   'tangy bright',
#   '',
#   '',
#   '',
#   ''],
#  ['oxidized',
#   'light_bodied baked',
#   'fruit fruit',
#   '',
#   '',
#   'spice cinnamon spice',
#   '',
#   'soft'],
#  ['length', 'light_bodied', 'pear fruit', 'fresh', '', '', '', 'fleshy'],
#  ['',
#   '',
#   'sugar ripe fruit apple pear peach honeycomb ripe',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['green', '', 'berry kiwi lime fruit', '', '', '', 'depth', ''],
#  ['spring_flower',
#   'light_bodied elegant',
#   'citrus_peel pineapple pear',
#   'fresh',
#   '',
#   'white_pepper spice',
#   '',
#   ''],
#  ['flower',
#   'light_bodied light_bodied',
#   'pear fruit sweet honey',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality',
#   '',
#   'citrus pineapple',
#   'crisp refreshing',
#   '',
#   '',
#   'complex',
#   ''],
#  ['wet_rocks',
#   'full_bodied light_bodied',
#   'fruit pear apple kiwi melon',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'polished'],
#  ['',
#   'light_bodied',
#   'fruit apple pear peach fruit',
#   'clean',
#   '',
#   'spice',
#   '',
#   ''],
#  ['pale length',
#   'light_bodied',
#   'strawberry',
#   'bite',
#   '',
#   '',
#   '',
#   'smooth phenolic'],
#  ['minerality dense',
#   'warm',
#   'peach guava',
#   'crisp fresh',
#   '',
#   '',
#   'lees',
#   ''],
#  ['cucumber minerality',
#   'light_bodied',
#   'gooseberry grapefruit fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['watery', 'light_bodied', 'lemon citrus dry', 'flat', '', '', '', 'hard'],
#  ['', '', 'pear', 'fresh fresh crisp', '', 'cinnamon spice', 'quaffer', ''],
#  ['green',
#   '',
#   'grapefruit apple melon fruit fruit',
#   'fresh crisp buoyant clean',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'citrus apple fruit',
#   'flat puckery',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['herb',
#   'light_bodied',
#   'pear lime fruit',
#   'fresh clean tart zippy clean',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality herb',
#   'pungent warm',
#   'citrus_peel',
#   'fresh refreshing',
#   '',
#   '',
#   'cream lees complex',
#   ''],
#  ['powerful stone length',
#   '',
#   'pineapple citrus pear',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['sappy',
#   '',
#   'apple pear grapefruit sweet lemon fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['',
#   'light_bodied',
#   'orange bone_dry pear peach fruit',
#   '',
#   '',
#   '',
#   'complex',
#   ''],
#  ['dense green powerful',
#   '',
#   'grapefruit orange apple banana juicy fruit-forward',
#   'tart sour',
#   '',
#   '',
#   '',
#   ''],
#  ['steel white', 'light_bodied', 'pear', '', '', 'spice', '', 'soft'],
#  ['steel', '', 'cider juicy fruit', 'tart fresh clean', '', '', 'closed', ''],
#  ['white', 'thick heavy', 'fruit ripe', 'fresh', '', '', '', ''],
#  ['pine',
#   '',
#   'fruit grapefruit citrus',
#   'tart puckery tangy refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   'dry lemon juicy ripe sweet fruit',
#   'sharp tart sour',
#   '',
#   '',
#   '',
#   ''],
#  ['sulfur', '', 'citrus fruit apple', 'crisp clean crisp', '', '', '', ''],
#  ['oak wet_rocks minerality white',
#   '',
#   'tropical_fruit pear',
#   'tart fresh fresh',
#   '',
#   '',
#   '',
#   'sleek'],
#  ['dust',
#   'full_bodied',
#   'ripe pear fruit fruit',
#   '',
#   '',
#   'cinnamon spice',
#   '',
#   ''],
#  ['',
#   'baked rich',
#   'sweet pear fruit',
#   '',
#   '',
#   'spice ginger cinnamon spice',
#   '',
#   ''],
#  ['tea',
#   'low_alcohol rich',
#   'sugar fruit pear stone_fruit honey',
#   '',
#   '',
#   '',
#   'complex',
#   'round'],
#  ['flower minerality steel',
#   '',
#   'stone_fruit melon peach lemon_peel lime',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['dust',
#   '',
#   'ripe apple pear nectarine brown_sugar dry',
#   '',
#   '',
#   'cinnamon',
#   '',
#   ''],
#  ['oil', 'rich', 'ripe pear apple fruit honey', '', '', 'spice', 'butter', ''],
#  ['steel grass herb',
#   'light_bodied thick heavy light_bodied',
#   'sweet pear',
#   'fresh fresh fresh fresh',
#   '',
#   '',
#   'lees lees cream',
#   ''],
#  ['oak flower minerality',
#   'rich',
#   '',
#   '',
#   '',
#   'white_pepper',
#   'cream butterscotch',
#   ''],
#  ['pine mint',
#   'elegant',
#   'grapefruit fruit',
#   '',
#   '',
#   'spice',
#   'complex depth',
#   ''],
#  ['steel', '', 'fruit juicy apple pear', 'fresh', '', '', '', 'gripping'],
#  ['oxidized', '', 'fruit ripe', '', '', '', 'modest', ''],
#  ['vanilla_cream', '', 'apple pear', 'fresh', '', '', 'brioche', 'round'],
#  ['minerality',
#   '',
#   'pear apple fruit orange',
#   'bright refreshing crisp',
#   '',
#   'spice',
#   '',
#   ''],
#  ['pale hibiscus tea rosewater',
#   'rich',
#   'orange ripe citrus fruit',
#   '',
#   '',
#   'spice cinnamon',
#   '',
#   'round'],
#  ['steel neutral_oak green vanilla',
#   'baked',
#   'apple peach',
#   '',
#   '',
#   'spice',
#   'lees',
#   ''],
#  ['yellow cucumber green oil steel new_oak minerality',
#   'rich',
#   'fruit lemon',
#   'tart',
#   '',
#   '',
#   '',
#   'gripping'],
#  ['green watery',
#   'light_bodied',
#   'apricot apple lemon fruit',
#   'flat clean',
#   '',
#   '',
#   'celery bland modest',
#   ''],
#  ['steel',
#   'light_bodied light_bodied',
#   'fruit sweet pear apple fruit',
#   'spritzy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oak',
#   'light_bodied',
#   'fruit',
#   'refreshing crisp assertive',
#   '',
#   '',
#   'complex cream lees',
#   ''],
#  ['steel oak',
#   'weight',
#   'ripe fruit melon kiwi',
#   'tart tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality toast',
#   '',
#   'pear fruit',
#   'tart',
#   '',
#   '',
#   'sparkling finessed sparkling',
#   'smooth'],
#  ['herb', '', 'melon apple fruit', 'fresh', '', '', '', 'smooth'],
#  ['',
#   'light_bodied',
#   'orange bone_dry pear peach fruit',
#   '',
#   '',
#   '',
#   'complex',
#   ''],
#  ['herb', '', 'juicy fruit', 'edgy', '', '', '', 'phenolic'],
#  ['length', 'light_bodied', 'pear citrus lemon', '', '', '', '', 'fleshy'],
#  ['', 'light_bodied', 'pear peach', 'fresh', '', 'spice', '', ''],
#  ['yellow cucumber green oil steel new_oak minerality',
#   'rich',
#   'fruit lemon',
#   'tart',
#   '',
#   '',
#   '',
#   'gripping'],
#  ['minerality',
#   '',
#   'dry citrus_peel fruit',
#   'edgy sour',
#   '',
#   '',
#   '',
#   'austere'],
#  ['',
#   'light_bodied',
#   'pear',
#   'crisp',
#   '',
#   'spice white_pepper',
#   'low_complexity',
#   ''],
#  ['yellow', 'light_bodied', 'apple grapefruit rind', '', '', '', 'yeast', ''],
#  ['herb',
#   'light_bodied elegant',
#   'stone_fruit orange',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['steel', '', 'pear citrus', 'fresh', '', '', '', ''],
#  ['oak oak oak wood toast wood wood herb stone',
#   'light_bodied',
#   'fruit',
#   'sharp',
#   '',
#   '',
#   'lees complex',
#   ''],
#  ['', 'hot', '', 'tart fresh sharp', '', '', 'yeast', 'gripping'],
#  ['pale hibiscus tea flower',
#   'thick full_bodied',
#   'juicy fruit peach citrus',
#   'high_acid',
#   '',
#   '',
#   'complex',
#   'chewi'],
#  ['shine medium_length_finish dense',
#   '',
#   'fruit apple citrus_peel',
#   'clean',
#   '',
#   '',
#   '',
#   ''],
#  ['sulfur', '', 'pear fruit orange lemon', '', '', 'spice', '', 'round'],
#  ['steel', '', 'pear fruit caramel', 'fresh', '', '', 'low_complexity', ''],
#  ['dense wood wood',
#   'rich rich light_bodied',
#   'apple pear fruit caramel',
#   '',
#   '',
#   '',
#   'butter',
#   ''],
#  ['',
#   'full_bodied light_bodied',
#   'fruit pear',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['',
#   'hot',
#   'fruit peach gooseberry',
#   'crisp racy bright clean',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'pear grapefruit honeysuckle juicy',
#   'fresh clean',
#   '',
#   '',
#   '',
#   'fleshy'],
#  ['green cucumber',
#   '',
#   'citrus_pith apple melon',
#   'fresh clean',
#   '',
#   '',
#   'lees',
#   ''],
#  ['length powerful minerality tarragon',
#   '',
#   'pear apple lemon',
#   'tart',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality green',
#   'light_bodied',
#   'fruit grapefruit apple melon',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated length',
#   '',
#   'lemon fruit pineapple',
#   'tart tangy fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'low_alcohol', 'fruit ripe pear orange fruit sugar', '', '', '', '', ''],
#  ['',
#   '',
#   'apple stone_fruit',
#   '',
#   '',
#   'pepper spice',
#   'brioche complex',
#   'fleshy'],
#  ['neutral_oak',
#   'rich light_bodied',
#   'citrus peach tropical_fruit fruit',
#   'fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['stone', '', 'citrus tropical_fruit fruit bone_dry', '', '', '', '', ''],
#  ['juniper',
#   '',
#   'citrus_peel grapefruit berry',
#   'tart snappy',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['white',
#   '',
#   'pear fruit orange juicy',
#   'fresh bright',
#   '',
#   'spice',
#   '',
#   'round fleshy'],
#  ['', 'light_bodied', 'fruit honey sweet dry', '', '', '', '', ''],
#  ['length', 'light_bodied', 'pear fruit', 'fresh', '', '', '', 'fleshy'],
#  ['white', 'light_bodied', 'lemon orange', 'tart', '', '', '', ''],
#  ['mineral oak mint',
#   'light_bodied',
#   'pear apple fruit',
#   'fresh clean',
#   '',
#   '',
#   'cream',
#   ''],
#  ['', '', 'sweet sugar fruit pear apricot', 'edgy', '', 'spice', '', 'fleshy'],
#  ['', '', 'grapefruit', 'tart', '', '', 'lees', ''],
#  ['', '', 'melon citrus pear fruit', '', '', '', 'lees cream finessed', ''],
#  ['powerful',
#   'rich lush',
#   'ripe tropical_fruit fruit banana caramel',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['sweat',
#   'light_bodied',
#   'pear fruit',
#   '',
#   '',
#   'cinnamon spice',
#   'yeast',
#   ''],
#  ['concentrated length grass',
#   '',
#   'grapefruit',
#   '',
#   '',
#   'spice spice',
#   '',
#   ''],
#  ['steel minerality',
#   '',
#   'lime pineapple lemon_verbena',
#   'fresh refreshing clean crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'ripe pear sugar dry fruit sweet',
#   'bright tart tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral_oak',
#   'full_bodied',
#   'pear tropical_fruit fruit banana juicy fruit fruit',
#   'sharp',
#   '',
#   '',
#   'butterscotch',
#   ''],
#  ['toast peanut',
#   'rich lush',
#   'honeycomb dry apricot',
#   '',
#   '',
#   '',
#   'brown butter',
#   ''],
#  ['', '', 'dry', '', '', 'spice', 'butter', 'soft supple'],
#  ['oak toast toast coconut',
#   '',
#   'ripe apple',
#   'aggressive',
#   '',
#   '',
#   'butter',
#   ''],
#  ['vanilla', '', 'honey pear dry fruit', 'crisp', '', '', '', ''],
#  ['length', '', 'fruit peach pear citrus', '', '', '', 'depth', ''],
#  ['oak',
#   'light_bodied',
#   'apple pear fruit',
#   'crisp tart bite sharp',
#   '',
#   'pepper',
#   '',
#   ''],
#  ['minerality',
#   '',
#   'lemon rind fruit',
#   'bright tangy tart refreshing clean',
#   '',
#   '',
#   '',
#   'tight'],
#  ['pea minerality stone',
#   'plump',
#   'grapefruit apple lemon',
#   'snappy crisp tangy lean',
#   '',
#   '',
#   '',
#   'chewi'],
#  ['diluted dull',
#   '',
#   'pear grapefruit orange citrus stone_fruit',
#   'snappy',
#   '',
#   'white_pepper licorice',
#   '',
#   'round'],
#  ['herb green',
#   'rich low_alcohol',
#   'lime fruit melon',
#   'sour',
#   '',
#   '',
#   'lees celery',
#   ''],
#  ['plastic',
#   'light_bodied light_bodied',
#   'fruit citrus melon',
#   'tart',
#   '',
#   '',
#   '',
#   ''],
#  ['white oxidized',
#   'light_bodied light_bodied',
#   'orange cherry dry fruit dry cherry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['green green',
#   'light_bodied',
#   'apple pear fruit',
#   'tart',
#   '',
#   'cinnamon',
#   '',
#   'tight'],
#  ['green',
#   'low_alcohol',
#   'fruit ripe ripe fruit gooseberry',
#   'fresh tart fresh',
#   '',
#   '',
#   'lees',
#   ''],
#  ['flower',
#   'elegant',
#   'apple citrus',
#   '',
#   '',
#   'cinnamon white_pepper',
#   '',
#   ''],
#  ['steel minerality',
#   'baked',
#   'apple pear fruit',
#   'tart',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oil', 'light_bodied', 'pear berry', '', '', '', '', ''],
#  ['steel white',
#   '',
#   'sugar lemon tangerine',
#   'fresh',
#   '',
#   '',
#   '',
#   'round austere'],
#  ['toast',
#   'weight light_bodied',
#   'pear peach fruit',
#   '',
#   '',
#   '',
#   '',
#   'gripping'],
#  ['minerality',
#   '',
#   'pear orange fruit',
#   'clean fresh',
#   '',
#   '',
#   'depth lees',
#   'round'],
#  ['steel', '', 'honey pear ripe apple', '', '', 'spice', '', ''],
#  ['', '', 'pear fruit-forward juicy', 'fresh clean crisp', '', '', '', ''],
#  ['',
#   '',
#   'apple pear melon fruit',
#   'crisp fresh snappy sizzling bright bite edgy',
#   '',
#   '',
#   '',
#   'phenolic bitter'],
#  ['pale hibiscus tea flower',
#   'thick full_bodied',
#   'juicy fruit peach citrus',
#   'high_acid',
#   '',
#   '',
#   'complex',
#   'chewi'],
#  ['green', '', 'lemon apple', 'sour high_acid tart', '', '', '', ''],
#  ['steel rosemary', 'pungent', 'citrus', '', '', '', 'lees', ''],
#  ['toast shine', 'light_bodied', 'melon pear', 'bright', '', 'spice', '', ''],
#  ['toast oil',
#   'light_bodied low_alcohol',
#   'apple lemon',
#   '',
#   '',
#   '',
#   'almond',
#   ''],
#  ['', '', 'fruit sweet melon pineapple', 'flat sour', '', '', '', 'round'],
#  ['vanilla',
#   '',
#   'fruit grapefruit apricot melon cookie',
#   '',
#   '',
#   '',
#   'butter',
#   ''],
#  ['concentrated',
#   'viscous lush',
#   'pear apple fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['white',
#   'light_bodied light_bodied',
#   'fruit apple pear melon',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'apple pear fruit',
#   'fresh exuberant',
#   '',
#   '',
#   'yeast',
#   ''],
#  ['minerality',
#   'medium_bodied',
#   'apple pear fruit',
#   'clean fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['flint minerality minerality',
#   '',
#   'pear lemon_curd',
#   'crisp sharp',
#   '',
#   '',
#   'cream',
#   ''],
#  ['', '', 'fruit pear apple orange juicy', '', '', '', '', ''],
#  ['powerful green pea oak minerality',
#   '',
#   'fruit melon apple pear',
#   'exuberant crisp fresh crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'fruit pear pear juicy', 'refreshing', '', 'spice', '', ''],
#  ['',
#   'light_bodied',
#   'fruit overripe sugar sweet pear fruit honey',
#   'edgy',
#   '',
#   '',
#   '',
#   'grainy'],
#  ['',
#   '',
#   'lemon juicy pear fruit unripe pineapple',
#   'tart bright',
#   '',
#   '',
#   '',
#   ''],
#  ['steel rosemary', 'pungent', 'citrus', '', '', '', 'lees', ''],
#  ['perfumed oak toast coconut',
#   '',
#   'apple orange ripe melon fruit',
#   'bright',
#   '',
#   '',
#   'almond',
#   ''],
#  ['minerality',
#   '',
#   'fruit citrus pineapple candy citrus_peel',
#   'refreshing',
#   '',
#   '',
#   'cream',
#   ''],
#  ['vanilla',
#   'light_bodied',
#   'pear apple citrus cookie',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['steel', 'plump weight', 'fruit', '', '', '', '', ''],
#  ['', '', 'sweet grapefruit', 'tangy pop', '', '', 'yeast', ''],
#  ['flint minerality minerality',
#   '',
#   'pear lemon_curd',
#   'crisp sharp',
#   '',
#   '',
#   'cream',
#   ''],
#  ['', '', 'fruit tangerine apple pear', 'tart crisp', '', '', '', ''],
#  ['', '', 'lemon_peel pear', 'fresh zesty', '', 'spice', 'complex', ''],
#  ['oak',
#   'full_bodied rich',
#   'ripe pear',
#   'fresh tangy',
#   '',
#   'spice cinnamon',
#   'butterscotch',
#   ''],
#  ['',
#   'low_alcohol',
#   'pear fruit sugar',
#   'high_acid tangy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['vanilla coconut',
#   '',
#   'pear melon tropical_fruit ripe',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'light_bodied', 'lemon juicy', 'sour', '', '', '', ''],
#  ['flower',
#   '',
#   'lemon_peel orange pineapple citrus papaya',
#   '',
#   '',
#   '',
#   '',
#   'tight'],
#  ['cucumber', '', 'peach', 'crisp refreshing', '', '', '', 'tight'],
#  ['vanilla vanilla',
#   '',
#   'fruit ripe pear',
#   'fresh',
#   '',
#   '',
#   'cream',
#   'smooth'],
#  ['steel minerality',
#   'full_bodied',
#   'fruit citrus',
#   'refreshing assertive',
#   '',
#   '',
#   'lees',
#   ''],
#  ['herb', '', 'citrus juicy rind honeysuckle', '', '', '', 'complex', ''],
#  ['oak',
#   'light_bodied baked',
#   'fruit overripe apple',
#   '',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['', '', 'orange grapefruit pear fruit', 'fresh', '', 'spice', '', ''],
#  ['',
#   'light_bodied',
#   'apple pear fruit',
#   'bright crisp clean fresh refreshing',
#   '',
#   'spice spice',
#   '',
#   ''],
#  ['flower green wet_rocks', '', 'melon pear', 'crisp fresh', '', '', '', ''],
#  ['tea',
#   '',
#   'sugar dry fruit honey apple pear lemon_verbena',
#   'bright',
#   '',
#   'spice',
#   '',
#   'round'],
#  ['oak stone minerality', '', 'pear', '', '', '', 'lees', 'rough sleek'],
#  ['green flower',
#   '',
#   'citrus melon apple fruit',
#   'crisp clean refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['oxidized length',
#   'light_bodied low_alcohol rich',
#   'apple fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'light_bodied', 'melon pear', '', '', '', '', 'soft'],
#  ['', '', 'ripe fruit pear melon fruit', 'fresh flabby', '', '', '', ''],
#  ['', 'medium_bodied', 'sweet sweet apple pear fruit', '', '', '', '', ''],
#  ['',
#   'light_bodied elegant',
#   'pear apple fruit',
#   '',
#   '',
#   '',
#   'yeast butter',
#   ''],
#  ['',
#   'plump full_bodied',
#   'melon citrus ripe citrus tropical_fruit',
#   '',
#   '',
#   '',
#   'cream',
#   'soft round smooth supple'],
#  ['', '', 'fruit melon lime grapefruit', 'crisp fresh', '', '', 'acacia', ''],
#  ['', '', 'ripe apple pear fruit', 'clean', '', 'spice cinnamon', '', ''],
#  ['minerality white length',
#   '',
#   'melon pear fruit',
#   'bright refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality',
#   '',
#   'pear apple fruit orange',
#   'bright refreshing crisp',
#   '',
#   'spice',
#   '',
#   ''],
#  ['steel oak neutral_oak oak',
#   'hot',
#   'lemon grapefruit orange citrus_peel',
#   'bite',
#   '',
#   '',
#   'yeast',
#   'phenolic round'],
#  ['mint', '', 'lemon_custard banana', '', '', '', '', 'smooth soft'],
#  ['', '', 'ripe', 'tart sour high_acid fresh', '', '', '', 'bitter'],
#  ['', '', 'ripe fruit pear melon fruit', 'fresh flabby', '', '', '', ''],
#  ['neutral_oak',
#   'rich light_bodied',
#   'citrus peach tropical_fruit fruit',
#   'fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['stone', '', 'citrus tropical_fruit fruit bone_dry', '', '', '', '', ''],
#  ['coffee',
#   '',
#   'pear citrus caramel juicy',
#   'crisp tart',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oak neutral_oak yellow yellow',
#   'warm',
#   'apple fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['concentrated flower minerality',
#   '',
#   'fruit lemon tangerine pear candy papaya',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality',
#   '',
#   'lemon rind fruit',
#   'bright tangy tart refreshing clean',
#   '',
#   '',
#   '',
#   'tight'],
#  ['',
#   'elegant',
#   'citrus grapefruit pear',
#   'fresh crisp refreshing',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dust concentrated',
#   'succulent light_bodied',
#   'juicy fruit apple pear',
#   'tart fresh',
#   '',
#   'cinnamon spice',
#   '',
#   ''],
#  ['grass herbacious green', '', '', 'sharp', '', 'pepper', '', ''],
#  ['',
#   '',
#   'lemon_verbena honey ripe fruit apple pear fruit-forward',
#   '',
#   '',
#   '',
#   'yeast',
#   ''],
#  ['', 'light_bodied', 'apple cider', 'high_acid', '', '', '', ''],
#  ['metal', 'light_bodied', 'lime tangerine', '', '', '', '', ''],
#  ['olive oil',
#   'light_bodied',
#   'apple pear peach juicy lemon',
#   'tart',
#   '',
#   'spice pepper',
#   'depth',
#   'tight'],
#  ['', 'medium_bodied', 'sweet sweet apple pear fruit', '', '', '', '', ''],
#  ['', 'light_bodied', 'pear fruit', 'bright clean crisp', '', '', '', ''],
#  ['', '', 'dry ripe fruit citrus lemon_peel', 'fresh', '', '', '', ''],
#  ['', 'light_bodied', 'ripe bone_dry', 'sour fresh', '', '', '', ''],
#  ['white dense', 'light_bodied', 'pear apple melon', 'fresh', '', '', '', ''],
#  ['white',
#   'light_bodied',
#   'fruit pear tangerine',
#   'bright tangy fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['dull green green metal',
#   '',
#   'ripe fruit berry apple grapefruit dry',
#   'crisp tart high_acid',
#   '',
#   '',
#   '',
#   ''],
#  ['oak',
#   'sturdy',
#   'ripe apple pear fruit citrus',
#   'refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['game',
#   'rich succulent light_bodied lush',
#   'pear fruit sweet ripe fruit sugar',
#   'fresh',
#   '',
#   'cinnamon',
#   'cream',
#   ''],
#  ['oil grass', '', 'sugar', '', '', '', '', ''],
#  ['metal', 'light_bodied', 'lime tangerine', '', '', '', '', ''],
#  ['cucumber',
#   'low_alcohol',
#   'lime pineapple apple dry bone_dry',
#   'racy refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['vanilla',
#   'lush',
#   'ripe pear melon sweet apple',
#   '',
#   '',
#   '',
#   'cream cream',
#   ''],
#  ['stone green concentrated white',
#   'chunky light_bodied',
#   'ripe fruit melon pear',
#   'clean',
#   '',
#   '',
#   '',
#   'fleshy'],
#  ['',
#   'elegant low_alcohol',
#   'melon pear fruit peach',
#   'clean crisp fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['punchy minerality',
#   '',
#   'juicy apple pear citrus lemon grapefruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['mint',
#   '',
#   'ripe fruit',
#   'bright clean fresh',
#   '',
#   'spice',
#   '',
#   'round fleshy'],
#  ['steel', '', 'fruit juicy apple pear', 'fresh', '', '', '', 'gripping'],
#  ['',
#   '',
#   'fruit apple grapefruit_pith lemon_peel',
#   'fresh',
#   '',
#   '',
#   'lees',
#   'phenolic'],
#  ['green',
#   '',
#   'apple pear fruit',
#   'clean crisp high_acid',
#   '',
#   '',
#   '',
#   'round'],
#  ['green',
#   'light_bodied',
#   'apple melon pear lemon fruit',
#   'tart',
#   '',
#   'spice',
#   '',
#   'closed'],
#  ['mineral',
#   '',
#   'apple pear fruit sugar',
#   'racy crisp fresh',
#   '',
#   '',
#   'complex',
#   'fleshy'],
#  ['concentrated',
#   '',
#   'citrus citrus apple pear melon fruit',
#   'fresh',
#   '',
#   '',
#   'cream depth',
#   ''],
#  ['herb', '', 'citrus juicy rind honeysuckle', '', '', '', 'complex', ''],
#  ['',
#   'baked rich',
#   'sweet pear fruit',
#   '',
#   '',
#   'spice ginger cinnamon spice',
#   '',
#   ''],
#  ['steel oak gold toast', 'rich', 'apple fruit', '', '', '', '', 'soft soft'],
#  ['',
#   '',
#   'gooseberry melon kiwi grapefruit fruit',
#   'clean fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'light_bodied', 'lemon_peel citrus', 'sharp', '', 'pepper', '', ''],
#  ['flower',
#   '',
#   'apple pineapple tangerine nectarine fruit',
#   '',
#   '',
#   '',
#   'almond',
#   ''],
#  ['oak', 'lush', 'sweet apple_sauce dry lemon', '', '', '', 'cream', ''],
#  ['steel white grain green',
#   'warm',
#   'fruit apple melon',
#   '',
#   '',
#   '',
#   'yeast depth',
#   'tight'],
#  ['grain',
#   '',
#   'fruit pear peach cracker sweet',
#   '',
#   '',
#   '',
#   '',
#   'soft phenolic'],
#  ['concentrated',
#   'light_bodied',
#   'melon pear fruit',
#   '',
#   '',
#   '',
#   'modest',
#   ''],
#  ['', '', 'apple peach', '', '', 'spice', '', ''],
#  ['', 'pungent', 'apple apple cider', 'crisp fresh', '', '', '', 'bitter'],
#  ['', '', 'sugar sweet', '', '', 'spice baking_spices', '', 'fleshy supple'],
#  ['oak',
#   'elegant light_bodied',
#   'apple pear apple citrus apple caramel',
#   '',
#   '',
#   'spice',
#   'butter',
#   ''],
#  ['oak oak',
#   'light_bodied light_bodied',
#   'honey botrytis',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['concrete green green', '', 'berry apple pear', 'crisp', '', '', '', ''],
#  ['herb white',
#   '',
#   'gooseberry lime pear fruit',
#   'fresh clean refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'melon pear fruit', 'bright refreshing', '', '', '', ''],
#  ['dust',
#   'light_bodied baked rich light_bodied',
#   'apple pie pear peach',
#   '',
#   '',
#   'cinnamon spice',
#   '',
#   ''],
#  ['pale',
#   'light_bodied',
#   'pear',
#   'snappy clean fresh',
#   '',
#   'cinnamon',
#   '',
#   ''],
#  ['peanut', '', 'citrus fruit fruit apple lemon', 'tart', '', '', '', ''],
#  ['', '', 'grapefruit nectarine fruit', 'fresh flat', '', '', '', ''],
#  ['tarragon', '', 'lemon', 'fresh', '', '', '', 'polished'],
#  ['minerality', '', 'apple', 'tart tangy', '', '', '', 'firm'],
#  ['dense length', '', 'fruit fruit sweet dry', '', '', '', '', 'fleshy'],
#  ['oak toast', 'light_bodied', 'apple pear', 'tangy', '', '', '', 'smooth'],
#  ['pale length concentrated dust',
#   '',
#   'melon berry apple dry',
#   '',
#   '',
#   '',
#   'complex depth',
#   ''],
#  ['white',
#   'light_bodied',
#   'fruit apple pear fruit',
#   'clean',
#   '',
#   'spice',
#   'quaffer',
#   ''],
#  ['watery',
#   '',
#   'pear fruit cracker',
#   '',
#   '',
#   'spice white_pepper',
#   '',
#   'tight big-boned'],
#  ['dust', 'light_bodied', 'ripe pear', '', '', 'cinnamon spice', '', 'fleshy'],
#  ['minerality wet_rocks herb green',
#   'light_bodied',
#   'dry dry citrus',
#   'crisp fresh',
#   '',
#   '',
#   'lees',
#   ''],
#  ['neutral_oak pale rose oak',
#   'light_bodied',
#   'strawberry fruit',
#   'puckery sour',
#   '',
#   '',
#   '',
#   'phenolic round astringent'],
#  ['concentrated',
#   'rich light_bodied',
#   'fruit pear cataloupe sugar sweet dry',
#   '',
#   '',
#   '',
#   '',
#   'round fleshy'],
#  ['', 'heavy', 'fruit dry pear apricot jam honey', '', '', 'spice', '', ''],
#  ['', '', 'fruit peach papaya melon citrus', 'fresh', '', '', '', ''],
#  ['white pollen length',
#   'plump',
#   'ripe apple pear fruit honey',
#   '',
#   '',
#   '',
#   '',
#   'gripping'],
#  ['', '', 'fruit lemon melon pineapple dry', 'clean fresh', '', '', '', ''],
#  ['grass',
#   '',
#   'grapefruit pineapple',
#   'bright bite racy refreshing acid_driven',
#   '',
#   'spice',
#   '',
#   ''],
#  ['concentrated',
#   'light_bodied',
#   'apple pear fruit caramel',
#   'fresh crisp bright',
#   '',
#   '',
#   'butter',
#   ''],
#  ['green concentrated length',
#   '',
#   'apple fruit',
#   'snappy crisp racy',
#   '',
#   '',
#   '',
#   ''],
#  ['grass wet_rocks',
#   'low_alcohol light_bodied',
#   'pear melon',
#   'fresh crisp refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['earth herb', 'hearty', '', '', '', '', '', 'rough tannin rustic'],
#  ['earth herb', '', 'bramble berry', '', '', '', '', 'tannin bitter'],
#  ['', '', 'cherry fruit ripe fruit', 'buoyant', '', '', '', ''],
#  ['herb diesel rhubarb earth',
#   'pungent light_bodied hearty',
#   'fruit cranberry',
#   'piercing edgy tart',
#   '',
#   '',
#   'bark',
#   'rustic'],
#  ['oak', 'light_bodied', 'cranberry juicy', 'tart', '', '', '', ''],
#  ['earth leafy herb',
#   '',
#   'cherry fruit berry ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin'],
#  ['', '', 'cranberry', 'tart sharp', '', '', '', 'tight polished'],
#  ['dense dark metal', 'warm', 'fruit', '', '', 'spice', 'butter', 'closed'],
#  ['dark coffee smoke', 'thick', 'juicy', '', '', '', 'black_tea', 'gritty'],
#  ['new_wood coffee', 'light_bodied', 'fruit', '', '', '', '', 'muscular'],
#  ['powerful coffee olive', 'hot', 'cherry', '', '', 'licorice', '', 'smooth'],
#  ['', '', 'berry fruit caramel', '', '', 'spice cola', 'depth', ''],
#  ['concentrated',
#   'rich',
#   'berry cherry pie',
#   '',
#   '',
#   'spice',
#   'depth',
#   'round'],
#  ['rhubarb dark length',
#   '',
#   'fruit cherry chocolate',
#   'tart',
#   '',
#   'cola',
#   'complex',
#   ''],
#  ['rhubarb',
#   'light_bodied',
#   'chocolate strawberry fruit',
#   'fresh',
#   '',
#   'pepper',
#   '',
#   'smooth'],
#  ['medicinal', '', 'bramble strawberry fruit', '', '', 'cinnamon', '', ''],
#  ['mint dust oak oak',
#   '',
#   'cherry pie cherry berry fruit cocoa',
#   'tart',
#   '',
#   'spice spice',
#   '',
#   ''],
#  ['earth herb', '', 'fruit ripe cherry', 'bright', '', 'spice', 'quaffer', ''],
#  ['coffee vanilla',
#   'hearty',
#   'ripe plum cherry fruit chocolate',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   'ripe fruit juicy cherry fruit',
#   '',
#   '',
#   '',
#   'butterscotch',
#   'round'],
#  ['white',
#   'light_bodied',
#   'orange pastry sweet',
#   'pop tart',
#   '',
#   '',
#   'sparkling',
#   ''],
#  ['tomato moist_earth leafy earth earth',
#   'pungent',
#   'fruit',
#   'assertive sharp',
#   '',
#   'pepper',
#   'complex',
#   ''],
#  ['watery diluted oak oak',
#   'light_bodied',
#   'ripe strawberry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood toast', '', 'ripe fruit', 'aggressive', '', '', '', 'bitter'],
#  ['oxidized oak coffee', '', 'caramel', '', '', '', '', 'soft'],
#  ['earth',
#   'light_bodied light_bodied',
#   'fruit cranberry',
#   'tart tingling',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['earth mineral', '', 'fruit berry', 'tart', '', '', '', 'bitter'],
#  ['rubber powerful', '', 'cherry candy', '', '', '', '', 'rough hard'],
#  ['rose',
#   'light_bodied',
#   'raspberry',
#   '',
#   '',
#   'dr_pepper cinnamon spice',
#   'depth',
#   ''],
#  ['oak coffee earth', 'hot', 'fruit cracker', '', '', '', '', ''],
#  ['', '', 'plum cherry', '', '', 'spice cola', '', 'soft supple smooth'],
#  ['herb earth herb oak',
#   '',
#   'bramble cranberry fruit',
#   '',
#   '',
#   'pepper',
#   '',
#   'chewi'],
#  ['sandalwood dark pine flower',
#   '',
#   'chocolate cherry chocolate',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['oak coffee toast', '', 'cherry', 'clean flat', '', 'cola', '', 'soft'],
#  ['pine',
#   '',
#   'chocolate cherry citrus',
#   '',
#   '',
#   'pepper',
#   'complex bark chalk',
#   'smooth supple polished'],
#  ['rose steel', '', 'chocolate berry fruit', 'tart', '', '', '', 'soft hard'],
#  ['', 'hearty', 'fig plum berry fruit chocolate', '', '', 'cinnamon', '', ''],
#  ['oak', '', 'juicy pineapple citrus', '', '', '', '', ''],
#  ['dark toast coffee coffee',
#   '',
#   'cranberry raspberry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'hard tight round'],
#  ['dark', '', 'fruit chocolate', 'fresh racy', '', 'spice', '', ''],
#  ['shine smoke sandalwood',
#   '',
#   'sweet candy fruit kirsch orange citrus',
#   'bright',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oak toast walnut', '', 'cherry fruit cherry', '', '', '', '', ''],
#  ['herb earth', '', 'citrus cherry cocoa', '', '', '', '', ''],
#  ['green', 'rich', 'strawberry fruit', 'fresh', '', '', '', 'bitter'],
#  ['vanilla', '', 'citrus fruit cherry', 'fresh clean', '', '', '', ''],
#  ['herb coffee truffle',
#   '',
#   'fruit',
#   'bite fresh',
#   '',
#   'licorice',
#   '',
#   'firm'],
#  ['oak herb powerful', '', 'cherry fruit', '', '', '', '', ''],
#  ['oak',
#   '',
#   'fruit fruit chocolate',
#   'bright',
#   '',
#   'spice',
#   'yeast complex',
#   'fleshy round'],
#  ['', '', 'sugar prune brown_sugar', '', '', '', 'finessed', ''],
#  ['', 'light_bodied light_bodied', 'cherry', 'fresh pop', '', '', 'depth', ''],
#  ['perfumed', 'lush', 'cherry dry cranberry', 'tart', '', '', '', 'soft'],
#  ['oak',
#   '',
#   'raspberry juicy fruit berry fruit',
#   'snappy lean edgy puckery',
#   '',
#   '',
#   'cedar',
#   ''],
#  ['minerality',
#   'opulent light_bodied',
#   'cherry',
#   'lean tart',
#   '',
#   'licorice',
#   'complex',
#   ''],
#  ['tarragon smoke lengthy dark herb',
#   '',
#   'ripe sweet cherry cherry',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['powerful',
#   'rich',
#   'cranberry pie cherry red_berry fruit',
#   'sour tart',
#   '',
#   '',
#   '',
#   'tight'],
#  ['oak coffee flower toast oak-driven herbacious',
#   '',
#   'caramel chocolate cherry',
#   'sour edgy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', '', 'cherry dry fruit', 'bright snappy crisp', '', '', '', ''],
#  ['dark purple flower oak toast vanilla wood vanilla oak',
#   'heavy rich',
#   'chocolate sweet',
#   '',
#   '',
#   '',
#   'depth',
#   ''],
#  ['dust', '', 'raspberry fruit fruit', '', '', 'cinnamon', '', 'sleek'],
#  ['leather', 'pungent full_bodied', 'berry', '', '', '', '', 'tight'],
#  ['smoke concentrated powerful', '', 'berry', '', '', '', '', 'rustic hard'],
#  ['oak oak toast oak coffee toast',
#   'chunky full_bodied',
#   'black_cherry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'round'],
#  ['oak', '', 'cherry fruit chocolate', '', '', '', '', 'smooth'],
#  ['', 'baked', 'strawberry raspberry cherry', '', '', 'spice', '', ''],
#  ['dense dark loamy concentrated loamy powerful',
#   'extracted extracted',
#   'fruit',
#   '',
#   '',
#   '',
#   'depth',
#   'closed tight'],
#  ['dull tire_rubber leather', '', '', 'flat', '', '', '', ''],
#  ['herb earth tire_rubber green tea',
#   '',
#   'plum cherry fruit',
#   '',
#   '',
#   'allspice cola',
#   'complex',
#   ''],
#  ['earth leather', '', 'fruit berry cherry', 'sour', '', '', '', 'tight'],
#  ['earth',
#   '',
#   'fruit ripe fruit stone_fruit chocolate',
#   '',
#   '',
#   '',
#   'depth complex',
#   'meaty'],
#  ['steel oak rubber tire_rubber plastic',
#   '',
#   'berry fruit',
#   '',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['green', '', 'fruit fruit juicy cherry', 'clean', '', '', '', ''],
#  ['neutral_oak oak concentrated length',
#   '',
#   'raspberry cherry fruit',
#   'fresh vibrant',
#   '',
#   '',
#   '',
#   ''],
#  ['pine oak vanilla toast', '', 'berry fruit', '', '', '', '', 'tight smooth'],
#  ['', '', 'raspberry cherry fruit juicy citrus_peel', '', '', '', 'depth', ''],
#  ['', '', 'fruit fruit', 'clean', '', '', '', ''],
#  ['oak powerful herb',
#   '',
#   'cherry berry chocolate sweet',
#   'fresh',
#   '',
#   'spice',
#   'depth',
#   ''],
#  ['powerful minerality',
#   'high_alcohol refined',
#   'fruity strawberry cherry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['potpourri herb mint tarragon',
#   '',
#   'berry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'tight'],
#  ['', 'elegant', 'raspberry cherry fruit', '', '', '', '', ''],
#  ['', '', 'cherry', '', '', 'spice cola', '', ''],
#  ['toast walnut oak',
#   'lush',
#   'sweet berry',
#   'tart fresh',
#   '',
#   '',
#   'butterscotch',
#   ''],
#  ['minerality earth minerality',
#   'lush',
#   'fruit fruit',
#   'tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['shine wood smoke',
#   '',
#   'fruit fig berry cherry',
#   '',
#   '',
#   'cola',
#   'cedar bacon complex',
#   ''],
#  ['',
#   'elegant',
#   'raspberry cherry orange molasses',
#   '',
#   '',
#   '',
#   'yeast',
#   'silky'],
#  ['flower rose coffee',
#   'pungent',
#   'sweet bramble berry fruit',
#   '',
#   'brine',
#   'spice spice',
#   'complex cedar',
#   ''],
#  ['',
#   '',
#   'fruit strawberry raspberry lemon',
#   'tart sharp',
#   '',
#   '',
#   '',
#   'tight smooth'],
#  ['toast oak',
#   'light_bodied',
#   'cranberry cherry fruit',
#   'fresh tart',
#   '',
#   '',
#   '',
#   ''],
#  ['sassafras',
#   'syrupy',
#   'cherry fruit ripe cranberry raspberry sweet',
#   'tangy',
#   '',
#   'cola',
#   '',
#   ''],
#  ['oak toast coconut concentrated length',
#   '',
#   'strawberry raspberry fruit',
#   'bright aggressive',
#   '',
#   'spice saffron',
#   '',
#   ''],
#  ['nut hazelnut', 'rich', 'raisin toffee dry', '', '', '', 'cream', ''],
#  ['', 'hearty', 'fig plum berry fruit chocolate', '', '', 'cinnamon', '', ''],
#  ['compost',
#   'elegant',
#   'cherry fruit',
#   'tart',
#   '',
#   'nutmeg',
#   'butter brilliant',
#   ''],
#  ['',
#   '',
#   'fruit pomegranate berry plum',
#   '',
#   '',
#   'pepper spice',
#   '',
#   'closed'],
#  ['violet herb earth', '', 'cherry', '', '', 'anise', '', 'soft silky'],
#  ['rose length',
#   'weight',
#   'strawberry berry dry',
#   'tart tangy',
#   '',
#   'white_pepper',
#   '',
#   ''],
#  ['coffee new_oak length',
#   'baked',
#   'plum cherry',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth'],
#  ['leafy herb',
#   'light_bodied light_bodied',
#   'raspberry fruit dry',
#   'clean',
#   '',
#   '',
#   '',
#   ''],
#  ['new_oak',
#   '',
#   'fruit cherry strawberry candy sweet cloying',
#   'bright',
#   '',
#   '',
#   '',
#   'polished'],
#  ['dark',
#   '',
#   'ripe cherry chocolate',
#   'aggressive',
#   '',
#   '',
#   'brown',
#   'firm tight chewi'],
#  ['tomato', '', 'fruit', '', '', '', '', 'firm'],
#  ['wet_rocks', '', 'raspberry pomegranate', '', '', '', '', 'sleek'],
#  ['minerality', '', 'fruit bramble fruit', '', '', '', 'complex', ''],
#  ['coffee', 'full_bodied', 'cherry chocolate', '', '', '', '', ''],
#  ['dark concentrated coffee',
#   '',
#   'ripe cherry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oak coffee maple',
#   'syrupy',
#   'raspberry cherry fruit fruit brown_sugar',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['oak undergrowth smoke earth',
#   'elegant low_alcohol light_bodied',
#   'bramble cherry cassis',
#   'clean',
#   '',
#   '',
#   '',
#   'silky'],
#  ['funky foxy leather',
#   '',
#   'plum cherry',
#   'sour edgy sour',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['stemmy', 'light_bodied', 'ripe fruit', '', '', '', '', ''],
#  ['',
#   'light_bodied',
#   'fruit cranberry raspberry cherry',
#   'tart clean',
#   '',
#   '',
#   'depth',
#   'closed'],
#  ['flower soapy', '', 'sweet fruit sweet', '', '', 'spice', 'brown', ''],
#  ['oak', 'elegant', 'cherry strawberry fruit', '', '', 'spice', '', ''],
#  ['funky funky', 'light_bodied', 'cherry fruit cherry', '', '', '', '', ''],
#  ['new_oak',
#   '',
#   'orange sweet cherry juicy',
#   'fresh',
#   '',
#   '',
#   'yeast',
#   'tight'],
#  ['mint oak toast',
#   'light_bodied',
#   'cranberry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['earth herb', '', 'bramble berry', '', '', '', '', 'tannin bitter'],
#  ['', '', 'raspberry fruit orange', 'tart bright tangy', '', '', '', ''],
#  ['',
#   '',
#   'fruit berry cherry fruit citrus orange rind',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated rhubarb oak lengthy',
#   'elegant',
#   'ripe fruit raspberry cranberry pie cherry',
#   'sharp',
#   '',
#   'spice nutmeg licorice',
#   'black_tea',
#   'sleek'],
#  ['concentrated lengthy earth leafy',
#   'rich chunky',
#   'ripe cherry fruit caramel',
#   'piercing',
#   '',
#   'cola pepper',
#   '',
#   'chewi soft'],
#  ['leafy smoke earth',
#   'elegant',
#   'fruit cherry raspberry plum',
#   '',
#   '',
#   'clove',
#   '',
#   'tight chewi'],
#  ['herb herb iron neutral_oak',
#   'low_alcohol low_alcohol',
#   'berry lemon citrus',
#   'tart fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['rose flower coffee', 'light_bodied', 'strawberry', 'fresh', '', '', '', ''],
#  ['steel tobacco', '', 'fruit fruit', '', '', '', '', 'tight firm'],
#  ['herb coffee oak neutral_oak',
#   'elegant',
#   'fruit cherry fruit',
#   'fresh tart',
#   '',
#   'pepper',
#   'finessed',
#   'smooth'],
#  ['concentrated dust sassafras',
#   '',
#   'cherry fruit cherry',
#   '',
#   '',
#   'cola cinnamon',
#   '',
#   ''],
#  ['watery', 'elegant', 'cherry chocolate', '', '', '', '', 'soft smooth'],
#  ['tomato moist_earth leafy earth earth',
#   'pungent',
#   'fruit',
#   'assertive sharp',
#   '',
#   'pepper',
#   'complex',
#   ''],
#  ['purple oak toast coconut',
#   'rich',
#   'fruit',
#   'bright fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oak smoke', '', 'fruit', 'aggressive', '', '', '', 'bitter bitter'],
#  ['coffee vanilla tea tobacco',
#   '',
#   'chocolate caramel',
#   '',
#   '',
#   '',
#   'complex',
#   'tight'],
#  ['herb',
#   'light_bodied',
#   'cherry pie blueberry',
#   '',
#   '',
#   '',
#   'butter',
#   'smooth'],
#  ['smoke dense dark dust',
#   'light_bodied',
#   'plum black_cherry fruit chocolate',
#   '',
#   '',
#   'cola',
#   'complex',
#   'chewi'],
#  ['oak smoke rhubarb',
#   'rich lush',
#   'fruit raspberry cherry orange',
#   'pop',
#   '',
#   'spice',
#   'complex',
#   ''],
#  ['', '', 'bone_dry fruit', 'sharp', '', 'spice', '', 'astringent tight'],
#  ['earth earth',
#   '',
#   'fruit cherry',
#   'edgy',
#   '',
#   'cola',
#   'bark',
#   'tannin rough smooth'],
#  ['oak dense coffee nut',
#   'lush',
#   'berry plum',
#   '',
#   '',
#   'spice',
#   'butter complex',
#   ''],
#  ['purple stone potpourri',
#   '',
#   'plum raspberry citrus',
#   'sour',
#   '',
#   '',
#   '',
#   ''],
#  ['dust',
#   'light_bodied',
#   'watermelon pomegranate fruit',
#   '',
#   '',
#   '',
#   'ash modest',
#   'gripping'],
#  ['herb loamy',
#   '',
#   'fruit blackberry raspberry',
#   'fresh clean',
#   '',
#   '',
#   'depth black_tea',
#   ''],
#  ['oak oak coffee dark',
#   '',
#   'ripe blackberry fruit chocolate',
#   '',
#   '',
#   'licorice',
#   '',
#   'round'],
#  ['oak',
#   '',
#   'ripe fruit chocolate caramel',
#   'zingy',
#   'saline',
#   'spice',
#   'blue complex',
#   ''],
#  ['oak dark',
#   'chunky light_bodied',
#   'berry fruit chocolate',
#   '',
#   '',
#   '',
#   '',
#   'plush'],
#  ['', '', 'cranberry cherry fruit', 'tart', '', '', '', 'tight'],
#  ['concentrated', '', 'juicy cranberry cherry fruit', '', '', '', '', ''],
#  ['oak',
#   'lush',
#   'fruit fruit strawberry cherry chocolate',
#   '',
#   '',
#   '',
#   '',
#   'soft smooth'],
#  ['wood toast coconut',
#   'lush low_alcohol',
#   'berry cherry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['herb',
#   'light_bodied baked',
#   'berry',
#   'tart',
#   '',
#   'spice',
#   'barnyard',
#   'firm smooth'],
#  ['pale herb',
#   'elegant refined pungent',
#   'fruit cranberry raspberry',
#   '',
#   '',
#   '',
#   'depth',
#   'supple'],
#  ['coffee', 'elegant', 'fruit ripe', 'edgy', '', '', '', 'soft satiny'],
#  ['flower',
#   '',
#   'fruit fruit strawberry cherry caramel orange',
#   '',
#   '',
#   'cola',
#   '',
#   ''],
#  ['', '', 'cherry sweet fruit', 'refreshing', '', 'cola', '', ''],
#  ['',
#   'light_bodied',
#   'fruit pomegranate berry chocolate',
#   'tart',
#   '',
#   '',
#   'low_complexity',
#   'silky'],
#  ['watery', 'light_bodied light_bodied', 'graham_cracker', '', '', '', '', ''],
#  ['smoke', '', 'fruit', 'tart', '', '', '', 'tight'],
#  ['coffee smoke wood oak',
#   'light_bodied',
#   'fruit fruit fruit raspberry plum cherry ripe apple sweet',
#   'bright',
#   '',
#   'cola spice',
#   '',
#   ''],
#  ['dense oak coffee coffee dark',
#   '',
#   'ripe raspberry chocolate',
#   '',
#   '',
#   'cinnamon',
#   'cedar',
#   ''],
#  ['concentrated',
#   'full_bodied',
#   'ripe strawberry peach fruit juicy',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'cranberry fruit dry', 'bright', '', '', '', 'bitter'],
#  ['vanilla coffee',
#   '',
#   'raspberry',
#   '',
#   '',
#   'licorice spice',
#   'depth complex low_complexity',
#   ''],
#  ['rose toast', '', 'ripe cherry', '', '', '', 'complex', ''],
#  ['earth herb', '', 'raspberry', '', '', 'cola', '', 'rustic smooth tight'],
#  ['flower lavender',
#   'elegant rich',
#   'cherry chocolate plum',
#   '',
#   '',
#   'clove anise',
#   '',
#   'chewi'],
#  ['earth game dark oak',
#   '',
#   'cherry cherry',
#   'bite',
#   '',
#   'spice spice',
#   'closed',
#   'supple firm'],
#  ['dark earth leather toast',
#   '',
#   'cherry cherry',
#   '',
#   '',
#   '',
#   'complex chalk',
#   'polished supple'],
#  ['tree_bark pine wood powerful',
#   'weight',
#   'ripe cherry',
#   '',
#   '',
#   '',
#   'complex',
#   'velvety'],
#  ['vanilla powerful', '', 'sweet cherry', '', '', '', '', 'polished smooth'],
#  ['dense french_oak forest_floor dark earth length',
#   'rich rich',
#   'cherry',
#   '',
#   '',
#   '',
#   '',
#   'tight'],
#  ['leather tarragon earth minerality',
#   '',
#   'ripe sweet cherry fruit sweet',
#   'crisp',
#   '',
#   '',
#   'complex',
#   'firm'],
#  ['earth oak', 'light_bodied', 'fruit', '', '', '', 'barnyard complex', ''],
#  ['dark', 'chunky baked', 'cranberry chocolate', 'bright', '', '', '', ''],
#  ['herb', 'elegant light_bodied', 'berry', '', '', '', '', ''],
#  ['', 'light_bodied', 'plum fruit', '', '', '', 'barnyard', 'smooth'],
#  ['coffee', '', 'cranberry raspberry fruit caramel', 'tart', '', '', '', ''],
#  ['coffee earth', '', 'cranberry fruit', 'sharp tangy', '', '', '', 'bitter'],
#  ['stemmy', '', 'fruit strawberry citrus', 'tart', '', '', '', 'gripping'],
#  ['oak',
#   '',
#   'cherry pomegranate fruit juicy fruit-forward',
#   'fresh',
#   '',
#   'cola',
#   '',
#   ''],
#  ['new_oak', '', 'cranberry fruit', 'sharp fresh', '', '', '', ''],
#  ['french_oak earth', '', 'fruit', 'sharp', '', 'spice', '', 'chewi'],
#  ['',
#   'light_bodied',
#   'cranberry raspberry fruit fruit',
#   'tart sharp',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dust length', '', 'fruit', 'sharp', '', 'licorice', '', ''],
#  ['earth oak toast', '', 'raspberry fruit', 'clean', '', 'cola', '', 'tight'],
#  ['',
#   'light_bodied',
#   'fruit chocolate bramble berry citrus',
#   '',
#   '',
#   'spice',
#   '',
#   'round'],
#  ['iron earth',
#   'light_bodied',
#   'cranberry pomegranate fruit',
#   'tart',
#   '',
#   '',
#   'complex',
#   ''],
#  ['', 'light_bodied', 'fruit watermelon berry citrus', 'sour', '', '', '', ''],
#  ['oak new_oak', '', 'berry strawberry raspberry fruit', '', '', '', '', ''],
#  ['', '', 'raspberry fruit fruit', 'bright clean', '', '', '', ''],
#  ['herb oak',
#   'light_bodied',
#   'ripe strawberry dry',
#   '',
#   '',
#   'white_pepper',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', ''],
#  ['oak tea herb leafy',
#   'light_bodied',
#   'cherry fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'cranberry fruit',
#   'tart high_acid clean',
#   '',
#   '',
#   'low_complexity complex',
#   ''],
#  ['new_oak steel dark earth iron', '', 'fruit', '', '', '', '', 'firm tight'],
#  ['toast toast',
#   'light_bodied',
#   'cherry',
#   'clean refreshing',
#   '',
#   'cola',
#   '',
#   ''],
#  ['concentrated',
#   '',
#   'cranberry raspberry',
#   'tart high_acid fresh',
#   '',
#   '',
#   'depth',
#   'tight gripping'],
#  ['concentrated dust sassafras',
#   '',
#   'cherry fruit cherry',
#   '',
#   '',
#   'cola cinnamon',
#   '',
#   ''],
#  ['earth leafy',
#   '',
#   'cherry fruit',
#   'clean',
#   '',
#   'cola',
#   'expansive complex',
#   ''],
#  ['vegetal herb rose',
#   'light_bodied',
#   'fruit citrus dry',
#   'clean',
#   '',
#   '',
#   '',
#   ''],
#  ['oak coffee', '', '', '', '', 'asian_spice', '', ''],
#  ['plastic',
#   'pungent medium_bodied',
#   'fruit-forward raspberry chocolate',
#   'zippy bright',
#   '',
#   'spice',
#   '',
#   'supple tight'],
#  ['', 'light_bodied', 'raspberry', 'tart', '', 'licorice', '', ''],
#  ['leafy green tea',
#   'light_bodied extracted',
#   'super_ripe',
#   '',
#   '',
#   '',
#   '',
#   'astringent'],
#  ['diluted earth herb', 'light_bodied', 'berry', 'tart edgy', '', '', '', ''],
#  ['herb leafy leafy herb earth',
#   'light_bodied',
#   'fruit plum berry',
#   'sharp aggressive',
#   '',
#   'spice',
#   '',
#   ''],
#  ['rose', '', 'apple cranberry fruit chocolate', '', '', 'spice', '', ''],
#  ['herb earth oak',
#   'light_bodied',
#   'cranberry fruit chocolate',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dust earth mushroom compost length',
#   '',
#   'cherry cherry chocolate cherry fruit dry',
#   '',
#   '',
#   'cola',
#   'complex',
#   ''],
#  ['wood coffee oak toast',
#   'lush',
#   'cherry marshmallow caramel',
#   'bright',
#   '',
#   '',
#   'butter',
#   ''],
#  ['rhubarb pine', '', 'citrus raspberry chocolate', 'tart', '', '', '', ''],
#  ['', '', 'cranberry cherry fruit', 'tart', '', 'spice', '', 'firm'],
#  ['herb',
#   'light_bodied elegant',
#   'fruit berry fruit',
#   '',
#   '',
#   'pepper spice',
#   '',
#   ''],
#  ['', '', 'raspberry cherry', 'edgy', '', '', '', ''],
#  ['concentrated earth',
#   '',
#   'strawberry cherry caramel chocolate',
#   '',
#   '',
#   'cola',
#   '',
#   ''],
#  ['rosewater',
#   'light_bodied weight',
#   'raspberry cherry strawberry fruit fruit',
#   '',
#   '',
#   '',
#   'complex',
#   ''],
#  ['pale toast concentrated',
#   'rich',
#   'raspberry cherry fruit',
#   '',
#   '',
#   '',
#   'finessed',
#   ''],
#  ['shine purple', '', 'ripe raspberry cherry', '', '', 'licorice', '', ''],
#  ['oak oak toast',
#   'light_bodied',
#   'fruit fruit citrus fruit chocolate',
#   'tart fresh',
#   '',
#   '',
#   '',
#   'smooth supple firm'],
#  ['rose stone', 'elegant', 'raspberry', '', '', '', 'complex finessed', ''],
#  ['oak toast',
#   '',
#   'fruit citrus plum berry juicy fruit',
#   'flat',
#   '',
#   '',
#   '',
#   'soft'],
#  ['leafy herb',
#   'light_bodied',
#   'fruit watermelon strawberry',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['stemmy herb oak', '', 'blueberry fruit', '', '', '', '', 'closed'],
#  ['green',
#   '',
#   'fruit cranberry raspberry cherry ripe',
#   'sour',
#   '',
#   '',
#   '',
#   'tight'],
#  ['coffee oak wood',
#   'lush hot',
#   'fruit caramel fruit cherry cassis',
#   '',
#   '',
#   '',
#   '',
#   'fleshy'],
#  ['herb rose sappy concentrated',
#   'elegant pungent',
#   'sticky berry raspberry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['oak concentrated', '', 'cherry fruit', 'tangy sharp', '', '', '', 'chewi'],
#  ['concentrated mint menthol',
#   'full_bodied',
#   'cherry candy fruit',
#   '',
#   '',
#   '',
#   'depth',
#   ''],
#  ['herb', 'medium_bodied', 'berry sweet ripe', 'fresh', '', '', '', 'smooth'],
#  ['rose length', '', 'sweet cherry citrus', 'tart', '', '', '', ''],
#  ['mint vanilla coffee oak',
#   '',
#   'black_cherry fruit',
#   '',
#   '',
#   'spice',
#   'cedar',
#   ''],
#  ['concentrated', '', 'raspberry fruit', '', '', '', '', 'hard tannin'],
#  ['',
#   'rich',
#   'fruit chocolate caramel citrus',
#   'tangy clean',
#   '',
#   '',
#   '',
#   'smooth soft'],
#  ['',
#   'lush',
#   'juicy fruit citrus rind raspberry blueberry fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'tight'],
#  ['new_oak oak',
#   'baked',
#   'fruit cookie dry cherry',
#   '',
#   '',
#   'spice gingerbread',
#   '',
#   ''],
#  ['herb oak sassafras',
#   'elegant',
#   'fruit berry plum bramble',
#   'snappy sharp',
#   '',
#   'spice clove cola',
#   '',
#   'supple'],
#  ['dark oak',
#   '',
#   'fruit ripe blackberry cherry fruit ripe',
#   'pickled',
#   '',
#   'spice',
#   'american_oak',
#   ''],
#  ['dense stemmy earth',
#   '',
#   'strawberry cherry chocolate',
#   'fresh',
#   '',
#   'cola',
#   '',
#   'gripping'],
#  ['rose flower minerality', '', 'strawberry sweet', '', '', '', '', ''],
#  ['', 'light_bodied thick', 'strawberry cherry candy', 'edgy', '', '', '', ''],
#  ['herb rhubarb',
#   'refined',
#   'fruit fruit raspberry citrus_peel',
#   'bright',
#   '',
#   'spice clove',
#   '',
#   'austere'],
#  ['toast', '', 'fruit berry cherry', 'bright', '', '', '', ''],
#  ['leafy rhubarb resin herb oil',
#   '',
#   'fruit cooked strawberry lemon',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['herb',
#   'light_bodied light_bodied',
#   'fruit raspberry',
#   'tart sharp',
#   '',
#   '',
#   '',
#   ''],
#  ['sassafras herb herb leafy oak length',
#   '',
#   'cherry fruit ripe',
#   'fresh',
#   '',
#   'cola pepper',
#   '',
#   ''],
#  ['oak purple earth green toast', '', 'fruit', '', '', '', '', ''],
#  ['shine coffee toast',
#   'warm',
# ...
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['rose vanilla',
#   'light_bodied',
#   'berry sweet chocolate',
#   '',
#   '',
#   'dr_pepper spice',
#   '',
#   ''],
#  ['oak coffee',
#   '',
#   'fruit chocolate',
#   '',
#   '',
#   'spice spice',
#   'depth burnt',
#   ''],
#  ['tomato resin herb', '', 'fruit ripe strawberry ripe', '', '', '', '', ''],
#  ['earth tomato vegetal herb',
#   '',
#   'fruit ripe',
#   'aggressive',
#   '',
#   '',
#   'modest',
#   'chewi'],
#  ['oak toast coconut concentrated length',
#   '',
#   'strawberry raspberry fruit',
#   'bright aggressive',
#   '',
#   'spice saffron',
#   '',
#   ''],
#  ['nut hazelnut', 'rich', 'raisin toffee dry', '', '', '', 'cream', ''],
#  ['', 'light_bodied', 'cherry brown_sugar', 'sour', '', '', 'clay', ''],
#  ['wood earth stemmy', '', 'ripe fruit', '', '', '', 'chalk', 'hard'],
#  ['oak oak stemmy leafy root', '', 'fruit', '', '', '', '', ''],
#  ['flower dust nut purple',
#   '',
#   'fruit cocoa fruit',
#   '',
#   '',
#   'spice',
#   'butter',
#   'silky'],
#  ['sandalwood dark', '', 'dry cherry cherry chocolate', '', '', '', '', ''],
#  ['soil rhubarb',
#   'light_bodied low_alcohol',
#   'raspberry',
#   '',
#   '',
#   'pepper',
#   'clay',
#   ''],
#  ['vanilla oak earth',
#   'full_bodied lush',
#   'fruit cherry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'round'],
#  ['leafy new_oak', '', 'fruit dry chocolate', 'tart', '', '', 'complex', ''],
#  ['minerality herb',
#   'light_bodied',
#   'cranberry raspberry fruit citrus',
#   'tart tangy',
#   '',
#   '',
#   '',
#   'tight'],
#  ['pink',
#   'light_bodied low_alcohol hot',
#   'strawberry juicy',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['smoke',
#   'hot',
#   'cherry fruit candy',
#   'bright',
#   '',
#   'spice pepper',
#   'burnt',
#   ''],
#  ['oak',
#   '',
#   'fruit strawberry stone_fruit',
#   '',
#   '',
#   'anise',
#   'butterscotch',
#   ''],
#  ['earth herb stemmy',
#   '',
#   'cranberry cherry',
#   'crisp',
#   '',
#   'spice',
#   'complex',
#   ''],
#  ['oak earth', 'hot', 'raspberry cherry fruit', '', '', '', '', ''],
#  ['tea',
#   'lush',
#   'fruit orange candy chocolate cherry',
#   '',
#   '',
#   'ginger',
#   '',
#   'smooth'],
#  ['', '', 'fruit sweet berry plum cherry', '', '', '', '', 'round'],
#  ['violet purple herb graphite',
#   'light_bodied',
#   'plum chocolate',
#   'assertive',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['rose toast oak',
#   'lush',
#   'strawberry fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'satiny hard'],
#  ['oak',
#   'lush',
#   'fruit fruit plum cherry caramel',
#   'bright',
#   '',
#   'cola cinnamon spice',
#   '',
#   'closed'],
#  ['herb meditteranean_herbs olive',
#   '',
#   'cranberry fruit',
#   'edgy tangy tart',
#   '',
#   '',
#   '',
#   ''],
#  ['oak coffee',
#   '',
#   'blueberry cherry fruit fruit-forward',
#   '',
#   '',
#   'cola',
#   'cream',
#   ''],
#  ['',
#   'chunky light_bodied',
#   'cherry fruit orange',
#   'crisp',
#   '',
#   'cinnamon',
#   'finessed',
#   ''],
#  ['oak oak',
#   '',
#   'bramble berry cherry cocoa',
#   '',
#   '',
#   'cola licorice',
#   '',
#   ''],
#  ['smoke toast',
#   '',
#   'raspberry fruit chocolate',
#   'fresh',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['coffee', '', 'strawberry', 'fresh', '', 'cola', 'quaffer', ''],
#  ['steel herb rhubarb', '', 'berry', 'tart', '', 'anise', 'beetroot', 'tight'],
#  ['',
#   '',
#   'ripe black_cherry fruit fruit juicy',
#   'tangy snappy',
#   '',
#   '',
#   '',
#   ''],
#  ['smoke',
#   'light_bodied light_bodied',
#   'cherry fruit',
#   'tart sour',
#   '',
#   '',
#   'bell_pepper',
#   ''],
#  ['pine resin root wax', 'elegant', '', '', '', '', 'beet', 'tight'],
#  ['', 'baked', 'sweet cherry fruit', '', '', 'spice', '', ''],
#  ['compost earth',
#   '',
#   'cranberry raspberry fruit',
#   'sharp',
#   '',
#   'cola',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'strawberry raspberry caramel',
#   'clean',
#   '',
#   '',
#   '',
#   'soft smooth'],
#  ['minerality diluted watery',
#   'medium_bodied',
#   'fruit cracker',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['herb', 'medium_bodied', 'berry sweet ripe', 'fresh', '', '', '', 'smooth'],
#  ['concentrated minerality oak',
#   '',
#   'berry chocolate',
#   'refreshing',
#   '',
#   'pepper',
#   'yeast',
#   'finegrained_tannin'],
#  ['earth', '', 'raspberry cherry fruit', 'tart', '', '', '', ''],
#  ['',
#   'baked hot',
#   'ripe cake plum pastry ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['coffee', '', 'strawberry', 'fresh', '', 'cola', 'quaffer', ''],
#  ['herb earth leather',
#   'light_bodied',
#   'citrus cherry fruit',
#   'tart',
#   '',
#   '',
#   '',
#   'soft rustic'],
#  ['purple herb',
#   '',
#   'fruit berry fruit fruit',
#   'crisp tart fresh',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['new_oak',
#   'light_bodied',
#   'cherry fruit apple',
#   'tart',
#   '',
#   '',
#   'complicated',
#   ''],
#  ['steel',
#   'light_bodied',
#   'pomegranate raspberry',
#   'tart tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['powerful concentrated', '', 'cherry fruit', '', '', '', '', ''],
#  ['iron coffee', '', 'berry fruit', 'fresh', '', '', '', 'firm polished'],
#  ['oak lavender tobacco',
#   '',
#   'blueberry citrus',
#   '',
#   '',
#   'spice nutmeg anise ginger',
#   'complex',
#   'firm'],
#  ['dark pine', '', 'fruit chocolate', '', '', 'spice', '', ''],
#  ['rose flower flower', 'elegant', 'fruit cherry', '', '', '', '', ''],
#  ['oak toast', '', 'fruit cranberry raspberry', 'crisp', '', '', '', ''],
#  ['oak new_oak root stemmy earth green',
#   '',
#   'ripe fruit',
#   '',
#   '',
#   'cola',
#   'beet',
#   ''],
#  ['earth coffee',
#   'warm',
#   'citrus black_cherry fruit',
#   'tart',
#   '',
#   'cola',
#   '',
#   ''],
#  ['', '', 'fruit-forward cherry fruit', 'fresh', '', '', '', ''],
#  ['length', 'chunky', 'fruit plum cherry', 'sour', '', '', '', ''],
#  ['sassafras herb dust earth',
#   'light_bodied',
#   'berry cherry',
#   'sharp tangy assertive fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'fruit cherry cocoa', '', '', 'cola', '', ''],
#  ['rhubarb pine', '', 'ripe fruit', 'tart fresh', '', 'spice', '', ''],
#  ['flower herb concentrated',
#   'elegant sturdy',
#   'raspberry cherry candy fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['toast', 'light_bodied', 'cherry fruit', '', '', '', 'butter', 'soft'],
#  ['flower rosewater',
#   'elegant',
#   'orange cherry',
#   'clean refreshing',
#   '',
#   'spice',
#   '',
#   ''],
#  ['shine toast coconut vanilla', 'full_bodied', '', '', '', '', '', ''],
#  ['white grass white',
#   '',
#   'sweet pear stone_fruit',
#   'fresh',
#   '',
#   '',
#   'modest',
#   ''],
#  ['',
#   'light_bodied light_bodied',
#   'red_currant raspberry juicy fruit',
#   'clean',
#   '',
#   'spice',
#   '',
#   ''],
#  ['',
#   'light_bodied light_bodied',
#   'cherry fruit chocolate',
#   'tart bright',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   'fruit strawberry raspberry lemon',
#   'tart sharp',
#   '',
#   '',
#   '',
#   'tight smooth'],
#  ['length powerful',
#   '',
#   'sweet raspberry fruit orange',
#   '',
#   '',
#   'spice clove',
#   'almond',
#   ''],
#  ['leafy herb oak oak',
#   '',
#   'fruit sweet',
#   'flat',
#   '',
#   '',
#   '',
#   'smooth supple'],
#  ['rhubarb herb',
#   'full_bodied light_bodied',
#   'fruit cranberry dry',
#   '',
#   '',
#   'pepper',
#   'clay',
#   ''],
#  ['white', '', '', '', '', '', '', ''],
#  ['mushroom oak toast',
#   'baked',
#   'berry plum',
#   '',
#   '',
#   'black_pepper spice',
#   '',
#   'polished'],
#  ['powerful', '', 'bramble berry', '', '', '', '', 'smooth'],
#  ['root sassafras', '', 'brown_sugar fruit', 'clean', '', '', 'beet', 'round'],
#  ['powerful earth green',
#   'light_bodied light_bodied',
#   'strawberry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'ripe cherry chocolate fruit cranberry cocoa', '', '', '', '', ''],
#  ['tire_rubber menthol oak wood',
#   'chunky',
#   'grapey chocolate orange plum sweet',
#   '',
#   '',
#   'cola',
#   '',
#   ''],
#  ['tree_bark',
#   'refined light_bodied',
#   'cherry cranberry chocolate',
#   '',
#   '',
#   '',
#   '',
#   'silky bitter'],
#  ['perfumed flower violet',
#   '',
#   'fruit cherry fruit graham_cracker raspberry fruit',
#   'sharp tart',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['toast menthol new_oak wood',
#   '',
#   'black_cherry juicy cranberry fruit',
#   '',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['shine',
#   'pungent light_bodied',
#   'fruit citrus raspberry',
#   'piercing tart',
#   '',
#   '',
#   '',
#   'tight hard astringent'],
#  ['', 'sturdy', 'fruit', '', '', '', 'closed', 'closed gripping'],
#  ['oak vanilla oak',
#   'chunky',
#   'fruit dry',
#   'fresh',
#   '',
#   '',
#   'depth complex',
#   ''],
#  ['minerality oak',
#   'light_bodied refined elegant',
#   'raspberry cherry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'elegant sturdy baked',
#   'red_currant fruit orange',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['truffle dark',
#   'lush',
#   'fruit ripe strawberry blackberry cherry fruit chocolate',
#   '',
#   '',
#   'licorice',
#   '',
#   ''],
#  ['', '', 'caramel', 'clean', '', '', '', ''],
#  ['concentrated smoke',
#   '',
#   'ripe cherry fruit',
#   'clean',
#   '',
#   '',
#   'complex',
#   'hard tight tannin'],
#  ['restrained sandalwood coffee oak',
#   'elegant',
#   'cherry fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   'soft round'],
#  ['dense iron dark dense',
#   'baked',
#   'cherry chocolate',
#   '',
#   '',
#   'cola spice',
#   '',
#   ''],
#  ['concentrated length',
#   'full_bodied elegant',
#   'fruit cherry fruit chocolate',
#   '',
#   '',
#   'cola',
#   'depth',
#   ''],
#  ['dark coffee wood powerful',
#   '',
#   'fruit cherry fruit',
#   '',
#   '',
#   'licorice',
#   '',
#   ''],
#  ['',
#   'chunky',
#   'ripe strawberry cherry fruit chocolate',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['pale dust toast incense',
#   'elegant light_bodied',
#   'cranberry strawberry fruit caramel',
#   '',
#   '',
#   '',
#   'depth complex',
#   ''],
#  ['sassafras',
#   'light_bodied',
#   'strawberry',
#   '',
#   '',
#   '',
#   '',
#   'gripping_tannin'],
#  ['', '', '', 'tart tart', '', '', '', ''],
#  ['concentrated',
#   'light_bodied light_bodied',
#   'cherry fruit',
#   'tart',
#   '',
#   'spice',
#   '',
#   'tight'],
#  ['coffee',
#   'light_bodied',
#   'raspberry fruit citrus caramel',
#   'tangy',
#   '',
#   '',
#   'modest',
#   ''],
#  ['tobacco', '', 'dry cherry cherry', '', '', '', '', 'chewi'],
#  ['oak earth length',
#   '',
#   'berry cherry fruit chocolate ripe',
#   '',
#   '',
#   '',
#   'complex',
#   ''],
#  ['oak smoke',
#   'elegant',
#   'ripe fruit',
#   '',
#   '',
#   'brown_spice',
#   'cedar',
#   'tight silky'],
#  ['wax sappy', 'thick', '', 'bright', '', '', '', ''],
#  ['pale', 'light_bodied', 'cherry fruit', 'tart sour fresh', '', '', '', ''],
#  ['umami oak coffee',
#   '',
#   'ripe blackberry cherry fruit',
#   '',
#   '',
#   'nutmeg',
#   'depth',
#   ''],
#  ['herb toast',
#   'light_bodied',
#   'bramble berry fruit fruit citrus',
#   'tart tangy',
#   '',
#   'black_pepper',
#   '',
#   ''],
#  ['concentrated',
#   'chunky chunky',
#   'raspberry cherry fruit dry',
#   '',
#   '',
#   '',
#   'chalk',
#   ''],
#  ['earth tomato oak', 'light_bodied', 'cherry fruit', '', '', 'cola', '', ''],
#  ['shine herb',
#   'elegant light_bodied',
#   'blackberry fruit ripe fruit',
#   '',
#   '',
#   'spice',
#   'complex',
#   ''],
#  ['incense toast nut',
#   'refined baked elegant hot',
#   'fruit fruit',
#   '',
#   '',
#   'spice',
#   'complex',
#   ''],
#  ['truffle earth dust minerality',
#   '',
#   'pomegranate raspberry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['oak restrained', '', 'fruit orange plum raisin', '', '', '', '', 'firm'],
#  ['oak french_oak',
#   'light_bodied',
#   'strawberry cherry fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['oak concentrated', '', 'fruit strawberry fruit', '', '', '', '', ''],
#  ['herb',
#   '',
#   'fruit bramble berry cranberry fruit',
#   'tart',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['perfumed rosewater',
#   '',
#   'raspberry fruit chocolate',
#   'crisp',
#   '',
#   '',
#   '',
#   'tight hard'],
#  ['smoke toast',
#   '',
#   'sweet cherry fruit',
#   'crisp',
#   '',
#   'anise',
#   'ash almond',
#   'smooth polished'],
#  ['sassafras smoke tar',
#   'weight',
#   'brown_sugar molasses cherry',
#   '',
#   '',
#   'cola dr_pepper licorice',
#   '',
#   ''],
#  ['',
#   'light_bodied weight',
#   'ripe raisin prune ripe ripe fruit',
#   '',
#   '',
#   '',
#   'depth burnt',
#   'hard'],
#  ['stemmy restrained',
#   'baked',
#   'raspberry cherry',
#   'bright',
#   '',
#   'spice',
#   '',
#   ''],
#  ['earth',
#   'light_bodied',
#   'fruit plum chocolate',
#   '',
#   '',
#   '',
#   '',
#   'hard chewi tannin tight'],
#  ['leather',
#   '',
#   'dry fruit cherry fruit candy orange',
#   '',
#   '',
#   '',
#   '',
#   'polished'],
#  ['oak oak concentrated minerality steel',
#   '',
#   'fruit blackberry cherry',
#   '',
#   '',
#   '',
#   'complex',
#   ''],
#  ['pencil_lead wax powerful',
#   'full_bodied',
#   'plum cherry red_currant fruit bramble ripe',
#   'clean',
#   '',
#   '',
#   '',
#   ''],
#  ['dark lengthy',
#   '',
#   'blackberry cherry fruit soy',
#   '',
#   '',
#   'asian_spice',
#   'complex',
#   ''],
#  ['rhubarb pine', '', 'citrus raspberry chocolate', 'tart', '', '', '', ''],
#  ['rhubarb dust toast walnut',
#   'light_bodied',
#   'fruit pomegranate',
#   '',
#   '',
#   'brown_spice',
#   'complex',
#   ''],
#  ['',
#   'light_bodied',
#   'juicy raspberry fruit',
#   'tart crisp',
#   '',
#   '',
#   'finessed american_oak',
#   ''],
#  ['',
#   'rich',
#   'raspberry cherry fruit',
#   '',
#   '',
#   'licorice',
#   'complex depth',
#   ''],
#  ['dark new_oak', '', 'fruit raspberry plum chocolate', '', '', '', '', ''],
#  ['dust rose dust coffee',
#   'baked',
#   'fruit cocoa berry',
#   'tart',
#   '',
#   'spice',
#   '',
#   ''],
#  ['herb', '', 'cranberry fruit', 'sharp tart', '', '', '', 'bitter'],
#  ['concentrated dust',
#   '',
#   'bramble berry cherry plum chocolate',
#   '',
#   '',
#   'cinnamon',
#   'blue',
#   ''],
#  ['toast oak', '', 'black_cherry fruit', '', '', 'spice', '', 'supple silky'],
#  ['dust',
#   'plump',
#   'ripe cherry fruit cocoa',
#   '',
#   '',
#   '',
#   '',
#   'finegrained_tannin'],
#  ['oak', '', 'cranberry citrus chocolate', '', '', '', '', ''],
#  ['stemmy', '', 'cranberry cherry juicy citrus', '', '', 'spice', '', 'firm'],
#  ['', '', 'juicy fruit raspberry cherry orange', '', '', '', '', ''],
#  ['concentrated',
#   '',
#   'sweet fruit fruit jam',
#   'crisp',
#   '',
#   'spice',
#   '',
#   'tight firm'],
#  ['oak',
#   'rich extracted',
#   'black_cherry fruit fruit',
#   'fresh',
#   '',
#   'spice',
#   'cream',
#   'hard'],
#  ['flower rose oak coffee walnut',
#   'elegant',
#   'plum strawberry raspberry fruit cocoa',
#   '',
#   '',
#   'spice',
#   'complex',
#   'firm'],
#  ['wood smoke',
#   '',
#   'cherry',
#   '',
#   '',
#   '',
#   'complex cedar bacon',
#   'tannin hard'],
#  ['leafy tobacco earth compost',
#   'light_bodied',
#   'fruit berry cherry plum fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['herb',
#   'refined',
#   'sweet fruit fruit sweet',
#   'pop tangy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['herb',
#   'elegant',
#   'fruit strawberry cherry dry chocolate',
#   'sour',
#   '',
#   '',
#   'complex',
#   ''],
#  ['',
#   '',
#   'fruit berry cherry fruit citrus orange rind',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'cherry fruit', 'tart', '', 'spice', '', ''],
#  ['new_oak watery', 'light_bodied', 'fruit', '', '', '', '', ''],
#  ['flower oak-driven leather smoke',
#   'pungent',
#   'bramble caramel red_fruit',
#   'piercing',
#   '',
#   '',
#   'complex',
#   ''],
#  ['',
#   'light_bodied weight thick',
#   'fruit apple strawberry',
#   '',
#   '',
#   'spice',
#   'sparkling',
#   'soft'],
#  ['powerful dark dark coffee graphite',
#   'hot',
#   'dry fruit chocolate',
#   'aggressive',
#   '',
#   '',
#   '',
#   ''],
#  ['watery wood herb',
#   'light_bodied',
#   'cherry fruit',
#   '',
#   '',
#   'cinnamon spice',
#   '',
#   ''],
#  ['rhubarb herb',
#   'full_bodied light_bodied',
#   'fruit cranberry dry',
#   '',
#   '',
#   'pepper',
#   'clay',
#   ''],
#  ['flower coffee herb',
#   '',
#   'chocolate cranberry fruit-forward',
#   'tart',
#   '',
#   '',
#   'bark',
#   ''],
#  ['rhubarb length',
#   'light_bodied',
#   'fruit raspberry',
#   '',
#   '',
#   '',
#   'yeast',
#   ''],
#  ['', 'light_bodied', '', '', '', '', '', ''],
#  ['vanilla',
#   'full_bodied',
#   'fruit cherry',
#   '',
#   '',
#   'spice',
#   '',
#   'hard bitter'],
#  ['toast',
#   'light_bodied',
#   'blueberry cherry pie',
#   '',
#   '',
#   '',
#   'butter cream',
#   'soft'],
#  ['flower toast', '', 'orange cherry cracker', '', '', '', '', ''],
#  ['rhubarb herb', 'light_bodied', 'apple fruit', 'tart fresh', '', '', '', ''],
#  ['rose perfumed flower rhubarb flower',
#   'lush elegant',
#   'cherry ripe strawberry cherry',
#   '',
#   '',
#   'ginger',
#   '',
#   ''],
#  ['length', '', 'ripe raspberry cherry fruit orange', 'fresh', '', '', '', ''],
#  ['toast coffee',
#   'light_bodied',
#   'fruit strawberry',
#   '',
#   '',
#   '',
#   'cream',
#   'round'],
#  ['coffee truffle',
#   '',
#   'black_cherry fruit chocolate',
#   'sharp',
#   '',
#   '',
#   '',
#   'closed'],
#  ['',
#   '',
#   'fruit-forward strawberry raspberry cherry fruit',
#   'bright',
#   '',
#   'cola spice',
#   '',
#   'supple'],
#  ...]

# %%
taste_descriptors = []
taste_vectors = []

for n, taste in enumerate(core_tastes):
    print(taste)
    taste_words = [r[n] for r in review_descriptors]
    
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit(taste_words)
    dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))
        
    wine_review_descriptors = []
    wine_review_vectors = []
    
    for d in taste_words:
        descriptor_count = 0
        weighted_review_terms = []
        terms = d.split(' ')
        for term in terms:
            if term in dict_of_tfidf_weightings.keys():
                tfidf_weighting = dict_of_tfidf_weightings[term]
                try:
                    word_vector = wine_word2vec_model.wv.get_vector(term).reshape(1, 300)
                    weighted_word_vector = tfidf_weighting * word_vector
                    weighted_review_terms.append(weighted_word_vector)
                    descriptor_count += 1
                except:
                    continue
            else:
                continue
        try:
            review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
            review_vector = review_vector[0]
        except:
            review_vector = np.nan
#         terms_and_vec = [terms, review_vector]
        wine_review_vectors.append(review_vector)
        wine_review_descriptors.append(terms)
    
    taste_vectors.append(wine_review_vectors)
    taste_descriptors.append(wine_review_descriptors)
    

taste_vectors_t = list(map(list, zip(*taste_vectors)))
taste_descriptors_t = list(map(list, zip(*taste_descriptors)))

review_vecs_df = pd.DataFrame(taste_vectors_t, columns=core_tastes)

columns_taste_descriptors = [a + '_descriptors' for a in core_tastes]
review_descriptors_df = pd.DataFrame(taste_descriptors_t, columns=columns_taste_descriptors)

wine_df_vecs = pd.concat([wine_df_merged, review_descriptors_df, review_vecs_df], axis=1)
wine_df_vecs.shape
# Out:
# aroma
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
# (4157, 30)

# %%
wine_df_vecs['geo_normalized']
# Out:
# 0       Willamette Valley, Oregon, USA
# 1       Willamette Valley, Oregon, USA
# 2       Willamette Valley, Oregon, USA
# 3       Willamette Valley, Oregon, USA
# 4       Willamette Valley, Oregon, USA
#                      ...
# 4152      Southern Oregon, Oregon, USA
# 4153      South Coast, California, USA
# 4154                               NaN
# 4155                               NaN
# 4156                               NaN
# Name: geo_normalized, Length: 4157, dtype: object

# %%
# pull the average embedding for the wine attribute across all wines. 
avg_taste_vecs = dict()
for t in core_tastes:
    # look at the average embedding for a taste, across all wines that have descriptors for that taste 
    review_arrays = wine_df_vecs[t].dropna()
    average_taste_vec = np.average(review_arrays)
    avg_taste_vecs[t] = average_taste_vec

# %%
normalized_geos = list(set(zip(wine_df_vecs['variety'], wine_df_vecs['geo_normalized'])))

def subset_wine_vectors(list_of_varieties, wine_attribute):
    wine_variety_vectors = []
    for v in list_of_varieties:

        one_var_only = wine_df_vecs.loc[(wine_df_vecs['Variety'] == v[0]) & 
                                                (wine_df_vecs['geo_normalized'] == v[1])]
        if len(list(one_var_only.index)) < 1 or str(v[1][-1]) == '0':
            continue
        else:
            taste_vecs = list(one_var_only[wine_attribute])
            taste_vecs = [avg_taste_vecs[wine_attribute] if 'numpy' not in str(type(x)) else x for x in taste_vecs]
            average_variety_vec = np.average(taste_vecs, axis=0)
            
            descriptor_colname = wine_attribute + '_descriptors'
            all_descriptors = [i[0] for i in list(one_var_only[descriptor_colname])]
            word_freqs = Counter(all_descriptors)
            most_common_words = word_freqs.most_common(50)
            top_n_words = [(i[0], "{:.2f}".format(i[1]/len(taste_vecs))) for i in most_common_words]
            top_n_words = [i for i in top_n_words if len(i[0])>2]
            wine_variety_vector = [v, average_variety_vec, top_n_words]
                
            wine_variety_vectors.append(wine_variety_vector)
            
    return wine_variety_vectors


def pca_wine_variety(list_of_varieties, wine_attribute, pca=True):
    wine_var_vectors = subset_wine_vectors(normalized_geos, wine_attribute)
    
    wine_varieties = [str(w[0]).replace('(', '').replace(')', '').replace("'", '').replace('"', '') for w in wine_var_vectors]
    wine_var_vec = [w[1] for w in wine_var_vectors]
    if pca:
        pca = PCA(1)
        wine_var_vec = pca.fit_transform(wine_var_vec)
        wine_var_vec = pd.DataFrame(wine_var_vec, index=wine_varieties)
    else:
        wine_var_vec = pd.Series(wine_var_vec, index=wine_varieties)
    wine_var_vec.sort_index(inplace=True)
    
    wine_descriptors = pd.DataFrame([w[2] for w in wine_var_vectors], index=wine_varieties)
    wine_descriptors = pd.melt(wine_descriptors.reset_index(), id_vars='index')
    wine_descriptors.sort_index(inplace=True)
    
    return wine_var_vec, wine_descriptors

taste_dataframes = []
# generate the dataframe of aromas vectors as output, 
aroma_vec, aroma_descriptors = pca_wine_variety(normalized_geos, 'aroma', pca=False)
taste_dataframes.append(aroma_vec)

# generate the dataframes of nonaroma scalars
for tw in core_tastes[1:]:
    pca_w_dataframe, nonaroma_descriptors = pca_wine_variety(normalized_geos, tw, pca=True)
    taste_dataframes.append(pca_w_dataframe)
    
# combine all the dataframes created above into one 
all_nonaromas = pd.concat(taste_dataframes, axis=1)
all_nonaromas.columns = core_tastes

# %%
taste_dataframes[2]
# Out:
#                                                             0
# Bordeaux-style Red Blend, Finger Lakes, New Yor... -16.163464
# Bordeaux-style Red Blend, Long Island, New York... -18.712917
# Bordeaux-style Red Blend, Sierra Foothills, Cal...  -7.328948
# Bordeaux-style Red Blend, South Coast, Californ... -28.132281
# Cabernet Franc, Finger Lakes, New York, USA        -14.533364
# ...                                                       ...
# White Blend, Sierra Foothills, California, USA      17.146842
# White Blend, Southern Oregon, Oregon, USA           17.980643
# White Blend, Willamette Valley, Oregon, USA         12.483386
# Zinfandel, Sierra Foothills, California, USA       -13.964235
# Zinfandel, South Coast, California, USA            -26.741860
#
# [68 rows x 1 columns]

# %%
# save the 50 top descriptors for each wine variety as a CSV file. We will us this later to dig deeper into our proposed wine recommendations.

aroma_descriptors_copy = aroma_descriptors.copy()
aroma_descriptors_copy.set_index('index', inplace=True)
aroma_descriptors_copy.dropna(inplace=True)

aroma_descriptors_copy = pd.DataFrame(aroma_descriptors_copy['value'].tolist(), index=aroma_descriptors_copy.index)
aroma_descriptors_copy.columns = ['descriptors', 'relative_frequency']
aroma_descriptors_copy.to_csv('wine_variety_descriptors.csv')

# %%
def normalize(df, cols_to_normalize):
    for feature_name in cols_to_normalize:
        print(feature_name)
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        df[feature_name] = df[feature_name].apply(lambda x: (x- min_value)/(max_value-min_value))
#         (df[feature_name] - min_value) / (max_value - min_value)
    return df

all_nonaromas_normalized = normalize(all_nonaromas, cols_to_normalize=core_tastes[1:])
all_nonaromas_normalized.to_csv('wine_aromas_nonaromas.csv')
# Out:
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
