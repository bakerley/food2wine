# %%
import os
import pandas as pd
import numpy as np
import string
from operator import itemgetter
from collections import Counter, OrderedDict

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %%
wine = pd.read_csv('../raw_data/winemag-data-130k-v2.csv')
wine_list = list(wine['description'])
#wine_list_normalized = [clean_description(w) for w in wine_list]
#wine_list_preprocessed = list(set(wine_list_normalized))

# %%
full_wine_reviews_list = [str(r) for r in wine_list]
full_wine_corpus = ' '.join(wine_list)
wine_sentences_tokenized = sent_tokenize(full_wine_corpus)

# %%
stop_words = set(stopwords.words('english')) 

punctuation_table = str.maketrans({key: None for key in string.punctuation})
sno = SnowballStemmer('english')

def normalize_text(raw_text):
    try:
        word_list = word_tokenize(raw_text)
        normalized_sentence = []
        for w in word_list:
            try:
                w = str(w)
                lower_case_word = str.lower(w)
                stemmed_word = sno.stem(lower_case_word)
                no_punctuation = stemmed_word.translate(punctuation_table)
                if len(no_punctuation) > 1 and no_punctuation not in stop_words:
                    normalized_sentence.append(no_punctuation)
            except:
                continue
        return normalized_sentence
    except:
        return ''

# normalized_sentences = []
# for s in sentences_tokenized:
#     normalized_text = normalize_text(s)
#     normalized_sentences.append(normalized_text)

normalized_wine_sentences = []
for s in wine_sentences_tokenized:
    normalized_text = normalize_text(s)
    normalized_wine_sentences.append(normalized_text)

# %%
import pickle

# %%
with open("../raw_data/g_wine_preprocessing.txt", "rb") as fp:   # Unpickling
    wine_sentences = pickle.load(fp)

# %%
wine_word2vec_model = Word2Vec.load("../raw_data/food_word2vec_model.bin")

# %%
descriptor_mapping = pd.read_csv('../raw_data/descriptor_mapping.csv',delimiter=';', encoding='latin1').set_index('raw descriptor')

# %%
descriptor_mapping
# Out:
#                     level_3       level_2 level_1    type
# raw descriptor
# abras              abrasive   high_tannin  tannin  bitter
# acacia               acacia       flowery  flower     fat
# acacia_flower        acacia       flowery  flower     fat
# aciddriven      acid_driven     high_acid    acid    acid
# aggress          aggressive     high_acid    acid    acid
# ...                     ...           ...     ...     ...
# zest                   zest  citrus_fruit   fruit   sweet
# zesti                 zesty     high_acid    acid    acid
# zing                  zingy     high_acid    acid    acid
# zingi                 zingy     high_acid    acid    acid
# zippi                 zippy     high_acid    acid    acid
#
# [1015 rows x 4 columns]

# %%
wine_trigram_model = Phraser.load('../raw_data/wine_trigrams.pkl')

# %%
variety_mapping = {'Shiraz': 'Syrah', 'Pinot Gris': 'Pinot Grigio', 'Pinot Grigio/Gris': 'Pinot Grigio', 
                   'Garnacha, Grenache': 'Grenache', 'Garnacha': 'Grenache', 'CarmenÃ¨re': 'Carmenere',
                    'GrÃ¼ner Veltliner': 'Gruner Veltliner', 'TorrontÃ©s': 'Torrontes', 
                   'RhÃ´ne-style Red Blend': 'Rhone-style Red Blend', 'AlbariÃ±o': 'Albarino',
                  'GewÃ¼rztraminer': 'Gewurztraminer', 'RhÃ´ne-style White Blend': 'Rhone-style White Blend',
                  'SpÃƒÂ¤tburgunder, Pinot Noir': 'Pinot Noir', 'Sauvignon, Sauvignon Blanc': 'Sauvignon Blanc',
                  'Pinot Nero, Pinot Noir': 'Pinot Noir', 'Malbec-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                  'Meritage, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Garnacha, Grenache': 'Grenache',
                   'FumÃ© Blanc': 'Sauvignon Blanc', 'Cabernet Sauvignon-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Cabernet Sauvignon-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Blend, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Malbec-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Merlot-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Franc-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Malbec, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Primitivo, Zinfandel': 'Zinfandel',
                   'AragonÃªs, Tempranillo': 'Aragonez, Tempranillo'
                  }

def consolidate_varieties(variety_name):
    if variety_name in variety_mapping:
        return variety_mapping[variety_name]
    else:
        return variety_name

wine_df_clean = wine.copy()
wine_df_clean['variety'] = wine_df_clean['variety'].apply(consolidate_varieties)

# %%
order_of_geographies = ['region_1', 'province', 'country']

# replace any nan values in the geography columns with the word none
def replace_nan_for_zero(value):
    if str(value) == '0' or str(value) == 'nan':
        return 'none'
    else:
        return value

for o in order_of_geographies:
    wine_df_clean[o] = wine_df_clean[o].apply(replace_nan_for_zero)

wine_df_clean.loc[:, order_of_geographies].fillna('none', inplace=True)

# %%
wine.shape
# Out:
# (129971, 14)

# %%
variety_geo = wine_df_clean.groupby(['variety', 'country', 'province', 'region_1']).size().reset_index().rename(columns={0:'count'})
variety_geo_sliced = variety_geo.loc[variety_geo['count'] > 1]

vgeos_df = pd.DataFrame(variety_geo_sliced, columns=['variety', 'country', 'province', 'region_1', 'count']) 
vgeos_df.to_csv('varieties_all_geos.csv')

# %%
wine_df_clean.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                 none                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2    Pinot Grigio            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_df_clean.replace('none', '' , inplace=True)

# %%
wine_df_clean['geo_normalized'] = wine_df_clean['region_1'].astype(str) + ', '+ wine_df_clean['province'].astype(str)+ ', '+ wine_df_clean['country'].astype(str)

# %%
wine_df_merged = wine_df_clean.copy()
wine_df_merged.drop(columns=["taster_name",'taster_twitter_handle'])
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                                     NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                                     NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)    Pinot Grigio
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)    Pinot Grigio
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery  \
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
#                            geo_normalized
# 0          Etna, Sicily & Sardinia, Italy
# 1                       , Douro, Portugal
# 2           Willamette Valley, Oregon, US
# 3       Lake Michigan Shore, Michigan, US
# 4           Willamette Valley, Oregon, US
# ...                                   ...
# 129966                   , Mosel, Germany
# 129967                 Oregon, Oregon, US
# 129968             Alsace, Alsace, France
# 129969             Alsace, Alsace, France
# 129970             Alsace, Alsace, France
#
# [129971 rows x 13 columns]

# %%
# variety_geo_df = pd.read_csv('../raw_data/varieties_all_geos_normalized.csv', index_col=0)
# wine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['variety', 'country', 'province', 'region_1', 'region_2'],
#                          right_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'])
# wine_df_merged.drop(['Unnamed: 0', 'Country', 'taster_name', 'taster_twitter_handle',
#                      'Region', 'Subregion', 'count'], 
#                     axis=1, inplace=True)
# wine_df_merged

# %%
variety_geo_df.Variety.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0f20e7ebf013> in <module>
# ----> 1 variety_geo_df.Variety.unique()
#
# NameError: name 'variety_geo_df' is not defined

# %%
variety_geo_df.geo_normalized.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-aac0291c30a0> in <module>
# ----> 1 variety_geo_df.geo_normalized.unique()
#
# NameError: name 'variety_geo_df' is not defined

# %%
wine_df_merged.geo_normalized.unique()
# Out:
# array(['Etna, Sicily & Sardinia, Italy', ', Douro, Portugal',
#        'Willamette Valley, Oregon, US', ...,
#        'Del Veneto, Northeastern Italy, Italy',
#        'Bardolino Superiore, Veneto, Italy',
#        'Paestum, Southern Italy, Italy'], dtype=object)

# %%
variety_geos = wine_df_merged.groupby(['variety', 'geo_normalized']).size()
at_least_n_types = variety_geos[variety_geos > 30].reset_index()
# at_least_n_types.head(10)
wine_df_merged_filtered = pd.merge(wine_df_merged, at_least_n_types, left_on=['variety', 'geo_normalized'], right_on=['variety', 'geo_normalized'])
wine_df_merged_filtered = wine_df_merged_filtered[['title', 'variety', 'geo_normalized', 'description']]
print(wine_df_merged_filtered.shape)
# Out:
# (92228, 4)

# %%
wine_reviews = list(wine_df_merged['description'])

core_tastes = ['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter']

descriptor_mappings = dict()
for c in core_tastes:
    descriptor_mapping_filtered=descriptor_mapping[descriptor_mapping['type']==c]
    descriptor_mappings[c] = descriptor_mapping_filtered                                                   
    

def return_descriptor_from_mapping(descriptor_mapping, word, core_tastes):
    if word in list(descriptor_mapping.index):
        descriptor_to_return = descriptor_mapping['level_3'][word]
        return descriptor_to_return
    else:
        return None

review_descriptors = []
for review in wine_reviews:
    taste_descriptors = []
    normalized_review = normalize_text(review)
    phrased_review = wine_trigram_model[normalized_review]
    #print(normalized_review)
    
    for c in core_tastes:                                                      
        descriptors_only = [return_descriptor_from_mapping(descriptor_mappings[c], word, c) for word in phrased_review]
        no_nones = [str(d).strip() for d in descriptors_only if d is not None]
        descriptorized_review = ' '.join(no_nones)
        taste_descriptors.append(descriptorized_review)
    review_descriptors.append(taste_descriptors)

# %%
review_descriptors
# Out:
# [['herb sage',
#   '',
#   'tropical_fruit fruit dry apple citrus dry',
#   'brisk',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'ripe fruit juicy berry fruit', 'fresh', '', '', '', 'smooth firm'],
#  ['green', '', 'lime rind pineapple', 'tart snappy crisp', '', '', '', ''],
#  ['',
#   'opulent',
#   'pineapple rind lemon_pith orange guava mango',
#   '',
#   '',
#   '',
#   '',
#   'astringent'],
#  ['earth herb', 'hearty', '', '', '', '', '', 'rough tannin rustic'],
#  ['tomato herb dark',
#   '',
#   'blackberry raspberry plum fruit',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'grabby'],
#  ['savory herb',
#   '',
#   'candy berry',
#   'bright fresh',
#   '',
#   'white_pepper',
#   '',
#   'soft'],
#  ['restrained', '', 'dry', '', '', 'spice', '', 'firm'],
#  ['savory thyme',
#   'elegant',
#   'dry peach off-dry fruit',
#   'brisk fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'apple pear fruit dry', 'fresh crisp', '', 'spice', 'depth', ''],
#  ['oak coffee', '', 'plum chocolate', '', '', '', '', 'soft supple'],
#  ['minerality', '', 'dry citrus', 'crisp', '', 'spice pepper', '', 'tight'],
#  ['oak', 'rich', 'juicy cherry', '', '', '', 'chalk cigar_box', 'tannin firm'],
#  ['oak oak-driven coffee coffee coconut vanilla',
#   '',
#   'plum chocolate dry',
#   '',
#   '',
#   '',
#   '',
#   'astringent'],
#  ['green',
#   '',
#   'apple pear ripe pineapple',
#   'lean tart',
#   '',
#   '',
#   'buttercream',
#   ''],
#  ['',
#   '',
#   'orange apple dry',
#   'zesty racy lean refreshing',
#   '',
#   '',
#   'quaffer',
#   ''],
#  ['oak tobacco green',
#   'baked weight',
#   'plum molasses red_berry plum',
#   'balsamic vinegar',
#   '',
#   'pepper',
#   'cheese',
#   'closed'],
#  ['oak oak',
#   'extracted hot',
#   'black_cherry juicy dark_berry fruit',
#   '',
#   '',
#   '',
#   '',
#   'meaty'],
#  ['leather wood mint oak wood_spice hickory oak',
#   'full_bodied',
#   'blackberry blackberry fruit',
#   '',
#   '',
#   'clove',
#   '',
#   'tannin'],
#  ['menthol restrained',
#   '',
#   'fruit ripe cherry plum',
#   '',
#   '',
#   'pepper',
#   'cigar_box',
#   ''],
#  ['dark toast vanilla dust tobacco oak-driven shine',
#   '',
#   'ripe berry red_currant',
#   'tart',
#   '',
#   'black_pepper',
#   '',
#   ''],
#  ['stemmy herb oak', '', 'berry chocolate', 'tart', '', '', '', 'sleek'],
#  ['white_flower minerality',
#   '',
#   'citrus passion_fruit lime peach',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'plum cherry', 'sour flat sour', '', 'licorice', 'cigar_box', ''],
#  ['toast oak coffee',
#   'extracted',
#   'prune blackcurrant cherry dry',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['oak earth forest_floor smoke',
#   'robust full_bodied',
#   'raspberry blackberry',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth'],
#  ['yellow_flower yellow vanilla toast oak',
#   'light_bodied',
#   'stone_fruit apple apricot',
#   'bright crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['dark toast vanilla coffee',
#   '',
#   'ripe berry cherry',
#   'sour',
#   '',
#   'cake_spice',
#   '',
#   'soft round'],
#  ['earth toast oak coffee vanilla dust',
#   '',
#   'berry ripe berry cocoa',
#   '',
#   '',
#   'anise',
#   '',
#   ''],
#  ['',
#   '',
#   'fruit sweet sugar pear lime',
#   'crisp',
#   '',
#   '',
#   'low_complexity',
#   ''],
#  ['', 'light_bodied', 'cherry fruit juicy', 'bright', '', '', '', ''],
#  ['meat', '', 'fruit', 'clean bright sharp', '', '', '', ''],
#  ['jasmine cut_grass sage',
#   '',
#   'honeysuckle ripe yellow_fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'dry berry currant', '', '', 'licorice spice', '', 'rustic'],
#  ['green',
#   'unoaked',
#   'gooseberry tropical_fruit fruit orange honey dry',
#   'tart',
#   '',
#   '',
#   '',
#   ''],
#  ['herb leafy herb', '', 'unripe fruit ripe sweet', '', '', '', '', 'bitter'],
#  ['white_flower mellow flower grass oily',
#   'warm plump',
#   'lychee apple sweet peach melon lime',
#   '',
#   '',
#   '',
#   '',
#   'powdery'],
#  ['concentrated meat rosemary',
#   'full_bodied',
#   'dry fruit',
#   '',
#   '',
#   'spice',
#   'barbecue',
#   'chewi'],
#  ['',
#   'plump',
#   'inky ripe fruit blackberry jam',
#   '',
#   '',
#   'rum_cake',
#   '',
#   'soft smooth'],
#  ['vegetal', '', 'fruit juicy berry', 'bright', '', '', '', ''],
#  ['white minerality', '', 'citrus', '', '', '', 'almond', ''],
#  ['earth herb', '', 'bramble berry', '', '', '', '', 'tannin bitter'],
#  ['', '', 'ripe fruit berry', '', '', '', '', 'soft'],
#  ['oak ham green',
#   'rich',
#   'dry honey sweet citrus pear tropical_fruit fruit grapefruit',
#   'clean brisk',
#   '',
#   '',
#   '',
#   ''],
#  ['herb', '', 'berry raspberry plum', 'tangy racy', '', 'cola', 'modest', ''],
#  ['oak vanilla oak-driven', '', 'caramel dry', '', '', '', 'finessed', ''],
#  ['minerality', '', 'citrus dry', 'fresh clean', '', 'spice', '', ''],
#  ['white vanilla', '', 'sweet sugar orange honey', 'crisp', '', '', '', ''],
#  ['grass',
#   '',
#   'grapefruit passion_fruit kiwi graham_cracker gooseberry',
#   '',
#   '',
#   '',
#   '',
#   'fleshy'],
#  ['', 'rich', 'fruit ripe juicy cherry fruit sweet', '', '', '', '', 'soft'],
#  ['savory meat tobacco wet_earth',
#   '',
#   'dry berry cassis',
#   '',
#   '',
#   '',
#   'almond',
#   'bitter'],
#  ['tar leafy herb length',
#   '',
#   'fruit',
#   'snappy',
#   'salt',
#   'spice',
#   '',
#   'hard gritty'],
#  ['',
#   '',
#   'cherry fruit',
#   'sour bright',
#   '',
#   'cola black_pepper',
#   '',
#   'rustic'],
#  ['herbacious', 'light_bodied', 'fruit grapefruit', 'bright', '', '', '', ''],
#  ['dust minerality',
#   '',
#   'berry',
#   'bright lean',
#   '',
#   'cola',
#   'blue_flower',
#   ''],
#  ['earth oak toast', '', 'orange pear caramel', '', '', '', 'butter', 'soft'],
#  ['vanilla', 'full_bodied', 'lime pear brown_sugar', '', '', '', 'cream', ''],
#  ['toast stone',
#   '',
#   'citrus stone_fruit lemon',
#   'tart crisp',
#   '',
#   '',
#   'almond',
#   ''],
#  ['herb oak',
#   'light_bodied light_bodied',
#   'strawberry raspberry juicy fruit dry dry',
#   'fresh snappy lean',
#   '',
#   'spice',
#   '',
#   ''],
#  ['oak herb',
#   '',
#   'cranberry cranberry',
#   'tart flat',
#   '',
#   'spice',
#   '',
#   'grainy hard'],
#  ['dense vanilla oak graphite leather',
#   'syrupy full_bodied',
#   'jam plum ripe',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense vanilla', '', 'plum', '', '', '', 'cedar', ''],
#  ['oak', 'elegant light_bodied', 'cherry', 'tart', '', 'spice', '', 'gritty'],
#  ['fat',
#   'light_bodied',
#   'ripe berry fruit',
#   '',
#   '',
#   '',
#   'yeast cream',
#   'soft'],
#  ['jasmine hay gold', '', 'apple honey', '', 'saline', '', '', ''],
#  ['white', 'warm light_bodied', 'fruit fruit ripe', '', '', '', '', 'soft'],
#  ['', '', 'ripe pear melon ripe', '', '', '', '', 'soft round smooth'],
#  ['wood vanilla wood oak',
#   'light_bodied plump',
#   'cherry cherry',
#   '',
#   '',
#   'spice',
#   '',
#   'round'],
#  ['smoke',
#   'full_bodied full_bodied',
#   'dark_fruit blackberry blueberry',
#   '',
#   '',
#   'spice cardamom',
#   'depth',
#   'hard'],
#  ['', '', 'ripe fruit', '', '', '', '', 'soft'],
#  ['vanilla toast oak', 'light_bodied', 'stone_fruit', '', '', '', 'cream', ''],
#  ['oak dense vanilla gravel',
#   'robust extracted full_bodied',
#   'cherry',
#   '',
#   '',
#   '',
#   '',
#   'rustic'],
#  ['leather undergrowth game',
#   '',
#   'fruit cherry dry',
#   'lean',
#   'brine',
#   'licorice',
#   '',
#   'grainy'],
#  ['pencil_lead tobacco oak',
#   'full_bodied full_bodied full_bodied',
#   'juicy plum raspberry',
#   '',
#   '',
#   '',
#   'cedar',
#   ''],
#  ['', 'light_bodied', 'fruit plum cranberry', 'tart', '', '', '', ''],
#  ['oak', '', 'juicy raisin ripe', '', '', '', '', ''],
#  ['earth pollen minerality savory',
#   '',
#   'medium_sweet pulpy overripe tangerine stone_fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['nut',
#   'medium_bodied',
#   'pineapple ripe pineapple',
#   '',
#   '',
#   '',
#   'cashew easy',
#   'soft'],
#  ['concentrated',
#   'light_bodied',
#   'juicy candy strawberry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['soil', 'light_bodied', 'fruit', '', '', '', '', 'soft'],
#  ['oak vanilla herb oak wood',
#   '',
#   'caramel plum',
#   '',
#   'salt',
#   '',
#   '',
#   'choppy astringent'],
#  ['white oily', '', 'fruit', 'pop', 'brine', '', 'bland lees', 'round grabby'],
#  ['wood',
#   '',
#   'fruit sweet ripe apricot pineapple fruit',
#   'refreshing',
#   '',
#   'spice',
#   '',
#   ''],
#  ['pale', '', 'passion_fruit', 'crisp racy refreshing', '', '', '', ''],
#  ['smoke coffee', 'weight rich', 'fruit', '', '', '', '', 'soft supple'],
#  ['dust pollen earth savory herb',
#   '',
#   'citrus tangerine lemon',
#   'racy fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['white_flower',
#   '',
#   'ripe pear melon off-dry fruit',
#   'vibrant lean',
#   '',
#   '',
#   '',
#   ''],
#  ['herb leather',
#   'light_bodied baked',
#   'cherry',
#   'lean',
#   '',
#   'black_pepper',
#   '',
#   ''],
#  ['french_oak toast oak-driven herb',
#   'rich',
#   'citrus fruit',
#   'lean racy',
#   '',
#   'spice',
#   'acacia',
#   ''],
#  ['white',
#   '',
#   'berry ripe cherry pastry honeydew',
#   'bright',
#   '',
#   '',
#   'yeast cream closed',
#   ''],
#  ['dust oak', 'rich light_bodied', 'ripe fruit', '', '', '', '', 'round soft'],
#  ['',
#   'light_bodied',
#   'sweet tropical_fruit dry apricot melon guava',
#   'crisp',
#   '',
#   '',
#   'low_complexity',
#   ''],
#  ['', 'full_bodied', 'ripe', '', '', '', 'cedar', 'tannin chewi brawny'],
#  ['green', '', 'pear citrus', 'fresh fresh', '', '', '', ''],
#  ['oak oak wood', 'baked', 'dry stone_fruit', '', '', 'spice', '', ''],
#  ['dense dark minerality concentrated', 'rich', '', '', '', '', '', ''],
#  ['', 'light_bodied', 'ripe fruit red_berry', 'crisp', '', '', '', ''],
#  ['savory pencil_lead',
#   '',
#   'bramble honey dry apple pear',
#   'bright fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['forest_floor menthol coffee violet coffee',
#   '',
#   'cranberry dry cherry fruit',
#   'lean sour assertive',
#   '',
#   'licorice',
#   'linear',
#   'firm'],
#  ['tobacco tar graphite savory',
#   'elegant',
#   'grapey plum juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['smoke nut white',
#   'full_bodied full_bodied rich',
#   'apple lemon pear',
#   'fresh brisk',
#   '',
#   '',
#   'cream',
#   ''],
#  ['dust minerality smoke struck_flint savory concentrated',
#   'light_bodied',
#   'dry apple nectarine tangerine',
#   'lean',
#   '',
#   '',
#   '',
#   ''],
#  ['smoke struck_flint',
#   '',
#   'apple pear citrus',
#   'bright fresh zippy',
#   '',
#   '',
#   'ash',
#   ''],
#  ['green oak oak',
#   'light_bodied',
#   'apple citrus apple nectarine',
#   'bright racy edgy high_acid',
#   'salt',
#   '',
#   '',
#   'round'],
#  ['thyme', '', 'fruit cherry', '', '', 'cinnamon', '', 'smooth'],
#  ['',
#   '',
#   'ripe fruit citrus fruit ripe apricot orange zest juicy pineapple',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['toast coffee',
#   'light_bodied light_bodied',
#   'fruit cherry red_currant',
#   'zesty',
#   '',
#   'spice',
#   'low_complexity',
#   'polished'],
#  ['yellow flower',
#   '',
#   'stone_fruit citrus ripe apricot peach candy nectarine zest',
#   '',
#   '',
#   '',
#   '',
#   'soft round'],
#  ['spearmint mint herb oregano marjoram thyme dill',
#   'hot',
#   'strawberry fruit sweet cherry blackberry fruit',
#   'snappy',
#   '',
#   'licorice ginger dr_pepper spice',
#   'cedar',
#   ''],
#  ['toast herb coffee coffee coffee',
#   '',
#   'berry cherry',
#   'bright',
#   '',
#   '',
#   '',
#   'soft silky'],
#  ['', '', 'ripe plum fruit fruit', '', '', '', '', ''],
#  ['leather herbacious', 'heady', 'marshmallow', '', '', 'clove', '', 'tannin'],
#  ['',
#   'baked',
#   'red_currant plum',
#   '',
#   '',
#   'spice clove',
#   'low_complexity',
#   'soft'],
#  ['white white wild_flower white',
#   '',
#   'citrus stone_fruit ripe apricot lime',
#   '',
#   'saline',
#   '',
#   '',
#   'round'],
#  ['tar meat thyme rose',
#   '',
#   'dry olallieberry dry strawberry plum dry',
#   'sharp',
#   '',
#   '',
#   'cedar',
#   ''],
#  ['yellow steel pink vanilla minerality',
#   'warm',
#   'pear apple apple sweet',
#   'sharp sharp',
#   '',
#   '',
#   'butter',
#   'tight'],
#  ['juniper petrol',
#   '',
#   'tropical_fruit mango pineapple pear orange rind dry lime_peel ripe tropical_fruit lime rind mango',
#   '',
#   '',
#   '',
#   '',
#   'tight tight'],
#  ['iron rose graphite',
#   'baked light_bodied',
#   'cherry juicy strawberry olallieberry',
#   'sizzling',
#   '',
#   'clove',
#   'complex cedar',
#   ''],
#  ['coffee dense toast leather',
#   '',
#   'black_currant caramel',
#   '',
#   '',
#   '',
#   'cedar',
#   'gripping'],
#  ['earth minerality petrol steel minerality',
#   'succulent rich viscous',
#   'fruit honey ripe citrus stone_fruit juicy',
#   'vibrant bright racy crisp',
#   '',
#   '',
#   'complex',
#   ''],
#  ['dark smoke meat earth', 'rich', 'fruit', '', '', '', 'complex', 'soft'],
#  ['toast new_oak toast vanilla wood',
#   'rich opulent',
#   'ripe pineapple pear lime pie mandarin orange',
#   '',
#   '',
#   '',
#   'butter',
#   ''],
#  ['meat',
#   'high_alcohol baked',
#   'fruit dry blackberry blackcurrant',
#   '',
#   '',
#   'cola pepper spice',
#   'cheese',
#   ''],
#  ['toast oak savory dust', '', 'berry cassis', '', '', '', '', 'rough'],
#  ['dense violet oak smoke',
#   'rich elegant',
#   'blackberry blackcurrant cherry',
#   '',
#   '',
#   '',
#   'complex',
#   'firm'],
#  ['wood powerful',
#   'rich elegant',
#   'fruit plum super_ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['flower sage',
#   'rich medium_bodied elegant',
#   'ripe citrus stone_fruit honey sweet sweet ripe juicy fruit honey off-dry',
#   'fresh',
#   '',
#   'spice spice spice',
#   'cream cream',
#   'smooth'],
#  ['minerality concentrated minerality',
#   'rich',
#   'ripe citrus stone_fruit juicy orange stone_fruit mango juicy',
#   'racy crisp bright',
#   '',
#   'spice spice',
#   '',
#   'smooth'],
#  ['minerality flower petrol minerality',
#   'refined',
#   'ripe stone_fruit juicy ripe stone_fruit nectarine',
#   'racy',
#   '',
#   '',
#   '',
#   ''],
#  ['olive vanilla dark leather',
#   '',
#   'raspberry mulberry plum',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dark earth mushroom leather', '', 'fruit', '', '', '', '', ''],
#  ['earth minerality',
#   'rich',
#   'citrus stone_fruit honey honey orange citrus sweet stone_fruit juicy sweet',
#   'tangy tangy crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['dense concentrated wood', '', 'cassis', '', '', 'spice', '', 'tannin'],
#  ['fat smoke meat oak', 'rich', '', '', '', '', '', ''],
#  ['smoke oak',
#   '',
#   'fruit blackberry cherry sweet',
#   'fresh',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['rose concentrated',
#   '',
#   'fruit caramel',
#   'edgy fresh vibrant',
#   '',
#   'licorice',
#   'brown complex',
#   'soft'],
#  ['tobacco vanilla smoke',
#   'hot elegant',
#   'cherry plum fruit ripe',
#   '',
#   '',
#   '',
#   'cream complex',
#   'supple'],
#  ['wood vanilla', 'rich', '', '', '', 'spice', 'cream almond', 'silky smooth'],
#  ['minerality minerality',
#   '',
#   'apple stone_fruit compote ripe apple cataloupe sweet nectarine',
#   'crisp',
#   '',
#   'spice',
#   '',
#   'austere'],
#  ['gold concentrated savory stone minerality',
#   'succulent',
#   'honey citrus marmalade botrytis sweet sweet ripe tropical_fruit fruit honey botrytis',
#   'vibrant',
#   '',
#   '',
#   'depth complex',
#   ''],
#  ['fat toast oak dark length',
#   'lush',
#   'jam fruit fruit',
#   '',
#   '',
#   'spice',
#   'finessed',
#   ''],
#  ['smoke meat truffle earth mushroom',
#   'heavy',
#   'blackberry fruit',
#   '',
#   '',
#   '',
#   'complex',
#   ''],
#  ['petrol minerality oak steel',
#   'refined',
#   'peach lime apricot',
#   'crisp',
#   '',
#   '',
#   '',
#   'sleek'],
#  ['gold smoke savory earth minerality savory earth sage length savory minerality',
#   'rich full_bodied rich warm',
#   'ripe fruit sweet brown_sugar honey dry ripe stone_fruit',
#   'crisp balsamic',
#   '',
#   '',
#   'cream',
#   ''],
#  ['dark herb graphite dense concentrated',
#   'thick full_bodied',
#   'sweet dry fruit',
#   '',
#   '',
#   '',
#   'cedar',
#   'tannin'],
#  ['roast_beef dark sage thyme',
#   '',
#   'cooked cranberry cranberry raspberry',
#   '',
#   '',
#   'spice anise pepper spice',
#   'bay_leaf',
#   ''],
#  ['pencil_lead dark dill game oregano marjoram',
#   'hot baked',
#   'elderberry fruit dry cooked strawberry blackberry',
#   '',
#   '',
#   '',
#   'asphalt',
#   'round'],
#  ['dill smoke',
#   'rich lush',
#   'cherry plum black_currant',
#   'fresh',
#   '',
#   '',
#   '',
#   'soft'],
#  ['',
#   '',
#   'stone_fruit dry ripe grapefruit melon',
#   'crisp fresh zesty',
#   '',
#   '',
#   'blossom',
#   'supple silky'],
#  ['slate smoke lavender',
#   'heavy',
#   'blackberry blueberry fruit caramel soy plum boysenberry',
#   '',
#   '',
#   '',
#   'burnt depth',
#   'finegrained_tannin'],
#  ['flower vanilla',
#   '',
#   'fruit ripe berry cherry',
#   'bright snappy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['wood yellow toast',
#   'rich rich warm',
#   'ripe tropical_fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'round'],
#  ['sage mint eucalyptus',
#   '',
#   'raspberry dry raspberry cherry',
#   'brisk',
#   '',
#   'licorice cola',
#   'linear camphor',
#   'soft'],
#  ['dark tar oak vanilla espresso purple flower',
#   'thick thick',
#   'blueberry',
#   '',
#   '',
#   '',
#   'campfire',
#   'bitter'],
#  ['dark coffee',
#   'full_bodied',
#   'ripe raisin plum berry chocolate',
#   '',
#   '',
#   'pepper',
#   'complex',
#   'bitter'],
#  ['smoke savory',
#   'plump syrupy rich',
#   'black_currant plum cherry boysenberry',
#   '',
#   '',
#   'spice anise black_pepper pepper',
#   'brown lavish',
#   ''],
#  ['slate length powerful',
#   '',
#   'fruit tangerine stone_fruit sweet honeycomb',
#   'zesty',
#   'salt',
#   '',
#   'depth',
#   ''],
#  ['dense dark dense dark concentrated',
#   'rich',
#   'juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['vanilla menthol mint french_oak coffee',
#   'baked elegant',
#   'plum cherry',
#   '',
#   '',
#   'asian_spice licorice',
#   '',
#   'fleshy finegrained_tannin firm polished'],
#  ['menthol coffee concentrated sage',
#   '',
#   'ripe berry cranberry dry cherry',
#   '',
#   '',
#   'anise licorice',
#   '',
#   'gripping'],
#  ['concentrated', 'super_rich opulent', 'plum berry', '', '', '', '', ''],
#  ['',
#   'hearty baked',
#   'strawberry plum',
#   '',
#   '',
#   'licorice black_pepper clove allspice nutmeg',
#   'bay_leaf',
#   ''],
#  ['wax coconut petrol nut',
#   '',
#   'lemon honeysuckle grapefruit lemon_peel grapefruit',
#   'sizzling spritzy',
#   '',
#   '',
#   'complex',
#   'grippy'],
#  ['smoke', 'rich elegant', 'cherry plum fruit ripe', 'fresh', '', '', '', ''],
#  ['oak toast olive herb herb',
#   'light_bodied',
#   'berry fruit',
#   'balsamic',
#   '',
#   '',
#   '',
#   ''],
#  ['olive herb vanilla',
#   'heavy',
#   'dry berry fruit cassis plum',
#   'fresh fresh',
#   '',
#   '',
#   '',
#   'choppy'],
#  ['concentrated dense', 'rich', 'fruit plum berry', '', '', '', '', ''],
#  ['fat smoke mint',
#   'rich',
#   'ripe blackberry cherry',
#   '',
#   '',
#   'black_pepper clove',
#   'chalk',
#   ''],
#  ['rose lavender rocky soil',
#   'elegant',
#   'cherry kirsch',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['toast oak', 'baked luxurious', 'juicy', '', '', '', 'bread', ''],
#  ['minerality',
#   '',
#   'peach apricot off-dry fruit',
#   'fresh tart',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'sweet lime', 'zesty fresh', '', '', '', ''],
#  ['tobacco vanilla olive herb earth',
#   'elegant',
#   'dry berry fruit dry berry cocoa dry',
#   'fresh balsamic',
#   '',
#   'spice pepper',
#   'cedar complex',
#   ''],
#  ['', '', 'cherry fruit ripe fruit', 'buoyant', '', '', '', ''],
#  ['herbacious',
#   'plump light_bodied',
#   'ripe grapefruit nectarine citrus stone_fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'round'],
#  ['tomato white stone',
#   'light_bodied',
#   'citrus grapefruit',
#   'crisp fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['coffee length',
#   'rich',
#   'cassis cherry fruit',
#   '',
#   '',
#   'licorice',
#   '',
#   'firm'],
#  ['rose',
#   'elegant',
#   'berry',
#   'bright',
#   '',
#   'ginger anise spice spice',
#   '',
#   ''],
#  ['dense',
#   '',
#   'dry ripe blackberry currant carob fruit',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['concentrated green',
#   'rich',
#   'fruit ripe apricot apple grapefruit',
#   'fresh edgy fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['oak vanilla',
#   '',
#   'pineapple jam lemon_custard ripe',
#   'crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['smoke oak',
#   'elegant',
#   'cherry raspberry',
#   'crisp tart',
#   '',
#   'cola',
#   '',
#   ''],
#  ['leather',
#   'full_bodied thick chunky succulent',
#   'ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'chewi'],
#  ['',
#   'mass',
#   'melon tropical_fruit lychee fruit tangerine honeydew dry',
#   'clean',
#   '',
#   '',
#   '',
#   'smooth round'],
#  ['',
#   '',
#   'ripe pineapple pear peach nectarine papaya',
#   'bright',
#   '',
#   'cinnamon spice',
#   'buttercream',
#   'firm'],
#  ['',
#   'rich',
#   'raisin molasses fruit cherry blackberry',
#   'sharp',
#   '',
#   'cola',
#   '',
#   ''],
#  ['coffee',
#   'rich',
#   'fruit cherry jam red_currant dry',
#   'crisp',
#   '',
#   'licorice',
#   '',
#   ''],
#  ['luminous concentrated toast oak vanilla coffee',
#   'thick',
#   'blueberry cherry',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dark herb',
#   '',
#   'ripe plum blackberry',
#   'clean',
#   '',
#   'spice anise pepper',
#   '',
#   'smooth smooth'],
#  ['',
#   'rich',
#   'pineapple apple cider citrus_pith citrus',
#   'clean fresh',
#   '',
#   '',
#   'modest',
#   ''],
#  ['coffee smoke rubber',
#   '',
#   'chocolate plum black_currant',
#   '',
#   '',
#   '',
#   '',
#   'muscular polished firm'],
#  ['perfumed mint',
#   '',
#   'cassis chocolate raisin fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['powerful',
#   'succulent',
#   'cherry blackberry sweet',
#   '',
#   '',
#   'clove cola',
#   '',
#   ''],
#  ['toast', '', 'lime lemon fruit', 'crisp fresh', '', '', '', 'bitter soft'],
#  ['violet',
#   'elegant',
#   'cherry berry',
#   'crisp',
#   '',
#   'cola',
#   'almond closed',
#   'closed'],
#  ['dark concentrated',
#   'thick heavy',
#   'jam plum prune_raisin black_currant',
#   'tart',
#   '',
#   'spice',
#   '',
#   'firm'],
#  ['luminous stone', '', 'passion_fruit', 'bright lean', '', 'spice', '', ''],
#  ['concentrated toast oak vanilla_cream toast nut',
#   'lush rich baked medium_bodied',
#   'apple pie sweet orange',
#   '',
#   '',
#   'clove anise',
#   '',
#   ''],
#  ['herb tobacco tea',
#   '',
#   'dry fruit red_currant cranberry',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['olive oak',
#   'light_bodied',
#   'cherry fruit',
#   '',
#   '',
#   'anise spice',
#   '',
#   'firm finegrained_tannin tannin'],
#  ['tobacco dark coffee',
#   'hot',
#   'berry dry cherry raspberry',
#   '',
#   '',
#   'spice licorice',
#   '',
#   'round velvety'],
#  ['herb',
#   'elegant',
#   'nectarine juicy apple peach',
#   'fresh',
#   '',
#   'ginger',
#   'acacia',
#   ''],
#  ['dark',
#   '',
#   'raspberry berry fruit cherry plum',
#   'bright',
#   'saline',
#   'black_pepper spice anise cardamom',
#   '',
#   'smooth'],
#  ['wood concentrated',
#   '',
#   'black_currant fruit',
#   'bright vibrant',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['violet potpourri flower savory purple flower',
#   '',
#   'candy blackberry fruit plum blackberry',
#   '',
#   '',
#   'black_pepper',
#   '',
#   ''],
#  ['oak lemongrass oxidized smoke',
#   'rich',
#   'honeysuckle',
#   'bright fresh tangy',
#   '',
#   '',
#   'almond brioche',
#   ''],
#  ['vanilla mellow oak', 'succulent', 'cherry raspberry', '', '', '', '', ''],
#  ['powerful dust',
#   '',
#   'juicy cranberry cherry fruit dry',
#   '',
#   '',
#   'pepper spice',
#   '',
#   'austere'],
#  ['stone flint grass herb yellow_flower',
#   'medium_bodied',
#   'ripe peach nectarine dry fruit',
#   'fresh clean fresh',
#   '',
#   '',
#   'cream',
#   'smooth'],
#  ['perfumed thyme lavender',
#   '',
#   'cherry blueberry fruit',
#   '',
#   '',
#   '',
#   'complex bay_leaf',
#   'supple silky'],
#  ['',
#   'medium_bodied',
#   'ripe apple pear orange',
#   'clean',
#   '',
#   '',
#   'closed',
#   'soft soft'],
#  ['thyme lavender herb',
#   '',
#   'cocoa plum ripe cherry raspberry',
#   '',
#   '',
#   '',
#   '',
#   'sinewy firm'],
#  ['mellow oak oak oak',
#   'plump chunky',
#   'white_fruit melon apricot apple',
#   '',
#   'salt',
#   '',
#   '',
#   ''],
#  ['pencil_lead loamy',
#   '',
#   'elderberry black_currant cassis kirsch',
#   '',
#   '',
#   '',
#   '',
#   'tight'],
#  ['dense leather',
#   'heavy',
#   'raspberry blueberry fruit',
#   '',
#   '',
#   'pepper nutmeg',
#   '',
#   'brawny'],
#  ['fennel smoke tobacco mellow',
#   '',
#   'blackberry cherry raspberry chocolate',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['tobacco meditteranean_herbs',
#   '',
#   'berry cherry orange',
#   'fresh',
#   '',
#   'licorice clove',
#   'linear',
#   'firm finegrained_tannin'],
#  ['wood dense toast',
#   'rich',
#   'ripe fruit ripe',
#   'crisp',
#   '',
#   'pepper',
#   '',
#   ''],
#  ['',
#   'light_bodied lush',
#   'pith grapefruit lemon_peel peach',
#   'crisp',
#   '',
#   'nutmeg',
#   '',
#   ''],
#  ['',
#   '',
#   'dry citrus_pith pineapple grapefruit juicy peach',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['green olive toast oak',
#   'full_bodied',
#   'tropical_fruit ripe apple pineapple mango fruit',
#   '',
#   'brine',
#   '',
#   '',
#   ''],
#  ['flower herb minerality',
#   'elegant',
#   'peach apple candy lemon',
#   'fresh',
#   '',
#   '',
#   'chamomile',
#   ''],
#  ['herb forest_floor leather coffee powerful tobacco coffee',
#   'rich',
#   'prune dry cherry fruit',
#   'balsamic',
#   '',
#   '',
#   '',
#   'firm finegrained_tannin'],
#  ['savory white herb minerality',
#   '',
#   'ripe apple pear citrus',
#   'bright fresh',
#   '',
#   '',
#   'cream',
#   ''],
#  ['dark',
#   'stout',
#   'blackberry plum prune ripe',
#   '',
#   '',
#   '',
#   '',
#   'tannin rough jagged'],
#  ['toast yellow',
#   '',
#   'sweet honeycomb melon apple fruit',
#   'flabby assertive',
#   '',
#   'spice spice',
#   '',
#   'plush'],
#  ['toast',
#   'rich lush baked weight',
#   'apple guava ripe peach tropical_fruit honeysuckle',
#   '',
#   '',
#   'spice',
#   '',
#   'round smooth'],
#  ['vanilla toast new_oak minerality earth',
#   '',
#   'fruit cherry pie',
#   '',
#   '',
#   '',
#   'depth complex complex',
#   'silky'],
#  ['',
#   '',
#   'quince apple lemon fruit lime',
#   'crisp edgy refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'rich',
#   'fruit jam blackberry cherry mandarin orange chocolate',
#   '',
#   '',
#   'anise spice',
#   '',
#   'soft'],
#  ['flower flower',
#   '',
#   'orange citrus lemon sweet',
#   'edgy edgy crisp clean',
#   '',
#   '',
#   '',
#   ''],
#  ['rubber dark length',
#   '',
#   'berry raisin raisin',
#   '',
#   '',
#   '',
#   'modest',
#   'meaty round'],
#  ['pine wood', '', '', '', '', 'pepper', 'cedar', ''],
#  ['herb diesel rhubarb earth',
#   'pungent light_bodied hearty',
#   'fruit cranberry',
#   'piercing edgy tart',
#   '',
#   '',
#   'bark',
#   'rustic'],
#  ['luminous minerality',
#   '',
#   'stone_fruit berry raspberry blueberry',
#   'fresh',
#   '',
#   '',
#   'ash',
#   ''],
#  ['fennel', '', 'sweet cherry jam chocolate pie', '', '', 'pepper', '', ''],
#  ['concentrated oak',
#   'rich hot',
#   'blackberry cherry currant cocoa dry caramel overripe berry',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['gold soapy flower',
#   '',
#   'honey peach sweet fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft silky'],
#  ['dust earth', 'warm', 'cherry fruit', '', '', '', '', 'rough'],
#  ['', '', 'blackberry fruit ripe raisin dry', '', '', '', '', 'rough'],
#  ['green', '', 'apple juicy', 'crisp fresh refreshing', '', '', '', 'tight'],
#  ['',
#   'rich',
#   'sweet cherry red_currant chocolate',
#   'edgy bright',
#   '',
#   'pepper',
#   'cheese',
#   'soft'],
#  ['green smoke oak',
#   '',
#   'ripe sweet pineapple jam apple',
#   '',
#   '',
#   '',
#   'butter cream',
#   ''],
#  ['toast',
#   'elegant',
#   'fruit fruit',
#   'clean refreshing',
#   '',
#   '',
#   'sparkling',
#   'soft'],
#  ['',
#   'plump mass',
#   'cherry blackberry sweet raspberry chocolate fruit',
#   '',
#   '',
#   '',
#   'cream complex depth',
#   'grabby soft hard'],
#  ['white', '', 'lemon_curd pear apple', 'fresh', '', 'spice', 'butter', ''],
#  ['',
#   '',
#   'juicy grapefruit lemon quince citrus gooseberry dry',
#   'pop',
#   '',
#   '',
#   'low_complexity',
#   ''],
#  ['smoke oak', '', 'cherry blackberry currant', '', '', '', '', 'soft'],
#  ['oak', 'light_bodied', 'cranberry juicy', 'tart', '', '', '', ''],
#  ['',
#   '',
#   'cherry boysenberry blueberry chocolate berry',
#   '',
#   '',
#   '',
#   '',
#   'velvety grippy'],
#  ['',
#   '',
#   'ripe sweet jelly blackberry cherry chocolate',
#   '',
#   '',
#   'anise',
#   '',
#   'soft'],
#  ['earth leafy herb',
#   '',
#   'cherry fruit berry ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin'],
#  ['tobacco coffee',
#   '',
#   'bramble berry sweet candy',
#   '',
#   '',
#   'asian_spice',
#   '',
#   ''],
#  ['',
#   'extracted full_bodied rich refined',
#   'berry jam fruit sweet',
#   '',
#   '',
#   '',
#   '',
#   'sinewy polished'],
#  ['smoke meat',
#   '',
#   'sweet jam blackberry blueberry sweet',
#   'edgy',
#   '',
#   '',
#   'bacon',
#   'firm tannin'],
#  ['powerful', 'light_bodied lush', 'fruit', '', '', 'spice', '', ''],
#  ['dust smoke',
#   '',
#   'plum cherry blueberry cocoa dry berry sweet',
#   'vibrant',
#   '',
#   '',
#   '',
#   ''],
#  ['menthol purple flower',
#   '',
#   'cherry berry',
#   '',
#   '',
#   'spice black_pepper',
#   '',
#   'velvety'],
#  ['herbacious green vanilla smoke oak',
#   'rich',
#   'ripe fruit sweet blackberry cassis sweet',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['perfumed dense herb dark',
#   '',
#   'fruit plum sweet fruit',
#   '',
#   '',
#   '',
#   '',
#   'tannin firm'],
#  ['', '', 'cranberry', 'tart sharp', '', '', '', 'tight polished'],
#  ['mint tobacco oak herb green',
#   'light_bodied clampy',
#   'plum sweet berry dry',
#   '',
#   '',
#   'pepper spice',
#   '',
#   'tannin'],
#  ['herb earth', 'sturdy', 'ripe fruit', '', '', '', '', ''],
#  ['', 'rich', 'cherry', '', '', 'licorice cola spice', 'complex', 'firm'],
#  ['earth tea meat',
#   'medium_bodied lush',
#   'cherry berry fruit sweet sweet cocoa',
#   '',
#   '',
#   'spice spice',
#   'cream',
#   'bittersweet'],
#  ['toast',
#   'medium_bodied baked',
#   'peach lemon_custard',
#   'assertive',
#   '',
#   'spice',
#   'buttercream brioche closed',
#   ''],
#  ['oak vanilla powerful dark',
#   'rich syrupy',
#   'berry chocolate',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin scratchy'],
#  ['luminous gold gold vanilla',
#   'elegant',
#   'stone_fruit citrus apple pear',
#   '',
#   '',
#   '',
#   'almond butter',
#   ''],
#  ['white toast',
#   'robust',
#   'stone_fruit candy lemon',
#   '',
#   '',
#   '',
#   'almond',
#   ''],
#  ['',
#   'rich rich full_bodied',
#   'ripe black_fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth'],
#  ['', 'elegant', 'peach pineapple', '', '', '', 'almond', 'tight'],
#  ['white',
#   '',
#   'lemon grapefruit melon grapefruit lemon_peel',
#   'fresh crisp clean',
#   '',
#   'spice',
#   '',
#   ''],
#  ['vanilla',
#   '',
#   'melon apricot grapefruit',
#   '',
#   '',
#   'spice',
#   'cream',
#   'smooth'],
#  ['leather earth coffee leafy wood',
#   'baked',
#   'berry raisin raspberry plum',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['white spring_flower herb white_almond',
#   '',
#   'peach honey',
#   'crisp',
#   '',
#   '',
#   'basil',
#   ''],
#  ['tobacco herb herb tobacco',
#   'medium_bodied weight',
#   'plum prune fruit raspberry plum',
#   '',
#   '',
#   'spice',
#   'cream',
#   ''],
#  ['smoke', '', 'sweet berry', '', '', 'black_pepper spice', 'bacon cedar', ''],
#  ['', 'elegant', 'ripe fruit blackberry blueberry', '', '', '', '', 'tannin'],
#  ['',
#   'light_bodied weight',
#   'fruit cherry fruit candy',
#   'refreshing',
#   '',
#   '',
#   'depth',
#   ''],
#  ['tomato', 'rich thick', 'peach citrus', '', '', 'spice', '', ''],
#  ['concentrated dense',
#   'rich weight',
#   'ripe tropical_fruit fruit',
#   '',
#   '',
#   'spice black_pepper',
#   'bitter_almond',
#   ''],
#  ['herb tea',
#   'opulent elegant rich',
#   'cherry dry',
#   '',
#   '',
#   'licorice cola indian_spice',
#   '',
#   'tannin'],
#  ['dark leather concentrated white',
#   '',
#   'fruit black_cherry',
#   '',
#   '',
#   'spice spice black_pepper licorice',
#   '',
#   'chewi'],
#  ['soil new_oak oak',
#   'refined',
#   'ripe raspberry chocolate',
#   '',
#   '',
#   '',
#   'clay',
#   'smooth supple'],
#  ['concentrated flower mint dense tea',
#   'thick syrupy',
#   'jam ripe prune_raisin blackberry',
#   '',
#   '',
#   '',
#   '',
#   'soft smooth'],
#  ['', 'rich', 'ripe pear lychee honey', 'fresh', '', 'spice spice', '', ''],
#  ['oak', '', 'raspberry cherry citrus', 'tart', '', 'cola', 'complex', ''],
#  ['concentrated coffee toast dark toast minerality',
#   'full_bodied',
#   'ripe blackberry cassis juicy blueberry blackberry chocolate',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'ripe pear apricot lychee', 'crisp crisp', '', '', '', 'round'],
#  ['oak', 'rich', 'chocolate blackberry', '', '', '', '', 'soft'],
#  ['dark dust', '', 'black_currant juicy', '', '', '', 'closed', 'firm tight'],
#  ['powerful meat truffle tobacco',
#   '',
#   'juicy fruit blackberry cherry ripe',
#   'bright',
#   '',
#   'cinnamon black_pepper',
#   '',
#   'tannin'],
#  ['smoke oxidized',
#   'rich',
#   'ripe peach ripe apple',
#   'tangy',
#   '',
#   '',
#   'almond complex',
#   ''],
#  ['concentrated dark dark vanilla',
#   '',
#   'inky berry fruit raisin plum dry fruit fig chocolate fudge sugar',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['graphite coconut powerful mellow',
#   'lush elegant full_bodied',
#   'fruit cassis blackberry',
#   '',
#   '',
#   'spice licorice',
#   'depth',
#   'smooth hard classy'],
#  ['sandalwood',
#   'rich',
#   'ripe fruit sweet jam blackberry cherry chocolate',
#   '',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['root leafy oak vanilla oak',
#   '',
#   'berry cherry raspberry sweet chocolate',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'blackberry cherry chocolate', '', '', '', 'cedar', 'soft'],
#  ['forest_floor dark flower foxy herb olive oregano',
#   'syrupy rich',
#   'prune sweet chocolate fig dry',
#   '',
#   '',
#   'licorice spice',
#   'cream',
#   'tannin rough'],
#  ['dark minerality smoke',
#   '',
#   'cherry berry',
#   'bright sharp sour',
#   '',
#   'cola licorice',
#   'closed cheese',
#   'tight'],
#  ['meat olive',
#   'light_bodied',
#   'raspberry red_currant',
#   '',
#   '',
#   'licorice spice',
#   'bacon cheese',
#   'soft hard'],
#  ['white',
#   'light_bodied light_bodied',
#   'fruit lime lemon',
#   'clean tart',
#   '',
#   'spice',
#   '',
#   ''],
#  ['tar meat', '', 'sweet cherry', 'fresh crisp tart', '', 'licorice', '', ''],
#  ['smoke white mushroom', '', 'fruit', '', '', '', 'bacon', ''],
#  ['tobacco', '', 'dry dry prune', '', '', '', '', ''],
#  ['steak', '', 'sweet ripe', '', '', 'black_pepper clove', '', ''],
#  ['concentrated toast',
#   'full_bodied',
#   'orange lemon honeysuckle apple',
#   'fresh',
#   '',
#   '',
#   'butter',
#   ''],
#  ['', 'rich', 'fruit cherry sweet', '', '', '', '', 'tannin'],
#  ['white white vegetal',
#   '',
#   'pineapple kiwi citrus fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['white smoke',
#   'light_bodied',
#   'fruit cherry berry',
#   '',
#   '',
#   'spice',
#   '',
#   'tight'],
#  ['oak tar smoke powerful',
#   '',
#   'berry',
#   'bright',
#   '',
#   'licorice',
#   'cigar',
#   'tight'],
#  ['', 'light_bodied', 'fruit cranberry', 'tart', '', 'pepper', '', 'meaty'],
#  ['coffee smoke oak', '', 'sweet ripe berry', '', '', 'spice', '', 'smooth'],
#  ['',
#   'sturdy',
#   'sweet cassis dry blueberry',
#   '',
#   '',
#   'baking_spices',
#   'closed',
#   'tight astringent'],
#  ['', 'rich', 'sweet blackberry cocoa', 'edgy', '', '', '', 'rough'],
#  ['green',
#   'light_bodied',
#   'honey citrus_peel lime fruit',
#   'bright',
#   '',
#   '',
#   'almond cream foamy',
#   'closed'],
#  ['herbacious perfumed', '', 'citrus', 'fresh', '', '', '', ''],
#  ['toast concentrated',
#   '',
#   'ripe peach pear',
#   'edgy',
#   '',
#   'spice',
#   '',
#   'soft round round velvety'],
#  ['',
#   '',
#   'juicy fruit plum cherry cassis',
#   'flashy',
#   '',
#   'cinnamon pepper',
#   '',
#   'round'],
#  ['luminous white stone', '', 'peach citrus fruit', 'fresh', '', '', '', ''],
#  ['soapy wax lavender luminous flower hay green',
#   '',
#   'dry melon lime',
#   '',
#   '',
#   '',
#   'sparkling',
#   ''],
#  ['white minerality',
#   '',
#   'dry stone_fruit pastry',
#   'tangy',
#   '',
#   '',
#   'fizz',
#   ''],
#  ['green luminous',
#   '',
#   'dry sweet peach kiwi melon',
#   '',
#   '',
#   '',
#   'sparkling',
#   'firm'],
#  ['mint wood grass',
#   '',
#   'fruit citrus plum raspberry',
#   'tart snappy crisp fresh lean',
#   '',
#   '',
#   'cheese',
#   'tight grabby'],
#  ['gold', '', 'peach honeysuckle', 'flat', '', 'white_pepper spice', '', ''],
#  ['white',
#   'light_bodied lush',
#   'citrus apricot apricot',
#   '',
#   '',
#   'spice',
#   'cream cheese',
#   'smooth'],
#  ['minerality',
#   '',
#   'dry peach dry sweet fruit',
#   '',
#   '',
#   '',
#   'sparkling sparkling foamy closed',
#   ''],
#  ['vanilla',
#   'elegant refined',
#   'cookie cracker orange tangerine apple citrus',
#   'tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['oak vanilla',
#   '',
#   'fruit pineapple honeysuckle peach fig',
#   '',
#   '',
#   '',
#   'buttercream',
#   ''],
#  ['sassafras coffee',
#   '',
#   'sweet ripe cherry raspberry red_currant',
#   '',
#   '',
#   'pepper',
#   '',
#   ''],
#  ['',
#   '',
#   'jam blackberry cherry',
#   'sharp',
#   '',
#   'spice',
#   '',
#   'rustic polished'],
#  ['flower',
#   '',
#   'orange lychee melon pineapple mango tropical_fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['luminous minerality white rose',
#   '',
#   'dry honey stone_fruit citrus',
#   'lean fresh',
#   '',
#   '',
#   'sparkling',
#   'smooth'],
#  ['minerality',
#   '',
#   'dry stone_fruit citrus sweet',
#   'crisp',
#   '',
#   '',
#   'sparkling foamy',
#   ''],
#  ['',
#   '',
#   'ripe fruit raspberry fruit',
#   '',
#   '',
#   '',
#   'cream',
#   'soft round smooth'],
#  ['white',
#   '',
#   'fruit',
#   'flat',
#   '',
#   'spice pepper',
#   'basil sparkling frothy',
#   ''],
#  ['peanut herb oak',
#   '',
#   'berry fruit plum currant',
#   '',
#   'brine',
#   '',
#   'burnt',
#   'gritty scratchy tannin rough'],
#  ['menthol',
#   'light_bodied light_bodied',
#   'red_currant cherry',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['earth', '', 'fruit', 'edgy', '', 'spice pepper', '', 'rustic'],
#  ['',
#   'heavy light_bodied',
#   'berry apple sweet',
#   '',
#   '',
#   '',
#   'effervescent',
#   ''],
#  ['white', '', '', 'spritzy', '', '', '', 'round'],
#  ['', '', 'plum cherry raisin cake prune', '', '', '', '', 'soft'],
#  ['funky vegetal',
#   'light_bodied',
#   'apple',
#   '',
#   'brine',
#   'cinnamon',
#   'yeast lees bread yeast foamy',
#   ''],
#  ['green tea grass grass leafy green_bean vegetal',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['corn root vegetal', '', 'apple', 'mealy', '', 'spice', '', ''],
#  ['concentrated dark concentrated',
#   'weight',
#   'dry fig molasses',
#   'fresh',
#   '',
#   '',
#   'black_tea complex',
#   ''],
#  ['moss maple',
#   'syrupy rich heavy',
#   'molasses',
#   'bright',
#   '',
#   '',
#   'depth brown complex',
#   'round'],
#  ['dust earth oil',
#   '',
#   'mango tangerine fruit sweet honey peach',
#   'piercing',
#   '',
#   '',
#   'complex',
#   'silky'],
#  ['concentrated coffee length',
#   'rich',
#   'dry fig molasses candy orange zest sweet',
#   '',
#   '',
#   '',
#   'depth black_tea',
#   ''],
#  ['olive', '', 'ripe plum', 'crisp', '', '', 'complex', 'supple'],
#  ['leather soil undergrowth concentrated tobacco',
#   'succulent',
#   'ripe berry juicy cherry raspberry',
#   '',
#   '',
#   'anise',
#   'blue_flower',
#   'firm velvety'],
#  ['',
#   'baked baked rich',
#   'honey beeswax apricot pear honey pear sweet apple sweet cloying',
#   'fresh tart fresh tart',
#   '',
#   '',
#   'cream',
#   'silky smooth velvety'],
#  ['stone minerality', '', 'apricot', 'crisp fresh', 'salt', '', '', ''],
#  ['yellow concentrated wood minerality',
#   'rich opulent',
#   'fruit ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'tight tight'],
#  ['white mushroom concentrated',
#   '',
#   'caramel apricot orange honey sweet caramel',
#   '',
#   '',
#   'saffron',
#   'complex',
#   ''],
#  ['smoke toast oak length',
#   'rich medium_bodied lush',
#   'melon apple',
#   '',
#   '',
#   'nutmeg cardamom',
#   '',
#   ''],
#  ['dust powerful coffee',
#   '',
#   'blackberry fruit chocolate',
#   '',
#   '',
#   'licorice spice',
#   '',
#   'firm'],
#  ['wood concentrated', '', 'ripe fruit', 'fresh bright', '', '', '', ''],
#  ['dust shine',
#   'luxurious',
#   'ripe peach caramel sugar tropical_fruit mango pineapple melon',
#   'bright',
#   '',
#   'pepper saffron',
#   '',
#   ''],
#  ['minerality', 'rich', 'ripe apple citrus fruit', '', '', '', '', ''],
#  ['olive dark', 'heavy', 'cooked', '', '', '', 'bacon cream', 'meaty'],
#  ['undergrowth herb eucalyptus rose minerality',
#   'elegant',
#   'ripe berry cherry',
#   'fresh tart',
#   '',
#   'cake_spice white_pepper',
#   '',
#   'polished'],
#  ['powerful oak tobacco',
#   'elegant refined rich',
#   'blueberry chocolate',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['white yellow wood',
#   'opulent weight',
#   'fruit ripe citrus',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dark concentrated earth',
#   '',
#   'jam cherry fruit ripe',
#   'clean',
#   '',
#   'anise',
#   '',
#   ''],
#  ['menthol vanilla toast wood',
#   'full_bodied',
#   'cherry plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'plush'],
#  ['oak smoke oak minerality',
#   'rich',
#   'brown_sugar honey caramel fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['mint dense oak toast wood',
#   'syrupy heavy',
#   'berry lemon fruit',
#   'pop',
#   '',
#   '',
#   '',
#   'plush round'],
#  ['',
#   'plump',
#   'juicy citrus fruit lime orange tangerine',
#   'zesty tart tart',
#   '',
#   '',
#   '',
#   ''],
#  ['smoke nut savory nut', 'medium_bodied', 'citrus', '', '', '', 'cheese', ''],
#  ['mint earth tobacco coffee',
#   '',
#   'brown_sugar',
#   '',
#   '',
#   '',
#   'bell_pepper',
#   'supple'],
#  ['grass green',
#   '',
#   'fruit gooseberry',
#   'fresh crisp vibrant',
#   '',
#   '',
#   '',
#   ''],
#  ['green concentrated',
#   'light_bodied light_bodied',
#   'plum',
#   'fresh crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['green grass', '', 'tropical_fruit fruit', 'crisp fresh', '', '', '', ''],
#  ['white mint',
#   '',
#   'citrus fruit fig melon peach sweet',
#   'crisp fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['tobacco earth', 'light_bodied', 'ripe cherry', 'tart', '', '', '', 'soft'],
#  ['',
#   'light_bodied',
#   'fruit peach',
#   'fresh crisp',
#   '',
#   'cinnamon',
#   'almond',
#   ''],
#  ['green', '', 'ripe plum apple fruit', 'fresh tangy vibrant', '', '', '', ''],
#  ['flower green flower',
#   'light_bodied light_bodied elegant',
#   'cherry',
#   '',
#   '',
#   '',
#   '',
#   'fleshy'],
#  ['', '', 'apple peach citrus fruit', 'fresh', '', '', 'cream', ''],
#  ['coffee',
#   '',
#   'blueberry chocolate plum blackberry',
#   'aggressive',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality smoke earth minerality oil',
#   '',
#   'apple',
#   'fresh fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['herb dark', '', 'plum chocolate plum', '', '', '', '', 'tight firm bitter'],
#  ['herb flower', '', 'juicy peach', '', '', '', '', ''],
#  ['rose', 'full_bodied rich', 'ripe', '', '', 'pepper spice', '', 'soft'],
#  ['herb grass minerality',
#   'rich viscous',
#   'melon citrus peach',
#   'edgy fresh clean',
#   '',
#   'spice',
#   '',
#   ''],
#  ['coffee tea',
#   'sturdy',
#   'blackberry chocolate',
#   'fresh',
#   '',
#   'cola',
#   '',
#   'bitter'],
#  ['smoke oak', 'rich', 'lime fig apricot', '', '', 'spice', '', 'polished'],
#  ['tobacco',
#   '',
#   'ripe cherry cranberry dry',
#   'lean tart',
#   '',
#   '',
#   'complex',
#   ''],
#  ['', 'rich', 'melon pear lime', 'fresh', '', '', '', ''],
#  ['oak',
#   'light_bodied',
#   'cranberry cassis fruit ripe',
#   '',
#   '',
#   '',
#   'butter',
#   'smooth'],
#  ['oak',
#   'extracted',
#   'pineapple apple pear fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'meaty'],
#  ['',
#   '',
#   'citrus ripe sweet honey dry',
#   'edgy clean refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['oak coconut coconut',
#   'rich',
#   'lemon_curd lemon pear',
#   'fresh bright',
#   '',
#   'nutmeg',
#   '',
#   'soft'],
#  ['oak',
#   '',
#   'berry plum cherry berry sweet',
#   'fresh tangy sour',
#   '',
#   '',
#   '',
#   'smooth soft tannin'],
#  ['', 'rich', 'fruit citrus', '', '', 'pepper', 'complex', ''],
#  ['', 'rich', 'chocolate fruit sweet', '', '', 'spice', 'barbecue', ''],
#  ['',
#   'light_bodied sturdy',
#   'cherry berry fruit plum pie cherry',
#   'fresh racy tart clean',
#   '',
#   '',
#   'chalk',
#   ''],
#  ['perfumed', 'plump', 'sweet nectarine melon grapefruit', '', '', '', '', ''],
#  ['nut luminous',
#   '',
#   'fruit stone_fruit pear',
#   '',
#   '',
#   '',
#   'almond sparkling',
#   ''],
#  ['white', '', 'lemon', 'lean', '', 'pepper', 'butterscotch', ''],
#  ['watery steel',
#   '',
#   'dry sweet lemon fruit',
#   'lean fresh',
#   '',
#   '',
#   'sparkling sparkling closed',
#   'firm'],
#  ['purple',
#   '',
#   'blackberry ripe grapey cherry',
#   'racy',
#   '',
#   'pepper',
#   'campfire',
#   ''],
#  ['olive',
#   'light_bodied',
#   'dry cherry orange zest citrus fruit',
#   'tart',
#   '',
#   '',
#   '',
#   ''],
#  ['funky sweat leather leather coffee',
#   '',
#   'blackberry currant',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['white_flower minerality',
#   '',
#   'citrus peach sweet stone_fruit',
#   'bright zesty',
#   '',
#   'pepper',
#   'effervescent',
#   'soft'],
#  ['', '', 'caramel custard', 'fresh tart', '', '', 'cream almond', ''],
#  ['nut oil toast',
#   'baked',
#   'apple dry melon pith peach_pit citrus_peel',
#   '',
#   '',
#   '',
#   '',
#   'round bitter'],
#  ['watery white_flower',
#   '',
#   'lime kiwi honey',
#   '',
#   '',
#   '',
#   'basil sparkling cream foamy effervescent',
#   'closed'],
#  ['flower',
#   'elegant',
#   'citrus dry',
#   'fresh refreshing',
#   '',
#   'spice spice',
#   '',
#   ''],
#  ['violet',
#   'elegant',
#   'blackberry cherry blackberry',
#   '',
#   '',
#   'spice pepper',
#   '',
#   'soft'],
#  ['herb smoke oak',
#   '',
#   'dry black_currant plum',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth'],
#  ['gold minerality', 'rich', 'peach dry apricot', '', '', '', 'sparkling', ''],
#  ['white minerality',
#   '',
#   'citrus lime grapefruit orange sweet',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['yellow rose',
#   'pungent',
#   'peach',
#   '',
#   '',
#   'spice',
#   'almond ash sparkling',
#   ''],
#  ['minerality',
#   'elegant',
#   'citrus sweet fruit',
#   '',
#   '',
#   'spice spice',
#   'cheese',
#   ''],
#  ['', '', 'stone_fruit citrus', '', '', '', '', ''],
#  ['luminous jasmine herb',
#   '',
#   'sweet peach honey',
#   'fresh',
#   '',
#   '',
#   'closed',
#   ''],
#  ['',
#   'rich hearty',
#   'sweet juicy fruit plum fig',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['perfumed',
#   '',
#   'blackcurrant berry fruit ripe',
#   'fresh',
#   '',
#   '',
#   '',
#   'smooth tannin polished'],
#  ['wood toast',
#   'rich full_bodied',
#   'fruit ripe pear apricot',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['oak', 'full_bodied', 'fruit fruit', '', '', 'spice spice', 'lees', ''],
#  ['', 'light_bodied', 'fruit citrus fruit', 'racy', '', '', '', ''],
#  ['savory moss green concentrated',
#   'warm',
#   'pear lime',
#   'zesty',
#   '',
#   '',
#   '',
#   ''],
#  ['coconut nut oak', 'rich', 'dry fruit banana', '', '', '', 'complex', ''],
#  ['smoke nut wax flower',
#   'light_bodied',
#   'berry',
#   'refreshing zesty',
#   '',
#   '',
#   '',
#   ''],
#  ['foxy rubber',
#   'warm',
#   'cherry cassis cherry cassis ripe',
#   '',
#   '',
#   '',
#   '',
#   'tight tannin hard'],
#  ['perfumed',
#   'elegant',
#   'ripe raspberry cherry',
#   'fresh',
#   '',
#   '',
#   'blossom sparkling mousse',
#   ''],
#  ['earth flower earth',
#   '',
#   'pear',
#   'fresh zesty fresh refreshing',
#   '',
#   '',
#   'yeast',
#   ''],
#  ['coffee oak',
#   'rich full_bodied',
#   'fruit blackberry',
#   '',
#   '',
#   'spice spice',
#   '',
#   ''],
#  ['yellow mint green',
#   'light_bodied',
#   'pear lime apple lime',
#   'brisk clean',
#   '',
#   '',
#   '',
#   'grippy'],
#  ['',
#   'rich',
#   'orange strawberry watermelon raspberry melon',
#   'zesty',
#   '',
#   'spice',
#   'cream cement',
#   'tight'],
#  ['flower jasmine flower', '', 'lime watermelon dry', 'pop', '', '', '', ''],
#  ['smoke concrete',
#   'full_bodied light_bodied',
#   'apricot dry fruit',
#   'tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['coffee toast oak coconut dense dark oak',
#   '',
#   'raspberry chocolate cherry',
#   '',
#   '',
#   'licorice',
#   '',
#   'fleshy finegrained_tannin'],
#  ['concentrated green',
#   '',
#   'pear apple pear',
#   'bright fresh fresh',
#   '',
#   '',
#   'cream cream',
#   'soft'],
#  ['flower flint',
#   '',
#   'apricot apricot peach honeydew',
#   'bright',
#   '',
#   '',
#   'almond closed',
#   ''],
#  ['concentrated lavender violet',
#   '',
#   '',
#   '',
#   '',
#   'licorice black_pepper',
#   '',
#   'soft'],
#  ['oak earth herb toast',
#   '',
#   'fruit plum cherry',
#   'fresh fresh',
#   '',
#   'licorice spice',
#   'easy',
#   'tight firm'],
#  ['leather savory smoke oak savory herb rubber',
#   'stout baked',
#   'berry juicy plum',
#   '',
#   'salt',
#   'spice spice pepper',
#   '',
#   'hard'],
#  ['oak herb flower',
#   '',
#   'fruit cherry dry chocolate cherry',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'apple strawberry citrus bone_dry strawberry',
#   'zesty tart refreshing',
#   '',
#   '',
#   'linear',
#   ''],
#  ['coffee oil',
#   'voluptuous rich luxurious',
#   'blackberry plum',
#   'edgy',
#   '',
#   'spice',
#   '',
#   'bitter'],
#  ['oak',
#   'full_bodied hearty',
#   'berry chocolate',
#   '',
#   '',
#   'licorice spice spice',
#   '',
#   'smooth'],
#  ['earth savory green concentrated',
#   '',
#   'pear',
#   '',
#   '',
#   'spice pepper spice',
#   'yeast tingly',
#   ''],
#  ['savory',
#   'baked',
#   'berry cherry juicy strawberry',
#   'vibrant bright bright crisp',
#   '',
#   'spice anise',
#   'blue_flower',
#   ''],
#  ['earth dill',
#   '',
#   'blueberry plum blackberry juicy',
#   'fresh fresh',
#   '',
#   'black_pepper',
#   'asphalt',
#   'tannin'],
#  ['minerality',
#   'light_bodied',
#   'melon ripe pear fruit fruit citrus ripe fruit',
#   'crisp bright',
#   '',
#   '',
#   '',
#   'soft tight'],
#  ['', '', 'citrus apple pineapple underripe melon', '', '', '', '', 'tight'],
#  ['white_flower nut',
#   'refined',
#   'sugar lemon_drop citrus apple bone_dry',
#   '',
#   '',
#   '',
#   'sparkling almond sparkling',
#   ''],
#  ['toast', 'elegant', 'dry citrus grapefruit', 'crisp', '', '', '', ''],
#  ['undergrowth tobacco gold',
#   'succulent warm elegant',
#   'ripe cherry cherry plum',
#   '',
#   '',
#   'spice baking_spices',
#   '',
#   'velvety'],
#  ['wood yellow',
#   '',
#   'ripe fruit apricot peach',
#   '',
#   '',
#   '',
#   'complex',
#   'tight'],
#  ['toast', 'rich', 'lemon apple fruit', 'bright', '', '', 'almond', ''],
#  ['dense lengthy',
#   'rich',
#   'peach papaya lychee brown_sugar sugar sugar',
#   '',
#   '',
#   '',
#   '',
#   ''],
# ...
#  ['toast', 'full_bodied', 'pear apple dry', 'crisp', '', '', 'butter', ''],
#  ['', '', 'fruit fruit', 'crisp', '', '', '', 'soft'],
#  ['oak nut oak tobacco vanilla',
#   '',
#   'ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'hard tannin'],
#  ['white vegetal tomato flint minerality',
#   '',
#   'citrus stone_fruit grapefruit pineapple peach',
#   'racy fresh',
#   '',
#   '',
#   'closed',
#   'bitter'],
#  ['white minerality herb',
#   'succulent',
#   'beeswax stone_fruit peach juicy nectarine',
#   'fresh tangy',
#   '',
#   '',
#   'acacia cream almond closed',
#   ''],
#  ['stone stone',
#   '',
#   'melon dry apple',
#   'fresh clean fresh',
#   '',
#   '',
#   '',
#   'soft soft'],
#  ['earth oak leafy game',
#   '',
#   'cherry fruit',
#   'fresh',
#   '',
#   '',
#   'depth depth',
#   'velvety'],
#  ['smoke wood perfumed wood', 'rich', 'fruit', '', '', '', '', ''],
#  ['perfumed', '', 'fruit raspberry plum', 'fresh', '', '', '', 'firm'],
#  ['perfumed minerality',
#   '',
#   'fruit citrus orange ripe',
#   'fresh zingy',
#   'salt',
#   '',
#   '',
#   ''],
#  ['dense',
#   '',
#   'red_currant raspberry fruit',
#   'bright fresh crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['earth', 'rich', 'apple', 'fresh', '', '', 'complex', 'phenolic'],
#  ['dust slate concentrated',
#   'light_bodied',
#   'lime honey marmalade',
#   'zesty',
#   '',
#   'saffron',
#   '',
#   ''],
#  ['herb dill sage',
#   'full_bodied plump',
#   'fruit cherry blueberry',
#   '',
#   '',
#   '',
#   '',
#   'sleek'],
#  ['nut',
#   '',
#   'pineapple marshmallow',
#   '',
#   '',
#   '',
#   'butter almond cream butter',
#   ''],
#  ['white_flower smoke nut savory white hazelnut flint minerality',
#   'medium_bodied',
#   'fruit citrus pear pineapple peach',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['tar dark smoke meat tobacco smoke',
#   'heavy',
#   'elderberry caramel reductive',
#   '',
#   '',
#   '',
#   'beef asphalt',
#   ''],
#  ['', '', 'pear fruit fruit', 'fresh crisp clean fresh fresh', '', '', '', ''],
#  ['leather leather smoke',
#   'full_bodied robust',
#   'juicy',
#   'edgy',
#   '',
#   'black_pepper',
#   'cigar',
#   'tannin'],
#  ['dense purple wood incense juniper coffee',
#   '',
#   'fruit elderberry fruit',
#   'fresh',
#   '',
#   'pepper',
#   'cedar lavish cigar_box',
#   'tannin'],
#  ['wild_flower hay fennel',
#   'baked',
#   'ripe berry strawberry juicy cherry',
#   'refreshing bright',
#   'saline',
#   'spice',
#   '',
#   ''],
#  ['herb fennel minerality',
#   '',
#   'berry dry candy cherry nectarine zest',
#   'bright',
#   '',
#   'white_pepper',
#   '',
#   ''],
#  ['vanilla hibiscus oregano dill pencil_lead minerality',
#   'light_bodied airy',
#   'bramble red_currant fruit cranberry pomegranate',
#   'pop',
#   '',
#   'baking_spices',
#   '',
#   ''],
#  ['',
#   'rich rich',
#   'ripe berry ripe blackberry plum',
#   '',
#   '',
#   '',
#   '',
#   'fleshy soft supple silky tannin'],
#  ['white dill hay vegetal tomato',
#   'heady',
#   'honeysuckle stone_fruit juicy grapefruit peach honeydew',
#   'tangy',
#   'saline',
#   '',
#   'depth',
#   ''],
#  ['meat',
#   'rich light_bodied',
#   'ripe raspberry',
#   '',
#   '',
#   'cola spice',
#   '',
#   'round'],
#  ['', 'elegant', 'fruit berry cherry', 'fresh crisp', '', '', 'complex', ''],
#  ['herb oak dense herb dark',
#   '',
#   'berry ripe blackberry chocolate',
#   '',
#   '',
#   'spice',
#   '',
#   'chewi'],
#  ['slate minerality earth slate',
#   'baked light_bodied',
#   'cherry red_currant cranberry cherry',
#   'tart',
#   '',
#   'cola',
#   '',
#   ''],
#  ['dark smoke',
#   'medium_bodied',
#   'raspberry',
#   '',
#   '',
#   'black_pepper pepper',
#   '',
#   ''],
#  ['new_oak coffee',
#   'full_bodied hearty',
#   'chocolate blackberry',
#   '',
#   '',
#   '',
#   'cigar',
#   'brawny'],
#  ['green wet_rocks white',
#   '',
#   'juicy citrus apple fruit',
#   'tart fresh tangy refreshing',
#   '',
#   '',
#   'lees',
#   ''],
#  ['white yellow white_flower',
#   '',
#   'botrytis apple apricot peach juicy citrus_peel grapefruit juicy caramel pineapple',
#   'crisp clean',
#   '',
#   '',
#   '',
#   ''],
#  ['perfumed dense',
#   'rich full_bodied',
#   'fruit ripe juicy',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality herb', '', 'black_currant fruit', 'edgy', '', '', '', 'austere'],
#  ['toast coffee restrained',
#   'lush baked heavy',
#   'ripe sweet raisin berry prune',
#   '',
#   '',
#   '',
#   'depth',
#   ''],
#  ['espresso tobacco',
#   'elegant plump',
#   'ripe cherry berry',
#   'clean',
#   '',
#   '',
#   '',
#   'plush soft'],
#  ['toast dense powerful',
#   'full_bodied rich rich rich',
#   'sweet blackberry juicy fruit',
#   '',
#   '',
#   'spice nutmeg',
#   '',
#   ''],
#  ['dense', 'chunky', 'black_currant fruit ripe fruit dry', '', '', '', '', ''],
#  ['smoke sandalwood',
#   'full_bodied rich',
#   'dry blackberry currant plum',
#   '',
#   '',
#   '',
#   'depth',
#   'tannin'],
#  ['mellow',
#   '',
#   'ripe fruit cherry blackberry plum prune',
#   '',
#   '',
#   '',
#   'complex',
#   'tight gritty firm hard'],
#  ['minerality oak',
#   'rich',
#   'fruit blackberry cherry currant dry',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['herb flower lengthy',
#   'elegant',
#   'ripe berry cherry dry',
#   'fresh',
#   '',
#   'licorice',
#   '',
#   ''],
#  ['dark vanilla toast',
#   'refined',
#   'dry ripe raspberry strawberry orange honey',
#   'flashy',
#   '',
#   '',
#   'sparkling sparkling yeast',
#   'silky'],
#  ['',
#   'elegant',
#   'sweet blackberry cherry red_currant ripe',
#   '',
#   '',
#   '',
#   '',
#   'soft silky'],
#  ['game flower earth',
#   'rich',
#   'cocoa jam berry',
#   '',
#   '',
#   'spice',
#   '',
#   'bittersweet velvety firm'],
#  ['hay concentrated wood herbacious',
#   '',
#   'citrus pineapple',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['toast graphite',
#   '',
#   'berry cherry bramble fruit fruit',
#   '',
#   '',
#   '',
#   'complex chalk',
#   ''],
#  ['sandalwood',
#   'rich',
#   'cherry pie orange zest sweet',
#   '',
#   '',
#   'cola anise cinnamon',
#   '',
#   ''],
#  ['', '', 'tangerine peach pear honey', 'zesty', '', '', 'butter cream', ''],
#  ['smoke sandalwood',
#   '',
#   'raspberry persimmon honey',
#   'vibrant',
#   '',
#   '',
#   '',
#   ''],
#  ['toast oak', '', 'cassis berry fruit', '', '', 'licorice', '', ''],
#  ['', 'weight', 'berry', 'tart crisp', '', '', 'complex', ''],
#  ['dense tobacco',
#   'elegant',
#   'cherry',
#   '',
#   '',
#   'spice',
#   'low_complexity',
#   'smooth soft plush'],
#  ['', '', 'berry', 'bright', '', '', '', 'soft velvety'],
#  ['oak dark mushroom savory mint',
#   'baked',
#   'blackberry',
#   '',
#   '',
#   '',
#   '',
#   'silky'],
#  ['dust coffee metal graphite',
#   'elegant',
#   'cocoa fruit',
#   '',
#   '',
#   '',
#   '',
#   'tight'],
#  ['coffee dark leather',
#   'rich extracted',
#   'chocolate fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'soft chewi'],
#  ['meat', 'lush', 'cherry', 'bright', '', 'spice', '', 'soft velvety'],
#  ['concentrated herb',
#   '',
#   'ripe fruit ripe blackberry chocolate',
#   '',
#   '',
#   '',
#   'burnt',
#   'smooth'],
#  ['wood white green',
#   '',
#   'ripe ripe plum melon fruit',
#   'bite',
#   '',
#   'spice',
#   '',
#   ''],
#  ['white restrained concentrated',
#   'weight',
#   'popcorn citrus underripe peach citrus',
#   '',
#   'salt',
#   '',
#   '',
#   ''],
#  ['smoke nut',
#   '',
#   'tangerine lime off-dry juicy',
#   'tart refreshing fresh',
#   '',
#   '',
#   'low_complexity',
#   ''],
#  ['leather dust violet',
#   'baked',
#   'dry cherry dry',
#   'sour',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dark', '', 'berry juicy ripe', '', '', '', 'barbecue', ''],
#  ['white_flower',
#   'medium_bodied',
#   'peach tropical_fruit fruit juicy peach pineapple',
#   'clean',
#   '',
#   '',
#   'chalk',
#   ''],
#  ['toast', '', 'fruit fruit', 'fresh crisp', '', '', 'almond', ''],
#  ['toast hazelnut dense',
#   '',
#   'dry cherry',
#   'fresh',
#   '',
#   'licorice',
#   '',
#   'round'],
#  ['toast oak menthol resin coffee medicinal thyme',
#   '',
#   '',
#   '',
#   '',
#   'clove licorice',
#   '',
#   'firm'],
#  ['dull mulch earth medicinal earth',
#   'thick syrupy',
#   'fig raisin',
#   'flat',
#   '',
#   '',
#   '',
#   ''],
#  ['dark purple violet vanilla',
#   '',
#   'juicy plum cherry boysenberry fruit-forward sweet',
#   '',
#   '',
#   'spice',
#   '',
#   'plush'],
#  ['dust',
#   'light_bodied',
#   'strawberry fruit dry',
#   'refreshing fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['mellow savory',
#   '',
#   'peach jam orange fruit apricot lemon_curd quince',
#   'bright',
#   '',
#   '',
#   'bitter_almond',
#   ''],
#  ['earth toast oak herb wood',
#   'full_bodied',
#   'berry plum dry',
#   '',
#   '',
#   'spice',
#   '',
#   'hard tannin'],
#  ['rhubarb',
#   'light_bodied',
#   'chocolate strawberry fruit',
#   'fresh',
#   '',
#   'pepper',
#   '',
#   'smooth'],
#  ['steel', '', 'fruit melon orange lemon_peel lime', 'tart', '', '', '', ''],
#  ['herb toast oak coffee game green sage',
#   '',
#   'dry cherry',
#   '',
#   '',
#   'anise',
#   '',
#   'bitter astringent'],
#  ['toast oak coffee sawdust coffee coffee',
#   '',
#   'dry cherry fruit',
#   '',
#   '',
#   '',
#   '',
#   'astringent'],
#  ['gold wax', '', 'apple apricot orange', '', '', 'spice', 'burnt', ''],
#  ['green_bean pea green',
#   '',
#   'citrus gooseberry fruit',
#   'snappy clean refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['perfumed',
#   '',
#   'fruit citrus pineapple',
#   'crisp refreshing',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['petrol length',
#   '',
#   'citrus juicy peach tangerine stone_fruit citrus orange',
#   'tangy fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'fruit ripe', '', '', '', '', 'soft smooth'],
#  ['green stone pea',
#   'medium_bodied',
#   'apple citrus lime grapefruit',
#   '',
#   '',
#   '',
#   '',
#   'silky'],
#  ['earth nut earth', '', 'sweet fruit sugar', '', '', '', 'complex', ''],
#  ['wood menthol herb savory oak savory',
#   '',
#   'plum grapey berry fruit grapey',
#   '',
#   '',
#   'cola',
#   '',
#   'muscular'],
#  ['',
#   '',
#   'medium_sweet red_currant ripe strawberry',
#   'crisp fresh bright clean',
#   '',
#   '',
#   'cream',
#   ''],
#  ['eucalyptus',
#   '',
#   'ripe cherry orange zest',
#   'assertive',
#   '',
#   'spice anise',
#   'celery',
#   'tight astringent'],
#  ['',
#   'full_bodied voluptuous rich',
#   'ripe overripe berry sweet dry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood rubber game rubber game',
#   '',
#   'berry plum',
#   '',
#   'salt',
#   '',
#   '',
#   'grabby tannin'],
#  ['menthol coffee coffee',
#   '',
#   'berry berry',
#   '',
#   '',
#   'licorice',
#   'low_complexity',
#   ''],
#  ['wood', 'rich light_bodied', 'juicy fruit', '', '', 'spice', '', ''],
#  ['', '', 'fruit red_berry fruit', 'fresh', '', '', '', 'firm tannin'],
#  ['wood smoke', '', 'ripe fruit', 'fresh', '', 'spice', '', ''],
#  ['', 'bold', 'ripe fruit', '', '', '', '', 'firm smooth'],
#  ['', 'light_bodied', 'green_fruit banana apple', '', '', '', '', ''],
#  ['white', '', 'apple grapefruit', 'crisp fresh', '', '', '', ''],
#  ['earth wet_rocks',
#   '',
#   'raisin raspberry plum currant raspberry',
#   'flat',
#   '',
#   '',
#   'complex',
#   'tannin'],
#  ['dark', '', 'jam ripe fruit', '', '', '', 'depth', 'soft'],
#  ['', 'rich', 'ripe apple pear fruit', 'crisp', '', '', '', 'soft'],
#  ['leather reedy oak oak herb',
#   'weight',
#   'cherry fruit',
#   'fresh',
#   '',
#   'cola spice pepper',
#   'cream cream',
#   ''],
#  ['dense', 'light_bodied', 'plum cherry jam ripe fruit', '', '', '', '', ''],
#  ['oak vanilla',
#   '',
#   'ripe juicy berry fruit',
#   '',
#   'salt',
#   '',
#   'modest',
#   'gritty tight'],
#  ['flower',
#   '',
#   'fruit lemon tangerine fruit',
#   'piercing',
#   '',
#   '',
#   'burnt',
#   'smooth'],
#  ['vanilla',
#   'lush',
#   'fruit ripe melon pineapple',
#   'clean',
#   '',
#   'nutmeg clove',
#   '',
#   ''],
#  ['french_oak oak oak leather',
#   '',
#   'ripe cherry cassis',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['wood',
#   'light_bodied',
#   'fruit red_berry fruit',
#   'bright',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dense concentrated restrained smoke',
#   'rich',
#   'ripe berry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['violet soil luminous',
#   '',
#   'berry cherry',
#   'fresh fresh sour racy',
#   '',
#   'anise',
#   '',
#   'polished'],
#  ['',
#   'rich',
#   'ripe apple pear tropical_fruit lemon pineapple',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'raspberry blackberry', '', '', '', '', 'finegrained_tannin firm'],
#  ['dust white',
#   '',
#   'stone_fruit nectarine citrus melon orange nectarine',
#   '',
#   '',
#   '',
#   'yeast linear',
#   ''],
#  ['medicinal', '', 'bramble strawberry fruit', '', '', 'cinnamon', '', ''],
#  ['oak', 'full_bodied', 'ripe plum', '', '', '', '', 'smooth'],
#  ['',
#   '',
#   'prune_raisin fruit',
#   'aggressive',
#   '',
#   'black_pepper',
#   '',
#   'tight firm'],
#  ['toast gold',
#   '',
#   'citrus fruit apple pear lemon_drop',
#   'racy',
#   '',
#   '',
#   'sparkling bitter_almond',
#   ''],
#  ['grass pea', 'thick voluptuous weight', '', '', '', '', '', ''],
#  ['',
#   'weight',
#   'plum citrus red_plum pith',
#   'crisp fresh',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['', '', 'ripe ripe citrus', '', '', '', '', 'soft'],
#  ['', '', 'fruit fruit', 'bright', '', 'spice', '', 'firm'],
#  ['smoke', 'rich', 'ripe fruit', '', '', '', '', 'firm'],
#  ['green',
#   'light_bodied',
#   'plum kiwi',
#   'edgy',
#   '',
#   '',
#   'complex cream',
#   'soft bitter'],
#  ['stalky wood',
#   '',
#   'black_currant fruit dry fruit',
#   'fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['stone vegetal', '', 'stone_fruit citrus honey', '', '', '', '', 'smooth'],
#  ['powerful wood wood',
#   'heavy heavy syrupy',
#   'sweet',
#   'fresh',
#   '',
#   '',
#   '',
#   'brawny'],
#  ['herb',
#   'light_bodied',
#   'pineapple grapefruit',
#   'tart zippy refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['oily',
#   'light_bodied plump',
#   'tropical_fruit citrus apple mango banana fruit sweet',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['white', '', 'raspberry cherry', 'fresh', '', '', '', ''],
#  ['green coconut herb', '', 'fruit bramble', 'snappy', '', '', 'burnt', ''],
#  ['tobacco herb',
#   '',
#   'blackberry currant sweet fruit',
#   '',
#   '',
#   '',
#   '',
#   'gritty'],
#  ['pink', 'light_bodied', 'dry sweet', 'fresh', '', '', '', ''],
#  ['smoke vanilla toast',
#   'rich',
#   'sweet jam apricot pineapple',
#   'crisp',
#   '',
#   '',
#   'butter',
#   ''],
#  ['earth herb', '', 'cherry cocoa fruit', '', '', '', '', 'soft'],
#  ['oxidized toast', '', '', '', '', '', '', 'soft bitter'],
#  ['', '', 'jam ripe prune_raisin', '', '', '', '', ''],
#  ['green vanilla',
#   'rich',
#   'citrus pear apple honey sweet',
#   'clean crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['green flower minerality vanilla smoke oak',
#   '',
#   'sweet pineapple apple pear honeysuckle brown_sugar',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['vanilla',
#   '',
#   'sweet pineapple grapefruit tangerine honeysuckle',
#   'crisp',
#   '',
#   'spice',
#   '',
#   ''],
#  ['herbacious grass white',
#   'heavy',
#   'currant gooseberry fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['rubber', '', 'fruit fruit', '', '', '', '', 'tight'],
#  ['white herbacious',
#   '',
#   'lemon grapefruit juicy fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['pine', 'light_bodied', 'cherry', 'crisp', '', '', 'cedar', ''],
#  ['flower vanilla dust',
#   '',
#   'off-dry sugar apricot pear',
#   'crisp',
#   '',
#   'asian_spice',
#   '',
#   ''],
#  ['tobacco mint earth tobacco tea',
#   '',
#   'cherry berry',
#   '',
#   '',
#   'spice spice',
#   'complex',
#   ''],
#  ['coconut dill flower herb powerful',
#   '',
#   'berry cassis berry',
#   'tingling',
#   '',
#   '',
#   '',
#   'tight hard'],
#  ['herb concentrated dense',
#   'rich',
#   'sweet berry jelly ripe sweet fruit berry dry fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['hay vanilla', 'full_bodied', 'fruit honey', 'vibrant', '', '', '', ''],
#  ['steel',
#   'light_bodied',
#   'fruit citrus pineapple',
#   'high_acid',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'chunky rich baked syrupy rich',
#   'black_fruit blackberry cassis',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['white savory spearmint vanilla',
#   '',
#   'citrus',
#   'crisp',
#   '',
#   'spice',
#   '',
#   'polished'],
#  ['new_wood mint', 'rich', 'berry fruit', '', '', 'spice', '', 'soft'],
#  ['new_wood', '', 'dry ripe berry prune', '', '', 'spice', '', ''],
#  ['minerality',
#   'rich',
#   'apricot sweet melon currant',
#   'fresh refreshing',
#   '',
#   'spice',
#   'complex',
#   ''],
#  ['perfumed white_flower yellow minerality',
#   'rich',
#   'apricot fruit ripe grapefruit',
#   'edgy',
#   '',
#   '',
#   'chalk',
#   'soft'],
#  ['toast minerality mint',
#   '',
#   'stone_fruit peach pear',
#   'fresh',
#   '',
#   '',
#   'almond',
#   ''],
#  ['smoke concentrated',
#   '',
#   'blueberry cherry',
#   '',
#   '',
#   'spice',
#   'bacon',
#   'round supple soft'],
#  ['',
#   'weight',
#   'plum chocolate fruit',
#   'crisp fresh',
#   '',
#   'spice',
#   'cream complex',
#   ''],
#  ['flower',
#   'rich heavy rich',
#   'fruit peach apple pear',
#   '',
#   '',
#   '',
#   'cream',
#   ''],
#  ['minerality', '', 'apple pear lime fruit', 'fresh', '', '', 'cream', ''],
#  ...]

# %%
taste_descriptors = []
taste_vectors = []

for n, taste in enumerate(core_tastes):
    print(taste)
    taste_words = [r[n] for r in review_descriptors]
    
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit(taste_words)
    dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))
        
    wine_review_descriptors = []
    wine_review_vectors = []
    
    for d in taste_words:
        descriptor_count = 0
        weighted_review_terms = []
        terms = d.split(' ')
        for term in terms:
            if term in dict_of_tfidf_weightings.keys():
                tfidf_weighting = dict_of_tfidf_weightings[term]
                try:
                    word_vector = wine_word2vec_model.wv.get_vector(term).reshape(1, 300)
                    weighted_word_vector = tfidf_weighting * word_vector
                    weighted_review_terms.append(weighted_word_vector)
                    descriptor_count += 1
                except:
                    continue
            else:
                continue
        try:
            review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
            review_vector = review_vector[0]
        except:
            review_vector = np.nan
#         terms_and_vec = [terms, review_vector]
        wine_review_vectors.append(review_vector)
        wine_review_descriptors.append(terms)
    
    taste_vectors.append(wine_review_vectors)
    taste_descriptors.append(wine_review_descriptors)
    

taste_vectors_t = list(map(list, zip(*taste_vectors)))
taste_descriptors_t = list(map(list, zip(*taste_descriptors)))

review_vecs_df = pd.DataFrame(taste_vectors_t, columns=core_tastes)

columns_taste_descriptors = [a + '_descriptors' for a in core_tastes]
review_descriptors_df = pd.DataFrame(taste_descriptors_t, columns=columns_taste_descriptors)

wine_df_vecs = pd.concat([wine_df_merged, review_descriptors_df, review_vecs_df], axis=1)
wine_df_vecs.shape
# Out:
# aroma
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
# (129971, 31)

# %%
wine_df_vecs['geo_normalized']
# Out:
# 0            Etna, Sicily & Sardinia, Italy
# 1                         , Douro, Portugal
# 2             Willamette Valley, Oregon, US
# 3         Lake Michigan Shore, Michigan, US
# 4             Willamette Valley, Oregon, US
#                         ...
# 129966                     , Mosel, Germany
# 129967                   Oregon, Oregon, US
# 129968               Alsace, Alsace, France
# 129969               Alsace, Alsace, France
# 129970               Alsace, Alsace, France
# Name: geo_normalized, Length: 129971, dtype: object

# %%
# pull the average embedding for the wine attribute across all wines. 
avg_taste_vecs = dict()
for t in core_tastes:
    # look at the average embedding for a taste, across all wines that have descriptors for that taste 
    review_arrays = wine_df_vecs[t].dropna()
    average_taste_vec = np.average(review_arrays)
    avg_taste_vecs[t] = average_taste_vec

# %%
normalized_geos = list(set(zip(wine_df_vecs['variety'], wine_df_vecs['geo_normalized'])))

def subset_wine_vectors(list_of_varieties, wine_attribute):
    wine_variety_vectors = []
    for v in list_of_varieties:

        one_var_only = wine_df_vecs.loc[(wine_df_vecs['variety'] == v[0]) & 
                                                (wine_df_vecs['geo_normalized'] == v[1])]
        if len(list(one_var_only.index)) < 1 or str(v[1][-1]) == '0':
            continue
        else:
            taste_vecs = list(one_var_only[wine_attribute])
            taste_vecs = [avg_taste_vecs[wine_attribute] if 'numpy' not in str(type(x)) else x for x in taste_vecs]
            average_variety_vec = np.average(taste_vecs, axis=0)
            
            descriptor_colname = wine_attribute + '_descriptors'
            all_descriptors = [i[0] for i in list(one_var_only[descriptor_colname])]
            word_freqs = Counter(all_descriptors)
            most_common_words = word_freqs.most_common(50)
            top_n_words = [(i[0], "{:.2f}".format(i[1]/len(taste_vecs))) for i in most_common_words]
            top_n_words = [i for i in top_n_words if len(i[0])>2]
            wine_variety_vector = [v, average_variety_vec, top_n_words]
                
            wine_variety_vectors.append(wine_variety_vector)
            
    return wine_variety_vectors


def pca_wine_variety(list_of_varieties, wine_attribute, pca=True):
    wine_var_vectors = subset_wine_vectors(normalized_geos, wine_attribute)
    
    wine_varieties = [str(w[0]).replace('(', '').replace(')', '').replace("'", '').replace('"', '') for w in wine_var_vectors]
    wine_var_vec = [w[1] for w in wine_var_vectors]
    if pca:
        pca = PCA(1)
        wine_var_vec = pca.fit_transform(wine_var_vec)
        wine_var_vec = pd.DataFrame(wine_var_vec, index=wine_varieties)
    else:
        wine_var_vec = pd.Series(wine_var_vec, index=wine_varieties)
    wine_var_vec.sort_index(inplace=True)
    
    wine_descriptors = pd.DataFrame([w[2] for w in wine_var_vectors], index=wine_varieties)
    wine_descriptors = pd.melt(wine_descriptors.reset_index(), id_vars='index')
    wine_descriptors.sort_index(inplace=True)
    
    return wine_var_vec, wine_descriptors

taste_dataframes = []
# generate the dataframe of aromas vectors as output, 
aroma_vec, aroma_descriptors = pca_wine_variety(normalized_geos, 'aroma', pca=False)
taste_dataframes.append(aroma_vec)

# generate the dataframes of nonaroma scalars
for tw in core_tastes[1:]:
    pca_w_dataframe, nonaroma_descriptors = pca_wine_variety(normalized_geos, tw, pca=True)
    taste_dataframes.append(pca_w_dataframe)
    
# combine all the dataframes created above into one 
all_nonaromas = pd.concat(taste_dataframes, axis=1)
all_nonaromas.columns = core_tastes

# %%
taste_dataframes[2]
# Out:
#                                                             0
# Abouriou, Côtes du Marmandais, Southwest France...  -8.063285
# Abouriou, Russian River Valley, California, US      -7.546587
# Agiorgitiko, , Arcadia, Greece                     -23.464617
# Agiorgitiko, , Attica, Greece                      -30.252591
# Agiorgitiko, , Corinth, Greece                     -15.694755
# ...                                                       ...
# Zweigelt, Naches Heights, Washington, US           -18.204896
# Zweigelt, Seneca Lake, New York, US                -19.744323
# Zweigelt, Yakima Valley, Washington, US            -15.713985
# Çalkarası, , Aegean, Turkey                         15.850864
# Žilavka, , Tikves, Macedonia                        43.140165
#
# [9561 rows x 1 columns]

# %%
# save the 50 top descriptors for each wine variety as a CSV file. We will us this later to dig deeper into our proposed wine recommendations.

aroma_descriptors_copy = aroma_descriptors.copy()
aroma_descriptors_copy.set_index('index', inplace=True)
aroma_descriptors_copy.dropna(inplace=True)

aroma_descriptors_copy = pd.DataFrame(aroma_descriptors_copy['value'].tolist(), index=aroma_descriptors_copy.index)
aroma_descriptors_copy.columns = ['descriptors', 'relative_frequency']
aroma_descriptors_copy.to_csv('wine_variety_descriptors.csv')

# %%
def normalize(df, cols_to_normalize):
    for feature_name in cols_to_normalize:
        print(feature_name)
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        df[feature_name] = df[feature_name].apply(lambda x: (x- min_value)/(max_value-min_value))
#         (df[feature_name] - min_value) / (max_value - min_value)
    return df

all_nonaromas_normalized = normalize(all_nonaromas, cols_to_normalize=core_tastes[1:])
all_nonaromas_normalized.to_csv('wine_aromas_nonaromas.csv')
# Out:
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
