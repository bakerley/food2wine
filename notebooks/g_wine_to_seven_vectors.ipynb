# %%
import os
import pandas as pd
import numpy as np
import string
from operator import itemgetter
from collections import Counter, OrderedDict

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %%
wine = pd.read_csv('../raw_data/winemag-data-130k-v2.csv')
wine_list = list(wine['description'])
#wine_list_normalized = [clean_description(w) for w in wine_list]
#wine_list_preprocessed = list(set(wine_list_normalized))

# %%
full_wine_reviews_list = [str(r) for r in wine_list]
full_wine_corpus = ' '.join(wine_list)
wine_sentences_tokenized = sent_tokenize(full_wine_corpus)

# %%
stop_words = set(stopwords.words('english')) 

punctuation_table = str.maketrans({key: None for key in string.punctuation})
sno = SnowballStemmer('english')

def normalize_text(raw_text):
    try:
        word_list = word_tokenize(raw_text)
        normalized_sentence = []
        for w in word_list:
            try:
                w = str(w)
                lower_case_word = str.lower(w)
                stemmed_word = sno.stem(lower_case_word)
                no_punctuation = stemmed_word.translate(punctuation_table)
                if len(no_punctuation) > 1 and no_punctuation not in stop_words:
                    normalized_sentence.append(no_punctuation)
            except:
                continue
        return normalized_sentence
    except:
        return ''

# normalized_sentences = []
# for s in sentences_tokenized:
#     normalized_text = normalize_text(s)
#     normalized_sentences.append(normalized_text)

normalized_wine_sentences = []
for s in wine_sentences_tokenized:
    normalized_text = normalize_text(s)
    normalized_wine_sentences.append(normalized_text)

# %%
import pickle

# %%
with open("../notebooks/g_wine_preprocessing.txt", "rb") as fp:   # Unpickling
    wine_sentences = pickle.load(fp)

# %%
wine_word2vec_model = Word2Vec.load("../raw_data/food_word2vec_model.bin")

# %%
descriptor_mapping = pd.read_csv('../raw_data/descriptor_mapping.csv',delimiter=';', encoding='latin1').set_index('ï»¿raw descriptor')

# %%
wine_trigram_model = Phraser.load('wine_trigrams.pkl')

# %%
variety_mapping = {'Shiraz': 'Syrah', 'Pinot Gris': 'Pinot Grigio', 'Pinot Grigio/Gris': 'Pinot Grigio', 
                   'Garnacha, Grenache': 'Grenache', 'Garnacha': 'Grenache', 'CarmenÃ¨re': 'Carmenere',
                    'GrÃ¼ner Veltliner': 'Gruner Veltliner', 'TorrontÃ©s': 'Torrontes', 
                   'RhÃ´ne-style Red Blend': 'Rhone-style Red Blend', 'AlbariÃ±o': 'Albarino',
                  'GewÃ¼rztraminer': 'Gewurztraminer', 'RhÃ´ne-style White Blend': 'Rhone-style White Blend',
                  'SpÃƒÂ¤tburgunder, Pinot Noir': 'Pinot Noir', 'Sauvignon, Sauvignon Blanc': 'Sauvignon Blanc',
                  'Pinot Nero, Pinot Noir': 'Pinot Noir', 'Malbec-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                  'Meritage, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Garnacha, Grenache': 'Grenache',
                   'FumÃ© Blanc': 'Sauvignon Blanc', 'Cabernet Sauvignon-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Cabernet Sauvignon-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Blend, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Malbec-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Merlot-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Franc-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Malbec, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Primitivo, Zinfandel': 'Zinfandel',
                   'AragonÃªs, Tempranillo': 'Aragonez, Tempranillo'
                  }

def consolidate_varieties(variety_name):
    if variety_name in variety_mapping:
        return variety_mapping[variety_name]
    else:
        return variety_name

wine_df_clean = wine.copy()
wine_df_clean['variety'] = wine_df_clean['variety'].apply(consolidate_varieties)

# %%
order_of_geographies = ['region_1', 'province', 'country']

# replace any nan values in the geography columns with the word none
def replace_nan_for_zero(value):
    if str(value) == '0' or str(value) == 'nan':
        return 'none'
    else:
        return value

for o in order_of_geographies:
    wine_df_clean[o] = wine_df_clean[o].apply(replace_nan_for_zero)

wine_df_clean.loc[:, order_of_geographies].fillna('none', inplace=True)

# %%
wine.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
variety_geo = wine_df_clean.groupby(['variety', 'country', 'province', 'region_1']).size().reset_index().rename(columns={0:'count'})
variety_geo_sliced = variety_geo.loc[variety_geo['count'] > 1]

vgeos_df = pd.DataFrame(variety_geo_sliced, columns=['variety', 'country', 'province', 'region_1', 'count']) 
vgeos_df.to_csv('varieties_all_geos.csv')

# %%
variety_geo_df = pd.read_csv('../raw_data/varieties_all_geos_normalized.csv', index_col=0)
wine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['variety', 'country', 'province', 'region_1', 'region_2'],
                         right_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'])
wine_df_merged.drop(['Unnamed: 0', 'Country', 'taster_name', 'taster_twitter_handle',
                     'Region', 'Subregion', 'count'], 
                    axis=1, inplace=True)
wine_df_merged.shape
# Out:
# (4157, 14)

# %%
'''variety_geo_df = pd.read_csv('../raw_data/varieties_all_geos_normalized.csv', index_col=0)

wine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['variety', 'country', 'province', 'region_1'],
                         right_on=['variety', 'country', 'province', 'region_1'])
wine_df_merged.drop(['Unnamed: 0', 'country', 
                     'designation', 'province', 
                     'region_1', 'taster_name', 'taster_twitter_handle', 'region_2', 'winery', 'count'], 
                    axis=1, inplace=True)
wine_df_merged.shape'''
# Out:
# "variety_geo_df = pd.read_csv('../raw_data/varieties_all_geos_normalized.csv', index_col=0)\n\nwine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['variety', 'country', 'province', 'region_1'],\n                         right_on=['variety', 'country', 'province', 'region_1'])\nwine_df_merged.drop(['Unnamed: 0', 'country', \n                     'designation', 'province', \n                     'region_1', 'taster_name', 'taster_twitter_handle', 'region_2', 'winery', 'count'], \n                    axis=1, inplace=True)\nwine_df_merged.shape"

# %%
wine_df_merged.head()
# Out:
#   country                                        description  \
# 0      US  Tart and snappy, the flavors of lime flesh and...
# 1      US  Quite tart, the fruit here touches (just barel...
# 2      US  Creamy and fresh, this is made from estate-gro...
# 3      US  This is a neutral, papery white wine, with a f...
# 4      US  Fruit-driven, with pear and apple, but an inte...
#
#                   designation  points  price province           region_1  \
# 0                         NaN      87   14.0   Oregon  Willamette Valley
# 1  Renovação Estate Vineyards      87   20.0   Oregon  Willamette Valley
# 2                         NaN      88   14.0   Oregon  Willamette Valley
# 3         Cloud Rest Vineyard      85   18.0   Oregon  Willamette Valley
# 4                         NaN      90   16.0   Oregon  Willamette Valley
#
#             region_2                                              title  \
# 0  Willamette Valley      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 1  Willamette Valley  Coelho 2015 Renovação Estate Vineyards Pinot G...
# 2  Willamette Valley  Stanton Vineyard 2013 Pinot Gris (Willamette V...
# 3  Willamette Valley  Oak Knoll 2014 Cloud Rest Vineyard Pinot Gris ...
# 4  Willamette Valley          Lange 2010 Pinot Gris (Willamette Valley)
#
#         variety            winery       Variety Province  \
# 0  Pinot Grigio         Rainstorm  Pinot Grigio   Oregon
# 1  Pinot Grigio            Coelho  Pinot Grigio   Oregon
# 2  Pinot Grigio  Stanton Vineyard  Pinot Grigio   Oregon
# 3  Pinot Grigio         Oak Knoll  Pinot Grigio   Oregon
# 4  Pinot Grigio             Lange  Pinot Grigio   Oregon
#
#                    geo_normalized
# 0  Willamette Valley, Oregon, USA
# 1  Willamette Valley, Oregon, USA
# 2  Willamette Valley, Oregon, USA
# 3  Willamette Valley, Oregon, USA
# 4  Willamette Valley, Oregon, USA

# %%
variety_geos = wine_df_merged.groupby(['Variety', 'geo_normalized']).size()
at_least_n_types = variety_geos[variety_geos > 30].reset_index()
# at_least_n_types.head(10)
wine_df_merged_filtered = pd.merge(wine_df_merged, at_least_n_types, left_on=['Variety', 'geo_normalized'], right_on=['Variety', 'geo_normalized'])
wine_df_merged_filtered = wine_df_merged_filtered[['title', 'Variety', 'geo_normalized', 'description']]
print(wine_df_merged_filtered.shape)
# Out:
# (2960, 4)

# %%
wine_reviews = list(wine_df_merged['description'])

core_tastes = ['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter']

descriptor_mappings = dict()
for c in core_tastes:
    descriptor_mapping_filtered=descriptor_mapping[descriptor_mapping['type']==c]
    descriptor_mappings[c] = descriptor_mapping_filtered                                                   
    

def return_descriptor_from_mapping(descriptor_mapping, word, core_tastes):
    if word in list(descriptor_mapping.index):
        descriptor_to_return = descriptor_mapping['level_3'][word]
        return descriptor_to_return
    else:
        return None

review_descriptors = []
for review in wine_reviews:
    taste_descriptors = []
    normalized_review = normalize_text(review)
    phrased_review = wine_trigram_model[normalized_review]
    #print(normalized_review)
    
    for c in core_tastes:                                                      
        descriptors_only = [return_descriptor_from_mapping(descriptor_mappings[c], word, c) for word in phrased_review]
        no_nones = [str(d).strip() for d in descriptors_only if d is not None]
        descriptorized_review = ' '.join(no_nones)
        taste_descriptors.append(descriptorized_review)
    review_descriptors.append(taste_descriptors)

# %%
review_descriptors
# Out:
# [['herb sage',
#   '',
#   'tropical_fruit fruit dry apple citrus dry',
#   'brisk',
#   '',
#   '',
#   '',
#   ''],
#  ['mineral jasmine jasmine', '', 'pear peach honeysuckle', '', '', '', '', ''],
#  ['white_flower flint white white minerality',
#   '',
#   'stone_fruit unripe peach citrus',
#   'crisp refreshing vibrant',
#   '',
#   '',
#   '',
#   ''],
#  ['yellow minerality', '', 'apple citrus_peel', 'crisp', '', '', '', ''],
#  ['white minerality', '', 'dry', 'crisp fresh', '', '', '', ''],
#  ['acacia yeast bread_crust savory green meditteranean_herbs minerality almond',
#   '',
#   'peach apple lemon_peel',
#   'tart bright',
#   '',
#   '',
#   '',
#   ''],
#  ['acacia white gold minerality meditteranean_herbs',
#   '',
#   'fruit apple pear dry',
#   'crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['flower white_flower hay meditteranean_herbs green minerality',
#   '',
#   'pear citrus beeswax apple citrus',
#   'bright fresh',
#   '',
#   '',
#   '',
#   'polished'],
#  ['green minerality rosemary',
#   '',
#   'honeysuckle stone_fruit apple citrus_peel',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['green minerality savory meditteranean_herbs almond',
#   'elegant',
#   'fruit peach apple citrus',
#   'tart crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['acacia yellow chamomile minerality',
#   '',
#   'apple',
#   'bright brisk',
#   '',
#   '',
#   '',
#   ''],
#  ['white_almond cut_grass minerality', '', 'citrus dry', '', '', '', '', ''],
#  ['white_flower almond',
#   'medium_bodied',
#   'apple pear citrus_peel',
#   'fresh bright',
#   'saline',
#   '',
#   '',
#   ''],
#  ['white_flower almond',
#   'medium_bodied',
#   'apple pear citrus_peel',
#   'fresh bright',
#   'saline',
#   '',
#   '',
#   ''],
#  ['yellow wild_flower herb',
#   '',
#   'citrus fruit peach lemon_drop',
#   'bright crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['toast hay savory herb green smoke',
#   'light_bodied',
#   'pear apple citrus',
#   'tart crisp fresh',
#   '',
#   'ginger',
#   '',
#   ''],
#  ['oak dill toast vanilla yellow minerality',
#   '',
#   'lemon_drop apple butterscotch candy apple',
#   'fresh',
#   '',
#   'ginger',
#   '',
#   ''],
#  ['meditteranean_herbs oregano yellow_flower cream yellow butter',
#   '',
#   'citrus dry pear apple nectarine zest',
#   '',
#   'saline saline',
#   '',
#   '',
#   'round'],
#  ['yellow_flower yellow minerality',
#   '',
#   'dry lemon_peel pear apple citrus',
#   'balsamic',
#   '',
#   '',
#   '',
#   ''],
#  ['cream green savory herb minerality',
#   '',
#   'lychee nectarine apple',
#   'balsamic edgy crisp clean',
#   '',
#   '',
#   '',
#   ''],
#  ['white jasmine cream yellow green mint minerality',
#   '',
#   'fruit apple pear',
#   'vibrant bright',
#   '',
#   '',
#   '',
#   ''],
#  ['white luminous hay green cream minerality',
#   'heavy thick',
#   'fruit citrus peach',
#   'crisp bright',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality bitter_almond',
#   '',
#   'dry candy lemon_peel butterscotch ripe apple candy',
#   '',
#   '',
#   'ginger',
#   '',
#   ''],
#  ['white wild_flower herb hay flint minerality rosemary',
#   '',
#   'dry tropical_fruit fruit apple',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['white', '', 'citrus apple', '', '', '', '', ''],
#  ['toast oak nut acacia yellow toast hazelnut flint minerality',
#   '',
#   'fruit apple candy nectarine zest',
#   'bright',
#   '',
#   '',
#   '',
#   'firm'],
#  ['herb minerality',
#   '',
#   'pineapple fruit apple peach',
#   '',
#   'saline',
#   '',
#   '',
#   'firm'],
#  ['oxidized',
#   '',
#   'caramel butterscotch apricot pear',
#   '',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['brown',
#   '',
#   'orange orange lemon_peel honey',
#   'bright',
#   '',
#   'spice nutmeg',
#   '',
#   ''],
#  ['chamomile herb vanilla cream minerality',
#   '',
#   'peach pear dry juicy apple peach',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['yellow wild_flower herb',
#   '',
#   'citrus fruit peach lemon_drop',
#   'bright crisp',
#   '',
#   '',
#   '',
#   ''],
#  ['white green length',
#   'heady',
#   'stone_fruit apple lemon tangerine peach',
#   'vibrant crisp',
#   '',
#   'ginger',
#   '',
#   ''],
#  ['flower herb sage',
#   '',
#   'fruit citrus nectarine zest lime peach',
#   'tangy',
#   'saline',
#   '',
#   '',
#   ''],
#  ['yellow yellow savory',
#   'elegant',
#   'beeswax stone_fruit apple nectarine candy lemon_drop',
#   'vibrant bright',
#   'saline',
#   '',
#   '',
#   ''],
#  ['white wild_flower herb hay flint minerality rosemary',
#   '',
#   'dry tropical_fruit fruit apple',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['white yellow spring_flower white savory herb cream minerality',
#   '',
#   'juicy fruit apple pear citrus candy',
#   'vibrant',
#   '',
#   'ginger',
#   '',
#   ''],
#  ['cream green minerality',
#   '',
#   'stone_fruit lychee juicy peach apple citrus',
#   'vibrant',
#   '',
#   '',
#   '',
#   'round'],
#  ['meditteranean_herbs minerality',
#   '',
#   'lemon pear nectarine candy citrus',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality granite hay herb', '', 'dry', 'fresh lean', '', '', '', ''],
#  ['herb minerality',
#   '',
#   'pineapple fruit apple peach',
#   '',
#   'saline',
#   '',
#   '',
#   'firm'],
#  ['chamomile flower acacia minerality almond',
#   '',
#   'dry citrus pear',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['chamomile green savory herb minerality',
#   'elegant',
#   'pear apple juicy pear',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['white flower stone', '', 'peach fruit', '', '', '', '', 'closed austere'],
#  ['white yellow minerality',
#   'heady',
#   'stone_fruit apple unripe peach lemon_peel',
#   'bright refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['meditteranean_herbs yellow_flower acacia savory herb minerality',
#   'elegant',
#   'citrus juicy lime ripe pear',
#   'fresh tangy crisp clean',
#   '',
#   '',
#   '',
#   ''],
#  ['meditteranean_herbs oregano yellow_flower cream yellow butter',
#   '',
#   'citrus dry pear apple nectarine zest',
#   '',
#   'saline saline',
#   '',
#   '',
#   'round'],
#  ['white chamomile flint gold minerality',
#   '',
#   'orange zest apple citrus',
#   'bright',
#   '',
#   'white_pepper',
#   '',
#   'round'],
#  ['hay hazelnut chamomile', '', 'fruit lime peach', '', 'saline', '', '', ''],
#  ['dust minerality',
#   '',
#   'dry fruit citrus pear melon grapefruit',
#   'tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['acacia yeast bread_crust savory green meditteranean_herbs minerality almond',
#   '',
#   'peach apple lemon_peel',
#   'tart bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'ripe fruit juicy berry fruit', 'fresh', '', '', '', 'smooth firm'],
#  ['powerful dark dark', 'rich', 'ripe fruit fruit', '', '', '', '', 'hard'],
#  ['', '', 'ripe fruit red_berry', '', '', '', '', 'soft smooth'],
#  ['minerality',
#   'full_bodied rich',
#   'ripe fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'tight'],
#  ['minerality herb', '', 'black_currant fruit', 'edgy', '', '', '', 'austere'],
#  ['wood',
#   'light_bodied',
#   'fruit red_berry fruit',
#   'bright',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dust concentrated', 'rich', 'plum fruit', '', '', '', '', ''],
#  ['granite powerful', '', 'ripe jam', '', '', '', '', ''],
#  ['wood', 'rich', '', '', '', '', '', ''],
#  ['dense dense new_wood dark',
#   'rich rich',
#   'ripe plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'tannin firm'],
#  ['dense', '', 'plum fruit', '', '', '', '', ''],
#  ['dust', '', 'fruit juicy', '', '', 'spice', '', 'firm firm'],
#  ['', 'light_bodied', 'ripe fruit red_berry', '', '', '', '', ''],
#  ['dark coffee dark',
#   '',
#   'chocolate fruit fig plum',
#   'edgy',
#   '',
#   '',
#   '',
#   'firm bitter'],
#  ['minerality concentrated', '', 'dry ripe fruit', '', '', '', '', ''],
#  ['concentrated',
#   'extracted',
#   'fruit dry red_berry',
#   'edgy',
#   '',
#   '',
#   '',
#   'firm hard'],
#  ['dense concentrated minerality',
#   'full_bodied rich',
#   'chocolate fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin tight firm'],
#  ['wood',
#   'rich full_bodied',
#   'red_fruit juicy fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['wood', '', 'fruit juicy cherry', '', '', '', '', 'round'],
#  ['wood concentrated minerality',
#   '',
#   'fruit juicy fruit',
#   'bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'ripe berry fruit juicy blackberry', 'crisp', '', '', '', ''],
#  ['dark concentrated perfumed minerality',
#   'rich',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   'tight'],
#  ['dense tar wood concentrated', '', 'fruit', '', '', '', '', ''],
#  ['smoke', 'rich', 'ripe ripe red_berry fruit', '', '', '', '', 'firm'],
#  ['', '', 'fruit ripe berry fruit', '', '', '', '', 'rustic firm'],
#  ['', 'rich', 'fruit red_berry fruit', '', '', '', '', 'soft'],
#  ['', '', 'red_berry fruit juicy', '', '', 'spice', '', 'soft firm'],
#  ['wood', 'rich', 'fruit', '', '', 'spice', '', ''],
#  ['', '', 'juicy berry fruit ripe cherry', 'fresh', '', '', '', ''],
#  ['powerful dark dense concentrated',
#   'full_bodied',
#   'fruit',
#   'brisk',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated new_wood dense', 'rich rich', 'fruit', '', '', '', '', ''],
#  ['powerful concentrated',
#   'rich bold',
#   'ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth silky'],
#  ['dense tar', 'rich', 'fruit', '', '', '', '', 'smooth'],
#  ['mint tar new_wood',
#   'full_bodied',
#   'ripe plum juicy',
#   '',
#   '',
#   '',
#   '',
#   'velvety smooth polished classy soft'],
#  ['', '', 'ripe fruit dry', '', '', '', '', ''],
#  ['', 'light_bodied', 'fruit fruit', '', '', '', '', 'soft'],
#  ['', 'light_bodied', 'fruit', '', '', '', '', 'soft'],
#  ['', '', 'ripe fruit red_berry', 'bright', '', '', '', ''],
#  ['', '', 'red_berry fruit', '', '', '', '', 'soft'],
#  ['', 'extracted', '', '', '', '', '', ''],
#  ['', 'weight', 'fruit', '', '', '', '', 'firm'],
#  ['minerality stalky', '', 'black_currant fruit', '', '', '', '', ''],
#  ['', '', 'ripe fruit', '', '', '', '', 'round firm'],
#  ['', '', 'fruit berry plum fruit fruit', 'fresh fresh', '', '', '', ''],
#  ['',
#   '',
#   'fruit ripe berry fruit',
#   'edgy edgy',
#   '',
#   '',
#   '',
#   'hard tannin bitter'],
#  ['powerful dark concentrated',
#   '',
#   'fruit plum juicy',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin'],
#  ['dense dark minerality', '', 'berry fruit sweet', '', '', '', '', ''],
#  ['barnyard dark minerality powerful dense',
#   'rich',
#   'plum ripe',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dark wood mint powerful',
#   '',
#   'fruit berry',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin round'],
#  ['',
#   'rich extracted',
#   'juicy fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   'soft round smooth'],
#  ['', 'light_bodied', 'fruit fruit plum', '', '', '', '', 'soft round soft'],
#  ['toast',
#   'light_bodied',
#   'fruit black_currant fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['', '', 'ripe fruit juicy', '', '', '', '', ''],
#  ['wood toast wood', '', 'fruit', '', '', 'spice', '', ''],
#  ['perfumed', 'light_bodied', 'fruit', '', '', '', '', ''],
#  ['wood concentrated toast vanilla', '', 'fruit', '', '', '', '', ''],
#  ['perfumed rhubarb', '', '', '', '', '', '', ''],
#  ['wood powerful dark concentrated',
#   'rich',
#   'ripe fruit chocolate cherry',
#   '',
#   '',
#   'spice',
#   '',
#   'bitter'],
#  ['french_oak dark dark',
#   '',
#   'dry ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm firm round'],
#  ['concentrated minerality', 'rich', 'dry', 'lean', '', '', '', ''],
#  ['powerful mint dark new_wood concentrated',
#   'rich',
#   'plum juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['white', 'weight warm', 'red_berry fruit', '', '', '', '', 'soft'],
#  ['herb', 'rich warm hot', 'ripe fig plum', 'fresh', '', 'spice', '', 'soft'],
#  ['wood concentrated powerful dark dense perfumed',
#   'rich',
#   'plum',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['', '', 'ripe red_berry fruit fruit', '', '', '', '', 'firm'],
#  ['smoke', 'weight', 'dry fruit juicy red_berry fruit', '', '', '', '', ''],
#  ['', '', 'fruit fruit', 'bright fresh', '', '', '', 'soft'],
#  ['dark minerality',
#   'rich full_bodied',
#   'plum ripe',
#   '',
#   '',
#   '',
#   '',
#   'smooth velvety firm'],
#  ['dark powerful dense dark',
#   '',
#   'fruit blackberry plum ripe',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense wood',
#   '',
#   'ripe juicy black_currant cassis',
#   'fresh vibrant',
#   '',
#   '',
#   '',
#   'round'],
#  ['minerality toast dense', '', 'chocolate', '', '', '', '', 'bitter'],
#  ['concentrated smoke',
#   'rich weight',
#   'ripe fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['powerful', 'rich', 'fruit', '', '', '', '', 'firm'],
#  ['powerful', '', 'fruit ripe berry fruit ripe sweet', '', '', '', '', ''],
#  ['powerful dense concentrated',
#   '',
#   'dry juicy plum',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'ripe juicy plum', 'fresh edgy', '', '', '', 'soft smooth firm'],
#  ['powerful wood dark coffee smoke oak minerality soil dense',
#   'weight',
#   'chocolate juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['smoke barbecue',
#   '',
#   'ripe berry fruit ripe',
#   'fresh edgy',
#   '',
#   '',
#   '',
#   'soft smooth'],
#  ['', 'rich rich warm', 'fruit blackberry fruit ripe', '', '', '', '', ''],
#  ['wood powerful dense concentrated wood',
#   '',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   'juicy black_currant fruit fruit',
#   'lean fresh fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['dark dense minerality concentrated',
#   '',
#   'dry plum fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dark dense wood',
#   'chunky full_bodied rich',
#   'dry fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['fat dense', '', 'fruit dry juicy', '', '', '', '', 'austere'],
#  ['', '', 'ripe berry fruit fruit', 'fresh', '', '', '', 'soft'],
#  ['sappy',
#   'medium_bodied',
#   'blackberry cherry chocolate',
#   '',
#   '',
#   'cinnamon anise',
#   '',
#   'bitter'],
#  ['oak concentrated', 'rich', 'fruit', '', '', 'spice', '', ''],
#  ['dense concentrated wood stalky',
#   '',
#   'fruit plum fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm smooth'],
#  ['wood',
#   'rich warm rich',
#   'dry berry plum fruit ripe juicy fruit sweet',
#   '',
#   '',
#   '',
#   '',
#   'firm firm'],
#  ['', 'light_bodied', 'ripe fruit', '', '', '', '', 'soft'],
#  ['concentrated powerful dense',
#   '',
#   'fruit blackberry plum',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'rich',
#   'fruit juicy plum fruit ripe jam',
#   '',
#   '',
#   '',
#   '',
#   'smooth soft'],
#  ['concentrated',
#   '',
#   'fruit black_cherry blackberry dry',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['dense powerful concentrated smoke minerality',
#   'rich rich',
#   'plum',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['toast concentrated',
#   '',
#   'ripe blackberry juicy fruit dry',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', 'rich', 'ripe fruit fruit fruit', '', '', '', '', 'smooth round'],
#  ['wood powerful',
#   'rich',
#   'cherry ripe plum fruit ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['dense wood', '', 'dry fruit berry dry', '', '', '', '', 'firm'],
#  ['', 'rich', 'berry fruit', '', '', 'spice', '', 'smooth'],
#  ['dense powerful concentrated', '', 'fruit', '', '', 'spice', '', ''],
#  ['powerful perfumed flower dense',
#   'rich elegant',
#   'fruit dry',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['smoke', '', 'ripe fruit fruit', '', '', '', '', ''],
#  ['minerality',
#   'rich',
#   'ripe plum fruit sweet fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['earth herb', '', 'fruit black_currant', 'fresh', '', 'spice', '', 'soft'],
#  ['leather dense wood', '', 'dry fruit', 'edgy', '', '', '', ''],
#  ['dark tar',
#   'rich rich extracted',
#   'plum fruit',
#   '',
#   '',
#   'licorice',
#   '',
#   'bitter'],
#  ['powerful',
#   'rich',
#   'dry blackberry fruit',
#   'edgy',
#   '',
#   'spice',
#   '',
#   'firm firm'],
#  ['powerful dark concentrated', 'rich rich', 'plum', '', '', '', '', 'firm'],
#  ['wood', 'rich', 'fruit plum fruit', '', '', 'spice', '', ''],
#  ['minerality concentrated dark', '', 'fruit dry', '', '', '', '', 'firm'],
#  ['', 'warm', 'fruit strawberry currant', '', '', 'spice', '', 'soft'],
#  ['wood', 'rich opulent', 'fruit', '', '', '', '', ''],
#  ['powerful dense stone dense wood',
#   'rich rich',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['powerful dark coffee concentrated granite',
#   'rich',
#   'ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'bitter'],
#  ['concentrated dense wood toast',
#   'rich',
#   'fruit',
#   'edgy',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['',
#   '',
#   'juicy fruit black_currant plum juicy',
#   'fresh bright',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['wood dense concentrated', 'rich', 'fruit ripe', '', '', '', '', ''],
#  ['concentrated american_oak',
#   '',
#   'ripe blackberry dry',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', '', 'ripe plum strawberry fruit sweet ripe', '', '', '', '', ''],
#  ['powerful', '', 'sweet juicy fruit', 'fresh', '', '', '', ''],
#  ['', 'rich', 'super_ripe fruit', '', '', '', '', ''],
#  ['powerful dense', 'lush', 'fruit', '', '', '', '', ''],
#  ['powerful', 'opulent', 'fruit fruit', '', '', '', '', ''],
#  ['concentrated', 'lush', 'fruit', '', '', '', '', ''],
#  ['powerful concentrated', '', 'fruit blackberry', '', '', '', '', ''],
#  ['minerality wood powerful dense concentrated',
#   '',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood concentrated', '', 'dry juicy', '', '', '', '', 'firm'],
#  ['wood',
#   'light_bodied',
#   'fruit juicy red_berry fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['powerful dense concentrated perfumed',
#   'rich light_bodied',
#   'plum',
#   '',
#   '',
#   '',
#   '',
#   'smooth polished'],
#  ['', 'rich', 'ripe fruit ripe', '', '', '', '', 'smooth'],
#  ['',
#   '',
#   'ripe fruit berry fruit blueberry',
#   'fresh edgy crisp',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['dark minerality dense concentrated',
#   '',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm grainy'],
#  ['powerful wood dense minerality dark',
#   'rich',
#   'ripe fruit berry dry',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dense', '', 'black_currant plum fruit fruit', '', '', '', '', ''],
#  ['', '', 'fruit fruit', '', '', '', '', 'firm'],
#  ['wood toast',
#   'light_bodied',
#   'fruit red_berry',
#   'crisp',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', '', 'ripe fruit-forward black_currant', '', '', '', '', 'firm'],
#  ['concentrated dark', 'rich', 'plum chocolate', '', '', 'spice', '', ''],
#  ['wood stalky',
#   '',
#   'black_currant fruit',
#   'edgy',
#   '',
#   '',
#   '',
#   'firm tannin rough round'],
#  ['', '', 'fruit', 'fresh', '', '', '', 'smooth soft'],
#  ['powerful dark concentrated dark wood', '', 'fruit', '', '', '', '', ''],
#  ['',
#   'medium_bodied',
#   'fruit red_currant cherry strawberry',
#   'bright fresh clean',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated', 'rich', 'fruit juicy', 'edgy fresh', '', '', '', ''],
#  ['dark', '', 'juicy fruit plum', 'lean piercing', '', '', '', ''],
#  ['minerality',
#   'light_bodied',
#   'cherry strawberry fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality stone',
#   '',
#   'ripe blackberry fruit dry',
#   '',
#   '',
#   'spice',
#   '',
#   'hard'],
#  ['concentrated powerful',
#   'rich',
#   'ripe fruit blackberry fruit dry',
#   '',
#   '',
#   'spice pepper',
#   '',
#   'firm'],
#  ['', '', 'ripe fruit jelly dry', 'edgy', '', '', '', 'rustic'],
#  ['wood dense',
#   'rich',
#   'berry juicy plum fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', '', 'black_currant', '', '', '', '', 'soft'],
#  ['earth dark', '', 'dry blackberry juicy', '', '', '', '', 'tannin'],
#  ['toast', 'rich succulent', 'fruit fruit', '', '', 'spice', '', 'soft'],
#  ['powerful concentrated yeast dense',
#   'heavy rich opulent rich',
#   'chocolate plum',
#   '',
#   '',
#   'licorice',
#   '',
#   'bitter'],
#  ['concentrated perfumed minerality',
#   '',
#   'ripe fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['wood stalky', '', 'berry fruit dry fruit ripe', '', '', '', '', 'smooth'],
#  ['perfumed wood', 'rich', 'dry fruit ripe', '', '', '', '', ''],
#  ['powerful dense dark concentrated',
#   'rich',
#   'fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'weight', 'fruit', 'fresh', '', '', '', ''],
#  ['dark powerful concentrated', 'rich', 'plum fruit', '', '', '', '', 'firm'],
#  ['vanilla', 'chunky', 'ripe fruit', '', '', 'spice nutmeg', '', ''],
#  ['concentrated dark coffee',
#   '',
#   'dry chocolate',
#   '',
#   '',
#   '',
#   '',
#   'firm bitter'],
#  ['', '', 'berry fruit', '', '', '', '', ''],
#  ['', '', 'ripe fruit red_berry', '', '', 'spice', '', 'soft'],
#  ['', '', 'fruit juicy fruit', 'bright', '', '', '', ''],
#  ['dense dark', 'rich', 'ripe juicy fruit', '', '', '', '', ''],
#  ['perfumed minerality',
#   'extracted rich',
#   'chocolate juicy black_currant fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   'tight bitter firm'],
#  ['concentrated dark',
#   'weight rich',
#   'dry super_ripe blackberry',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['wood dense dark wood oak powerful',
#   'rich extracted',
#   'berry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'firm'],
#  ['powerful dense', 'rich', 'ripe fruit', '', '', '', '', 'smooth'],
#  ['', 'full_bodied', 'berry fruit ripe', '', '', '', '', 'firm firm'],
#  ['wood stalky', 'rich', 'fruit dry', '', '', '', '', 'polished'],
#  ['', 'light_bodied', 'fruit fruit plum', '', '', '', '', 'soft round soft'],
#  ['powerful concentrated dense',
#   'rich elegant',
#   'fruit ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth firm'],
#  ['dark powerful concentrated dark dense wood',
#   'rich weight',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['restrained powerful dark',
#   'rich',
#   'ripe juicy fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['powerful dark wood concentrated dark',
#   'rich',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense powerful powerful', 'rich', 'fruit juicy', '', '', '', '', ''],
#  ['', '', 'ripe berry fruit', '', '', '', '', 'smooth round'],
#  ['powerful', 'elegant', 'dry ripe fruit', '', '', 'spice', '', 'smooth'],
#  ['dark wood minerality', 'weight', 'juicy fruit dry', '', '', '', '', 'firm'],
#  ['powerful dark concentrated dense wood',
#   '',
#   'fruit dry blackberry fruit',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['concentrated wood', '', 'dark_berry', '', '', 'spice', '', 'smooth round'],
#  ['concentrated', '', 'blackberry fruit ripe', '', '', '', '', 'firm'],
#  ['wood', '', 'berry fruit dry', '', '', '', '', 'firm'],
#  ['',
#   'light_bodied',
#   'juicy black_fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   'soft smooth round'],
#  ['dense dark wood', '', 'jam fruit berry dry', 'lean', '', 'spice', '', ''],
#  ['perfumed',
#   'full_bodied',
#   'fruit ripe blackberry fruit',
#   '',
#   '',
#   '',
#   '',
#   'round smooth'],
#  ['concentrated', 'rich rich', 'fruit fruit', '', '', '', '', 'soft'],
#  ['minerality', '', 'ripe plum', 'edgy', '', 'spice', '', 'soft'],
#  ['barbecue', '', 'fruit', 'fresh', '', '', '', ''],
#  ['minerality',
#   '',
#   'berry plum fruit dry fruit',
#   'edgy lean edgy',
#   '',
#   '',
#   '',
#   'firm'],
#  ['minerality', '', 'plum berry fruit dry', '', '', '', '', 'austere firm'],
#  ['perfumed wood', '', 'ripe fruit', '', '', '', '', ''],
#  ['dark concentrated dense',
#   'rich opulent hot',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['wood toast',
#   'rich elegant rich heavy',
#   'sweet stone_fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth soft tight velvety'],
#  ['violet leather burnt',
#   'rich',
#   'black_currant fruit',
#   'edgy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['powerful dark dust',
#   '',
#   'ripe ripe plum juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth velvety'],
#  ['concentrated powerful dark wood dense',
#   '',
#   'stone_fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense dust powerful wood',
#   'rich',
#   'fruit chocolate plum dry',
#   '',
#   '',
#   'spice',
#   '',
#   'bitter'],
#  ['dense mineral restrained powerful', '', 'stone_fruit', '', '', '', '', ''],
#  ['powerful concentrated dark herb wood',
#   '',
#   'berry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'firm'],
#  ['powerful', 'rich rich', 'ripe fruit dry', '', '', '', '', 'smooth round'],
#  ['wood', 'light_bodied', 'fruit ripe', 'bright', '', 'spice', '', ''],
#  ['tar', '', 'ripe juicy black_currant fruit', '', '', '', '', 'firm'],
#  ['wood dust', '', 'chocolate stone_fruit', '', '', '', '', 'grainy firm'],
#  ['wood', '', 'dry', 'lean', '', '', '', 'tannin firm'],
#  ['dense', 'rich', 'ripe fruit plum strawberry', '', '', 'pepper', '', ''],
#  ['barbecue meat', '', 'fruit fruit', 'bright', '', '', '', 'soft'],
#  ['', '', 'ripe juicy berry fruit fruit', '', '', 'spice', '', 'soft'],
#  ['', 'rich', 'juicy fruit', '', '', 'spice', '', 'soft'],
#  ['concentrated dense',
#   'rich elegant weight',
#   'ripe',
#   'fresh',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['wood dark dense concentrated',
#   'opulent weight',
#   'ripe fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['wood wood', '', 'fruit', '', '', '', '', ''],
#  ['concentrated', 'weight', 'dry ripe fruit', '', '', '', '', ''],
#  ['', '', 'ripe red_berry', 'fresh crisp', '', '', '', ''],
#  ['',
#   'rich',
#   'ripe fruit fruit',
#   'exuberant',
#   '',
#   '',
#   '',
#   'smooth soft round'],
#  ['concentrated dust oak', 'rich', 'ripe plum', '', '', '', '', 'tannin'],
#  ['', '', 'ripe juicy fruit blackberry fruit', '', '', '', '', ''],
#  ['', '', 'ripe fruit', 'edgy', '', '', '', 'firm'],
#  ['', '', 'dry ripe juicy', '', '', '', '', 'firm'],
#  ['', 'light_bodied', 'fruit fruit', '', '', '', '', 'soft'],
#  ['', 'weight rich', 'berry plum fruit', '', '', 'spice', '', 'round smooth'],
#  ['powerful dense dark', 'rich', 'blackberry ripe', '', '', '', '', ''],
#  ['wood',
#   'light_bodied light_bodied',
#   'ripe fruit juicy fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'soft'],
#  ['dark', 'rich', 'berry fruit sweet fruit', '', '', '', '', 'firm'],
#  ['dark wood dark concentrated', 'weight', 'fruit', '', '', '', '', ''],
#  ['powerful concentrated',
#   'weight',
#   'ripe berry fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['concentrated powerful',
#   'elegant',
#   'ripe fruit berry juicy',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood dark powerful concentrated',
#   'rich',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['', 'elegant', 'berry fruit', 'lean fresh', '', '', '', 'austere'],
#  ['minerality', '', 'berry fruit', '', '', '', '', ''],
#  ['', '', 'ripe fruit fruit fruit', '', '', '', '', 'smooth'],
#  ['dense wood tar dark', 'rich', 'ripe fruit chocolate', '', '', '', '', ''],
#  ['oak minerality',
#   '',
#   'ripe juicy black_currant fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['powerful concentrated dark dense minerality soil',
#   '',
#   'fruit dry',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['perfumed', '', 'ripe juicy fruit juicy', '', '', '', '', 'soft soft'],
#  ['minerality wood',
#   '',
#   'ripe fruit ripe black_currant',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth round'],
#  ['',
#   'full_bodied rich',
#   'ripe fruit black_currant fruit',
#   '',
#   '',
#   '',
#   '',
#   'round soft'],
#  ['earth dark dense concentrated powerful',
#   '',
#   'ripe fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality dense',
#   '',
#   'bramble fruit fruit juicy',
#   'fresh',
#   '',
#   '',
#   '',
#   'austere firm'],
#  ['dark dense concentrated', '', 'fruit', '', '', '', '', 'firm firm'],
#  ['minerality',
#   '',
#   'red_fruit fruit',
#   'fresh fresh',
#   '',
#   '',
#   '',
#   'soft smooth'],
#  ['', 'light_bodied', 'cherry ripe berry fruit', 'fresh', '', '', '', ''],
#  ['soil dark powerful', '', '', '', '', '', '', ''],
#  ['dense concentrated', 'rich', 'ripe fruit juicy', '', '', '', '', 'tannin'],
#  ['minerality dense dark concentrated',
#   '',
#   'ripe plum fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm firm'],
#  ['powerful dense minerality', 'rich', 'fruit', '', '', '', '', 'hard firm'],
#  ['concentrated dense powerful dense',
#   '',
#   'juicy plum sweet',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['vanilla', '', 'blackberry', '', '', '', '', ''],
#  ['concentrated',
#   '',
#   'ripe blackberry fruit',
#   '',
#   '',
#   'pepper',
#   '',
#   'silky soft'],
#  ['smoke wood',
#   'rich',
#   'ripe red_berry fruit fruit',
#   'edgy',
#   '',
#   '',
#   '',
#   'soft'],
#  ['', '', 'fruit ripe berry', '', '', '', '', 'firm'],
#  ['wood toast wood',
#   'rich',
#   'ripe blackberry fruit ripe',
#   '',
#   '',
#   'nutmeg cinnamon',
#   '',
#   ''],
#  ['concentrated', 'rich', 'ripe plum fruit', '', '', '', '', ''],
#  ['',
#   'rich rich',
#   'red_berry fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   'smooth smooth round'],
#  ['minerality concentrated', '', 'dry ripe fruit', '', '', '', '', ''],
#  ['wood dark',
#   'rich',
#   'berry fruit juicy blackberry fruit',
#   '',
#   '',
#   'spice spice',
#   '',
#   ''],
#  ['concentrated', '', 'fruit berry fruit', '', '', '', '', ''],
#  ['dark', 'rich', 'red_berry fruit juicy', '', '', '', '', ''],
#  ['vanilla toast concentrated', '', 'red_berry fruit', '', '', '', '', ''],
#  ['dark concentrated wood', '', 'red_berry fruit', '', '', 'spice', '', ''],
#  ['powerful dense oak dark', 'rich', '', '', '', '', '', 'smooth'],
#  ['',
#   'bold full_bodied light_bodied',
#   'ripe blueberry fruit dry',
#   'edgy',
#   '',
#   'pepper',
#   '',
#   'soft'],
#  ['stone wood', 'rich full_bodied', 'fruit', '', '', '', '', 'smooth'],
#  ['wood dense',
#   'rich full_bodied',
#   'ripe plum fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['', '', 'ripe fruit', '', '', '', '', 'tannin'],
#  ['concentrated', 'rich', 'fruity fruit', '', '', '', '', ''],
#  ['', '', 'chocolate fruit', '', '', 'spice', '', ''],
#  ['minerality', 'rich', 'ripe fruit fruit', 'edgy', '', '', '', 'firm'],
#  ['dense powerful herb', 'opulent', 'fruit fruit', '', '', '', '', ''],
#  ['dense powerful', '', 'plum jam fruit super_ripe ripe', '', '', '', '', ''],
#  ['coffee wood dust',
#   '',
#   'ripe fruit dry',
#   '',
#   '',
#   'licorice spice',
#   '',
#   'firm'],
#  ['wood', 'rich', 'ripe blackcurrant fruit', '', '', 'spice', '', 'smooth'],
#  ['', 'rich', 'fruit fruit', 'bright crisp', '', '', '', 'firm'],
#  ['powerful dense wood', 'rich', 'dry fruit', 'fresh', '', '', '', 'firm'],
#  ['wood concentrated',
#   'rich',
#   'juicy fruit fruit',
#   'crisp',
#   '',
#   'spice',
#   '',
#   'firm'],
#  ['brilliant dark dense', 'rich weight', 'fruit', 'fresh', '', '', '', ''],
#  ['concentrated dense powerful minerality granite stone',
#   'rich elegant',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['dark powerful', 'bold elegant', 'plum fruit', 'fresh', '', '', '', ''],
#  ['', '', 'dry dry raisin fruit juicy', '', '', '', '', ''],
#  ['minerality stalky', '', 'juicy', 'crisp', '', '', '', ''],
#  ['dense wood', 'rich', 'black_currant', '', '', 'spice', '', 'firm tannin'],
#  ['oak dense', 'rich', 'fruit', '', '', '', '', 'smooth'],
#  ['toast wood dark',
#   'rich rich full_bodied rich',
#   'fruit black_currant plum fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', 'warm', 'ripe berry', '', '', 'spice', '', ''],
#  ['powerful concentrated', '', 'ripe fruit berry', '', '', '', '', ''],
#  ['', 'warm rich', 'ripe berry plum fruit', '', '', 'spice', '', 'soft'],
#  ['concentrated minerality',
#   'full_bodied',
#   'ripe fruit fruit',
#   'bright',
#   '',
#   '',
#   '',
#   'firm'],
#  ['', '', 'dry fruit', 'crisp', '', '', '', 'firm'],
#  ['', '', 'fruit juicy ripe fruit', '', '', '', '', 'soft'],
#  ['', 'rich', '', '', '', 'spice', '', 'tannin'],
#  ['dense', 'rich', 'black_currant fruit fruit', 'crisp', '', '', '', 'smooth'],
#  ['dark dark leather concentrated', '', 'plum chocolate', '', '', '', '', ''],
#  ['powerful', 'rich', 'fruit dry', '', '', '', '', ''],
#  ['stone concentrated dense wood',
#   'rich',
#   'ripe plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['dense', 'rich', 'fruit ripe fruit juicy', '', '', '', '', 'smooth'],
#  ['concentrated dark herb wood minerality',
#   'rich',
#   'ripe berry',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['powerful concentrated dark shine wood dense',
#   '',
#   'plum juicy blackcurrant',
#   '',
#   '',
#   '',
#   '',
#   'tannin smooth'],
#  ['minerality',
#   'light_bodied',
#   'fruit fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'firm firm'],
#  ['', '', 'ripe juicy fruit jam', 'crisp', '', '', '', 'soft'],
#  ['dense', '', 'ripe fruit', '', '', '', '', ''],
#  ['powerful dense dark dark', '', 'plum berry', '', '', '', '', ''],
#  ['powerful concentrated dark minerality',
#   '',
#   'ripe fruit fruit plum',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['dense',
#   'high_alcohol rich rich',
#   'super_ripe fruit',
#   '',
#   '',
#   'pepper',
#   '',
#   ''],
#  ['concentrated dense', 'elegant', '', '', '', '', '', ''],
#  ['concentrated dark minerality',
#   'rich',
#   'plum berry fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft round tight'],
#  ['minerality', 'weight rich', 'dry', '', '', 'spice', '', 'firm'],
#  ['dense dust', '', 'berry fruit juicy', 'fresh', '', '', '', 'firm'],
#  ['concentrated', 'rich bold', 'fruit', '', '', '', '', ''],
#  ['', 'rich', 'dry ripe strawberry plum', '', '', '', '', 'soft soft'],
#  ['smoke wood', 'elegant light_bodied', 'fruit', '', '', '', '', ''],
#  ['dense tar dense', 'rich', 'fruit blackberry', '', '', '', '', ''],
#  ['minerality', 'light_bodied', 'dry fruit dry', 'fresh', '', '', '', 'firm'],
#  ['', 'rich', 'juicy blackberry fruit fruit', 'fresh', '', '', '', ''],
#  ['wood wood',
#   'opulent',
#   'ripe sweet berry fruit dry sweet dry',
#   '',
#   '',
#   '',
#   '',
#   'velvety polished'],
#  ['minerality', 'rich', 'dry', '', '', '', '', 'soft round'],
#  ['earth dark',
#   'rich extracted',
#   'chocolate berry fruit',
#   '',
#   '',
#   '',
#   '',
#   'rustic bitter firm'],
#  ['powerful dark wood concentrated dark',
#   'rich',
#   'ripe fruit chocolate',
#   '',
#   '',
#   'spice licorice',
#   '',
#   'bitter'],
#  ['toast vanilla wood powerful',
#   'weight',
#   'sweet fruit fruit',
#   '',
#   '',
#   'pepper',
#   '',
#   ''],
#  ['powerful dense', 'opulent', 'ripe fruit', '', '', '', '', ''],
#  ['powerful dense',
#   'rich',
#   'black_cherry plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin'],
#  ['powerful dense concentrated powerful dark',
#   '',
#   'ripe blackberry black_currant fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['perfumed wood', '', 'ripe fruit', '', '', '', '', ''],
#  ['perfumed dense oak',
#   '',
#   'black_currant fruit fruit',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'smooth firm'],
#  ['dense burnt',
#   'rich',
#   'ripe blackberry fruit juicy fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth firm'],
#  ['dense coffee dark',
#   'hot rich',
#   'fruit plum dry',
#   '',
#   '',
#   'spice pepper',
#   '',
#   'bitter'],
#  ['concentrated minerality',
#   'rich',
#   'blackberry fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['stone wood', 'warm rich', 'ripe fruit', '', '', '', '', ''],
#  ['dark dense concentrated restrained',
#   'rich',
#   'chocolate fruit',
#   '',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['wood dense', '', 'fruit juicy blackberry', '', '', 'spice', '', ''],
#  ['concentrated perfumed',
#   'rich warm rich',
#   'fruit ripe plum',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['wood', '', 'fruit juicy cherry', '', '', '', '', 'round'],
#  ['', 'light medium_bodied', 'fruit dry fruit', 'fresh', '', '', '', ''],
#  ['', 'hot super_rich full_bodied rich', 'fruit', '', '', '', '', 'soft'],
#  ['wood',
#   'chunky',
#   'berry fruit ripe',
#   '',
#   '',
#   'licorice nutmeg',
#   '',
#   'firm tannin'],
#  ['oak concentrated powerful',
#   'rich',
#   'ripe blackberry fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['stone dark concentrated', 'opulent', 'fruit', '', '', '', '', ''],
#  ['concentrated powerful',
#   'elegant',
#   'ripe fruit berry juicy',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['powerful', 'elegant', 'berry plum', 'exuberant', '', '', '', 'tannin'],
#  ['dense powerful', 'extracted rich', 'fruit juicy', '', '', '', '', ''],
#  ['stalky', 'light_bodied', 'fruit fruit', 'sharp edgy crisp', '', '', '', ''],
#  ['', '', 'fruit fruit', 'fresh edgy bright', '', '', '', 'tannin firm'],
#  ['toast minerality',
#   'light_bodied',
#   'ripe fruit berry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense wood toast powerful', 'rich', 'juicy fruit', '', '', 'spice', '', ''],
#  ['wood', 'warm rich', 'ripe ripe fruit', '', '', 'spice', '', 'soft'],
#  ['dense', '', 'black_currant', '', '', 'spice', '', 'smooth round'],
#  ['concentrated dark minerality', 'rich', 'fruit', '', '', '', '', 'tight'],
#  ['wood minerality',
#   '',
#   'super_ripe fruit berry',
#   '',
#   '',
#   '',
#   '',
#   'round tight'],
#  ['minerality', '', 'fruit fruit ripe berry', '', '', '', '', 'tight'],
#  ['wood dense', '', 'fruit juicy blackberry', '', '', 'spice', '', ''],
#  ['', 'rich', 'ripe fruit juicy fruit', '', '', '', '', 'smooth'],
#  ['wood',
#   'elegant',
#   'juicy fruit blackberry dry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', '', 'fruit berry fruit fruit', 'fresh bright bright', '', '', '', ''],
#  ['powerful dark concentrated dense wood',
#   'rich',
#   'fruit juicy dry ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'ripe sweet berry fruit fruit', '', '', 'spice', '', ''],
#  ['wood',
#   '',
#   'ripe cherry fruit blueberry chocolate',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'smooth bitter'],
#  ['concentrated dense oak',
#   'rich',
#   'plum currant dry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood mint toast dense stone powerful concentrated',
#   'rich',
#   'ripe fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['perfumed', 'rich', 'ripe fruit', '', '', '', '', 'tannin firm'],
#  ['dense dust concentrated wood',
#   'rich',
#   'fruit ripe jam fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality',
#   'rich succulent',
#   'ripe juicy black_currant fruit dry',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['dense', 'high_alcohol', 'fruit overripe', '', '', '', '', ''],
#  ['powerful concentrated',
#   'rich',
#   'fruit juicy',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin'],
#  ['minerality',
#   'unoaked',
#   'ripe fruit blackberry fruit',
#   'edgy bite',
#   '',
#   '',
#   '',
#   ''],
#  ['oak dark dense dark',
#   'rich rich',
#   'blackberry plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['new_wood dark dense concentrated',
#   'rich',
#   'blackberry fruit plum',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin smooth'],
#  ['powerful dark dense concentrated',
#   'full_bodied',
#   'fruit',
#   'brisk',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated wood',
#   'weight',
#   'berry fruit ripe fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'soft firm'],
#  ['wood', '', 'berry fruit fruit', 'fresh bright', '', '', '', ''],
#  ['minerality',
#   'full_bodied',
#   'ripe ripe fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'firm'],
#  ['powerful restrained dust concentrated',
#   'rich opulent',
#   'ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dark powerful wood',
#   '',
#   'fruit juicy fruit sweet fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'tannin'],
#  ['', 'elegant', 'fruit', '', '', '', '', 'firm'],
#  ['wood',
#   'rich light_bodied full_bodied chunky',
#   'ripe fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['mint wood',
#   '',
#   'sweet fruit ripe chocolate plum',
#   '',
#   '',
#   'spice',
#   '',
#   'round polished'],
#  ['gold smoke wood',
#   'light_bodied',
#   'fig fruit fruit',
#   'bright fresh edgy',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'fruit ripe fruit juicy', '', '', 'spice', '', 'soft'],
#  ['',
#   '',
#   'fruit red_currant juicy',
#   'bright crisp',
#   '',
#   '',
#   '',
#   'tight tight'],
#  ['dense powerful toast dark',
#   'rich extracted high_alcohol',
#   'fruit',
#   '',
#   '',
#   'spice pepper',
#   '',
#   'bitter'],
#  ['', 'light_bodied', 'ripe fruit juicy fruit', '', '', '', '', 'soft'],
#  ['tar dark dense dark wood',
#   'rich weight',
#   'ripe fruit chocolate',
#   '',
#   '',
#   'licorice spice',
#   '',
#   'bitter'],
#  ['dark dust concentrated wood dense powerful dark',
#   'weight rich',
#   'fruit plum berry',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['powerful dense dark', 'rich', 'plum', '', '', 'spice licorice', '', 'firm'],
#  ['powerful dark wood', 'elegant', 'fruit', '', '', '', '', ''],
#  ['dense concentrated', 'rich', 'fruit dry', '', '', 'spice', '', ''],
#  ['dark dense', '', 'cherry berry fruit', '', '', '', '', 'firm tight round'],
#  ['dense', 'weight elegant', 'fruit', '', '', '', '', ''],
#  ['', 'rich', 'fruit berry red_currant fruit', '', '', '', '', 'soft'],
#  ['concentrated',
#   'rich full_bodied',
#   'fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin'],
#  ['', '', 'fruit juicy black_currant fruit ripe', 'fresh', '', '', '', 'soft'],
#  ['',
#   '',
#   'ripe black_currant berry fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   'tannin tight'],
#  ['dark dense powerful mineral', '', 'fruit', '', '', '', '', ''],
#  ['', '', 'fruit', 'fresh bright', '', '', '', ''],
#  ['wood', '', 'ripe berry fruit', '', '', '', '', 'soft'],
#  ['', 'rich', 'fruit fruit juicy fruit', '', '', '', '', ''],
#  ['', '', 'chocolate fruit', '', '', 'spice', '', ''],
#  ['tar dark', 'rich', 'plum fruit ripe', '', '', '', '', ''],
#  ['', 'light_bodied', 'berry fruit', '', '', '', '', 'soft'],
#  ['wood dense', '', 'berry plum fruit dry', '', '', '', '', ''],
#  ['stalky herb',
#   'rich',
#   'ripe sweet fruit berry',
#   'fresh',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['concentrated', '', 'ripe fruit juicy', '', '', 'spice pepper', '', 'firm'],
#  ['', 'elegant', 'ripe dry', '', '', '', '', 'smooth'],
#  ['dark concentrated', 'opulent', 'plum', '', '', 'spice', '', ''],
#  ['powerful', '', 'fruit', '', '', 'licorice pepper', '', ''],
#  ['herb wood',
#   'elegant',
#   'berry fruit dry',
#   'exuberant fresh',
#   '',
#   'spice',
#   '',
#   'tight firm'],
#  ['wood', 'rich', 'ripe juicy fruit fruit', '', '', 'pepper', '', ''],
#  ['wood',
#   'light_bodied',
#   'ripe juicy fruit fruit-forward',
#   'bright',
#   '',
#   '',
#   '',
#   'soft soft'],
#  ['dark concentrated minerality',
#   'heavy rich',
#   'plum ripe',
#   'edgy',
#   '',
#   '',
#   '',
#   'firm firm'],
#  ['', '', 'berry fruit fruit ripe', 'fresh', '', '', '', ''],
#  ['minerality',
#   'light_bodied',
#   'ripe fruit juicy fruit fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'soft'],
#  ['wood minerality soil dense',
#   'rich weight',
#   'ripe juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['new_wood dense minerality concentrated powerful',
#   '',
#   'bramble fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin'],
#  ['new_wood powerful', 'elegant rich', 'blackberry', '', '', '', '', ''],
#  ['perfumed minerality',
#   'rich weight elegant',
#   'ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'tannin round'],
#  ['dust', 'light_bodied warm', 'jelly juicy', '', '', '', '', ''],
#  ['', '', 'fruit black_currant fruit', '', '', 'spice', '', 'soft'],
#  ['minerality', 'light_bodied', 'berry fruit', 'fresh', '', '', '', 'soft'],
#  ['wood mint', '', 'fruit', '', '', 'spice', '', 'bitter'],
#  ['', '', 'fruit jelly ripe plum cherry', 'fresh', '', '', '', 'tight tannin'],
#  ['',
#   'rich elegant',
#   'fruit dry fruit ripe',
#   'fresh vibrant clean',
#   '',
#   '',
#   '',
#   'firm'],
#  ['concentrated dense dark dark',
#   '',
#   'sweet ripe plum chocolate',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['concentrated dark dark',
#   'super_rich high_alcohol',
#   'juicy stone_fruit mulberry chocolate ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['powerful',
#   '',
#   'ripe plum prune fruit chocolate',
#   'tingling',
#   '',
#   'spice pepper',
#   '',
#   'bitter'],
#  ['dark herb concentrated',
#   'rich opulent',
#   'dry fruit cocoa',
#   '',
#   '',
#   '',
#   '',
#   'smooth firm'],
#  ['wood',
#   'light_bodied',
#   'fruit ripe berry black_currant juicy dry',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['powerful concentrated dark',
#   'rich',
#   'ripe fruit plum berry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['toast powerful dense concentrated',
#   'weight',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense mint dark minerality soil',
#   'rich hot',
#   'plum berry fruit',
#   '',
#   '',
#   '',
#   '',
#   'tight hard'],
#  ['wood',
#   'rich rich light_bodied',
#   'blackberry fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['wood dark concentrated',
#   'rich',
#   'juicy fruit ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'fruit dry', 'edgy', '', '', '', 'tight firm'],
#  ['wood', '', 'berry fruit fruit', 'fresh bright', '', '', '', ''],
#  ['', 'light_bodied', 'fruit berry fruit', 'fresh', '', '', '', ''],
#  ['dark', '', 'fruit', '', '', '', '', 'tight'],
#  ['dark minerality dense',
#   'rich',
#   'black_currant juicy',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['cedar tobacco vanilla',
#   'medium_bodied',
#   'plum dry cherry plum fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'smooth'],
#  ['cedar', '', 'cherry plum cherry fruit', 'bright', '', '', '', 'astringent'],
#  ['dense minerality concentrated', '', 'fruit juicy plum', '', '', '', '', ''],
#  ['', '', 'fruit cherry juicy', 'fresh bright', '', '', '', 'soft'],
#  ['wood toast new_wood wood',
#   'rich hot',
#   'sweet blackberry fruit',
#   'exuberant',
#   '',
#   'spice',
#   '',
#   ''],
#  ['concentrated wood dense',
#   '',
#   'black_fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'polished'],
#  ['powerful leather concentrated',
#   'rich',
#   'fruit dry plum fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['powerful concentrated',
#   'rich',
#   'fruit juicy',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin'],
#  ['wood',
#   'chunky',
#   'berry fruit ripe',
#   '',
#   '',
#   'licorice nutmeg',
#   '',
#   'firm tannin'],
#  ['dense powerful soil', '', 'ripe plum fruit', '', '', '', '', 'tight'],
#  ['minerality',
#   'light_bodied',
#   'ripe red_fruit red_berry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality concentrated', '', 'ripe berry', '', '', '', '', 'firm'],
#  ['oak minerality',
#   'light_bodied',
#   'fruit ripe berry fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   'soft'],
#  ['earth', 'rich rich', 'plum fruit', '', '', 'licorice', '', ''],
#  ['wood coffee',
#   'light_bodied',
#   'red_fruit cherry',
#   'fresh',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['powerful dark',
#   'elegant',
#   'ripe fruit berry fruit juicy',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['new_wood wood',
#   '',
#   'ripe berry fruit fruit',
#   'vibrant',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['powerful',
#   '',
#   'berry plum berry fruit fruit',
#   'edgy bright',
#   '',
#   'spice',
#   '',
#   ''],
#  ['',
#   'rich',
#   'fruit chocolate blackberry caramel',
#   'exuberant',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'juicy fruit berry', '', '', '', '', ''],
#  ['dense wood', 'weight', 'fruit ripe', 'fresh', '', 'spice', '', ''],
#  ['vanilla wood',
#   'light_bodied elegant',
#   'fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   'soft'],
#  ['minerality',
#   'light_bodied',
#   'red_currant',
#   'crisp fresh',
#   '',
#   '',
#   '',
#   'tight'],
#  ['dense powerful concentrated',
#   'rich rich',
#   'fruit plum fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['dense', '', 'plum fruit dry', 'fresh', '', '', '', ''],
#  ['powerful wood dark wood', '', 'juicy', 'edgy', '', '', '', 'firm tannin'],
#  ['dark dense', '', 'cherry berry fruit', '', '', '', '', 'firm tight round'],
#  ['wood concentrated dark dense', '', 'fruit', '', '', '', '', ''],
#  ['dense smoke minerality',
#   'rich',
#   'dry blackberry fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood', '', 'fruit black_currant', 'fresh', '', 'spice', '', ''],
#  ['', 'rich', 'berry fruit sweet jam dry juicy', '', '', 'spice', '', ''],
#  ['', 'rich', 'fruit ripe juicy fruit', '', '', '', '', 'smooth'],
#  ['dark dark', 'rich', 'fruit plum chocolate', 'fresh', '', '', '', 'firm'],
#  ['american_oak concentrated',
#   '',
#   'juicy blackberry fruit',
#   'bright bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'light_bodied', 'fruit fruit', 'bright fresh', '', '', '', ''],
#  ['dark concentrated powerful dark dense',
#   '',
#   'dry fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['wood dense concentrated powerful',
#   'elegant',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['perfumed dust',
#   'rich',
#   'plum sweet dry fruit',
#   '',
#   '',
#   'spice',
#   '',
#   'soft'],
#  ['wood toast wood', '', 'blackberry', '', '', 'spice', '', ''],
#  ['perfumed toast dense concentrated',
#   'rich full_bodied',
#   'plum fruit sweet fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['concentrated', 'rich', 'fruit juicy ripe fruit', '', '', '', '', 'firm'],
#  ['minerality powerful', '', 'black_currant fruit', '', '', '', '', ''],
#  ['flower', '', 'sweet fruit', '', '', 'licorice', '', ''],
#  ['dark powerful', 'rich rich', 'fruit', '', '', '', '', ''],
#  ['earth powerful dense', 'elegant', 'dry ripe fruit', '', '', '', '', 'firm'],
#  ['',
#   'rich',
#   'fruit juicy plum fruit ripe jam',
#   '',
#   '',
#   '',
#   '',
#   'smooth soft'],
#  ['wood',
#   '',
#   'fruit blackberry sweet juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft smooth'],
#  ['', 'light_bodied full_bodied', 'ripe berry fruit', '', '', '', '', 'soft'],
#  ['', 'rich', 'fruit dry fruit', '', '', '', '', ''],
#  ['tar wood',
#   'rich',
#   'juicy fruit blackberry sweet',
#   '',
#   '',
#   '',
#   '',
#   'smooth round'],
#  ['concentrated dense dark',
#   'rich',
#   'ripe fruit sweet blackberry',
#   'edgy',
#   '',
#   '',
#   '',
#   'firm'],
#  ['dense', '', 'black_currant fruit dry juicy fruit', '', '', '', '', 'firm'],
#  ['dark', 'rich', 'ripe plum fruit fruit', '', '', '', '', 'round'],
#  ['dark concentrated wood', '', 'red_berry fruit', '', '', 'spice', '', ''],
#  ['',
#   'full_bodied rich',
#   'ripe blackcurrant fruit',
#   '',
#   '',
#   'licorice',
#   '',
#   'soft'],
#  ['wood', 'light_bodied', 'ripe fruit', '', '', 'spice', '', 'smooth'],
#  ['', '', 'fruit', 'lean', '', '', '', 'austere tannin firm'],
#  ['', '', 'ripe fruit fruit', '', '', '', '', 'soft'],
#  ['dense concentrated wood', '', 'fruit', '', '', '', '', 'firm'],
#  ['', '', 'dry ripe juicy', '', '', '', '', 'firm'],
#  ['powerful dense wood dark herb powerful',
#   '',
#   'chocolate cocoa ripe fruit fig',
#   '',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['powerful punchy dust dark',
#   'rich',
#   'fig plum',
#   '',
#   '',
#   '',
#   '',
#   'smooth firm'],
#  ['soil minerality',
#   '',
#   'fruit juicy fruit',
#   'edgy bright',
#   '',
#   '',
#   '',
#   'beefy'],
#  ['wood perfumed',
#   'elegant rich rich',
#   'fruit dry dry',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['smoke wood',
#   'rich',
#   'fruit berry sweet ripe fruit',
#   'fresh bright',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated wood',
#   'bold rich',
# ...
#   '',
#   '',
#   '',
#   '',
#   'tannin round'],
#  ['concentrated dark powerful lengthy', '', '', '', '', '', '', ''],
#  ['soil', '', 'black_fruit dry', '', '', '', '', 'firm tannin'],
#  ['oak minerality',
#   'light_bodied',
#   'fruit ripe berry fruit',
#   'crisp',
#   '',
#   '',
#   '',
#   'soft'],
#  ['smoke dense', '', 'ripe fruit', '', '', 'spice', '', ''],
#  ['', 'rich', 'black_fruit juicy', '', '', '', '', ''],
#  ['oak', '', 'ripe juicy dry fruit black_currant', '', '', 'spice', '', ''],
#  ['tar dense concentrated',
#   'rich warm hot',
#   'fruit fruit super_ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dark powerful wood toast', '', 'fruit ripe', '', '', 'spice', '', ''],
#  ['perfumed flower concentrated', 'rich', 'fruit', '', '', '', '', ''],
#  ['minerality',
#   '',
#   'ripe juicy blackcurrant fruit',
#   'crisp edgy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['earth', '', 'fruit fruit', '', '', '', '', 'soft'],
#  ['dark',
#   'chunky full_bodied rich',
#   'inky berry fruit sweet plum fruit juicy',
#   '',
#   '',
#   '',
#   '',
#   'austere'],
#  ['gold gold wood', '', 'sweet fruit', '', '', 'spice', '', 'tight'],
#  ['minerality',
#   'warm rich',
#   'ripe dark_berry fruit fruit',
#   'edgy',
#   '',
#   '',
#   '',
#   ''],
#  ['dark concentrated dense',
#   'full_bodied weight',
#   'fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['flower dense', '', 'dry dry fruit', '', '', '', '', 'firm firm'],
#  ['',
#   'light_bodied light_bodied',
#   'fruit berry juicy',
#   'bright fresh bright',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'light_bodied', 'ripe berry fruit', '', '', '', '', ''],
#  ['dense minerality wood powerful', 'rich', 'fruit', '', '', '', '', ''],
#  ['minerality',
#   'warm full_bodied',
#   'juicy fruit ripe plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['powerful', '', 'berry fruit', '', '', 'spice', '', 'soft'],
#  ['vanilla wood',
#   'full_bodied full_bodied',
#   'ripe blackcurrant fruit fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['toast wood wood', '', 'ripe berry fruit', '', '', 'spice', '', ''],
#  ['smoke', 'extracted', 'fruit', '', '', '', '', 'firm'],
#  ['minerality dark', '', 'ripe fruit', '', '', '', '', ''],
#  ['dust', '', 'fruit fruit ripe fruit', '', '', '', '', ''],
#  ['powerful dark minerality',
#   'rich',
#   'ripe juicy fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['lengthy dense dark flower', '', 'fruit', 'fresh', '', '', '', ''],
#  ['new_wood', 'elegant', 'fruit fruit', '', '', '', '', 'smooth'],
#  ['concentrated dark',
#   'rich',
#   'fruit plum super_ripe fruit chocolate',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['perfumed dense dark',
#   'super_rich',
#   'fruit berry plum dry',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['toast wood', '', 'fruit', '', '', '', '', 'firm'],
#  ['dense minerality', '', 'ripe fruit', '', '', '', '', ''],
#  ['', '', 'red_currant', 'fresh', '', '', '', 'tight'],
#  ['dense wood dark',
#   'rich',
#   'fruit dry fruit fruit ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['stone concentrated dense', 'rich', 'fruit fruit', '', '', '', '', ''],
#  ['',
#   'full_bodied weight warm',
#   'ripe juicy fruit blackberry dry',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['wood dust',
#   '',
#   'ripe ripe plum fruit super_ripe fruit',
#   '',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['perfumed',
#   'elegant rich elegant',
#   'fruit juicy blackberry jam',
#   '',
#   '',
#   'spice',
#   '',
#   'firm'],
#  ['wood',
#   '',
#   'fruit dry fruit blueberry juicy plum',
#   '',
#   '',
#   '',
#   '',
#   'austere tight firm'],
#  ['new_wood vanilla toast', 'rich', 'fruit', '', '', '', '', ''],
#  ['concentrated powerful dense',
#   '',
#   'fruit blackberry plum',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'rich', 'ripe blackberry fruit dry juicy fruit', '', '', '', '', 'firm'],
#  ['', 'rich', 'jam fruit', '', '', '', '', ''],
#  ['wood concentrated powerful dark',
#   'rich',
#   'plum fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['concentrated minerality dark powerful', '', 'fruit', '', '', '', '', ''],
#  ['wood dark', 'rich', 'fruit fruit', '', '', 'licorice spice', '', 'firm'],
#  ['minerality concentrated dense',
#   '',
#   'juicy plum dry',
#   '',
#   '',
#   '',
#   '',
#   'firm tannin'],
#  ['shine', 'rich', 'ripe plum', '', '', '', '', 'smooth soft'],
#  ['earth', '', 'fruit fruit ripe', 'fresh', '', '', '', 'soft'],
#  ['dust', '', 'ripe fruit sweet', 'fresh', '', '', '', ''],
#  ['wood', 'rich', 'juicy fruit ripe fruit', 'fresh', '', 'spice', '', 'soft'],
#  ['dark wood minerality',
#   'rich',
#   'ripe plum berry',
#   '',
#   '',
#   '',
#   '',
#   'smooth firm'],
#  ['steel minerality',
#   'full_bodied',
#   'ripe berry fruit fruit',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['barbecue', '', 'fruit fruit ripe', '', '', '', '', 'soft'],
#  ['dense dark wood',
#   'rich rich high_alcohol',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['concentrated', 'rich', 'fruit', '', '', '', '', ''],
#  ['dense steel minerality',
#   'super_rich',
#   'ripe plum',
#   'edgy fresh',
#   '',
#   '',
#   '',
#   'firm'],
#  ['dark dense', 'rich', 'berry fruit', '', '', '', '', ''],
#  ['dark dense',
#   'full_bodied',
#   'ripe fruit berry ripe plum juicy',
#   '',
#   '',
#   '',
#   '',
#   'tannin'],
#  ['new_wood powerful dense', 'rich', 'fruit fruit', '', '', '', '', ''],
#  ['concentrated dense', '', '', '', '', '', '', 'firm tannin'],
#  ['minerality concentrated',
#   'rich hot',
#   'fruit fruit dry',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['dense dark steel wood',
#   'rich',
#   'juicy ripe sweet fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['herb wood coffee concentrated',
#   'rich',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   'polished'],
#  ['concentrated', '', 'ripe fruit', '', '', '', '', 'firm tannin'],
#  ['dense wood', '', 'plum fruit', '', '', 'spice', '', 'firm'],
#  ['wood', '', 'black_currant juicy fruit fruit', '', '', '', '', ''],
#  ['dark concentrated', '', 'ripe ripe fruit', '', '', 'spice', '', ''],
#  ['wood toast', '', 'ripe juicy fruit', '', '', 'spice spice', '', ''],
#  ['dense dust powerful',
#   'rich weight',
#   'fig raisin',
#   '',
#   '',
#   'spice pepper',
#   '',
#   ''],
#  ['concentrated',
#   'weight weight',
#   'ripe plum cherry fruit',
#   '',
#   '',
#   '',
#   '',
#   'tight firm tannin'],
#  ['', 'rich rich', 'ripe berry fruit', '', '', 'spice', '', 'round'],
#  ['wood concentrated', 'rich rich', 'plum fruit', '', '', 'spice', '', ''],
#  ['soil',
#   '',
#   'fruit ripe blackcurrant fruit juicy fruit ripe',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'warm', 'fruit berry', '', '', 'spice', '', 'soft smooth'],
#  ['dense dense minerality oak',
#   'full_bodied rich',
#   'ripe fruit juicy fruit',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['', '', 'berry fruit', '', '', '', '', 'hard firm tannin'],
#  ['', '', 'ripe ripe plum fruit', 'refreshing', '', '', '', 'soft smooth'],
#  ['concentrated',
#   'rich',
#   'super_ripe fruit fruit',
#   'bite',
#   '',
#   '',
#   '',
#   'firm'],
#  ['concentrated', 'warm', 'ripe berry fruit ripe fruit', '', '', '', '', ''],
#  ['', '', 'fruit red_berry fruit', 'crisp', '', '', '', ''],
#  ['', '', 'fruit berry sweet', '', '', '', '', ''],
#  ['', 'rich', 'fruit berry ripe juicy fruit', '', '', '', '', ''],
#  ['smoke',
#   '',
#   'ripe fruit red_berry fruit',
#   'bright crisp edgy',
#   '',
#   '',
#   '',
#   'firm'],
#  ['', '', 'berry fruit', 'fresh', '', '', '', 'soft'],
#  ['dark', 'rich', 'ripe fruit fruit', '', '', '', '', 'firm tight'],
#  ['', '', 'dry fruit', '', '', '', '', 'firm firm'],
#  ['oak', 'rich', '', '', '', '', '', 'smooth'],
#  ['minerality dense', 'rich', 'juicy fruit', '', '', '', '', 'firm'],
#  ['dark minerality leather',
#   '',
#   'plum',
#   'lean',
#   '',
#   '',
#   '',
#   'tannin firm tight'],
#  ['concentrated perfumed concentrated',
#   'rich',
#   'ripe juicy blackberry fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['wood', 'rich weight', 'ripe black_currant', '', '', 'spice', '', 'smooth'],
#  ['', 'rich opulent succulent', 'ripe fruit', '', '', '', '', 'smooth'],
#  ['concentrated powerful burnt', '', 'ripe fruit', '', '', 'pepper', '', ''],
#  ['dense concentrated dark',
#   'weight elegant lush',
#   'ripe blackcurrant fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm soft'],
#  ['', 'extracted', 'dry fruit dry', 'edgy', '', '', '', 'hard'],
#  ['', '', 'fruit berry', '', '', '', '', ''],
#  ['wood', '', 'ripe black_currant', '', '', '', '', 'soft'],
#  ['dust',
#   'elegant',
#   'blackberry dry fruit fruit',
#   'bright fresh',
#   '',
#   'spice',
#   '',
#   ''],
#  ['dense powerful dark minerality concentrated',
#   '',
#   'fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['powerful concentrated', 'rich', 'ripe berry fruit', '', '', '', '', ''],
#  ['concentrated powerful dark', 'rich', 'fruit', '', '', '', '', 'firm'],
#  ['perfumed powerful', 'rich weight', 'fruit', '', '', '', '', 'firm'],
#  ['', '', 'blackberry fruit ripe', 'fresh', '', '', '', 'soft'],
#  ['dense dust', 'heavy', 'fruit', '', '', 'spice', '', 'firm'],
#  ['wood mint', '', 'fruit', '', '', 'spice', '', 'bitter'],
#  ['concentrated dark', '', 'plum berry fruit', '', '', '', '', ''],
#  ['', 'elegant', 'fruit ripe fruit', 'vibrant', '', '', '', ''],
#  ['stalky', 'light_bodied', 'fruit fruit', 'sharp edgy crisp', '', '', '', ''],
#  ['concentrated powerful dense minerality',
#   'hot',
#   'ripe fruit juicy fruit',
#   '',
#   '',
#   '',
#   '',
#   'closed firm'],
#  ['minerality stalky',
#   'light_bodied',
#   'blackcurrant fruit',
#   'edgy',
#   '',
#   '',
#   '',
#   'soft'],
#  ['concentrated', 'rich rich', 'fruit fruit', '', '', '', '', 'soft'],
#  ['', 'rich', 'ripe sweet berry fruit fruit', '', '', 'spice', '', ''],
#  ['dark powerful concentrated dense dense',
#   'rich',
#   'fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   'firm'],
#  ['stone', 'rich', 'ripe fruit black_currant fruit', '', '', '', '', 'firm'],
#  ['green', '', 'lime rind pineapple', 'tart snappy crisp', '', '', '', ''],
#  ['steel', '', 'fruit melon orange lemon_peel lime', 'tart', '', '', '', ''],
#  ['cream steel oak',
#   '',
#   'fruit melon pear sweet honeysuckle',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['white', '', 'apple fruit', 'flat fresh', '', 'licorice', '', ''],
#  ['', '', 'fruit-forward pear apple fruit', '', '', 'licorice', '', ''],
#  ['cream',
#   'lush',
#   'stone_fruit sweet pear',
#   'fresh',
#   '',
#   'cinnamon spice',
#   '',
#   ''],
#  ['watery', 'light_bodied', 'fruit', 'tart', '', '', '', ''],
#  ['gold shine dense pollen oil vanilla',
#   'light_bodied',
#   'lemon apple pear cookie',
#   'bright clean',
#   '',
#   '',
#   '',
#   ''],
#  ['white',
#   '',
#   'ripe apple pear fruit citrus',
#   'fresh',
#   '',
#   '',
#   '',
#   'firm polished'],
#  ['minerality',
#   'refined',
#   'lemon lemon grapefruit nectarine',
#   'refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['grass', 'light_bodied', 'fruit', 'sour tart', '', '', '', ''],
#  ['dust', 'light_bodied', 'sweet apple sugar', '', '', '', '', ''],
#  ['oak', '', 'pear apple honey', '', '', '', '', 'round fleshy'],
#  ['pine tar', '', 'fruit apple orange', 'sharp fresh', '', '', '', ''],
#  ['green celery',
#   '',
#   'fruit-forward apple melon pear fruit',
#   '',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['flower steel',
#   '',
#   'lemon fruit apricot sweet',
#   'tangy bright',
#   '',
#   '',
#   '',
#   ''],
#  ['oxidized',
#   'light_bodied baked',
#   'fruit fruit',
#   '',
#   '',
#   'spice cinnamon spice',
#   '',
#   'soft'],
#  ['length', 'light_bodied', 'pear fruit', 'fresh', '', '', '', 'fleshy'],
#  ['',
#   '',
#   'sugar ripe fruit apple pear peach honeycomb ripe',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['green', '', 'berry kiwi lime fruit', '', '', '', '', ''],
#  ['spring_flower',
#   'light_bodied elegant',
#   'citrus_peel pineapple pear',
#   'fresh',
#   '',
#   'white_pepper spice',
#   '',
#   ''],
#  ['flower',
#   'light_bodied light_bodied',
#   'pear fruit sweet honey',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['minerality', '', 'citrus pineapple', 'crisp refreshing', '', '', '', ''],
#  ['wet_rocks',
#   'full_bodied light_bodied',
#   'fruit pear apple kiwi melon',
#   'fresh',
#   '',
#   'spice',
#   '',
#   'polished'],
#  ['',
#   'light_bodied',
#   'fruit apple pear peach fruit',
#   'clean',
#   '',
#   'spice',
#   '',
#   ''],
#  ['pale length',
#   'light_bodied',
#   'strawberry',
#   'bite',
#   '',
#   '',
#   '',
#   'smooth phenolic'],
#  ['lees minerality dense',
#   'warm',
#   'peach guava',
#   'crisp fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['cucumber minerality',
#   'light_bodied',
#   'gooseberry grapefruit fruit fruit',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['watery', 'light_bodied', 'lemon citrus dry', 'flat', '', '', '', 'hard'],
#  ['', '', 'pear', 'fresh fresh crisp', '', 'cinnamon spice', '', ''],
#  ['green',
#   '',
#   'grapefruit apple melon fruit fruit',
#   'fresh crisp buoyant clean',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   'light_bodied',
#   'citrus apple fruit',
#   'flat puckery',
#   '',
#   '',
#   '',
#   'bitter'],
#  ['herb',
#   'light_bodied',
#   'pear lime fruit',
#   'fresh clean tart zippy clean',
#   '',
#   '',
#   '',
#   ''],
#  ['cream lees minerality herb',
#   'pungent warm',
#   'citrus_peel',
#   'fresh refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['powerful stone length',
#   '',
#   'pineapple citrus pear',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['sappy',
#   '',
#   'apple pear grapefruit sweet lemon fruit',
#   '',
#   '',
#   '',
#   '',
#   'soft'],
#  ['', 'light_bodied', 'orange bone_dry pear peach fruit', '', '', '', '', ''],
#  ['dense green powerful',
#   '',
#   'grapefruit orange apple banana juicy fruit-forward',
#   'tart sour',
#   '',
#   '',
#   '',
#   ''],
#  ['steel white', 'light_bodied', 'pear', '', '', 'spice', '', 'soft'],
#  ['steel', '', 'cider juicy fruit', 'tart fresh clean', '', '', '', ''],
#  ['white', 'thick heavy', 'fruit ripe', 'fresh', '', '', '', ''],
#  ['pine',
#   '',
#   'fruit grapefruit citrus',
#   'tart puckery tangy refreshing',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   'dry lemon juicy ripe sweet fruit',
#   'sharp tart sour',
#   '',
#   '',
#   '',
#   ''],
#  ['sulfur', '', 'citrus fruit apple', 'crisp clean crisp', '', '', '', ''],
#  ['oak wet_rocks minerality white',
#   '',
#   'tropical_fruit pear',
#   'tart fresh fresh',
#   '',
#   '',
#   '',
#   'sleek'],
#  ['dust',
#   'full_bodied',
#   'ripe pear fruit fruit',
#   '',
#   '',
#   'cinnamon spice',
#   '',
#   ''],
#  ['',
#   'baked rich',
#   'sweet pear fruit',
#   '',
#   '',
#   'spice ginger cinnamon spice',
#   '',
#   ''],
#  ['tea',
#   'low_alcohol rich',
#   'sugar fruit pear stone_fruit honey',
#   '',
#   '',
#   '',
#   '',
#   'round'],
#  ['flower minerality steel',
#   '',
#   'stone_fruit melon peach lemon_peel lime',
#   'fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['dust',
#   '',
#   'ripe apple pear nectarine brown_sugar dry',
#   '',
#   '',
#   'cinnamon',
#   '',
#   ''],
#  ['oil butter',
#   'rich',
#   'ripe pear apple fruit honey',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['lees steel lees grass herb cream',
#   'light_bodied thick heavy light_bodied',
#   'sweet pear',
#   'fresh fresh fresh fresh',
#   '',
#   '',
#   '',
#   ''],
#  ['oak cream flower minerality',
#   'rich',
#   'butterscotch',
#   '',
#   '',
#   'white_pepper',
#   '',
#   ''],
#  ['pine mint', 'elegant', 'grapefruit fruit', '', '', 'spice', '', ''],
#  ['steel', '', 'fruit juicy apple pear', 'fresh', '', '', '', 'gripping'],
#  ['oxidized', '', 'fruit ripe', '', '', '', '', ''],
#  ['brioche vanilla_cream', '', 'apple pear', 'fresh', '', '', '', 'round'],
#  ['minerality',
#   '',
#   'pear apple fruit orange',
#   'bright refreshing crisp',
#   '',
#   'spice',
#   '',
#   ''],
#  ['pale hibiscus tea rosewater',
#   'rich',
#   'orange ripe citrus fruit',
#   '',
#   '',
#   'spice cinnamon',
#   '',
#   'round'],
#  ['steel neutral_oak lees green vanilla',
#   'baked',
#   'apple peach',
#   '',
#   '',
#   'spice',
#   '',
#   ''],
#  ['yellow cucumber green oil steel new_oak minerality',
#   'rich',
#   'fruit lemon',
#   'tart',
#   '',
#   '',
#   '',
#   'gripping'],
#  ['celery green bland watery',
#   'light_bodied',
#   'apricot apple lemon fruit',
#   'flat clean',
#   '',
#   '',
#   '',
#   ''],
#  ['steel',
#   'light_bodied light_bodied',
#   'fruit sweet pear apple fruit',
#   'spritzy',
#   '',
#   'spice',
#   '',
#   ''],
#  ['cream lees oak',
#   'light_bodied',
#   'fruit',
#   'refreshing crisp assertive',
#   '',
#   '',
#   '',
#   ''],
#  ['steel oak',
#   'weight',
#   'ripe fruit melon kiwi',
#   'tart tangy',
#   '',
#   '',
#   '',
#   ''],
#  ['sparkling minerality sparkling toast',
#   '',
#   'pear fruit',
#   'tart',
#   '',
#   '',
#   '',
#   'smooth'],
#  ['herb', '', 'melon apple fruit', 'fresh', '', '', '', 'smooth'],
#  ['', 'light_bodied', 'orange bone_dry pear peach fruit', '', '', '', '', ''],
#  ['herb', '', 'juicy fruit', 'edgy', '', '', '', 'phenolic'],
#  ['length', 'light_bodied', 'pear citrus lemon', '', '', '', '', 'fleshy'],
#  ...]

# %%
taste_descriptors = []
taste_vectors = []

for n, taste in enumerate(core_tastes):
    print(taste)
    taste_words = [r[n] for r in review_descriptors]
    
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit(taste_words)
    dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))
        
    wine_review_descriptors = []
    wine_review_vectors = []
    
    for d in taste_words:
        descriptor_count = 0
        weighted_review_terms = []
        terms = d.split(' ')
        for term in terms:
            if term in dict_of_tfidf_weightings.keys():
                tfidf_weighting = dict_of_tfidf_weightings[term]
                try:
                    word_vector = wine_word2vec_model.wv.get_vector(term).reshape(1, 300)
                    weighted_word_vector = tfidf_weighting * word_vector
                    weighted_review_terms.append(weighted_word_vector)
                    descriptor_count += 1
                except:
                    continue
            else:
                continue
        try:
            review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
            review_vector = review_vector[0]
        except:
            review_vector = np.nan
#         terms_and_vec = [terms, review_vector]
        wine_review_vectors.append(review_vector)
        wine_review_descriptors.append(terms)
    
    taste_vectors.append(wine_review_vectors)
    taste_descriptors.append(wine_review_descriptors)
    

taste_vectors_t = list(map(list, zip(*taste_vectors)))
taste_descriptors_t = list(map(list, zip(*taste_descriptors)))

review_vecs_df = pd.DataFrame(taste_vectors_t, columns=core_tastes)

columns_taste_descriptors = [a + '_descriptors' for a in core_tastes]
review_descriptors_df = pd.DataFrame(taste_descriptors_t, columns=columns_taste_descriptors)

wine_df_vecs = pd.concat([wine_df_merged, review_descriptors_df, review_vecs_df], axis=1)
wine_df_vecs.head(5)
# Out:
# aroma
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
#   country                                        description  \
# 0      US  Tart and snappy, the flavors of lime flesh and...
# 1      US  Quite tart, the fruit here touches (just barel...
# 2      US  Creamy and fresh, this is made from estate-gro...
# 3      US  This is a neutral, papery white wine, with a f...
# 4      US  Fruit-driven, with pear and apple, but an inte...
#
#                   designation  points  price province           region_1  \
# 0                         NaN      87   14.0   Oregon  Willamette Valley
# 1  Renovação Estate Vineyards      87   20.0   Oregon  Willamette Valley
# 2                         NaN      88   14.0   Oregon  Willamette Valley
# 3         Cloud Rest Vineyard      85   18.0   Oregon  Willamette Valley
# 4                         NaN      90   16.0   Oregon  Willamette Valley
#
#             region_2                                              title  \
# 0  Willamette Valley      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 1  Willamette Valley  Coelho 2015 Renovação Estate Vineyards Pinot G...
# 2  Willamette Valley  Stanton Vineyard 2013 Pinot Gris (Willamette V...
# 3  Willamette Valley  Oak Knoll 2014 Cloud Rest Vineyard Pinot Gris ...
# 4  Willamette Valley          Lange 2010 Pinot Gris (Willamette Valley)
#
#         variety  ... fat_descriptors bitter_descriptors  \
# 0  Pinot Grigio  ...              []                 []
# 1  Pinot Grigio  ...              []                 []
# 2  Pinot Grigio  ...         [cream]                 []
# 3  Pinot Grigio  ...              []                 []
# 4  Pinot Grigio  ...              []                 []
#
#                                                aroma  \
# 0  [-2.3044057, 1.7656577, -1.8665085, -5.7635765...
# 1  [3.4671462, -0.65168643, 2.7401485, -1.7691413...
# 2  [-1.4443628, -1.4515445, 0.6221052, -2.2628999...
# 3  [2.6959183, -0.6034039, -4.4925923, -2.9032035...
# 4                                                NaN
#
#                                               weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [-4.169179, 1.1868968, 0.30094403, -6.1035743,...
#
#                                                sweet  \
# 0  [0.66069156, 1.1582786, -4.7787557, -5.734443,...
# 1  [-0.7474705, 2.661012, -1.3973554, -5.317113, ...
# 2  [0.040976427, 0.48068962, -1.0463705, -4.39017...
# 3  [-1.4620538, -0.22076248, -0.9846976, -1.64091...
# 4  [-0.8910833, -0.31242326, -2.0574894, -3.88909...
#
#                                                 acid salt  \
# 0  [0.5593994, 2.9896472, -1.1942301, -2.1565619,...  NaN
# 1  [-2.4111335, 0.49238068, -2.552854, -4.102157,...  NaN
# 2  [3.874277, 1.713511, 0.7658327, -3.1345055, 5....  NaN
# 3  [1.0365291, -3.7425401, -2.6575792, -2.730917,...  NaN
# 4                                                NaN  NaN
#
#                                              piquant  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [-6.965675, 6.647032, 0.32544118, 8.876246, 4....
# 4  [-6.965675, 6.647032, 0.32544118, 8.876246, 4....
#
#                                                  fat bitter
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2  [-3.4364169, 4.4776816, 3.0765462, -1.009486, ...    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN
#
# [5 rows x 30 columns]

# %%
# pull the average embedding for the wine attribute across all wines. 
avg_taste_vecs = dict()
for t in core_tastes:
    # look at the average embedding for a taste, across all wines that have descriptors for that taste 
    review_arrays = wine_df_vecs[t].dropna()
    average_taste_vec = np.average(review_arrays)
    avg_taste_vecs[t] = average_taste_vec

# %%
normalized_geos = list(set(zip(wine_df_vecs['variety'], wine_df_vecs['geo_normalized'])))

def subset_wine_vectors(list_of_varieties, wine_attribute):
    wine_variety_vectors = []
    for v in list_of_varieties:

        one_var_only = wine_df_vecs.loc[(wine_df_vecs['Variety'] == v[0]) & 
                                                (wine_df_vecs['geo_normalized'] == v[1])]
        if len(list(one_var_only.index)) < 1 or str(v[1][-1]) == '0':
            continue
        else:
            taste_vecs = list(one_var_only[wine_attribute])
            taste_vecs = [avg_taste_vecs[wine_attribute] if 'numpy' not in str(type(x)) else x for x in taste_vecs]
            average_variety_vec = np.average(taste_vecs, axis=0)
            
            descriptor_colname = wine_attribute + '_descriptors'
            all_descriptors = [i[0] for i in list(one_var_only[descriptor_colname])]
            word_freqs = Counter(all_descriptors)
            most_common_words = word_freqs.most_common(50)
            top_n_words = [(i[0], "{:.2f}".format(i[1]/len(taste_vecs))) for i in most_common_words]
            top_n_words = [i for i in top_n_words if len(i[0])>2]
            wine_variety_vector = [v, average_variety_vec, top_n_words]
                
            wine_variety_vectors.append(wine_variety_vector)
            
    return wine_variety_vectors


def pca_wine_variety(list_of_varieties, wine_attribute, pca=True):
    wine_var_vectors = subset_wine_vectors(normalized_geos, wine_attribute)
    
    wine_varieties = [str(w[0]).replace('(', '').replace(')', '').replace("'", '').replace('"', '') for w in wine_var_vectors]
    wine_var_vec = [w[1] for w in wine_var_vectors]
    if pca:
        pca = PCA(1)
        wine_var_vec = pca.fit_transform(wine_var_vec)
        wine_var_vec = pd.DataFrame(wine_var_vec, index=wine_varieties)
    else:
        wine_var_vec = pd.Series(wine_var_vec, index=wine_varieties)
    wine_var_vec.sort_index(inplace=True)
    
    wine_descriptors = pd.DataFrame([w[2] for w in wine_var_vectors], index=wine_varieties)
    wine_descriptors = pd.melt(wine_descriptors.reset_index(), id_vars='index')
    wine_descriptors.sort_index(inplace=True)
    
    return wine_var_vec, wine_descriptors

taste_dataframes = []
# generate the dataframe of aromas vectors as output, 
aroma_vec, aroma_descriptors = pca_wine_variety(normalized_geos, 'aroma', pca=False)
taste_dataframes.append(aroma_vec)

# generate the dataframes of nonaroma scalars
for tw in core_tastes[1:]:
    pca_w_dataframe, nonaroma_descriptors = pca_wine_variety(normalized_geos, tw, pca=True)
    taste_dataframes.append(pca_w_dataframe)
    
# combine all the dataframes created above into one 
all_nonaromas = pd.concat(taste_dataframes, axis=1)
all_nonaromas.columns = core_tastes

# %%
all_nonaromas
# Out:
#                                                                                                 aroma  \
# Bordeaux-style Red Blend, Finger Lakes, New Yor...  [-3.226746, 1.7810324, 0.24879082, -0.5414489,...
# Bordeaux-style Red Blend, Long Island, New York...  [0.06627969, -1.5383883, 1.3340853, 1.2963829,...
# Bordeaux-style Red Blend, Sierra Foothills, Cal...  [-3.3335855, -1.2797539, 1.4143531, -1.6117953...
# Bordeaux-style Red Blend, South Coast, Californ...  [-3.9725761, 4.5112786, 1.0302643, 0.9029363, ...
# Cabernet Franc, Finger Lakes, New York, USA         [-2.397506, 1.0332931, 0.472259, -0.4593114, -...
# ...                                                                                               ...
# White Blend, Sierra Foothills, California, USA      [-1.4988766, 0.14053038, 0.92164135, 0.2661283...
# White Blend, Southern Oregon, Oregon, USA           [-2.0954926, 0.8583569, 0.16689874, -1.1808553...
# White Blend, Willamette Valley, Oregon, USA         [-0.29822418, 0.046197098, -3.7454133, -4.2599...
# Zinfandel, Sierra Foothills, California, USA        [-3.6750522, 1.0363878, 1.1606226, -0.08287661...
# Zinfandel, South Coast, California, USA             [-1.5133424, 0.5326165, 2.4757433, 2.2378552, ...
#
#                                                        weight      sweet  \
# Bordeaux-style Red Blend, Finger Lakes, New Yor...  -0.030542 -16.017256
# Bordeaux-style Red Blend, Long Island, New York...  -2.164904 -18.015681
# Bordeaux-style Red Blend, Sierra Foothills, Cal... -10.952851  -6.562218
# Bordeaux-style Red Blend, South Coast, Californ...  -9.925279 -28.133741
# Cabernet Franc, Finger Lakes, New York, USA         -1.704316 -14.265391
# ...                                                       ...        ...
# White Blend, Sierra Foothills, California, USA      -0.881381  17.292646
# White Blend, Southern Oregon, Oregon, USA           -5.383383  18.265796
# White Blend, Willamette Valley, Oregon, USA         15.473466  12.493213
# Zinfandel, Sierra Foothills, California, USA        -2.012935 -13.769359
# Zinfandel, South Coast, California, USA              2.176828 -26.112520
#
#                                                         acid      salt  \
# Bordeaux-style Red Blend, Finger Lakes, New Yor... -3.070442 -0.149744
# Bordeaux-style Red Blend, Long Island, New York... -7.464947 -0.149744
# Bordeaux-style Red Blend, Sierra Foothills, Cal... -1.269620 -0.149745
# Bordeaux-style Red Blend, South Coast, Californ... -1.404779 -0.149744
# Cabernet Franc, Finger Lakes, New York, USA        -4.267620  0.488892
# ...                                                      ...       ...
# White Blend, Sierra Foothills, California, USA     -0.320422 -0.149744
# White Blend, Southern Oregon, Oregon, USA           6.483460 -0.149744
# White Blend, Willamette Valley, Oregon, USA         2.018470 -0.149745
# Zinfandel, Sierra Foothills, California, USA       -1.044039 -0.149744
# Zinfandel, South Coast, California, USA            -7.789907 -0.149745
#
#                                                       piquant        fat  \
# Bordeaux-style Red Blend, Finger Lakes, New Yor...   2.258673  -0.835478
# Bordeaux-style Red Blend, Long Island, New York...  -5.160767  -0.835478
# Bordeaux-style Red Blend, Sierra Foothills, Cal...  -1.357033  11.643385
# Bordeaux-style Red Blend, South Coast, Californ...  -0.593666  -0.835478
# Cabernet Franc, Finger Lakes, New York, USA         -1.547599  -0.830551
# ...                                                       ...        ...
# White Blend, Sierra Foothills, California, USA      -3.068713   4.192974
# White Blend, Southern Oregon, Oregon, USA           -1.865767  -0.835478
# White Blend, Willamette Valley, Oregon, USA         -2.498153  -0.835479
# Zinfandel, Sierra Foothills, California, USA         3.013351  -2.068554
# Zinfandel, South Coast, California, USA             20.105466  -0.835478
#
#                                                        bitter
# Bordeaux-style Red Blend, Finger Lakes, New Yor...  -5.074528
# Bordeaux-style Red Blend, Long Island, New York...  -5.240400
# Bordeaux-style Red Blend, Sierra Foothills, Cal... -13.837542
# Bordeaux-style Red Blend, South Coast, Californ...   0.865868
# Cabernet Franc, Finger Lakes, New York, USA         -0.729579
# ...                                                       ...
# White Blend, Sierra Foothills, California, USA      -2.754886
# White Blend, Southern Oregon, Oregon, USA            0.865868
# White Blend, Willamette Valley, Oregon, USA          0.865868
# Zinfandel, Sierra Foothills, California, USA        -4.271967
# Zinfandel, South Coast, California, USA             -0.641214
#
# [68 rows x 8 columns]

# %%
# save the 50 top descriptors for each wine variety as a CSV file. We will us this later to dig deeper into our proposed wine recommendations.

aroma_descriptors_copy = aroma_descriptors.copy()
aroma_descriptors_copy.set_index('index', inplace=True)
aroma_descriptors_copy.dropna(inplace=True)

aroma_descriptors_copy = pd.DataFrame(aroma_descriptors_copy['value'].tolist(), index=aroma_descriptors_copy.index)
aroma_descriptors_copy.columns = ['descriptors', 'relative_frequency']
aroma_descriptors_copy.to_csv('wine_variety_descriptors.csv')

# %%
def normalize(df, cols_to_normalize):
    for feature_name in cols_to_normalize:
        print(feature_name)
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        df[feature_name] = df[feature_name].apply(lambda x: (x- min_value)/(max_value-min_value))
#         (df[feature_name] - min_value) / (max_value - min_value)
    return df

all_nonaromas_normalized = normalize(all_nonaromas, cols_to_normalize=core_tastes[1:])
all_nonaromas_normalized.to_csv('wine_aromas_nonaromas.csv')
# Out:
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
