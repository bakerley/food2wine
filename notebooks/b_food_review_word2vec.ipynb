# %%
# Import modules
import pandas as pd
import numpy as np
import nltk
import re

# %% [markdown]
# ## Load our data

# %%
dataset = pd.read_csv('../raw_data/Reviews.csv')

# %%
dataset.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# Selecting only the columns that contains the text

# %%
data = dataset[["Text"]].copy()

# %%
data.head(5)
# Out:
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %%
data.isnull().sum()
# Out:
# Text    0
# dtype: int64

# %%
data.shape
# Out:
# (568454, 1)

# %%
data = data.drop_duplicates()

# %% [markdown]
# ## Creating cleaning function

# %%
data.sample(5)
# Out:
#                                                      Text
# 532824  Just received my Lobster Corn Chowder. Was ver...
# 273637  never had smoked pepper before- it will be use...
# 172018  The only thing I don't like is having to buy t...
# 389366  My little Cavalier has just finished eating th...
# 126409  I haven't done a side by side taste test but I...

# %%
from bs4 import BeautifulSoup
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
def clean_reviews(review):
    cleantext = BeautifulSoup(review, "lxml").text
    # 2. Retaining only alphabets.
    review_text = re.sub("[^a-zA-Z]"," ",cleantext)
    # 3. Converting to lower case and splittingç
    word_tokens= review_text.lower().split()
    # 4. Remove stopwords
    le=WordNetLemmatizer()
    stop_words= set(stopwords.words("english"))     
    word_tokens= [le.lemmatize(w) for w in word_tokens if not w in stop_words]
    cleaned_review=" ".join(word_tokens)
    return cleaned_review

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
sentences=[]
sum=0
for review in data['Text']:
  sents =tokenizer.tokenize(review.strip())
  sum+=len(sents)
  for sent in sents:
    cleaned_sent=clean_reviews(sent)
    sentences.append(cleaned_sent) # can use word_tokenize also.
print(sum)
print(len(sentences))  # total no of sentences
# Out:
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:332: MarkupResemblesLocatorWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:332: MarkupResemblesLocatorWarning: ".." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/Greenies-Dental-Chews-ounce-Teenie/dp/B001CWEC2W/ref=sr_1_1?ie=UTF8&s=home-garden&qid=1266273814&sr=8-1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B004QQA4KK/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.doyourownpestcontrol.com/SPEC/pick-gophertrap.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B002Q7RMLA/ref=oss_product" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B000K8ESB4/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/s/ref=bl_sr_grocery?_encoding=UTF8&node=16310101&field-brandtextbin=The+Simply+Bar" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B007R900WA/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.squidoo.com/ekobrew" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:332: MarkupResemblesLocatorWarning: "///" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B004HYXZB6/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B0076MB68U/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.cooksillustrated.com/bookstore/detail.asp?PID=520" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B001THVITA/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/benoit/.pyenv/versions/3.8.6/envs/food2wine/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/B0038ZS6PU/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# 1955249
# 1955249

# %%
clean_sentence = []
for sentence in sentences:
    clean_sentence.append(sentence.split(" "))
clean_sentence
# Out:
# [['bought',
#   'several',
#   'vitality',
#   'canned',
#   'dog',
#   'food',
#   'product',
#   'found',
#   'good',
#   'quality'],
#  ['product', 'look', 'like', 'stew', 'processed', 'meat', 'smell', 'better'],
#  ['labrador', 'finicky', 'appreciates', 'product', 'better'],
#  ['product',
#   'arrived',
#   'labeled',
#   'jumbo',
#   'salted',
#   'peanut',
#   'peanut',
#   'actually',
#   'small',
#   'sized',
#   'unsalted'],
#  ['sure', 'error', 'vendor', 'intended', 'represent', 'product', 'jumbo'],
#  ['confection', 'around', 'century'],
#  ['light', 'pillowy', 'citrus', 'gelatin', 'nut', 'case', 'filbert'],
#  ['cut', 'tiny', 'square', 'liberally', 'coated', 'powdered', 'sugar'],
#  ['tiny', 'mouthful', 'heaven'],
#  ['chewy', 'flavorful'],
#  ['highly', 'recommend', 'yummy', 'treat'],
#  ['familiar', 'story', 'c'],
#  ['lewis',
#   'lion',
#   'witch',
#   'wardrobe',
#   'treat',
#   'seduces',
#   'edmund',
#   'selling',
#   'brother',
#   'sister',
#   'witch'],
#  ['looking', 'secret', 'ingredient', 'robitussin', 'believe', 'found'],
#  ['got',
#   'addition',
#   'root',
#   'beer',
#   'extract',
#   'ordered',
#   'good',
#   'made',
#   'cherry',
#   'soda'],
#  ['flavor', 'medicinal'],
#  ['great', 'taffy', 'great', 'price'],
#  ['wide', 'assortment', 'yummy', 'taffy'],
#  ['delivery', 'quick'],
#  ['taffy', 'lover', 'deal'],
#  ['got', 'wild', 'hair', 'taffy', 'ordered', 'five', 'pound', 'bag'],
#  ['taffy',
#   'enjoyable',
#   'many',
#   'flavor',
#   'watermelon',
#   'root',
#   'beer',
#   'melon',
#   'peppermint',
#   'grape',
#   'etc'],
#  ['complaint',
#   'bit',
#   'much',
#   'red',
#   'black',
#   'licorice',
#   'flavored',
#   'piece',
#   'particular',
#   'favorite'],
#  ['kid', 'husband', 'lasted', 'two', 'week'],
#  ['would', 'recommend', 'brand', 'taffy', 'delightful', 'treat'],
#  ['saltwater', 'taffy', 'great', 'flavor', 'soft', 'chewy'],
#  ['candy', 'individually', 'wrapped', 'well'],
#  ['none',
#   'candy',
#   'stuck',
#   'together',
#   'happen',
#   'expensive',
#   'version',
#   'fralinger'],
#  ['would', 'highly', 'recommend', 'candy'],
#  ['served', 'beach', 'themed', 'party', 'everyone', 'loved'],
#  ['taffy', 'good'],
#  ['soft', 'chewy'],
#  ['flavor', 'amazing'],
#  ['would', 'definitely', 'recommend', 'buying'],
#  ['satisfying'],
#  [''],
#  ['right', 'mostly', 'sprouting', 'cat', 'eat', 'grass'],
#  ['love'],
#  ['rotate', 'around', 'wheatgrass', 'rye'],
#  ['healthy', 'dog', 'food'],
#  ['good', 'digestion'],
#  ['also', 'good', 'small', 'puppy'],
#  ['dog', 'eats', 'required', 'amount', 'every', 'feeding'],
#  ['know',
#   'cactus',
#   'tequila',
#   'unique',
#   'combination',
#   'ingredient',
#   'flavour',
#   'hot',
#   'sauce',
#   'make',
#   'one',
#   'kind'],
#  ['picked',
#   'bottle',
#   'trip',
#   'brought',
#   'back',
#   'home',
#   'u',
#   'totally',
#   'blown',
#   'away'],
#  ['realized',
#   'simply',
#   'find',
#   'anywhere',
#   'city',
#   'bummed',
#   'magic',
#   'internet',
#   'case',
#   'sauce',
#   'ecstatic',
#   'love',
#   'hot',
#   'sauce',
#   'mean',
#   'really',
#   'love',
#   'hot',
#   'sauce',
#   'want',
#   'sauce',
#   'tastelessly',
#   'burn',
#   'throat',
#   'grab',
#   'bottle',
#   'tequila',
#   'picante',
#   'gourmet',
#   'de',
#   'inclan'],
#  ['realize',
#   'taste',
#   'never',
#   'want',
#   'use',
#   'sauce',
#   'thank',
#   'personal',
#   'incredible',
#   'service'],
#  ['one', 'boy', 'needed', 'lose', 'weight'],
#  ['put',
#   'food',
#   'floor',
#   'chubby',
#   'guy',
#   'protein',
#   'rich',
#   'product',
#   'food',
#   'higher',
#   'skinny',
#   'boy',
#   'jump'],
#  ['higher', 'food', 'sits', 'going', 'stale'],
#  ['really', 'go', 'food'],
#  ['chubby', 'boy', 'losing', 'ounce', 'week'],
#  ['cat', 'happily', 'eating', 'felidae', 'platinum', 'two', 'year'],
#  ['got', 'new', 'bag', 'shape', 'food', 'different'],
#  ['tried',
#   'new',
#   'food',
#   'first',
#   'put',
#   'bowl',
#   'bowl',
#   'sit',
#   'full',
#   'kitty',
#   'touch',
#   'food'],
#  ['noticed', 'similar', 'review', 'related', 'formula', 'change', 'past'],
#  ['unfortunately', 'need', 'find', 'new', 'food', 'cat', 'eat'],
#  ['good', 'flavor'],
#  ['came', 'securely', 'packed', 'fresh', 'delicious'],
#  ['love', 'twizzlers'],
#  ['strawberry', 'twizzlers', 'guilty', 'pleasure', 'yummy'],
#  ['six', 'pound', 'around', 'son'],
#  ['daughter',
#   'love',
#   'twizzlers',
#   'shipment',
#   'six',
#   'pound',
#   'really',
#   'hit',
#   'spot'],
#  ['exactly', 'would', 'expect', 'six', 'package', 'strawberry', 'twizzlers'],
#  ['love', 'eating', 'good', 'watching', 'tv', 'looking', 'movie'],
#  ['sweet'],
#  ['like',
#   'transfer',
#   'zip',
#   'lock',
#   'baggie',
#   'stay',
#   'fresh',
#   'take',
#   'time',
#   'eating'],
#  ['satisfied', 'twizzler', 'purchase'],
#  ['shared', 'others', 'enjoyed'],
#  ['definitely', 'ordering'],
#  ['twizzlers',
#   'strawberry',
#   'childhood',
#   'favorite',
#   'candy',
#   'made',
#   'lancaster',
#   'pennsylvania',
#   'candy',
#   'inc',
#   'one',
#   'oldest',
#   'confectionery',
#   'firm',
#   'united',
#   'state',
#   'subsidiary',
#   'hershey',
#   'company',
#   'company',
#   'established',
#   'young',
#   'smylie',
#   'also',
#   'make',
#   'apple',
#   'licorice',
#   'twist',
#   'green',
#   'color',
#   'blue',
#   'raspberry',
#   'licorice',
#   'twist',
#   'like',
#   'alli',
#   'keep',
#   'dry',
#   'cool',
#   'place',
#   'recommended',
#   'put',
#   'fridge'],
#  ['according',
#   'guinness',
#   'book',
#   'record',
#   'longest',
#   'licorice',
#   'twist',
#   'ever',
#   'made',
#   'measured',
#   'foot',
#   'weighted',
#   'pound',
#   'kg',
#   'made',
#   'candy',
#   'inc'],
#  ['record',
#   'breaking',
#   'twist',
#   'became',
#   'guinness',
#   'world',
#   'record',
#   'july'],
#  ['product', 'kosher'],
#  ['thank'],
#  ['candy', 'delivered', 'fast', 'purchased', 'reasonable', 'price'],
#  ['home', 'bound', 'unable', 'get', 'store', 'perfect'],
#  ['husband', 'twizzlers', 'addict'],
#  ['bought',
#   'many',
#   'time',
#   'amazon',
#   'government',
#   'employee',
#   'living',
#   'overseas',
#   'get',
#   'country',
#   'assigned'],
#  ['always', 'fresh', 'tasty', 'packed', 'well', 'arrive', 'timely', 'manner'],
#  ['bought', 'husband', 'currently', 'overseas'],
#  ['love',
#   'apparently',
#   'staff',
#   'like',
#   'also',
#   'generous',
#   'amount',
#   'twizzlers',
#   'ounce',
#   'bag',
#   'well',
#   'worth',
#   'price'],
#  ['twizzlers', 'strawberry', 'ounce', 'bag', 'pack'],
#  ['remember', 'buying', 'candy', 'kid', 'quality', 'dropped', 'year'],
#  ['still', 'superb', 'product', 'disappointed'],
#  ['love', 'candy'],
#  ['weight', 'watcher', 'cut', 'back', 'still', 'craving'],
#  ['lived', 'u', 'yr', 'miss', 'twizzlers'],
#  ['go', 'back', 'visit', 'someone', 'visit', 'always', 'stock'],
#  ['say',
#   'yum',
#   'sell',
#   'mexico',
#   'faithful',
#   'buyer',
#   'often',
#   'able',
#   'buy',
#   'right'],
#  ['product',
#   'received',
#   'advertised',
#   'twizzlers',
#   'strawberry',
#   'ounce',
#   'bag',
#   'pack'],
#  ['candy', 'red', 'flavor'],
#  ['plan', 'chewy'],
#  ['would', 'never', 'buy'],
#  ['glad', 'amazon', 'carried', 'battery'],
#  ['hard', 'time', 'finding', 'elsewhere', 'unique', 'size'],
#  ['need', 'garage', 'door', 'opener', 'great', 'deal', 'price'],
#  ['got',
#   'mum',
#   'diabetic',
#   'need',
#   'watch',
#   'sugar',
#   'intake',
#   'father',
#   'simply',
#   'chooses',
#   'limit',
#   'unnecessary',
#   'sugar',
#   'intake',
#   'one',
#   'sweet',
#   'tooth',
#   'loved',
#   'toffee',
#   'would',
#   'never',
#   'guess',
#   'sugar',
#   'free',
#   'great',
#   'eat',
#   'pretty',
#   'much',
#   'guilt',
#   'free'],
#  ['impressed',
#   'ordered',
#   'w',
#   'dark',
#   'chocolate',
#   'take',
#   'office',
#   'eat',
#   'instead',
#   'snacking',
#   'sugary',
#   'sweet',
#   'excellent'],
#  ['never', 'huge', 'coffee', 'fan'],
#  ['however',
#   'mother',
#   'purchased',
#   'little',
#   'machine',
#   'talked',
#   'trying',
#   'latte',
#   'macciato'],
#  ['coffee',
#   'shop',
#   'better',
#   'one',
#   'like',
#   'product',
#   'usually',
#   'non',
#   'coffee',
#   'drinker'],
#  ['little',
#   'dolche',
#   'guesto',
#   'machine',
#   'super',
#   'easy',
#   'use',
#   'prepares',
#   'really',
#   'good',
#   'coffee',
#   'latte',
#   'cappuccino',
#   'etc',
#   'le',
#   'minute',
#   'water',
#   'heated'],
#  ['would', 'recommend', 'dolce', 'gusto', 'anyone'],
#  ['good', 'price', 'getting', 'one'],
#  [''],
#  ['offer',
#   'great',
#   'price',
#   'great',
#   'taste',
#   'thanks',
#   'amazon',
#   'selling',
#   'product',
#   'staral'],
#  ['mccann',
#   'instant',
#   'oatmeal',
#   'great',
#   'must',
#   'oatmeal',
#   'scrape',
#   'together',
#   'two',
#   'three',
#   'minute',
#   'prepare'],
#  ['escaping',
#   'fact',
#   'however',
#   'even',
#   'best',
#   'instant',
#   'oatmeal',
#   'nowhere',
#   'near',
#   'good',
#   'even',
#   'store',
#   'brand',
#   'oatmeal',
#   'requiring',
#   'stovetop',
#   'preparation'],
#  ['still', 'mccann', 'good', 'get', 'instant', 'oatmeal'],
#  ['even', 'better', 'organic', 'natural', 'brand', 'tried'],
#  ['variety', 'mccann', 'variety', 'pack', 'taste', 'good'],
#  ['prepared',
#   'microwave',
#   'adding',
#   'boiling',
#   'water',
#   'convenient',
#   'extreme',
#   'time',
#   'issue',
#   'mccann',
#   'use',
#   'actual',
#   'cane',
#   'sugar',
#   'instead',
#   'high',
#   'fructose',
#   'corn',
#   'syrup',
#   'helped',
#   'decide',
#   'buy',
#   'product'],
#  ['real', 'sugar', 'taste', 'better', 'harmful', 'stuff'],
#  ['one', 'thing', 'like', 'though', 'mccann', 'use', 'thickener'],
#  ['oat',
#   'plus',
#   'water',
#   'plus',
#   'heat',
#   'make',
#   'creamy',
#   'tasty',
#   'oatmeal',
#   'without',
#   'need',
#   'guar',
#   'gum'],
#  ['convenience', 'product'],
#  ['maybe',
#   'guar',
#   'gum',
#   'sitting',
#   'bowl',
#   'instant',
#   'mccann',
#   'becomes',
#   'thick',
#   'gluey'],
#  ['good', 'instant', 'oatmeal', 'best', 'oatmeal', 'brand'],
#  ['us',
#   'cane',
#   'sugar',
#   'instead',
#   'high',
#   'fructouse',
#   'corn',
#   'syrup',
#   'better',
#   'sweetness',
#   'doctor',
#   'say',
#   'form',
#   'sugar',
#   'better'],
#  ['great', 'cold', 'morning', 'time', 'make', 'mccann', 'steel', 'cut', 'oat'],
#  ['apple', 'cinnamon', 'best', 'maple', 'brown', 'sugar', 'regular', 'good'],
#  ['plus',
#   'require',
#   'doctoring',
#   'actually',
#   'tell',
#   'three',
#   'flavor',
#   'apart'],
#  ['instant', 'oatmeal', 'become', 'soggy', 'minute', 'water', 'hit', 'bowl'],
#  ['mccann',
#   'instant',
#   'oatmeal',
#   'hold',
#   'texture',
#   'excellent',
#   'flavor',
#   'good',
#   'time'],
#  ['mccann',
#   'regular',
#   'oat',
#   'meal',
#   'excellent',
#   'may',
#   'take',
#   'bit',
#   'longer',
#   'prepare',
#   'time',
#   'morning'],
#  ['best',
#   'instant',
#   'brand',
#   'ever',
#   'eaten',
#   'close',
#   'second',
#   'non',
#   'instant',
#   'variety',
#   'mccann',
#   'instant',
#   'irish',
#   'oatmeal',
#   'variety',
#   'pack',
#   'regular',
#   'apple',
#   'cinnamon',
#   'maple',
#   'brown',
#   'sugar',
#   'count',
#   'box',
#   'pack'],
#  ['mccann',
#   'instant',
#   'irish',
#   'oatmeal',
#   'variety',
#   'pack',
#   'regular',
#   'apple',
#   'cinnamon',
#   'maple',
#   'brown',
#   'sugar',
#   'count',
#   'box',
#   'pack',
#   'fan',
#   'mccann',
#   'steel',
#   'cut',
#   'oat',
#   'thought',
#   'give',
#   'instant',
#   'variety',
#   'try'],
#  ['found',
#   'hardy',
#   'meal',
#   'sweet',
#   'great',
#   'folk',
#   'like',
#   'post',
#   'bariatric',
#   'surgery',
#   'need',
#   'food',
#   'palatable',
#   'easily',
#   'digestible',
#   'fiber',
#   'make',
#   'bloat'],
#  ['u',
#   'celiac',
#   'disease',
#   'product',
#   'lifesaver',
#   'could',
#   'better',
#   'getting',
#   'almost',
#   'half',
#   'price',
#   'grocery',
#   'health',
#   'food',
#   'store'],
#  ['love', 'mccann', 'instant', 'oatmeal', 'flavor'],
#  ['thanks', 'abby'],
#  ['else', 'need', 'know'],
#  ['oatmeal',
#   'instant',
#   'make',
#   'half',
#   'cup',
#   'low',
#   'fat',
#   'milk',
#   'add',
#   'raisin',
#   'nuke',
#   'second'],
#  ['expensive',
#   'kroger',
#   'store',
#   'brand',
#   'oatmeal',
#   'maybe',
#   'little',
#   'tastier',
#   'better',
#   'texture',
#   'something'],
#  ['still', 'oatmeal'],
#  ['mmm', 'convenient'],
#  ['visiting',
#   'friend',
#   'nate',
#   'morning',
#   'coffee',
#   'came',
#   'storage',
#   'room',
#   'packet',
#   'mccanns',
#   'instant',
#   'irish',
#   'oatmeal'],
#  ['suggested', 'try', 'use', 'stash'],
#  ['sometimes',
#   'nate',
#   'dose',
#   'give',
#   'chance',
#   'say',
#   'ended',
#   'trying',
#   'apple',
#   'cinn'],
#  ['found', 'tastefull', 'made', 'water', 'powdered', 'milk'],
#  ['go', 'good', 'j'],
#  ['coffee',
#   'slice',
#   'toast',
#   'ready',
#   'take',
#   'world',
#   'day',
#   'least',
#   'jerry',
#   'reith'],
#  ['ordered', 'wife', 'reccomended', 'daughter'],
#  ['almost', 'every', 'morning', 'like', 'flavor'],
#  ['happy', 'happy'],
#  ['mccann',
#   'instant',
#   'irish',
#   'oatmeal',
#   'variety',
#   'pack',
#   'regular',
#   'apple',
#   'cinnamon',
#   'maple',
#   'brown',
#   'sugar',
#   'count',
#   'box',
#   'pack'],
#  ['variety', 'pack', 'taste', 'great', 'every', 'morning'],
#  ['cent',
#   'per',
#   'meal',
#   'understand',
#   'everyone',
#   'earth',
#   'buying',
#   'stuff',
#   'maple',
#   'brown',
#   'sugar',
#   'terrific',
#   'followed',
#   'apple',
#   'cinnamon',
#   'followed',
#   'regular'],
#  ['get',
#   'tired',
#   'ole',
#   'thing',
#   'taste',
#   'great',
#   'boil',
#   'water',
#   'small',
#   'pot',
#   'empty',
#   'packet',
#   'bowl',
#   'pour',
#   'boiling',
#   'water',
#   'watch',
#   'expand',
#   'x',
#   'size',
#   'taste',
#   'really',
#   'good',
#   'take',
#   'minute',
#   'prepare',
#   'sure',
#   'everyone',
#   'earth'],
#  ['convenient',
#   'healthy',
#   'quick',
#   'excellent',
#   'quality',
#   'extremely',
#   'cheap'],
#  ['mccann',
#   'make',
#   'oatmeal',
#   'every',
#   'oatmeal',
#   'connoisseur',
#   'whether',
#   'one',
#   'like',
#   'raw',
#   'pellet',
#   'state',
#   'cook',
#   'half',
#   'hour',
#   'sloth',
#   'addled',
#   'instant',
#   'done',
#   'microwave',
#   'three',
#   'minute'],
#  ['good',
#   'sure',
#   'beauty',
#   'instant',
#   'variety',
#   'available',
#   'different',
#   'flavor',
#   'well',
#   'regular',
#   'variety',
#   'pack',
#   'allows',
#   'different',
#   'taste',
#   'explored',
#   'well',
#   'giving',
#   'chance',
#   'experience',
#   'difference',
#   'mccann',
#   'well',
#   'known',
#   'oatmeal'],
#  ['personally',
#   'like',
#   'mccann',
#   'cook',
#   'thicker',
#   'body',
#   'top',
#   'brand',
#   'america'],
#  ['apple',
#   'cinnamon',
#   'though',
#   'tends',
#   'little',
#   'liquidy',
#   'may',
#   'want',
#   'experiment',
#   'amount',
#   'water',
#   'add'],
#  ['watt',
#   'microwave',
#   'oatmeal',
#   'cook',
#   'one',
#   'minute',
#   'twenty',
#   'seven',
#   'second',
#   'also',
#   'watch',
#   'get',
#   'handle',
#   'much',
#   'time',
#   'water',
#   'use',
#   'bad',
#   'thing',
#   'consider',
#   'bad',
#   'thing',
#   'offering',
#   'buy',
#   'lot',
#   'end',
#   'six',
#   'ten',
#   'count',
#   'box'],
#  ['good',
#   'whole',
#   'family',
#   'oatmeal',
#   'eater',
#   'single',
#   'person',
#   'alone',
#   'well',
#   'love',
#   'oatmeal'],
#  ['mccann',
#   'oatmeal',
#   'every',
#   'morning',
#   'ordering',
#   'amazon',
#   'able',
#   'save',
#   'almost',
#   'per',
#   'box',
#   'great',
#   'product'],
#  ['taste', 'great', 'healthy'],
#  ['mccann', 'oatmeal', 'good', 'quality', 'choice'],
#  ['favorite', 'apple', 'cinnamon', 'find', 'none', 'overly', 'sugary'],
#  ['good', 'hot', 'breakfast', 'minute', 'excellent'],
#  ['really',
#   'like',
#   'mccann',
#   'steel',
#   'cut',
#   'oat',
#   'find',
#   'cook',
#   'often',
#   'taste',
#   'much',
#   'better',
#   'grocery',
#   'store',
#   'brand',
#   'convenient',
#   'anything',
#   'keep',
#   'eating',
#   'oatmeal',
#   'regularly',
#   'good',
#   'thing'],
#  ['seems',
#   'little',
#   'wholesome',
#   'supermarket',
#   'brand',
#   'somewhat',
#   'mushy',
#   'quite',
#   'much',
#   'flavor',
#   'either'],
#  ['pas', 'muster', 'kid', 'probably', 'buy'],
#  ['good', 'oatmeal'],
#  ['like', 'apple', 'cinnamon', 'best'],
#  ['though',
#   'follow',
#   'direction',
#   'package',
#   'since',
#   'always',
#   'come',
#   'soupy',
#   'taste'],
#  ['could',
#   'since',
#   'like',
#   'oatmeal',
#   'really',
#   'thick',
#   'add',
#   'milk',
#   'top'],
#  ['flavor', 'good'],
#  ['however', 'see', 'differce', 'oaker', 'oat', 'brand', 'mushy'],
#  ['really', 'like', 'maple', 'brown', 'sugar', 'flavor'],
#  ['regular', 'fine', 'brown', 'sugar', 'added'],
#  ['apple', 'cinnamon', 'flavor', 'ok'],
#  ['quick', 'easy', 'satisfying', 'breakfast', 'order', 'brand', 'variety'],
#  ['get', 'maple', 'brown', 'sugar'],
#  ['stuff', 'buy', 'big', 'box', 'store'],
#  ['nothing', 'healthy'],
#  ['carbs', 'sugar'],
#  ['save', 'money', 'get', 'something', 'least', 'taste'],
#  ['oatmeal', 'good'],
#  ['mushy', 'soft', 'like'],
#  ['quaker', 'oat', 'way', 'go'],
#  ['got',
#   'free',
#   'package',
#   'bottle',
#   'bloody',
#   'mary',
#   'mix',
#   'bought',
#   'seller',
#   'advertising',
#   'worked',
#   'lol',
#   'tried',
#   'shared',
#   'buddy',
#   'loved'],
#  ['im', 'buy', 'noticed', 'review', 'yet', 'well'],
#  ['hot', 'burn', 'mouth', 'forever', 'hot', 'nice', 'temp'],
#  ['perfect', 'u'],
#  ['stock', 'last', 'time', 'looked'],
#  ['go',
#   'vermont',
#   'country',
#   'store',
#   'weston',
#   'find',
#   'along',
#   'jaw',
#   'harp',
#   'cranberry',
#   'horseradish',
#   'sauce',
#   'fartless',
#   'black',
#   'bean',
#   'salsa',
#   'apple',
#   'cider',
#   'jelly',
#   'newton',
#   'cradle',
#   'art',
#   'motion',
#   'staple',
#   'vermont',
#   'maple',
#   'syrup',
#   'back',
#   'as',
#   'kickin',
#   'peanut'],
#  ['hot'],
#  ['activate', 'perspiration', 'gland', 'behind', 'ear', 'arm'],
#  ['requires',
#   'beverage',
#   'advertised',
#   'glass',
#   'cold',
#   'milk',
#   'box',
#   'kleenex',
#   'since',
#   'make',
#   'nose',
#   'run'],
#  ['look', 'like', 'ordinary', 'peanut', 'already', 'giving', 'idea', 'work'],
#  ['suspect',
#   'people',
#   'hitting',
#   'goody',
#   'absence',
#   'especially',
#   'colleague',
#   'greg'],
#  ['going',
#   'take',
#   'work',
#   'earliest',
#   'opportunity',
#   'empty',
#   'content',
#   'ordinary',
#   'planter',
#   'peanut',
#   'see',
#   'whose',
#   'cry',
#   'whose',
#   'nose',
#   'running',
#   'return',
#   'shaken',
#   'ensure',
#   'spice',
#   'evenly',
#   'distributed'],
#  ['important',
#   'wash',
#   'hand',
#   'consumption',
#   'touch',
#   'eye',
#   'go',
#   'nut',
#   'as',
#   'kickin',
#   'peanut',
#   'p'],
#  ['sharing',
#   'peanut',
#   'deliberately',
#   'probably',
#   'give',
#   'greg',
#   'jaw',
#   'harp',
#   'christmas'],
#  ['insulted'],
#  ['used', 'spicy', 'food', 'south', 'texas', 'spicy'],
#  ['doubt', 'much', 'habanero', 'used'],
#  ['could', 'take', 'notch', 'two'],
#  ['roast', 'home', 'stove', 'top', 'popcorn', 'popper', 'outside', 'course'],
#  ['bean',
#   'coffee',
#   'bean',
#   'direct',
#   'green',
#   'mexican',
#   'altura',
#   'seem',
#   'well',
#   'suited',
#   'method'],
#  ['first',
#   'second',
#   'crack',
#   'distinct',
#   'roasted',
#   'bean',
#   'medium',
#   'slightly',
#   'dark',
#   'great',
#   'result',
#   'every',
#   'time'],
#  ['aroma', 'strong', 'persistent'],
#  ['taste', 'smooth', 'velvety', 'yet', 'lively'],
#  ['roast', 'large', 'cast', 'iron', 'pan', 'grill', 'bag', 'time'],
#  ['smell', 'wonderful', 'roasted', 'bean', 'taste', 'delicious'],
#  ['importantly', 'coffee', 'smooth', 'bitter', 'aftertaste'],
#  ['numerous',
#   'occasion',
#   'send',
#   'roasted',
#   'bean',
#   'home',
#   'friend',
#   'like',
#   'much'],
#  ['deal', 'awesome'],
#  ['arrived',
#   'halloween',
#   'indicated',
#   'enough',
#   'satisfy',
#   'trick',
#   'treater'],
#  ['love',
#   'quality',
#   'product',
#   'much',
#   'le',
#   'expensive',
#   'local',
#   'store',
#   'candy'],
#  ['chocolate', 'say'],
#  ['great', 'variety', 'everything', 'family', 'love'],
#  ['family', 'six', 'go', 'fast'],
#  ['perfect', 'variety'],
#  ['kit', 'kat', 'reeses', 'take', 'five'],
#  ['great', 'product', 'nice', 'combination', 'chocolate', 'perfect', 'size'],
#  ['bag', 'plenty', 'shipped', 'promptly'],
#  ['kid', 'neighborhood', 'liked', 'candy'],
#  ['halloween', 'sent', 'bag', 'daughter', 'class', 'share'],
#  ['chocolate', 'fresh', 'enjoyed', 'many'],
#  ['watch', 'price'],
#  ['assortment',
#   'good',
#   'get',
#   'gold',
#   'box',
#   'purchase',
#   'price',
#   'le',
#   'target'],
#  ['bag',
#   'candy',
#   'online',
#   'pretty',
#   'expensive',
#   'cheaper',
#   'order',
#   'compete',
#   'grocery',
#   'store',
#   'good',
#   'combination',
#   'favorite',
#   'candy'],
#  ['arrived', 'day', 'stale', 'could', 'eat', 'bag'],
#  [''],
#  ['used',
#   'endurolyte',
#   'product',
#   'several',
#   'year',
#   'pill',
#   'powder',
#   'form'],
#  ['long',
#   'desert',
#   'ride',
#   'dirt',
#   'bike',
#   'always',
#   'found',
#   'camelbak',
#   'water',
#   'heavily',
#   'laced',
#   'endurolyte',
#   'powder',
#   'overly',
#   'tasty',
#   'quite',
#   'effective',
#   'never',
#   'got',
#   'cramp',
#   'several',
#   'hundred',
#   'mile',
#   'ride'],
#  ['desert', 'racing', 'buggy', 'camelbaks', 'always', 'laced', 'powder'],
#  ['fizz', 'great', 'product'],
#  ['firstly',
#   'hammer',
#   'endurolyte',
#   'product',
#   'great',
#   'endurance',
#   'athlete',
#   'world',
#   'use',
#   'product'],
#  ['second', 'convenient', 'handly', 'tablet', 'dissovle', 'fizz'],
#  ['third', 'taste', 'great'],
#  ['imagine',
#   'getting',
#   'nice',
#   'cool',
#   'drink',
#   'body',
#   'starving',
#   'hydration',
#   'electrolyte',
#   'rather',
#   'getting',
#   'salty',
#   'taste',
#   'get',
#   'refreshing',
#   'lemon',
#   'lime',
#   'mango'],
#  ['camelbaks', 'always', 'get', 'fizz'],
#  ['also',
#   'drop',
#   'tablet',
#   'bottled',
#   'water',
#   'whenever',
#   'exercise',
#   'nice',
#   'flavored',
#   'water',
#   'chock',
#   'full',
#   'electrolyte'],
#  ['cannot', 'recommend', 'product', 'hammer', 'product', 'highly', 'enough'],
#  ['product',
#   'serf',
#   'well',
#   'source',
#   'electrolyte',
#   'long',
#   'run',
#   'bike',
#   'ride',
#   'tried',
#   'flavor',
#   'really',
#   'like',
#   'grapefruit',
#   'flavor',
#   'taste',
#   'actually',
#   'like',
#   'slight',
#   'carbonation',
#   'use',
#   'hammer',
#   'product',
#   'really',
#   'like',
#   'whole',
#   'product',
#   'line'],
#  ['stuff',
#   'really',
#   'work',
#   'preventing',
#   'cramping',
#   'middle',
#   'latter',
#   'stage',
#   'ride'],
#  ['pop', 'water', 'bottle', 'set'],
#  ['flavor', 'fine', 'go', 'easy'],
#  ['u',
#   'low',
#   'carb',
#   'diet',
#   'little',
#   'tablet',
#   'thing',
#   'two',
#   'year',
#   'ago',
#   'started',
#   'cycling',
#   'many',
#   'year',
#   'heart',
#   'arrhythmia',
#   'longer',
#   'ride',
#   'high',
#   'heat'],
#  ['drinking',
#   'plain',
#   'water',
#   'little',
#   'research',
#   'thought',
#   'electrolyte',
#   'might',
#   'issue'],
#  ['gatorade',
#   'option',
#   'loaded',
#   'carbohydrate',
#   'looked',
#   'around',
#   'low',
#   'carb',
#   'alternative'],
#  ['zero', 'carb', 'sport', 'drink', 'help'],
#  ['one',
#   'day',
#   'ran',
#   'across',
#   'bike',
#   'shop',
#   'tried',
#   'tube',
#   'voila',
#   'problem',
#   'solved'],
#  ['shared',
#   'two',
#   'friend',
#   'particular',
#   'whose',
#   'problem',
#   'leg',
#   'cramp',
#   'resolved',
#   'using',
#   'guy',
#   'got',
#   'right',
#   'superbly',
#   'formulated',
#   'simply',
#   'work'],
#  ['purchased', 'mango', 'flavor', 'take', 'like', 'mango'],
#  ['hint',
#   'sweetness',
#   'unfortunately',
#   'hint',
#   'aftertaste',
#   'almost',
#   'like',
#   'licorice'],
#  ['consuming',
#   'various',
#   'sport',
#   'nutrition',
#   'product',
#   'decade',
#   'familiar',
#   'come',
#   'like',
#   'taste',
#   'product',
#   'tried'],
#  ['mango', 'flavor', 'one', 'least', 'appealing', 'tasted'],
#  ['terrible',
#   'bad',
#   'enough',
#   'notice',
#   'bad',
#   'taste',
#   'every',
#   'sip',
#   'take'],
#  ['impulsive',
#   'like',
#   'ok',
#   'get',
#   'wrong',
#   'quality',
#   'baby',
#   'good',
#   'complaint'],
#  ['retrospect', 'price', 'little', 'ridiculous', 'esp'],
#  ['add', 'shipping'],
#  ['sooooo', 'deliscious', 'bad', 'ate', 'em', 'fast', 'gained', 'pd'],
#  ['fault'],
#  ['albanese', 'gummi', 'bear', 'ring', 'good', 'tasty', 'high', 'quality'],
#  ['bear', 'even', 'little', 'face'],
#  ['local',
#   'candy',
#   'store',
#   'type',
#   'gummi',
#   'stuff',
#   'bear',
#   'ring',
#   'snake',
#   'ball',
#   'worm',
#   'whatever',
#   'lb'],
#  ['twin', 'pack', 'pound', 'bag', 'screaming', 'deal', 'far', 'concerned'],
#  ['probably', 'pound', 'deep', 'friggin', 'thing'],
#  ['consumed'],
#  ['grape', 'gummy', 'bear', 'hard', 'find', 'area'],
#  ['fact',
#   'pretty',
#   'much',
#   'anyone',
#   'talk',
#   'grape',
#   'gummy',
#   'bear',
#   'think',
#   'lying'],
#  ['bought',
#   'lb',
#   'bear',
#   'little',
#   'bit',
#   'bigger',
#   'brand',
#   'kind',
#   'sour',
#   'kick',
#   'nothing',
#   'strong'],
#  ['love', 'grape', 'flavored', 'candy', 'soda', 'pretty', 'good'],
#  ['another',
#   'company',
#   'make',
#   'grape',
#   'gummy',
#   'bear',
#   'little',
#   'bit',
#   'better',
#   'opinion',
#   'well',
#   'worth',
#   'price'],
#  ['like',
#   'use',
#   'gummy',
#   'bear',
#   'home',
#   'made',
#   'popsicle',
#   'flavored',
#   'sport',
#   'drink'],
#  ['salt',
#   'sport',
#   'drink',
#   'make',
#   'softer',
#   'popsicle',
#   'gummy',
#   'bear',
#   'awesome',
#   'frozen'],
#  ['delicious'],
#  ['ordered',
#   'two',
#   'two',
#   'raspberry',
#   'latice',
#   'tart',
#   'directly',
#   'fantasicakes',
#   'website',
#   'dinner',
#   'party',
#   'hosting'],
#  ['arrived', 'fresh', 'intact'],
#  ['good', 'size'],
#  ['froze', 'half', 'later', 'use'],
#  ['pastry', 'lover', 'best', 'ever', 'tasted'],
#  ['pastry', 'soft', 'jam', 'really', 'good', 'taste', 'great'],
#  ['gone', 'time'],
#  ['guest', 'really', 'impressed'],
#  ['buyer', 'beware', 'please'],
#  ['sweetener', 'everybody'],
#  ['maltitol', 'alcohol', 'sugar', 'undigestible', 'body'],
#  ['know',
#   'short',
#   'time',
#   'consuming',
#   'one',
#   'unsuspecting',
#   'many',
#   'cannot',
#   'digest',
#   'extreme',
#   'intestinal',
#   'bloating',
#   'cramping',
#   'massive',
#   'amount',
#   'gas',
#   'person',
#   'experience'],
#  ['nausea', 'diarrhea', 'headache', 'also', 'experienced'],
#  ['learned',
#   'lesson',
#   'hard',
#   'way',
#   'year',
#   'ago',
#   'fell',
#   'love',
#   'sugar',
#   'free',
#   'chocolate',
#   'suzanne',
#   'sommers',
#   'used',
#   'sell'],
#  ['thought',
#   'found',
#   'sugar',
#   'free',
#   'chocolate',
#   'nirvana',
#   'first',
#   'taste',
#   'bliss',
#   'short',
#   'lived',
#   'terrible',
#   'side',
#   'effect',
#   'maltitol',
#   'kicked'],
#  ['discomfort', 'unlike', 'anything', 'ever', 'felt'],
#  ['blew', 'like', 'balloon', 'painful', 'abdominal', 'cramping'],
#  ['symptom', 'passed', 'unpleasant'],
#  ['though',
#   'hard',
#   'believe',
#   'low',
#   'calorie',
#   'sweetener',
#   'could',
#   'culprit',
#   'symptom',
#   'gone',
#   'stopped',
#   'eating',
#   'chocolate'],
#  ['hunch',
#   'something',
#   'maltitol',
#   'unfortunately',
#   'confirmed',
#   'year',
#   'later',
#   'purchased',
#   'delicious',
#   'sugar',
#   'free',
#   'popcorn',
#   'local',
#   'market'],
#  ['taste',
#   'amazing',
#   'looking',
#   'label',
#   'wondering',
#   'could',
#   'possibly',
#   'make',
#   'yummy',
#   'new',
#   'sugarfree',
#   'treat',
#   'taste',
#   'good',
#   'heart',
#   'sank',
#   'followed',
#   'little',
#   'asterisk',
#   'next',
#   'sugarfree',
#   'sweetener',
#   'bottom',
#   'label',
#   'read',
#   'maltitol',
#   'tiny',
#   'little',
#   'letter'],
#  ['thank', 'goodness', 'eaten', 'little'],
#  ['still', 'ended', 'side', 'effect', 'much', 'shorter', 'duration'],
#  ['people',
#   'use',
#   'maltitol',
#   'heart',
#   'content',
#   'others',
#   'like',
#   'bad',
#   'reaction'],
#  ['case', 'like', 'maltitol'],
#  ['okay'],
#  ['would', 'go', 'way', 'buy'],
#  ['tea', 'flavor'],
#  ['whole', 'brunch', 'artifial', 'flavor'],
#  ['returnable'],
#  ['wasted', 'buck'],
#  ['looked', 'like', 'perfect', 'snack', 'trail', 'mix'],
#  ['unfortunately', 'arrived', 'solid', 'mass', 'melted', 'chocolate'],
#  ['left', 'pantry', 'day', 'opened', 'room', 'temperature', 'still', 'gooey'],
#  ['fridge', 'breaking', 'hunk', 'ever', 'since'],
#  ['taste', 'good', 'chocolate', 'grainy', 'melting', 'solidifying'],
#  ['order', 'online', 'see', 'store', 'would', 'pick'],
#  ['taste', 'really', 'good'],
#  ['purchasing', 'different', 'brand', 'similar', 'taste', 'texture'],
#  ['agree', 'reviewer', 'regarding', 'ordering', 'summer'],
#  ['insulating',
#   'packaging',
#   'ice',
#   'pack',
#   'melt',
#   'warm',
#   'weather',
#   'like',
#   'chocolate',
#   'food',
#   'item'],
#  ['order', 'cold', 'weather', 'buy', 'enough', 'last'],
#  [''],
#  ['taste', 'great', 'berry', 'melted'],
#  ['may', 'order', 'winter'],
#  ['order', 'cold', 'weather', 'enjoy', 'flavor'],
#  ['know', 'cannot', 'make', 'tea', 'good'],
#  ['granted',
#   'south',
#   'know',
#   'never',
#   'enjoyed',
#   'tea',
#   'sweet',
#   'without',
#   'sweet'],
#  ['taste', 'crisp'],
#  ['peppermint', 'stick', 'delicious', 'fun', 'eat'],
#  ['dad',
#   'got',
#   'one',
#   'christmas',
#   'remembered',
#   'similar',
#   'one',
#   'little',
#   'girl'],
#  ['love'],
#  ['great', 'gift', 'age'],
#  ['purchased',
#   'giant',
#   'cane',
#   'recipient',
#   'loved',
#   'much',
#   'kept',
#   'would',
#   'eat'],
#  ['know',
#   'product',
#   'title',
#   'say',
#   'molecular',
#   'gastronomy',
#   'let',
#   'scare'],
#  ['looking', 'food', 'science', 'something', 'earth'],
#  ['use',
#   'make',
#   'coffee',
#   'creamer',
#   'coffee',
#   'blonde',
#   'sweet',
#   'flavored',
#   'creamer',
#   'full',
#   'bad',
#   'kind',
#   'fat',
#   'honestly',
#   'hate',
#   'use',
#   'manufactured',
#   'food',
#   'item'],
#  ['really', 'think', 'good', 'body'],
#  ['hand',
#   'hate',
#   'using',
#   'cold',
#   'milk',
#   'cream',
#   'like',
#   'hot',
#   'coffee',
#   'stumbled',
#   'across',
#   'amazon',
#   'one',
#   'day',
#   'got',
#   'idea',
#   'making',
#   'creamer'],
#  ['also',
#   'bought',
#   'low',
#   'fat',
#   'non',
#   'instant',
#   'milk',
#   'powder',
#   'regular',
#   'milk',
#   'powder'],
#  ['non',
#   'instant',
#   'lowfat',
#   'milk',
#   'little',
#   'sweeter',
#   'taste',
#   'fresher',
#   'regular',
#   'instant',
#   'low',
#   'fat',
#   'milk',
#   'dissolve',
#   'good',
#   'cold',
#   'water',
#   'problem',
#   'hot',
#   'coffee'],
#  ['play', 'ratio', 'would', 'heavy', 'cream', 'made', 'coffee', 'rich'],
#  ['also', 'think', 'powder', 'expensive', 'use'],
#  ['like',
#   'mixing',
#   'together',
#   'flavoring',
#   'bough',
#   'cocoa',
#   'bean',
#   'powder',
#   'vanilla',
#   'bean',
#   'powder',
#   'caster',
#   'superfine',
#   'sugar'],
#  ['mix',
#   'small',
#   'batch',
#   'along',
#   'spice',
#   'like',
#   'cinnamon',
#   'nutmeg',
#   'make',
#   'flavored',
#   'creamer'],
#  ['wanted', 'could', 'use', 'fake', 'sweetner', 'powder', 'instead'],
#  ['make', 'small', 'amount', 'store', 'jelly', 'canning', 'jar'],
#  ['also',
#   'use',
#   'little',
#   'food',
#   'chopper',
#   'food',
#   'processor',
#   'blend',
#   'everything',
#   'sugar',
#   'heavier',
#   'sink',
#   'bottom'],
#  ['let',
#   'settle',
#   'bit',
#   'opening',
#   'top',
#   'though',
#   'stuff',
#   'taste',
#   'way',
#   'better',
#   'storebought',
#   'creamer',
#   'fun',
#   'experiment',
#   'come',
#   'flavor'],
#  ['going',
#   'try',
#   'using',
#   'essential',
#   'oil',
#   'next',
#   'see',
#   'get',
#   'good',
#   'chocolate',
#   'orange',
#   'mix',
#   'ingredient',
#   'mentioned',
#   'online'],
#  ['take', 'time', 'experiment'],
#  ['maybe', 'use', 'low', 'fat', 'milk'],
#  ['add', 'flavoring'],
#  [''],
#  ['also',
#   'would',
#   'make',
#   'great',
#   'housewarming',
#   'host',
#   'es',
#   'gift',
#   'sure',
#   'molecular',
#   'people',
#   'able',
#   'tell',
#   'sure',
#   'experiment',
#   'cooking',
#   'main',
#   'reason',
#   'bought',
#   'make',
#   'creamer',
#   'worked',
#   'great'],
#  ['dog',
#   'like',
#   'flavor',
#   'tried',
#   'dog',
#   'food',
#   'reason',
#   'itching',
#   'increased',
#   'tried',
#   'lamb',
#   'rice'],
#  ['itchy',
#   'dog',
#   'giving',
#   'limited',
#   'ingredient',
#   'dog',
#   'food',
#   'try',
#   'help'],
#  ['duck',
#   'sweet',
#   'potato',
#   'cut',
#   'itching',
#   'significantly',
#   'tried',
#   'lamb',
#   'rice',
#   'started',
#   'itching'],
#  ['like', 'natural', 'balance', 'quality', 'ingredient'],
#  ['awesome', 'dog', 'food'],
#  ['however',
#   'given',
#   'boston',
#   'severe',
#   'reaction',
#   'food',
#   'ingredient',
#   'itching',
#   'increased',
#   'violent',
#   'jumping',
#   'bed',
#   'night',
#   'scratching'],
#  ['soon', 'changed', 'different', 'formula', 'scratching', 'stopped'],
#  ['glad', 'natural', 'balance', 'choice'],
#  ['guess', 'try', 'find', 'best', 'pet'],
#  ['three', 'dog', 'love', 'food'],
#  ['bought',
#   'specifically',
#   'one',
#   'dog',
#   'food',
#   'allergy',
#   'work',
#   'great',
#   'hot',
#   'spot',
#   'tummy',
#   'problem',
#   'love',
#   'ship',
#   'right',
#   'door',
#   'free',
#   'shipping'],
#  ['dog', 'ton', 'allergy', 'environmental', 'food'],
#  ['prescription', 'dog', 'food', 'tested', 'see', 'allergy'],
#  ['got',
#   'test',
#   'back',
#   'learned',
#   'allergic',
#   'something',
#   'prescription',
#   'brand'],
#  ['finally', 'found', 'dog', 'food', 'done', 'well'],
#  ['still',
#   'environmental',
#   'trigger',
#   'happy',
#   'finally',
#   'eat',
#   'something',
#   'know',
#   'cause',
#   'pain'],
#  ['shepherd', 'collie', 'mix', 'ibs'],
#  ['vet', 'recommended', 'limited', 'ingredient', 'food'],
#  ['really', 'helped', 'symptom', 'like'],
#  ['always', 'buy', 'amazon', 'cheaper', 'free', 'shipping'],
#  ['natural',
#   'balance',
#   'dry',
#   'dog',
#   'food',
#   'lamb',
#   'meal',
#   'brown',
#   'rice',
#   'recipe',
#   'wonder',
#   'jack',
#   'russell'],
#  ['awful',
#   'food',
#   'allergy',
#   'food',
#   'last',
#   'hope',
#   'last',
#   'food',
#   'could',
#   'find',
#   'something',
#   'allergic'],
#  ['problem',
#   'eating',
#   'dry',
#   'normally',
#   'mix',
#   'natural',
#   'balance',
#   'dry',
#   'lamb',
#   'brown',
#   'rice',
#   'natural',
#   'balance',
#   'wet',
#   'lamb',
#   'brown',
#   'rice',
#   'seems',
#   'like',
#   'better'],
#  ['started', 'feeding', 'dog', 'bichon', 'love'],
#  ['dog',
#   'allergy',
#   'stomach',
#   'issue',
#   'want',
#   'dog',
#   'eat',
#   'better',
#   'food'],
#  ['see', 'difference', 'pet'],
#  ['great', 'food'],
#  ['love', 'idea', 'one', 'food', 'age', 'breed'],
#  ['real', 'convenience', 'well', 'really', 'good', 'product'],
#  ['dog',
#   'eat',
#   'le',
#   'almost',
#   'gas',
#   'poop',
#   'regular',
#   'perfect',
#   'consistency',
#   'else',
#   'mom',
#   'ask'],
#  [''],
#  ['standard', 'poodle', 'pomeranian', 'wonderful', 'food'],
#  ['switched',
#   'different',
#   'food',
#   'due',
#   'price',
#   'couple',
#   'time',
#   'end',
#   'going',
#   'right',
#   'back',
#   'natural',
#   'balance'],
#  ['great', 'dog', 'food', 'dog', 'severs', 'allergy', 'brand', 'one', 'feed'],
#  ['food', 'great', 'age', 'dog'],
#  ['year', 'old', 'puppy'],
#  ['soft', 'hardly', 'ever', 'get', 'sick'],
#  ['food', 'good', 'especially', 'amazon', 'prime', 'shipping'],
#  ['golden', 'retriever', 'one', 'picky', 'dog', 'ever', 'met'],
#  ['experimenting',
#   'various',
#   'type',
#   'food',
#   'found',
#   'love',
#   'natural',
#   'balance'],
#  ['really',
#   'like',
#   'natural',
#   'balance',
#   'fact',
#   'multiple',
#   'flavor',
#   'dry',
#   'wet',
#   'variety'],
#  ['mix', 'dry', 'food', 'little', 'wet', 'food', 'golden', 'love'],
#  ['furthermore',
#   'like',
#   'mixing',
#   'flavor',
#   'time',
#   'think',
#   'meal',
#   'day',
#   'day',
#   'might',
#   'get',
#   'little',
#   'boring',
#   'figured'],
#  ['tend',
#   'stay',
#   'away',
#   'fish',
#   'type',
#   'though',
#   'smell',
#   'additionally',
#   'started',
#   'purchasing',
#   'amazon',
#   'petco',
#   'wet',
#   'food',
#   'box',
#   'couple',
#   'can'],
#  ['came',
#   'home',
#   'surprise',
#   'realized',
#   'could',
#   'save',
#   'time',
#   'bought',
#   'dog',
#   'food',
#   'buy',
#   'amazon',
#   'definitely',
#   'recommend',
#   'give',
#   'stamp',
#   'approval',
#   'natural',
#   'balance',
#   'dog',
#   'food'],
#  ['never', 'eaten', 'dog', 'seems', 'love'],
#  ['food', 'get', 'pet', 'store'],
#  ['delivered', 'door'],
#  ['price', 'slightly', 'le'],
#  ['pleased', 'natural', 'balance', 'dog', 'food'],
#  ['dog',
#   'issue',
#   'dog',
#   'food',
#   'past',
#   'someone',
#   'recommend',
#   'natural',
#   'balance',
#   'grain',
#   'free',
#   'since',
#   'possible',
#   'allergic',
#   'grain'],
#  ['since', 'switching', 'issue'],
#  ['also',
#   'helpful',
#   'different',
#   'kibble',
#   'size',
#   'larger',
#   'smaller',
#   'sized',
#   'dog'],
#  ['year', 'old', 'basenji', 'jack', 'russell', 'mix', 'love', 'dog', 'food'],
#  ['noticeably',
#   'healthier',
#   'energetic',
#   'since',
#   'switched',
#   'standard',
#   'dog',
#   'food',
#   'earlier',
#   'year'],
#  ['despite',
#   'higher',
#   'cost',
#   'natural',
#   'dog',
#   'food',
#   'find',
#   'eats',
#   'significantly',
#   'le',
#   'natural',
#   'balance',
#   'dog',
#   'food',
#   'still',
#   'stay',
#   'happy',
#   'full'],
#  ['normal',
#   'dog',
#   'food',
#   'eat',
#   'cup',
#   'dog',
#   'food',
#   'day',
#   'recommended',
#   'serving',
#   'size',
#   'whereas',
#   'eats',
#   'cup',
#   'cup',
#   'natural',
#   'balance',
#   'dog',
#   'food',
#   'day'],
#  ['take',
#   'account',
#   'actually',
#   'getting',
#   'bang',
#   'buck',
#   'natural',
#   'dog',
#   'food',
#   'since',
#   'buy',
#   'much',
#   'last',
#   'long',
#   'normal',
#   'dog',
#   'food',
#   'healthier',
#   'happier',
#   'dog',
#   'boot'],
#  ['add', 'fact', 'get', 'free', 'day', 'shipping', 'amazon', 'prime'],
#  ['sold'],
#  [''],
#  ['pup',
#   'experienced',
#   'allergy',
#   'form',
#   'hotspot',
#   'itching',
#   'dog',
#   'food'],
#  ['cheap',
#   'buy',
#   'anywhere',
#   'food',
#   'crazy',
#   'preservative',
#   'cause',
#   'health',
#   'problem',
#   'pet'],
#  ['food',
#   'work',
#   'wonder',
#   'reducing',
#   'allergy',
#   'dog',
#   'love',
#   'food',
#   'message',
#   'ramsey',
#   'frankenstein',
#   'approved'],
#  ['english', 'bulldog', 'skin', 'allergy', 'summer', 'got', 'age'],
#  ['vet',
#   'recommended',
#   'wean',
#   'food',
#   'previous',
#   'owner',
#   'gave',
#   'iams',
#   'lamb',
#   'rice',
#   'onto',
#   'new',
#   'kind'],
#  ['second', 'one', 'tried', 'working', 'ever', 'since'],
#  ['dog',
#   'need',
#   'limited',
#   'diet',
#   'sensitive',
#   'additive',
#   'protein',
#   'commonly',
#   'found',
#   'commercial',
#   'dog',
#   'food',
#   'like',
#   'chicken',
#   'beef'],
#  ['fed', 'golden', 'retriever', 'hated'],
#  ['eat', 'gave', 'terrible', 'diarrhea'],
#  ['buying'],
#  ['also', 'super', 'expensive'],
#  ['mouth',
#   'say',
#   'love',
#   'thee',
#   'let',
#   'count',
#   'way',
#   'like',
#   'apple',
#   'product',
#   'must',
#   'item'],
#  ['draw', 'back', 'shipping', 'cost'],
#  ['heavy'],
#  ['arrived', 'slightly', 'thawed'],
#  ['parent', 'accept'],
#  ['however', 'company', 'helpful', 'issued', 'full', 'refund'],
#  ['crust', 'tart', 'perfect'],
#  ['husband', 'love', 'crazy'],
#  ['sour', 'tart', 'taste'],
#  ['eat', 'crust', 'hubby', 'take', 'filling'],
#  ['kid', 'think', 'great', 'maybe'],
#  ['absolutely', 'scrumptuous'],
#  ['husband',
#   'love',
#   'however',
#   'another',
#   'customer',
#   'put',
#   'expensive',
#   'ship'],
#  ['cost', 'shipping', 'tartlet'],
#  ['nice', 'alternative', 'apple', 'pie'],
#  ['love', 'fact', 'slicing', 'dicing'],
#  ['easy', 'prepare'],
#  ['also', 'loved', 'fact', 'make', 'fresh', 'whenever', 'needed'],
#  ['like', 'creme', 'brulee'],
#  ['loved', 'easy'],
#  ['sprinkle', 'sugar', 'came', 'broil'],
#  ['look', 'amazing', 'taste', 'great'],
#  ['guess', 'thought', 'really', 'went', 'way', 'really', 'took', 'minute'],
#  ['ordering'],
#  ['expecting',
#   'term',
#   'company',
#   'reputation',
#   'excellent',
#   'home',
#   'delivery',
#   'product'],
#  ['first',
#   'bought',
#   'pickled',
#   'asparagus',
#   'amish',
#   'market',
#   'love',
#   'first',
#   'bite'],
#  ['hence', 'saw', 'discount', 'rack', 'local', 'safeway', 'cleaned'],
#  ['even', 'better', 'one', 'amish', 'market'],
#  ['fantastic', 'jar', 'bonus', 'clove', 'garlic', 'bottom'],
#  ['going', 'order', 'six', 'pack', 'household', 'one'],
#  ['wont', 'go', 'waste'],
#  ['love', 'asparagus'],
#  ['recently', 'never', 'pickled', 'asparagus'],
#  ['oh',
#   'goodness',
#   'friend',
#   'introduced',
#   'exact',
#   'brand',
#   'believe',
#   'great',
#   'stuff',
#   'tasted'],
#  ['loved', 'much', 'bought', 'six', 'pack'],
#  ['got', 'jar', 'left'],
#  ['gonna', 'need'],
#  [''],
#  ['presently',
#   'diet',
#   'fresh',
#   'easy',
#   'neighborhood',
#   'grocery',
#   'looking',
#   'possible',
#   'diet',
#   'food'],
#  ['wanted', 'thing', 'tasty', 'non', 'fat', 'low', 'calorie'],
#  ['came', 'home', 'dozen', 'item'],
#  ['discovered', 'tillen', 'farm', 'pickled', 'crispy', 'asparagus'],
#  ['well',
#   'always',
#   'liked',
#   'asparagus',
#   'anyway',
#   'enjoyed',
#   'several',
#   'brand',
#   'pickled',
#   'asparagus'],
#  ['tillen', 'farm', 'brand', 'really', 'really', 'good'],
#  ['best', 'recall'],
#  ['excellent',
#   'flavor',
#   'big',
#   'clove',
#   'garlic',
#   'bottom',
#   'jar',
#   'looking',
#   'forward',
#   'eating'],
#  ['believe',
#   'good',
#   'asparagus',
#   'taste',
#   'right',
#   'front',
#   'say',
#   'calorie',
#   'per',
#   'jar'],
#  ['idea', 'good', 'diet', 'food', 'gary', 'peterson'],
#  ['diappointed', 'flavor', 'texture', 'mix'],
#  ['usually',
#   'like',
#   'low',
#   'carb',
#   'thing',
#   'tried',
#   'diappointed',
#   'specific',
#   'one'],
#  ['drinking', 'tea', 'long', 'time'],
#  ['used', 'purchase', 'doctor', 'office', 'available', 'elsewhere'],
#  ['glad', 'buy', 'amazon', 'com'],
#  ['drink', 'tea', 'throughout', 'day', 'like', 'folk', 'drink', 'coffee'],
#  ['wonderful', 'taste'],
#  ['drinking',
#   'royal',
#   'king',
#   'natural',
#   'organic',
#   'green',
#   'tea',
#   'tea',
#   'bag',
#   'x',
#   'g',
#   'every',
#   'day',
#   'tea',
#   'several',
#   'year'],
#  ['buy', 'box', 'time', 'save', 'shipping'],
#  ['many', 'year', 'used', 'drink', 'coffee', 'morning', 'till', 'night'],
#  ['finally', 'realized', 'drinking', 'much', 'coffee', 'healthy'],
#  ['finally',
#   'resolved',
#   'improve',
#   'health',
#   'stopped',
#   'drinking',
#   'coffee',
#   'together'],
#  ['tried', 'many', 'alternative', 'drink', 'replace', 'coffee', 'habit'],
#  ['found', 'green', 'tea', 'good', 'tasting', 'also', 'health', 'benefit'],
#  ['green',
#   'tea',
#   'one',
#   'drink',
#   'actually',
#   'make',
#   'healthier',
#   'coffe',
#   'drink',
#   'healthier',
#   'drink',
#   'quality',
#   'cold',
#   'water'],
#  ['opinion',
#   'price',
#   'royal',
#   'king',
#   'natural',
#   'organic',
#   'green',
#   'tea',
#   'one',
#   'best',
#   'tasting',
#   'tea'],
#  ['green', 'tea', 'beautiful', 'golden', 'color', 'taste', 'bright', 'fresh'],
#  ['recommend', 'adding', 'tiny', 'amount'],
#  ['organic',
#   'bee',
#   'farm',
#   'raw',
#   'honey',
#   'tea',
#   'add',
#   'sweetness',
#   'health',
#   'benefit'],
#  ['also',
#   'give',
#   'treat',
#   'much',
#   'expense',
#   'tea',
#   'tribute',
#   'xi',
#   'hu',
#   'long',
#   'jing',
#   'fantastic',
#   'tea',
#   'practical',
#   'drink',
#   'every',
#   'day',
#   'tea',
#   'although',
#   'would',
#   'could',
#   'afford',
#   'con',
#   'latest',
#   'shipment',
#   'package',
#   'shown',
#   'amazon',
#   'page',
#   'different',
#   'one',
#   'shipped'],
#  ['one',
#   'shipped',
#   'display',
#   'naturally',
#   'high',
#   'polyphenol',
#   'catechin',
#   'key',
#   'contributive',
#   'element',
#   'possible',
#   'health',
#   'effect',
#   'tea',
#   'whereas',
#   'amazon',
#   'package',
#   'display',
#   'caffene',
#   'free'],
#  ['sure', 'green', 'tea', 'caffene', 'free'],
#  ['con',
#   'sometimes',
#   'tea',
#   'bag',
#   'rip',
#   'open',
#   'unwrap',
#   'string',
#   'around',
#   'tea',
#   'bag'],
#  ['string',
#   'seems',
#   'stuck',
#   'tea',
#   'bag',
#   'put',
#   'bag',
#   'hot',
#   'water',
#   'unstick'],
#  ['one',
#   'best',
#   'tea',
#   'ever',
#   'tasted',
#   'clean',
#   'bright',
#   'fresh',
#   'great',
#   'delivery',
#   'quality',
#   'try'],
#  ['love', 'love', 'green', 'tea'],
#  ['hard',
#   'find',
#   'area',
#   'place',
#   'internet',
#   'charge',
#   'big',
#   'price',
#   'usually',
#   'get',
#   'many',
#   'box',
#   'merchant'],
#  ['definitely', 'order', 'seller'],
#  ['thanks'],
#  ['depend', 'green', 'tea', 'fix', 'everyday'],
#  ['love', 'tea'],
#  ['help', 'curb', 'eating', 'day'],
#  ['mom', 'given', 'friend', 'try'],
#  ['italian', 'lived', 'italy', 'year'],
#  ['used', 'buy', 'cooky', 'everyday', 'breakfast', 'italian', 'espresso'],
#  ['find', 'anywhere', 'bay', 'area', 'great'],
#  ['spent', 'several', 'summer', 'italy'],
#  ['biscotti', 'often', 'given', 'breakfast', 'food', 'mid', 'day', 'snack'],
#  ['simple', 'delicious', 'sold', 'u', 'back'],
#  ['good', 'brought', 'back', 'two', 'bag', 'recent', 'trip', 'italy'],
#  ['great',
#   'see',
#   'may',
#   'found',
#   'amazon',
#   'note',
#   'great',
#   'open',
#   'bag',
#   'smell',
#   'content',
#   'pour',
#   'glass',
#   'milk',
#   'dip',
#   'macines',
#   'milk'],
#  ['great', 'routine', 'treat', 'kid'],
#  ['heard',
#   'little',
#   'product',
#   'local',
#   'pet',
#   'store',
#   'tried',
#   'small',
#   'bag',
#   'cat',
#   'year',
#   'respectively'],
#  ['female',
#   'younger',
#   'one',
#   'took',
#   'right',
#   'away',
#   'older',
#   'male',
#   'unfortunately',
#   'weaned',
#   'junk',
#   'cat',
#   'food',
#   'corn',
#   'meal',
#   'etc',
#   'would',
#   'usually',
#   'refuse',
#   'diet',
#   'change',
#   'actually',
#   'liked'],
#  ['older',
#   'male',
#   'overweight',
#   'trying',
#   'switch',
#   'soft',
#   'food',
#   'doctor',
#   'request',
#   'totally',
#   'refused'],
#  ['posh', 'cat'],
#  ['still',
#   'consumes',
#   'many',
#   'calorie',
#   'fatty',
#   'least',
#   'know',
#   'eating',
#   'good',
#   'food'],
#  ['course',
#   'know',
#   'product',
#   'seems',
#   'cost',
#   'feline',
#   'food',
#   'market',
#   'see',
#   'feeding',
#   'animal',
#   'lousy',
#   'alternative',
#   'marketed',
#   'healthy'],
#  ['commercial',
#   'show',
#   'cat',
#   'eating',
#   'vegetarian',
#   'diet',
#   'mostly',
#   'corn',
#   'meal'],
#  ['right'],
#  ['stay',
#   'stay',
#   'tuned',
#   'updating',
#   'review',
#   'month',
#   'using',
#   'cat',
#   'food',
#   'two',
#   'cat'],
#  ['upgraded', 'star', 'really', 'good', 'food', 'two'],
#  ['garfield',
#   'still',
#   'eats',
#   'little',
#   'much',
#   'big',
#   'cat',
#   'exercise',
#   'much',
#   'let',
#   'face'],
#  ['female', 'cat', 'year', 'old', 'couple', 'month', 'healthy'],
#  ['tiny', 'happy', 'agile'],
#  ['tried',
#   'chicken',
#   'version',
#   'holistic',
#   'select',
#   'garfield',
#   'seemd',
#   'miss',
#   'sardine',
#   'version',
#   'went',
#   'back',
#   'one'],
#  ['ordered', 'duck', 'version', 'update', 'try'],
#  ['started',
#   'buying',
#   'noticed',
#   'year',
#   'old',
#   'cat',
#   'already',
#   'starting',
#   'lose',
#   'spunk',
#   'decided',
#   'time',
#   'start',
#   'buying',
#   'real',
#   'cat',
#   'food',
#   'garbage',
#   'super',
#   'market'],
#  ['found',
#   'pet',
#   'store',
#   'million',
#   'choice',
#   'sure',
#   'brand',
#   'good',
#   'one',
#   'went',
#   'try',
#   'first',
#   'great',
#   'purchase'],
#  ['cat',
#   'past',
#   'month',
#   'active',
#   'kitten',
#   'coat',
#   'became',
#   'sooo',
#   'soft'],
#  ['mainly', 'loved', 'taste', 'even'],
#  ['highly', 'recommend', 'brand', 'friend', 'family', 'animal'],
#  ['done',
#   'lot',
#   'research',
#   'find',
#   'best',
#   'food',
#   'cat',
#   'excellent',
#   'food'],
#  ['also', 'according', 'holistic', 'veterinarian'],
#  ['put', 'probiotic', 'kibble', 'last', 'step', 'important'],
#  ['best',
#   'thing',
#   'cat',
#   'loved',
#   'immediately',
#   'stop',
#   'mixing',
#   'old',
#   'food',
#   'would',
#   'eat',
#   'holistic',
#   'select'],
#  ['cat',
#   'food',
#   'recommended',
#   'vet',
#   'year',
#   'old',
#   'cleo',
#   'cat',
#   'trouble',
#   'keeping',
#   'food',
#   'loosing',
#   'weight'],
#  ['stopped', 'problem'],
#  ['eat',
#   'much',
#   'since',
#   'seems',
#   'satisfied',
#   'eating',
#   'help',
#   'justify',
#   'added',
#   'price'],
#  ['aid',
#   'digestion',
#   'since',
#   'ok',
#   'sorry',
#   'smell',
#   'gone',
#   'ya',
#   'know',
#   'mean'],
#  ['add',
#   'anyone',
#   'experiencing',
#   'problem',
#   'cat',
#   'see',
#   'lot',
#   'benifits',
#   'cat',
#   'food'],
#  ['year', 'old', 'male', 'cat', 'chronic', 'urinary', 'tract', 'infection'],
#  ['feed',
#   'dry',
#   'food',
#   'combination',
#   'wet',
#   'food',
#   'water',
#   'added',
#   'uri',
#   'ease'],
#  ['combination', 'seems', 'keep', 'uti', 'control'],
#  ['switch', 'another', 'type', 'dry', 'food', 'uti', 'get', 'worse'],
#  ['cat', 'seem', 'enjoy', 'food', 'well'],
#  ['expensive', 'seems', 'best', 'solution'],
#  ['educated',
#   'feline',
#   'nutrition',
#   'allowed',
#   'cat',
#   'become',
#   'addicted',
#   'dry',
#   'cat',
#   'food'],
#  ['always',
#   'offered',
#   'canned',
#   'dry',
#   'wish',
#   'would',
#   'fed',
#   'premium',
#   'quality',
#   'canned',
#   'food',
#   'limited',
#   'dry',
#   'food'],
#  ['two', 'year', 'old', 'cat', 'two', 'year', 'old', 'cat'],
#  ['good', 'quality', 'dry', 'food', 'eat', 'wellness', 'innova'],
#  ['innova', 'manufacturer', 'recently', 'purchased', 'procter', 'gamble'],
#  ['began', 'looking', 'replacement'],
#  ['offering',
#   'several',
#   'sample',
#   'local',
#   'holistic',
#   'pet',
#   'store',
#   'holistic',
#   'select',
#   'one',
#   'usual',
#   'wellness',
#   'innova',
#   'would',
#   'eat'],
#  ['finicky', 'cat', 'recommend', 'trying', 'holistic', 'select'],
#  ['good', 'quality', 'food', 'palatable', 'finicky', 'eater'],
#  ['holistic', 'vet', 'recommended', 'along', 'brand'],
#  ['tried', 'cat', 'prefer', 'especially', 'sardine', 'version'],
#  ['best', 'part', 'coat', 'soft', 'clean', 'eye', 'clear'],
#  ['want',
#   'rude',
#   'say',
#   'delicately',
#   'waste',
#   'far',
#   'le',
#   'odorous',
#   'cat',
#   'eat',
#   'mcdonalds',
#   'junk',
#   'found',
#   'store',
#   'definite',
#   'plus'],
#  ['health', 'benefit', 'obvious', 'highly', 'recommend', 'holistic', 'select'],
#  ['one', 'cat', 'allergic', 'fish', 'beef'],
#  ['formula',
#   'one',
#   'eat',
#   'much',
#   'better',
#   'ingredient',
#   'prescription',
#   'diet',
#   'available',
#   'vet'],
#  ['kitty', 'active', 'soft', 'shiny', 'fur', 'neither', 'fat'],
#  ['dry', 'food', 'reduces', 'tartar', 'buildup', 'teeth', 'also'],
#  ['cat', 'thrive', 'extremely', 'well', 'dry', 'cat', 'food'],
#  ['definitely', 'much', 'le', 'hair', 'ball', 'throw', 'ups', 'fur', 'great'],
#  ['fit', 'weight'],
#  ['vendor', 'ship', 'extremely', 'fast'],
#  ['one', 'top', 'amazon', 'supplier', 'book'],
#  ['fan', 'hot', 'spicy', 'maruchan', 'ramen', 'long', 'time'],
#  ['enjoy', 'spice', 'love', 'ramen', 'love', 'product'],
#  ['bad', 'way', 'expensive', 'amazon'],
#  ['per', 'walmart'],
#  ['eating',
#   'ramen',
#   'noodle',
#   'since',
#   'little',
#   'kid',
#   'never',
#   'found',
#   'better',
#   'flavor',
#   'hot',
#   'spicy',
#   'chicken'],
#  ['hot', 'chilihead', 'like', 'sure', 'good'],
#  ['love',
#   'spicy',
#   'ramen',
#   'whatever',
#   'reason',
#   'thing',
#   'burn',
#   'stomach',
#   'badly',
#   'burning',
#   'sensation',
#   'go',
#   'away',
#   'like',
#   'hour'],
#  ['sure', 'healthy', 'buy', 'walmart', 'way', 'cheaper', 'amazon'],
#  ['always',
#   'fan',
#   'ramen',
# ...
#  ['tried', 'different', 'instant', 'coffee', 'one', 'one', 'better', 'one'],
#  ['another',
#   'one',
#   'favorite',
#   'want',
#   'try',
#   'though',
#   'organic',
#   'africafe',
#   'pure',
#   'instant',
#   'coffee'],
#  ['taste', 'great', 'give', 'energy', 'without', 'jitter'],
#  ['love',
#   'product',
#   'however',
#   'wish',
#   'came',
#   'sort',
#   'resealable',
#   'jar',
#   'hard',
#   'plastic',
#   'container',
#   'instead',
#   'zip',
#   'lock',
#   'pouch',
#   'zip',
#   'lock',
#   'ripped',
#   'quit',
#   'working',
#   'awhile'],
#  ['product', 'fantastic', 'crazy', 'packaging'],
#  ['little',
#   'guy',
#   'tasty',
#   'refreshing',
#   'usually',
#   'eat',
#   'salad',
#   'lunch',
#   'terrible',
#   'thing',
#   'breath'],
#  ['eat',
#   'lunch',
#   'small',
#   'find',
#   'sufficiently',
#   'resolve',
#   'problem',
#   'sugar',
#   'free',
#   'sugar',
#   'actually',
#   'help',
#   'smelly',
#   'bacteria',
#   'grow',
#   'great',
#   'tasty',
#   'enough',
#   'almost',
#   'think',
#   'part',
#   'lunch',
#   'good',
#   'bulk',
#   'value',
#   'buy',
#   'highly',
#   'recommend',
#   'mint'],
#  ['cheer'],
#  ['like', 'better', 'regular', 'altoids', 'even', 'costly', 'better', 'like'],
#  ['little',
#   'tin',
#   'sugar',
#   'free',
#   'mine',
#   'mint',
#   'great',
#   'deal',
#   'perfict',
#   'go',
#   'fifty',
#   'mint',
#   'per',
#   'tin',
#   'right',
#   'amount',
#   'cary',
#   'along',
#   'safer',
#   'teeth',
#   'one',
#   'sugar',
#   'price',
#   'twelve',
#   'dollar',
#   'resonable',
#   'also',
#   'great',
#   'shareing',
#   'looking',
#   'mint',
#   'try',
#   'one',
#   'youll',
#   'glad'],
#  ['pro',
#   'packaging',
#   'shipping',
#   'price',
#   'sold',
#   'year',
#   'expiration',
#   'date',
#   'enough',
#   'eat',
#   'share',
#   'box',
#   'fresh',
#   'like',
#   'regular',
#   'wintergreen',
#   'powdery',
#   'form'],
#  ['real', 'mint', 'con', 'none'],
#  ['careful', 'eat', 'many', 'one', 'day', 'one', 'chemical', 'laxative'],
#  ['lololol'],
#  [''],
#  ['mint', 'really', 'strong', 'great', 'taste'],
#  ['also', 'convenient', 'size', 'carry', 'pocket', 'purse'],
#  ['huge', 'supply'],
#  ['still', 'working', 'plenty', 'spare'],
#  ['much',
#   'effective',
#   'buying',
#   'one',
#   'grocery',
#   'store',
#   'every',
#   'time',
#   'want',
#   'mint'],
#  ['even', 'small', 'container', 'fill'],
#  ['little', 'tin', 'le', 'half', 'filled', 'price', 'charged', 'seems', 'rip'],
#  ['exotic', 'ingredient', 'costly', 'gold', 'contained', 'tiny', 'square'],
#  ['cereal',
#   'ploy',
#   'filled',
#   'factory',
#   'settled',
#   'transport',
#   'manufacturer',
#   'honest',
#   'dealing'],
#  ['love',
#   'use',
#   'empty',
#   'container',
#   'medicine',
#   'advil',
#   'purse',
#   'desk',
#   'suitcase'],
#  ['also', 'line', 'felt', 'keep', 'earring'],
#  ['perfect',
#   'little',
#   'size',
#   'disguise',
#   'small',
#   'valuable',
#   'traveling',
#   'love',
#   'mint'],
#  ['tiny', 'powerful', 'without', 'burning', 'mouth'],
#  ['received', 'shown'],
#  ['mother', 'law', 'like', 'walgreens', 'quit', 'carrying'],
#  ['great', 'could', 'get', 'amazon'],
#  ['keep',
#   'case',
#   'office',
#   'always',
#   'least',
#   'tin',
#   'two',
#   'desk',
#   'visitor',
#   'help'],
#  ['folk', 'stop', 'grab', 'mint', 'others', 'pop', 'like', 'candy', 'meet'],
#  ['find', 'someone', 'keep', 'coming', 'back', 'give', 'tin'],
#  ['one',
#   'co',
#   'worker',
#   'asked',
#   'save',
#   'tin',
#   'could',
#   'use',
#   'pillbox',
#   'safety',
#   'pin',
#   'box'],
#  ['like', 'said', 'theyre', 'real', 'hit'],
#  ['since',
#   'able',
#   'keep',
#   'hand',
#   'candy',
#   'dish',
#   'good',
#   'alternative',
#   'around',
#   'nice',
#   'around',
#   'garlic',
#   'lunch'],
#  ['gave',
#   'item',
#   'star',
#   'tasty',
#   'sugar',
#   'version',
#   'mint',
#   'sugar',
#   'free',
#   'item',
#   'good',
#   'full',
#   'sugar',
#   'counterpart'],
#  ['fact',
#   'tin',
#   'wrapped',
#   'plastic',
#   'seems',
#   'like',
#   'waste',
#   'irritating',
#   'remove',
#   'although',
#   'totally',
#   'get',
#   'wrap',
#   'still',
#   'make',
#   'easy',
#   'deal'],
#  ['tiny',
#   'altoids',
#   'great',
#   'quick',
#   'breath',
#   'freshening',
#   'small',
#   'box',
#   'great',
#   'portability'],
#  ['full',
#   'compact',
#   'run',
#   'yet',
#   'probably',
#   'couple',
#   'month',
#   'wait',
#   'buy'],
#  ['loved',
#   'wintergreen',
#   'altoid',
#   'small',
#   'much',
#   'come',
#   'write',
#   'review'],
#  ['packaging',
#   'small',
#   'convenience',
#   'altoids',
#   'smaller',
#   'well',
#   'square',
#   'shape',
#   'blue',
#   'hue',
#   'even',
#   'delicious',
#   'taste',
#   'opinion'],
#  ['definitely',
#   'prefer',
#   'regular',
#   'size',
#   'altoids',
#   'continue',
#   'purchasing'],
#  ['highly', 'recommended'],
#  ['fresh', 'scent', 'taste'],
#  ['easy', 'eat', 'one', 'tin', 'hour'],
#  ['use', 'favor', 'everyone', 'loved'],
#  ['hard',
#   'find',
#   'wintergreen',
#   'small',
#   'sugar',
#   'free',
#   'store',
#   'red',
#   'small',
#   'peppermint',
#   'common',
#   'flavor'],
#  ['wintergreen', 'refreshing', 'absolutely', 'delicious'],
#  ['driving',
#   'cross',
#   'country',
#   'someone',
#   'cut',
#   'turn',
#   'daughter',
#   'hand',
#   'say',
#   'wintergreen'],
#  ['pull', 'one', 'put', 'hand', 'right', 'world'],
#  ['nothing', 'like', 'regular', 'altoids', 'breath', 'mint'],
#  ['pleasant',
#   'tasting',
#   'little',
#   'candy',
#   'cute',
#   'convenient',
#   'tin',
#   'far',
#   'go'],
#  ['mintiness',
#   'strong',
#   'wintergreen',
#   'definitely',
#   'weaker',
#   'peppermint',
#   'mini'],
#  ['dragon',
#   'breath',
#   'person',
#   'still',
#   'one',
#   'mint',
#   'small',
#   'effect',
#   'breath'],
#  ['four', 'five', 'freshen', 'breath', 'short', 'maybe', 'minute'],
#  ['point',
#   'think',
#   'icebreaker',
#   'frost',
#   'mint',
#   'best',
#   'sugar',
#   'free',
#   'breath',
#   'mint'],
#  ['fed', 'cat', 'lot', 'stuff'],
#  ['boy', 'cat', 'picky', 'eater'],
#  ['loved', 'purina'],
#  ['loved', 'nutro'],
#  ['loved', 'iams'],
#  ['love',
#   'whatever',
#   'feed',
#   'review',
#   'based',
#   'affectionate',
#   'owner',
#   'love'],
#  ['certain',
#   'age',
#   'instructed',
#   'vet',
#   'consider',
#   'senior',
#   'food',
#   'lower',
#   'carb',
#   'food',
#   'catty',
#   'fatty'],
#  ['tried', 'type', 'food'],
#  ['evinced', 'change'],
#  ['made', 'litter', 'super', 'stink'],
#  ['small',
#   'kibble',
#   'cat',
#   'barfed',
#   'chew',
#   'swallow',
#   'felidae',
#   'done',
#   'trick'],
#  ['problem', 'speak'],
#  ['consistent', 'litter', 'bearable', 'nose'],
#  ['cat', 'love'],
#  ['kibble', 'sized', 'appropriate', 'chewing'],
#  ['kicker', 'feeding', 'cat', 'felidae', 'demeanor', 'improved'],
#  ['coat',
#   'super',
#   'soft',
#   'lush',
#   'new',
#   'improvement',
#   'directly',
#   'attribute',
#   'food'],
#  ['loyal',
#   'felidae',
#   'consumer',
#   'additionally',
#   'absence',
#   'corn',
#   'product',
#   'feed',
#   'seems',
#   'lessen',
#   'remove',
#   'reaction',
#   'friend',
#   'cat',
#   'allergy'],
#  ['started', 'cat', 'felidae', 'platinum', 'week', 'ago', 'love'],
#  ['older', 'cat', 'somewhat', 'overweight', 'grouchy', 'temperament'],
#  ['first',
#   'mixed',
#   'previous',
#   'food',
#   'figured',
#   'ate',
#   'felidae',
#   'left',
#   'old',
#   'food'],
#  ['felidae',
#   'ten',
#   'day',
#   'old',
#   'food',
#   'entirely',
#   'much',
#   'sweeter',
#   'happier',
#   'cat'],
#  ['think', 'must', 'agree', 'better', 'easily', 'digested', 'something'],
#  ['case', 'happy', 'purchaser', 'felidae'],
#  ['agree', 'previous', 'reviewer', 'cat', 'like'],
#  ['clearly', 'mine'],
#  ['three',
#   'cat',
#   'youngest',
#   'eleven',
#   'year',
#   'old',
#   'another',
#   'fifteen',
#   'oldest',
#   'well',
#   'ancient'],
#  ['vet', 'told', 'u', 'ten', 'year', 'ago'],
#  ['youngest', 'blob'],
#  ['lay', 'look', 'like', 'footstool'],
#  ['two',
#   'arthritic',
#   'skinny',
#   'since',
#   'success',
#   'canidae',
#   'platinum',
#   'senior',
#   'dog',
#   'figured',
#   'give',
#   'try',
#   'cat'],
#  ['low',
#   'ash',
#   'purina',
#   'one',
#   'urinary',
#   'tract',
#   'formula',
#   'entire',
#   'life',
#   'thankfully',
#   'ut',
#   'problem',
#   'buster',
#   'youngest',
#   'still',
#   'blob',
#   'six',
#   'month',
#   'plus',
#   'felidae',
#   'senior',
#   'overweight',
#   'cat'],
#  ['however',
#   'two',
#   'much',
#   'active',
#   'tell',
#   'really',
#   'feeling',
#   'better',
#   'since',
#   'changed',
#   'food',
#   'felidae'],
#  ['even',
#   'prissy',
#   'ancient',
#   'one',
#   'started',
#   'play',
#   'tease',
#   'dog',
#   'getting',
#   'chase',
#   'purina',
#   'one',
#   'wanted',
#   'sleep',
#   'think',
#   'get',
#   'cat',
#   'fairly',
#   'early',
#   'weight',
#   'problem',
#   'effective',
#   'however',
#   'glucosamine',
#   'certainly',
#   'help',
#   'older',
#   'fur',
#   'ball',
#   'happier',
#   'life'],
#  ['much', 'good', 'thing'],
#  ['worked',
#   'kibble',
#   'time',
#   'slowly',
#   'shifting',
#   'percentage',
#   'felidae',
#   'national',
#   'junk',
#   'food',
#   'brand',
#   'bowl',
#   'natural'],
#  ['time', 'cat', 'keep'],
#  ['mess'],
#  ['moved'],
#  ['canidae', 'felidae', 'also', 'changed', 'formula'],
#  ['cat', 'like', 'change', 'come', 'food'],
#  ['change', 'without', 'putting', 'label'],
#  ['noticed', 'color', 'food', 'changed', 'smell'],
#  ['notice', 'also', 'reviewd', 'canidae', 'happened', 'time', 'dog', 'issue'],
#  ['prior',
#   'change',
#   'food',
#   'almost',
#   'lost',
#   'two',
#   'cat',
#   'moved',
#   'new',
#   'home'],
#  ['cat',
#   'get',
#   'upset',
#   'change',
#   'enviorment',
#   'loud',
#   'noise',
#   'stop',
#   'eating'],
#  ['depends', 'cat'],
#  ['two', 'stopped', 'eating', 'lost', 'lot', 'weight'],
#  ['took', 'vet', 'took', 'month', 'get', 'back', 'normal'],
#  ['year', 'since', 'better'],
#  ['formula',
#   'food',
#   'changed',
#   'started',
#   'noitce',
#   'eating',
#   'much',
#   'started',
#   'bug',
#   'u'],
#  ['asked', 'shop', 'owner', 'feed', 'store', 'knowledge', 'change', 'food'],
#  ['customer', 'yelling', 'dog', 'food', 'making', 'dog', 'sick'],
#  ['right',
#   'away',
#   'changed',
#   'cat',
#   'food',
#   'started',
#   'chowing',
#   'suffered',
#   'one',
#   'bit',
#   'like',
#   'dog',
#   'cat',
#   'sensitve',
#   'animal',
#   'change',
#   'thier',
#   'food',
#   'could',
#   'cause',
#   'stop',
#   'eating'],
#  ['anyone', 'thinking', 'purchasing', 'food'],
#  ['rescued',
#   'fixed',
#   'cat',
#   'none',
#   'picky',
#   'eater',
#   'change',
#   'formula',
#   'could',
#   'death',
#   'found',
#   'change',
#   'formula',
#   'urge',
#   'anyone',
#   'problem',
#   'go',
#   'consumer',
#   'affair',
#   'website',
#   'also',
#   'fda',
#   'website',
#   'write',
#   'letter',
#   'let',
#   'know',
#   'affected',
#   'animal'],
#  ['canidae', 'care', 'change', 'affected', 'animal', 'tell', 'buy'],
#  ['horrible'],
#  ['buy'],
#  ['order', 'case'],
#  ['even',
#   'remember',
#   'first',
#   'time',
#   'tasted',
#   'anchovy',
#   'stuffed',
#   'olive',
#   'tried',
#   'several',
#   'brand',
#   'online',
#   'brand',
#   'favorite'],
#  ['order', 'olive', 'lot'],
#  ['un', 'like', 'olive'],
#  ['subtle', 'flavor', 'brine', 'go', 'great', 'cheese'],
#  ['one', 'favorite', 'appetizer', 'treat', 'guest'],
#  ['hey', 'description', 'say', 'gram', 'roughly', 'ounce', 'per'],
#  ['way', 'approximate', 'price', 'gram'],
#  ['husband',
#   'kind',
#   'wimpy',
#   'come',
#   'hot',
#   'thing',
#   'seasoning',
#   'bit',
#   'spicy',
#   'u'],
#  ['definitely', 'make', 'sweat', 'bit', 'eating'],
#  ['still',
#   'edible',
#   'u',
#   'adding',
#   'good',
#   'sized',
#   'dollop',
#   'sour',
#   'cream',
#   'think',
#   'would',
#   'buy',
#   'due',
#   'heat'],
#  ['prefer', 'milder', 'mccormick', 'brand', 'fajita', 'mix'],
#  ['also',
#   'fajitas',
#   'couple',
#   'different',
#   'restaurant',
#   'spicy',
#   'mix',
#   'like',
#   'super',
#   'spicy',
#   'burning',
#   'hot',
#   'might',
#   'want',
#   'keep',
#   'mind'],
#  ['medium',
#   'hot',
#   'much',
#   'gave',
#   'three',
#   'star',
#   'pretty',
#   'easy',
#   'make',
#   'versatile',
#   'could',
#   'vary',
#   'veggie',
#   'put'],
#  ['take',
#   'plastic',
#   'bag',
#   'couple',
#   'tb',
#   'vegetable',
#   'oil',
#   'cup',
#   'water',
#   'mix',
#   'seasoning',
#   'water',
#   'oil',
#   'together',
#   'add',
#   'chicken',
#   'strip',
#   'bag',
#   'let',
#   'marinate',
#   'minute'],
#  ['meantime',
#   'say',
#   'stir',
#   'fry',
#   'veggie',
#   'pepper',
#   'onion',
#   'found',
#   'easier',
#   'cook',
#   'chicken',
#   'veggie',
#   'together',
#   'think',
#   'affected',
#   'quality',
#   'taste'],
#  ['also',
#   'used',
#   'extra',
#   'virgin',
#   'olive',
#   'oil',
#   'rather',
#   'vegetable',
#   'oil',
#   'one',
#   'package',
#   'use',
#   'next',
#   'time',
#   'going',
#   'add',
#   'veggie',
#   'maybe',
#   'chopped',
#   'tomato',
#   'cut',
#   'heat',
#   'bit'],
#  ['friend', 'drinking', 'tea', 'year', 'introduced', 'tea', 'month', 'ago'],
#  ['even', 'took', 'store', 'bought', 'pound'],
#  ['lb'],
#  ['retail',
#   'store',
#   'little',
#   'shipping',
#   'online',
#   'merchant',
#   'think',
#   'great'],
#  ['drinking',
#   'earl',
#   'grey',
#   'english',
#   'breakfast',
#   'irish',
#   'breakfast',
#   'lapsang',
#   'souchong',
#   'assam',
#   'etc'],
#  ['lb'],
#  ['shipping'],
#  ['aside', 'lapsang', 'souchong', 'think', 'great', 'replacement', 'rest'],
#  ['everything',
#   'looking',
#   'strong',
#   'full',
#   'bodied',
#   'black',
#   'tea',
#   'enough',
#   'character',
#   'keep',
#   'becoming',
#   'boring'],
#  ['current', 'favorite', 'afternoon', 'tea'],
#  ['unless', 'extremely', 'jaded', 'tea', 'snob', 'love'],
#  ['love',
#   'strong',
#   'full',
#   'bodied',
#   'quality',
#   'tea',
#   'typically',
#   'drink',
#   'assam',
#   'irish',
#   'breakfast',
#   'early',
#   'grey',
#   'tea',
#   'reviewer',
#   'noted',
#   'price',
#   'per',
#   'pound',
#   'discouraging'],
#  ['searching',
#   'quality',
#   'full',
#   'bodied',
#   'tea',
#   'bitter',
#   'palatable',
#   'price',
#   'point',
#   'certainly',
#   'fit',
#   'bill'],
#  ['unlike', 'tea', 'tend', 'better', 'one', 'form', 'another', 'e'],
#  ['iced', 'v', 'hot', 'tea', 'excellent', 'form'],
#  ['would',
#   'certainly',
#   'recommend',
#   'anyone',
#   'prefers',
#   'smooth',
#   'full',
#   'bodied',
#   'quality',
#   'tea',
#   'cost',
#   'arm',
#   'leg'],
#  ['drink',
#   'tea',
#   'plain',
#   'without',
#   'sugar',
#   'milk',
#   'pleasant',
#   'aroma',
#   'price',
#   'amazon',
#   'cheaper',
#   'local',
#   'grocery',
#   'store'],
#  ['one', 'reviewer', 'right', 'think', 'herbal', 'smell', 'make', 'aroma'],
#  ['label',
#   'imperial',
#   'blend',
#   'kind',
#   'implied',
#   'herb',
#   'exactly',
#   'black',
#   'tea',
#   'drinker',
#   'tea',
#   'surprise',
#   'affordable'],
#  ['usually',
#   'prefer',
#   'white',
#   'chinese',
#   'tea',
#   'like',
#   'white',
#   'peony',
#   'expensive',
#   'requires',
#   'lower',
#   'temperature',
#   'water'],
#  ['black', 'tea', 'aroma', 'kind', 'remind', 'softness', 'white', 'tea'],
#  ['tried', 'variety', 'ahmad', 'tea'],
#  ['particularly', 'like', 'brand', 'easier', 'come', 'across'],
#  ['imperial',
#   'blend',
#   'believe',
#   'complex',
#   'yet',
#   'well',
#   'balanced',
#   'one',
#   'tried'],
#  ['full',
#   'body',
#   'like',
#   'good',
#   'cup',
#   'assam',
#   'mean',
#   'overpower',
#   'delightful',
#   'clean',
#   'taste',
#   'darjeerling',
#   'complete',
#   'long',
#   'lasting',
#   'note',
#   'bergamot'],
#  ['enjoy', 'best', 'evening'],
#  ['give',
#   'satisfying',
#   'relaxing',
#   'finish',
#   'busy',
#   'day',
#   'interested',
#   'specific',
#   'use',
#   'teaspoon',
#   'lose',
#   'tea',
#   'stainless',
#   'steel',
#   'infuser',
#   'oz',
#   'mug',
#   'let',
#   'steep',
#   'f',
#   'water',
#   'min',
#   'take',
#   'infuser',
#   'drink',
#   'without',
#   'sugar',
#   'milk',
#   'savor',
#   'sophistication'],
#  ['tried',
#   'literally',
#   'dozen',
#   'tea',
#   'since',
#   'introduced',
#   'russian',
#   'custom',
#   'preparing',
#   'drinking',
#   'tea',
#   'ahmad',
#   'imperial',
#   'blend',
#   'probably',
#   'favorite',
#   'due',
#   'fact',
#   'equally',
#   'delicious',
#   'hot',
#   'iced'],
#  ['buy', 'three', 'pack', 'needed', 'amazon', 'go', 'rapidly'],
#  ['family', 'love', 'friend', 'home', 'try', 'one', 'box', 'love'],
#  ['excellent', 'tea'],
#  ['one', 'best', 'ever'],
#  ['especially', 'great', 'prepare', 'samovar'],
#  ['herbal', 'additive', 'blend', 'destroy', 'real', 'tea', 'taste'],
#  ['people', 'like', 'herbal', 'taste'],
#  [''],
#  ['make', 'tasty', 'super', 'easy', 'meal', 'fast'],
#  ['high',
#   'calorie',
#   'instruction',
#   'say',
#   'saute',
#   'veggie',
#   'first',
#   'recommend',
#   'cooking',
#   'chicken',
#   'first'],
#  ['chicken',
#   'take',
#   'longer',
#   'cook',
#   'raw',
#   'chicken',
#   'ontop',
#   'veggie',
#   'make',
#   'slimy',
#   'mess'],
#  ['made', 'snow', 'pea', 'carrot'],
#  ['dont', 'like', 'little', 'corn'],
#  ['added', 'red', 'pepper', 'flake', 'heat', 'served', 'ontop', 'rice'],
#  ['came', 'wonderful'],
#  ['dinner', 'table', 'le', 'min'],
#  ['think',
#   'tried',
#   'every',
#   'bloody',
#   'mary',
#   'mixer',
#   'market',
#   'one',
#   'time'],
#  ['much', 'sugar', 'worst', 'corn', 'syrup'],
#  ['mixer', 'natural', 'ingredient', 'tasty'],
#  ['little', 'kick'],
#  ['enjoy'],
#  ...]

# %%
from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec
import pickle

# %%
food_bigram_model = Phrases(clean_sentence, min_count=100)
food_bigrams = [food_bigram_model[sent] for sent in clean_sentence]
food_trigram_model = Phrases(food_bigrams, min_count=50)
phrased_food_sentences = [food_trigram_model[sent] for sent in food_bigrams]

# %%
with open("b_list_food_preprocessed.txt", "bw") as fp:   #Pickling
    pickle.dump(phrased_food_sentences, fp)
